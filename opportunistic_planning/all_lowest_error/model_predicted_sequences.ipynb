# %%
import ast
import numpy as np
import pandas as pd

from opportunistic_planning import prediction, processing

# %%
data = pd.read_csv('all_task_environments_list_2022-09-12_unique_sequences.csv', header=0)

# %%
distances_dict = processing.generate_distances_dict(data, use_string_for_seq=False,
                                                   dimensions=[[2, 'xy'], [3, 'xyz']])

# %%
distances_dict['xy']
# Out:
# {'a1': {(-0.451354, -0.413918): {'plate': 1.4459178173547762,
#    'plate_small': 1.368096623795264,
#    'cup': 1.3392278666492867,
#    'glass': 1.6531706987885433,
#    'knife': 1.2219225591673148,
#    'spoon_small': 1.1675352349787993},
#   (0.513, -0.531): {'plate': 1.571425690218917,
#    'plate_small': 1.6173697783747538,
#    'cup': 1.786728176343005,
#    'glass': 2.08311358691767,
#    'knife': 1.3764788073116128,
#    'spoon_small': 1.695938442180317}},
#  'a3': {(-0.451354, -0.413918): {'cup': 1.35337885269314,
#    'glass': 1.6531706987885433,
#    'wineglass': 1.7879633892415134,
#    'plate': 1.4459178173547762,
#    'fork': 1.183447393772955,
#    'knife': 1.2219225591673148,
#    'spoon': 1.2727831868550903},
#   (0.513, -0.531): {'cup': 1.8683849247307152,
#    'glass': 2.08311358691767,
#    'wineglass': 2.015545721357866,
#    'plate': 1.571425690218917,
#    'fork': 1.4649661266432066,
#    'knife': 1.3764788073116128,
#    'spoon': 1.3513424160829852}},
#  'a5': {(-0.451354, -0.413918): {'knife': 1.2219225591673148,
#    'fork': 1.1752257964906148,
#    'spoon': 1.2890068799350918,
#    'plate': 1.419893593743559,
#    'wineglass': 1.813044341665421,
#    'glass': 1.6916953788282927},
#   (0.513, -0.531): {'knife': 1.3764788073116128,
#    'fork': 1.4870136654183783,
#    'spoon': 1.339755543224211,
#    'plate': 1.5454289235374106,
#    'wineglass': 1.9709434437408395,
#    'glass': 2.2219123065505983}},
#  'a11': {(-0.451354, -0.413918): {'plate': 1.419893593743559,
#    'fork': 1.1752257964906148,
#    'knife': 1.234027146419397,
#    'spoon': 1.2727831868550903,
#    'wineglass': 1.7879633892415134,
#    'plate_small': 1.355424813506452,
#    'cup': 1.35337885269314,
#    'glass': 1.6916953788282927},
#   (0.513, -0.531): {'plate': 1.5454289235374106,
#    'fork': 1.4870136654183783,
#    'knife': 1.363402755644861,
#    'spoon': 1.3513424160829852,
#    'wineglass': 2.015545721357866,
#    'plate_small': 1.605718381906678,
#    'cup': 1.8683849247307152,
#    'glass': 2.2219123065505983}},
#  'a13': {(-0.451354, -0.413918): {'wineglass': 1.7879633892415134,
#    'plate': 1.4459178173547762,
#    'tray': 1.953333029511353,
#    'glass': 1.6531706987885433,
#    'knife': 1.2219225591673148,
#    'fork': 1.1929871282612399,
#    'spoon': 1.2890068799350918,
#    'plate_small': 1.368096623795264,
#    'cup': 1.3392278666492867},
#   (0.513, -0.531): {'wineglass': 2.015545721357866,
#    'plate': 1.571425690218917,
#    'tray': 2.3654705561684763,
#    'glass': 2.08311358691767,
#    'knife': 1.3764788073116128,
#    'fork': 1.444384509792666,
#    'spoon': 1.339755543224211,
#    'plate_small': 1.6173697783747538,
#    'cup': 1.786728176343005}},
#  'a16': {(-0.451354, -0.413918): {'plate': 1.3939455194092056,
#    'wineglass': 1.848554258971048,
#    'fork': 1.183447393772955,
#    'knife': 1.2068731775513946,
#    'glass': 1.6916953788282927},
#   (0.513, -0.531): {'plate': 1.5195357098656812,
#    'wineglass': 1.9351000900211852,
#    'fork': 1.4649661266432066,
#    'knife': 1.3952996598182772,
#    'glass': 2.2219123065505983}},
#  'a19': {(-0.451354, -0.413918): {'plate': 1.419893593743559,
#    'plate_small': 1.368096623795264,
#    'wineglass': 1.7879633892415134,
#    'cup': 1.3392278666492867,
#    'fork_small': 1.1987604480316325,
#    'spoon_small': 1.1675352349787993},
#   (0.513, -0.531): {'plate': 1.5454289235374106,
#    'plate_small': 1.6173697783747538,
#    'wineglass': 2.015545721357866,
#    'cup': 1.786728176343005,
#    'fork_small': 1.804998747452474,
#    'spoon_small': 1.695938442180317}},
#  'a22': {(-0.451354, -0.413918): {'cup': 1.380649005739692,
#    'plate_small': 1.355424813506452,
#    'plate': 1.419893593743559,
#    'spoon_small': 1.1582825994259778,
#    'fork_small': 1.1987604480316325,
#    'knife': 1.2219225591673148},
#   (0.513, -0.531): {'cup': 1.9559625198275146,
#    'plate_small': 1.605718381906678,
#    'plate': 1.5454289235374106,
#    'spoon_small': 1.628178220422138,
#    'fork_small': 1.804998747452474,
#    'knife': 1.3764788073116128}},
#  'a26': {(-0.451354, -0.413918): {'wineglass': 1.813044341665421,
#    'plate_small': 1.355424813506452,
#    'plate': 1.419893593743559,
#    'fork': 1.1929871282612399,
#    'knife': 1.2068731775513946,
#    'spoon': 1.2727831868550903},
#   (0.513, -0.531): {'wineglass': 1.9709434437408395,
#    'plate_small': 1.605718381906678,
#    'plate': 1.5454289235374106,
#    'fork': 1.444384509792666,
#    'knife': 1.3952996598182772,
#    'spoon': 1.3513424160829852}},
#  'a29': {(-0.451354, -0.413918): {'plate_small': 1.355424813506452,
#    'plate': 1.419893593743559,
#    'wineglass': 1.813044341665421,
#    'glass': 1.668055398723016,
#    'cup': 1.35337885269314},
#   (0.513, -0.531): {'plate_small': 1.605718381906678,
#    'plate': 1.5454289235374106,
#    'wineglass': 1.9709434437408395,
#    'glass': 2.149923213070876,
#    'cup': 1.8683849247307152}},
#  'a31': {(-0.451354, -0.413918): {'plate': 1.419893593743559,
#    'plate_small': 1.355424813506452,
#    'cup': 1.35337885269314,
#    'spoon_small': 1.1582825994259778,
#    'fork': 1.183447393772955,
#    'knife': 1.234027146419397,
#    'spoon': 1.3056068678932413},
#   (0.513, -0.531): {'plate': 1.5454289235374106,
#    'plate_small': 1.605718381906678,
#    'cup': 1.8683849247307152,
#    'spoon_small': 1.628178220422138,
#    'fork': 1.4649661266432066,
#    'knife': 1.363402755644861,
#    'spoon': 1.3292199950294157}},
#  'a35': {(-0.451354, -0.413918): {'cup': 1.35337885269314,
#    'glass': 1.6531706987885433,
#    'plate': 1.4459178173547762,
#    'plate_small': 1.368096623795264},
#   (0.513, -0.531): {'cup': 1.8683849247307152,
#    'glass': 2.08311358691767,
#    'plate': 1.571425690218917,
#    'plate_small': 1.6173697783747538}},
#  'a37': {(-0.451354, -0.413918): {'plate': 1.419893593743559,
#    'wineglass': 1.813044341665421,
#    'plate_small': 1.355424813506452,
#    'cup': 1.35337885269314,
#    'glass': 1.668055398723016,
#    'fork': 1.1752257964906148,
#    'knife': 1.2068731775513946,
#    'spoon': 1.3056068678932413,
#    'spoon_small': 1.1675352349787993,
#    'fork_small': 1.1987604480316325},
#   (0.513, -0.531): {'plate': 1.5454289235374106,
#    'wineglass': 1.9709434437408395,
#    'plate_small': 1.605718381906678,
#    'cup': 1.8683849247307152,
#    'glass': 2.149923213070876,
#    'fork': 1.4870136654183783,
#    'knife': 1.3952996598182772,
#    'spoon': 1.3292199950294157,
#    'spoon_small': 1.695938442180317,
#    'fork_small': 1.804998747452474}},
#  'a39': {(-0.451354, -0.413918): {'plate_small': 1.368096623795264,
#    'cup': 1.3392278666492867,
#    'wineglass': 1.7879633892415134,
#    'glass': 1.6531706987885433,
#    'spoon_small': 1.1675352349787993,
#    'knife': 1.2219225591673148},
#   (0.513, -0.531): {'plate_small': 1.6173697783747538,
#    'cup': 1.786728176343005,
#    'wineglass': 2.015545721357866,
#    'glass': 2.08311358691767,
#    'spoon_small': 1.695938442180317,
#    'knife': 1.3764788073116128}},
#  'a40': {(-0.451354, -0.413918): {'wineglass': 1.7879633892415134,
#    'plate': 1.4459178173547762,
#    'glass': 1.6531706987885433,
#    'spoon': 1.2890068799350918,
#    'fork': 1.1752257964906148,
#    'knife': 1.2219225591673148},
#   (0.513, -0.531): {'wineglass': 2.015545721357866,
#    'plate': 1.571425690218917,
#    'glass': 2.08311358691767,
#    'spoon': 1.339755543224211,
#    'fork': 1.4870136654183783,
#    'knife': 1.3764788073116128}},
#  'a43': {(-0.451354, -0.413918): {'plate': 1.4459178173547762,
#    'wineglass': 1.7879633892415134,
#    'plate_small': 1.368096623795264,
#    'fork': 1.1929871282612399,
#    'spoon': 1.2890068799350918,
#    'glass': 1.6531706987885433},
#   (0.513, -0.531): {'plate': 1.571425690218917,
#    'wineglass': 2.015545721357866,
#    'plate_small': 1.6173697783747538,
#    'fork': 1.444384509792666,
#    'spoon': 1.339755543224211,
#    'glass': 2.08311358691767}},
#  'a45': {(-0.451354, -0.413918): {'plate': 1.3939455194092056,
#    'plate_small': 1.355424813506452,
#    'cup': 1.35337885269314,
#    'wineglass': 1.848554258971048,
#    'glass': 1.6916953788282927,
#    'knife': 1.2068731775513946,
#    'fork': 1.1929871282612399,
#    'spoon': 1.2890068799350918},
#   (0.513, -0.531): {'plate': 1.5195357098656812,
#    'plate_small': 1.605718381906678,
#    'cup': 1.8683849247307152,
#    'wineglass': 1.9351000900211852,
#    'glass': 2.2219123065505983,
#    'knife': 1.3952996598182772,
#    'fork': 1.444384509792666,
#    'spoon': 1.339755543224211}},
#  'a47': {(-0.451354, -0.413918): {'plate': 1.3939455194092056,
#    'plate_small': 1.355424813506452,
#    'cup': 1.35337885269314,
#    'glass': 1.668055398723016,
#    'wineglass': 1.813044341665421},
#   (0.513, -0.531): {'plate': 1.5195357098656812,
#    'plate_small': 1.605718381906678,
#    'cup': 1.8683849247307152,
#    'glass': 2.149923213070876,
#    'wineglass': 1.9709434437408395}},
#  'a51': {(-0.451354, -0.413918): {'plate': 1.419893593743559,
#    'wineglass': 1.813044341665421,
#    'glass': 1.668055398723016,
#    'plate_small': 1.368096623795264,
#    'cup': 1.3392278666492867,
#    'knife': 1.2219225591673148,
#    'fork': 1.183447393772955,
#    'spoon': 1.2727831868550903,
#    'spoon_small': 1.1675352349787993,
#    'fork_small': 1.2064864899649725,
#    'tray': 1.953333029511353},
#   (0.513, -0.531): {'plate': 1.5454289235374106,
#    'wineglass': 1.9709434437408395,
#    'glass': 2.149923213070876,
#    'plate_small': 1.6173697783747538,
#    'cup': 1.786728176343005,
#    'knife': 1.3764788073116128,
#    'fork': 1.4649661266432066,
#    'spoon': 1.3513424160829852,
#    'spoon_small': 1.695938442180317,
#    'fork_small': 1.8251410626524187,
#    'tray': 2.3654705561684763}},
#  'a55': {(-0.451354, -0.413918): {'plate_small': 1.355424813506452,
#    'cup': 1.35337885269314,
#    'plate': 1.419893593743559,
#    'wineglass': 1.813044341665421,
#    'glass': 1.668055398723016,
#    'fork': 1.1752257964906148,
#    'knife': 1.2068731775513946,
#    'spoon': 1.3056068678932413,
#    'spoon_small': 1.1675352349787993,
#    'fork_small': 1.2064864899649725},
#   (0.513, -0.531): {'plate_small': 1.605718381906678,
#    'cup': 1.8683849247307152,
#    'plate': 1.5454289235374106,
#    'wineglass': 1.9709434437408395,
#    'glass': 2.149923213070876,
#    'fork': 1.4870136654183783,
#    'knife': 1.3952996598182772,
#    'spoon': 1.3292199950294157,
#    'spoon_small': 1.695938442180317,
#    'fork_small': 1.8251410626524187}},
#  'a56': {(-0.451354, -0.413918): {'cup': 1.35337885269314,
#    'plate_small': 1.3427775687570151,
#    'plate': 1.3939455194092056,
#    'wineglass': 1.848554258971048,
#    'glass': 1.6531706987885433,
#    'spoon_small': 1.1582825994259778,
#    'fork_small': 1.2064864899649725,
#    'spoon': 1.2727831868550903,
#    'knife': 1.2068731775513946},
#   (0.513, -0.531): {'cup': 1.8683849247307152,
#    'plate_small': 1.5941103082989585,
#    'plate': 1.5195357098656812,
#    'wineglass': 1.9351000900211852,
#    'glass': 2.08311358691767,
#    'spoon_small': 1.628178220422138,
#    'fork_small': 1.8251410626524187,
#    'spoon': 1.3513424160829852,
#    'knife': 1.3952996598182772}},
#  'a59': {(-0.451354, -0.413918): {'plate': 1.419893593743559,
#    'wineglass': 1.813044341665421,
#    'tray': 1.953333029511353,
#    'fork_small': 1.2064864899649725,
#    'spoon_small': 1.1582825994259778,
#    'fork': 1.183447393772955,
#    'knife': 1.2219225591673148},
#   (0.513, -0.531): {'plate': 1.5454289235374106,
#    'wineglass': 1.9709434437408395,
#    'tray': 2.3654705561684763,
#    'fork_small': 1.8251410626524187,
#    'spoon_small': 1.628178220422138,
#    'fork': 1.4649661266432066,
#    'knife': 1.3764788073116128}},
#  'a60': {(-0.451354, -0.413918): {'plate': 1.3939455194092056,
#    'plate_small': 1.355424813506452,
#    'cup': 1.35337885269314,
#    'wineglass': 1.813044341665421,
#    'glass': 1.668055398723016,
#    'fork': 1.183447393772955,
#    'knife': 1.2219225591673148,
#    'spoon': 1.3056068678932413,
#    'spoon_small': 1.1675352349787993,
#    'fork_small': 1.2064864899649725},
#   (0.513, -0.531): {'plate': 1.5195357098656812,
#    'plate_small': 1.605718381906678,
#    'cup': 1.8683849247307152,
#    'wineglass': 1.9709434437408395,
#    'glass': 2.149923213070876,
#    'fork': 1.4649661266432066,
#    'knife': 1.3764788073116128,
#    'spoon': 1.3292199950294157,
#    'spoon_small': 1.695938442180317,
#    'fork_small': 1.8251410626524187}},
#  'a61': {(-0.451354, -0.413918): {'wineglass': 1.813044341665421,
#    'plate': 1.419893593743559,
#    'plate_small': 1.355424813506452,
#    'fork': 1.183447393772955,
#    'cup': 1.35337885269314,
#    'glass': 1.668055398723016,
#    'knife': 1.2219225591673148,
#    'spoon_small': 1.1675352349787993,
#    'spoon': 1.2890068799350918},
#   (0.513, -0.531): {'wineglass': 1.9709434437408395,
#    'plate': 1.5454289235374106,
#    'plate_small': 1.605718381906678,
#    'fork': 1.4649661266432066,
#    'cup': 1.8683849247307152,
#    'glass': 2.149923213070876,
#    'knife': 1.3764788073116128,
#    'spoon_small': 1.695938442180317,
#    'spoon': 1.339755543224211}},
#  'a69': {(-0.451354, -0.413918): {'cup': 1.35337885269314,
#    'wineglass': 1.813044341665421,
#    'plate': 1.419893593743559,
#    'fork': 1.1752257964906148,
#    'knife': 1.2068731775513946,
#    'spoon': 1.3056068678932413,
#    'plate_small': 1.355424813506452,
#    'spoon_small': 1.1582825994259778},
#   (0.513, -0.531): {'cup': 1.8683849247307152,
#    'wineglass': 1.9709434437408395,
#    'plate': 1.5454289235374106,
#    'fork': 1.4870136654183783,
#    'knife': 1.3952996598182772,
#    'spoon': 1.3292199950294157,
#    'plate_small': 1.605718381906678,
#    'spoon_small': 1.628178220422138}},
#  'a73': {(-0.451354, -0.413918): {'plate': 1.419893593743559,
#    'wineglass': 1.813044341665421,
#    'fork': 1.183447393772955,
#    'knife': 1.2068731775513946,
#    'spoon': 1.2727831868550903,
#    'plate_small': 1.355424813506452,
#    'spoon_small': 1.1675352349787993,
#    'cup': 1.35337885269314},
#   (0.513, -0.531): {'plate': 1.5454289235374106,
#    'wineglass': 1.9709434437408395,
#    'fork': 1.4649661266432066,
#    'knife': 1.3952996598182772,
#    'spoon': 1.3513424160829852,
#    'plate_small': 1.605718381906678,
#    'spoon_small': 1.695938442180317,
#    'cup': 1.8683849247307152}},
#  'a76': {(-0.451354, -0.413918): {'plate': 1.419893593743559,
#    'plate_small': 1.355424813506452,
#    'cup': 1.35337885269314,
#    'glass': 1.668055398723016,
#    'wineglass': 1.813044341665421,
#    'knife': 1.2068731775513946,
#    'fork': 1.183447393772955,
#    'spoon': 1.2890068799350918,
#    'fork_small': 1.2064864899649725,
#    'spoon_small': 1.1675352349787993},
#   (0.513, -0.531): {'plate': 1.5454289235374106,
#    'plate_small': 1.605718381906678,
#    'cup': 1.8683849247307152,
#    'glass': 2.149923213070876,
#    'wineglass': 1.9709434437408395,
#    'knife': 1.3952996598182772,
#    'fork': 1.4649661266432066,
#    'spoon': 1.339755543224211,
#    'fork_small': 1.8251410626524187,
#    'spoon_small': 1.695938442180317}},
#  'a77': {(-0.451354, -0.413918): {'plate': 1.419893593743559,
#    'plate_small': 1.355424813506452,
#    'wineglass': 1.813044341665421,
#    'cup': 1.35337885269314,
#    'tray': 1.953333029511353,
#    'glass': 1.6916953788282927},
#   (0.513, -0.531): {'plate': 1.5454289235374106,
#    'plate_small': 1.605718381906678,
#    'wineglass': 1.9709434437408395,
#    'cup': 1.8683849247307152,
#    'tray': 2.3654705561684763,
#    'glass': 2.2219123065505983}},
#  'a80': {(-0.451354, -0.413918): {'plate': 1.3939455194092056,
#    'plate_small': 1.3427718863559812,
#    'wineglass': 1.813044341665421,
#    'glass': 1.668055398723016,
#    'cup': 1.35337885269314},
#   (0.513, -0.531): {'plate': 1.5195357098656812,
#    'plate_small': 1.5941044761758874,
#    'wineglass': 1.9709434437408395,
#    'glass': 2.149923213070876,
#    'cup': 1.8683849247307152}},
#  'a85': {(-0.451354, -0.413918): {'plate': 1.419893593743559,
#    'wineglass': 1.813044341665421,
#    'fork': 1.183447393772955,
#    'knife': 1.2219225591673148,
#    'tray': 1.953333029511353},
#   (0.513, -0.531): {'plate': 1.5454289235374106,
#    'wineglass': 1.9709434437408395,
#    'fork': 1.4649661266432066,
#    'knife': 1.3764788073116128,
#    'tray': 2.3654705561684763}},
#  'a87': {(-0.451354, -0.413918): {'plate': 1.419893593743559,
#    'wineglass': 1.813044341665421,
#    'plate_small': 1.355424813506452,
#    'knife': 1.234027146419397,
#    'fork': 1.183447393772955,
#    'spoon_small': 1.1675352349787993,
#    'glass': 1.668055398723016},
#   (0.513, -0.531): {'plate': 1.5454289235374106,
#    'wineglass': 1.9709434437408395,
#    'plate_small': 1.605718381906678,
#    'knife': 1.363402755644861,
#    'fork': 1.4649661266432066,
#    'spoon_small': 1.695938442180317,
#    'glass': 2.149923213070876}},
#  'a89': {(-0.451354, -0.413918): {'cup': 1.3392278666492867,
#    'plate_small': 1.368096623795264,
#    'plate': 1.3939455194092056,
#    'glass': 1.6916953788282927,
#    'wineglass': 1.813044341665421,
#    'fork': 1.183447393772955,
#    'knife': 1.2219225591673148,
#    'spoon': 1.2727831868550903,
#    'spoon_small': 1.1675352349787993},
#   (0.513, -0.531): {'cup': 1.786728176343005,
#    'plate_small': 1.6173697783747538,
#    'plate': 1.5195357098656812,
#    'glass': 2.2219123065505983,
#    'wineglass': 1.9709434437408395,
#    'fork': 1.4649661266432066,
#    'knife': 1.3764788073116128,
#    'spoon': 1.3513424160829852,
#    'spoon_small': 1.695938442180317}},
#  'a93': {(-0.451354, -0.413918): {'plate': 1.419893593743559,
#    'glass': 1.668055398723016,
#    'spoon': 1.2890068799350918,
#    'fork': 1.183447393772955,
#    'knife': 1.2068731775513946},
#   (0.513, -0.531): {'plate': 1.5454289235374106,
#    'glass': 2.149923213070876,
#    'spoon': 1.339755543224211,
#    'fork': 1.4649661266432066,
#    'knife': 1.3952996598182772}},
#  'a99': {(-0.451354, -0.413918): {'wineglass': 1.813044341665421,
#    'glass': 1.6916953788282927,
#    'plate': 1.419893593743559,
#    'tray': 1.953333029511353,
#    'plate_small': 1.355424813506452,
#    'cup': 1.380649005739692},
#   (0.513, -0.531): {'wineglass': 1.9709434437408395,
#    'glass': 2.2219123065505983,
#    'plate': 1.5454289235374106,
#    'tray': 2.3654705561684763,
#    'plate_small': 1.605718381906678,
#    'cup': 1.9559625198275146}},
#  'a100': {(-0.451354, -0.413918): {'plate': 1.419893593743559,
#    'plate_small': 1.355424813506452,
#    'wineglass': 1.813044341665421,
#    'cup': 1.35337885269314,
#    'glass': 1.668055398723016,
#    'spoon_small': 1.1675352349787993,
#    'fork_small': 1.1987604480316325},
#   (0.513, -0.531): {'plate': 1.5454289235374106,
#    'plate_small': 1.605718381906678,
#    'wineglass': 1.9709434437408395,
#    'cup': 1.8683849247307152,
#    'glass': 2.149923213070876,
#    'spoon_small': 1.695938442180317,
#    'fork_small': 1.804998747452474}},
#  'a102': {(-0.451354, -0.413918): {'plate': 1.4459178173547762,
#    'fork_small': 1.1987604480316325,
#    'spoon_small': 1.1582825994259778,
#    'knife': 1.2068731775513946,
#    'spoon': 1.2890068799350918,
#    'cup': 1.3392278666492867,
#    'wineglass': 1.7879633892415134,
#    'glass': 1.6531706987885433,
#    'tray': 1.953333029511353,
#    'fork': 1.1929871282612399},
#   (0.513, -0.531): {'plate': 1.571425690218917,
#    'fork_small': 1.804998747452474,
#    'spoon_small': 1.628178220422138,
#    'knife': 1.3952996598182772,
#    'spoon': 1.339755543224211,
#    'cup': 1.786728176343005,
#    'wineglass': 2.015545721357866,
#    'glass': 2.08311358691767,
#    'tray': 2.3654705561684763,
#    'fork': 1.444384509792666}},
#  'a106': {(-0.451354, -0.413918): {'plate': 1.419893593743559,
#    'cup': 1.3392278666492867,
#    'glass': 1.668055398723016,
#    'wineglass': 1.7879633892415134,
#    'plate_small': 1.368096623795264,
#    'spoon_small': 1.1672914336055928,
#    'knife': 1.20686502498001,
#    'fork': 1.183400276237926,
#    'spoon': 1.2884371537925317},
#   (0.513, -0.531): {'plate': 1.5454289235374106,
#    'cup': 1.786728176343005,
#    'glass': 2.149923213070876,
#    'wineglass': 2.015545721357866,
#    'plate_small': 1.6173697783747538,
#    'spoon_small': 1.694827954224558,
#    'knife': 1.3953349994893698,
#    'fork': 1.4650146742527872,
#    'spoon': 1.3401663815888685}},
#  'a108': {(-0.451354, -0.413918): {'plate': 1.419893593743559,
#    'plate_small': 1.355424813506452,
#    'cup': 1.35337885269314,
#    'glass': 1.668055398723016,
#    'knife': 1.2068731775513946,
#    'spoon_small': 1.1675352349787993},
#   (0.513, -0.531): {'plate': 1.5454289235374106,
#    'plate_small': 1.605718381906678,
#    'cup': 1.8683849247307152,
#    'glass': 2.149923213070876,
#    'knife': 1.3952996598182772,
#    'spoon_small': 1.695938442180317}},
#  'a109': {(-0.451354, -0.413918): {'plate': 1.4459178173547762,
#    'wineglass': 1.813044341665421,
#    'tray': 1.953333029511353,
#    'glass': 1.6531706987885433,
#    'cup': 1.380649005739692,
#    'fork': 1.1929871282612399,
#    'knife': 1.2219225591673148,
#    'spoon': 1.2727831868550903,
#    'spoon_small': 1.1675352349787993},
#   (0.513, -0.531): {'plate': 1.571425690218917,
#    'wineglass': 1.9709434437408395,
#    'tray': 2.3654705561684763,
#    'glass': 2.08311358691767,
#    'cup': 1.9559625198275146,
#    'fork': 1.444384509792666,
#    'knife': 1.3764788073116128,
#    'spoon': 1.3513424160829852,
#    'spoon_small': 1.695938442180317}},
#  'a114': {(-0.451354, -0.413918): {'plate': 1.419893593743559,
#    'plate_small': 1.355424813506452,
#    'cup': 1.35337885269314,
#    'wineglass': 1.813044341665421,
#    'knife': 1.2068731775513946,
#    'fork': 1.1929871282612399},
#   (0.513, -0.531): {'plate': 1.5454289235374106,
#    'plate_small': 1.605718381906678,
#    'cup': 1.8683849247307152,
#    'wineglass': 1.9709434437408395,
#    'knife': 1.3952996598182772,
#    'fork': 1.444384509792666}},
#  'a116': {(-0.451354, -0.413918): {'plate': 1.419893593743559,
#    'glass': 1.6916953788282927,
#    'knife': 1.2068731775513946,
#    'fork': 1.183447393772955},
#   (0.513, -0.531): {'plate': 1.5454289235374106,
#    'glass': 2.2219123065505983,
#    'knife': 1.3952996598182772,
#    'fork': 1.4649661266432066}},
#  'a118': {(-0.451354, -0.413918): {'cup': 1.35337885269314,
#    'wineglass': 1.7879633892415134,
#    'plate_small': 1.368096623795264,
#    'plate': 1.4459178173547762,
#    'glass': 1.3843454752062432},
#   (0.513, -0.531): {'cup': 1.8683849247307152,
#    'wineglass': 2.015545721357866,
#    'plate_small': 1.6173697783747538,
#    'plate': 1.571425690218917,
#    'glass': 1.3434006793343525}},
#  'a120': {(-0.451354, -0.413918): {'plate': 1.419893593743559,
#    'plate_small': 1.355424813506452,
#    'wineglass': 1.7879633892415134,
#    'cup': 1.3392278666492867,
#    'glass': 1.6916953788282927,
#    'knife': 1.2219225591673148,
#    'fork': 1.183447393772955,
#    'spoon_small': 1.1675352349787993},
#   (0.513, -0.531): {'plate': 1.5454289235374106,
#    'plate_small': 1.605718381906678,
#    'wineglass': 2.015545721357866,
#    'cup': 1.786728176343005,
#    'glass': 2.2219123065505983,
#    'knife': 1.3764788073116128,
#    'fork': 1.4649661266432066,
#    'spoon_small': 1.695938442180317}},
#  'a128': {(-0.451354, -0.413918): {'wineglass': 1.813044341665421,
#    'plate': 1.419893593743559,
#    'glass': 1.668055398723016,
#    'fork': 1.183447393772955,
#    'knife': 1.2068731775513946,
#    'spoon': 1.3056068678932413},
#   (0.513, -0.531): {'wineglass': 1.9709434437408395,
#    'plate': 1.5454289235374106,
#    'glass': 2.149923213070876,
#    'fork': 1.4649661266432066,
#    'knife': 1.3952996598182772,
#    'spoon': 1.3292199950294157}},
#  'a131': {(-0.451354, -0.413918): {'plate': 1.419893593743559,
#    'plate_small': 1.355424813506452,
#    'cup': 1.35337885269314,
#    'wineglass': 1.7879633892415134,
#    'fork_small': 1.1987604480316325,
#    'spoon_small': 1.1582825994259778},
#   (0.513, -0.531): {'plate': 1.5454289235374106,
#    'plate_small': 1.605718381906678,
#    'cup': 1.8683849247307152,
#    'wineglass': 2.015545721357866,
#    'fork_small': 1.804998747452474,
#    'spoon_small': 1.628178220422138}},
#  'a137': {(-0.451354, -0.413918): {'plate': 1.4459178173547762,
#    'wineglass': 1.7879633892415134,
#    'knife': 1.2219225591673148,
#    'fork': 1.183447393772955},
#   (0.513, -0.531): {'plate': 1.571425690218917,
#    'wineglass': 2.015545721357866,
#    'knife': 1.3764788073116128,
#    'fork': 1.4649661266432066}},
#  'a142': {(-0.451354, -0.413918): {'cup': 1.3392278666492867,
#    'plate': 1.4459311821037681,
#    'tray': 1.953333029511353,
#    'glass': 1.6531706987885433,
#    'plate_small': 1.3554246190740376},
#   (0.513, -0.531): {'cup': 1.786728176343005,
#    'plate': 1.571404550657787,
#    'tray': 2.3654705561684763,
#    'glass': 2.08311358691767,
#    'plate_small': 1.605715742564667}},
#  'a149': {(-0.451354, -0.413918): {'plate': 1.419893593743559,
#    'plate_small': 1.355424813506452,
#    'cup': 1.3392278666492867,
#    'fork': 1.183447393772955,
#    'knife': 1.234027146419397,
#    'spoon': 1.2890068799350918,
#    'wineglass': 1.848554258971048,
#    'glass': 1.668055398723016,
#    'spoon_small': 1.1675352349787993},
#   (0.513, -0.531): {'plate': 1.5454289235374106,
#    'plate_small': 1.605718381906678,
#    'cup': 1.786728176343005,
#    'fork': 1.4649661266432066,
#    'knife': 1.363402755644861,
#    'spoon': 1.339755543224211,
#    'wineglass': 1.9351000900211852,
#    'glass': 2.149923213070876,
#    'spoon_small': 1.695938442180317}},
#  'a152': {(-0.451354, -0.413918): {'plate': 1.419893593743559,
#    'plate_small': 1.355424813506452,
#    'wineglass': 1.813044341665421,
#    'cup': 1.35337885269314,
#    'fork': 1.183447393772955,
#    'knife': 1.2068731775513946},
#   (0.513, -0.531): {'plate': 1.5454289235374106,
#    'plate_small': 1.605718381906678,
#    'wineglass': 1.9709434437408395,
#    'cup': 1.8683849247307152,
#    'fork': 1.4649661266432066,
#    'knife': 1.3952996598182772}},
#  'a153': {(-0.451354, -0.413918): {'plate': 1.419893593743559,
#    'wineglass': 1.813044341665421,
#    'glass': 1.668055398723016,
#    'fork': 1.183447393772955,
#    'knife': 1.234027146419397,
#    'spoon': 1.2890068799350918},
#   (0.513, -0.531): {'plate': 1.5454289235374106,
#    'wineglass': 1.9709434437408395,
#    'glass': 2.149923213070876,
#    'fork': 1.4649661266432066,
#    'knife': 1.363402755644861,
#    'spoon': 1.339755543224211}},
#  'a156': {(-0.451354, -0.413918): {'glass': 1.668055398723016,
#    'plate': 1.4459178173547762,
#    'wineglass': 1.7879633892415134,
#    'fork': 1.1929871282612399,
#    'knife': 1.2068731775513946,
#    'spoon': 1.2727831868550903},
#   (0.513, -0.531): {'glass': 2.149923213070876,
#    'plate': 1.571425690218917,
#    'wineglass': 2.015545721357866,
#    'fork': 1.444384509792666,
#    'knife': 1.3952996598182772,
#    'spoon': 1.3513424160829852}},
#  'a158': {(-0.451354, -0.413918): {'cup': 1.3392278666492867,
#    'glass': 1.6531706987885433,
#    'wineglass': 1.813044341665421,
#    'plate': 1.4459178173547762},
#   (0.513, -0.531): {'cup': 1.786728176343005,
#    'glass': 2.08311358691767,
#    'wineglass': 1.9709434437408395,
#    'plate': 1.571425690218917}},
#  'a161': {(-0.451354, -0.413918): {'cup': 1.380649005739692,
#    'wineglass': 1.848554258971048,
#    'plate_small': 1.3427718863559812,
#    'plate': 1.3939455194092056,
#    'glass': 1.6916953788282927,
#    'tray': 1.953333029511353,
#    'spoon_small': 1.1675352349787993,
#    'fork_small': 1.2064864899649725,
#    'knife': 1.234027146419397,
#    'fork': 1.1752257964906148,
#    'spoon': 1.2890068799350918},
#   (0.513, -0.531): {'cup': 1.9559625198275146,
#    'wineglass': 1.9351000900211852,
#    'plate_small': 1.5941044761758874,
#    'plate': 1.5195357098656812,
#    'glass': 2.2219123065505983,
#    'tray': 2.3654705561684763,
#    'spoon_small': 1.695938442180317,
#    'fork_small': 1.8251410626524187,
#    'knife': 1.363402755644861,
#    'fork': 1.4870136654183783,
#    'spoon': 1.339755543224211}},
#  'a164': {(-0.451354, -0.413918): {'plate': 1.4459178173547762,
#    'plate_small': 1.368096623795264,
#    'cup': 1.380649005739692,
#    'spoon': 1.3056068678932413,
#    'fork': 1.1752257964906148,
#    'knife': 1.2219225591673148,
#    'wineglass': 1.7879633892415134},
#   (0.513, -0.531): {'plate': 1.571425690218917,
#    'plate_small': 1.6173697783747538,
#    'cup': 1.9559625198275146,
#    'spoon': 1.3292199950294157,
#    'fork': 1.4870136654183783,
#    'knife': 1.3764788073116128,
#    'wineglass': 2.015545721357866}},
#  'a172': {(-0.451354, -0.413918): {'plate_small': 1.355424813506452,
#    'cup': 1.35337885269314,
#    'plate': 1.419893593743559,
#    'wineglass': 1.813044341665421,
#    'glass': 1.668055398723016,
#    'fork': 1.183447393772955,
#    'knife': 1.2219225591673148},
#   (0.513, -0.531): {'plate_small': 1.605718381906678,
#    'cup': 1.8683849247307152,
#    'plate': 1.5454289235374106,
#    'wineglass': 1.9709434437408395,
#    'glass': 2.149923213070876,
#    'fork': 1.4649661266432066,
#    'knife': 1.3764788073116128}},
#  'a174': {(-0.451354, -0.413918): {'plate': 1.4459178173547762,
#    'wineglass': 1.813044341665421,
#    'glass': 1.668055398723016,
#    'tray': 1.953333029511353,
#    'fork_small': 1.1987604480316325,
#    'spoon_small': 1.1675352349787993,
#    'knife': 1.2068731775513946,
#    'fork': 1.1929871282612399,
#    'spoon': 1.2727831868550903,
#    'plate_small': 1.368096623795264,
#    'cup': 1.3392278666492867},
#   (0.513, -0.531): {'plate': 1.571425690218917,
#    'wineglass': 1.9709434437408395,
#    'glass': 2.149923213070876,
#    'tray': 2.3654705561684763,
#    'fork_small': 1.804998747452474,
#    'spoon_small': 1.695938442180317,
#    'knife': 1.3952996598182772,
#    'fork': 1.444384509792666,
#    'spoon': 1.3513424160829852,
#    'plate_small': 1.6173697783747538,
#    'cup': 1.786728176343005}},
#  'a177': {(-0.451354, -0.413918): {'plate': 1.4459178173547762,
#    'plate_small': 1.368096623795264,
#    'cup': 1.3392278666492867,
#    'glass': 1.6531706987885433,
#    'wineglass': 1.7879633892415134,
#    'spoon_small': 1.1582825994259778,
#    'knife': 1.2219225591673148,
#    'fork': 1.1929871282612399,
#    'spoon': 1.2890068799350918},
#   (0.513, -0.531): {'plate': 1.571425690218917,
#    'plate_small': 1.6173697783747538,
#    'cup': 1.786728176343005,
#    'glass': 2.08311358691767,
#    'wineglass': 2.015545721357866,
#    'spoon_small': 1.628178220422138,
#    'knife': 1.3764788073116128,
#    'fork': 1.444384509792666,
#    'spoon': 1.339755543224211}},
#  'a178': {(-0.451354, -0.413918): {'tray': 1.953333029511353,
#    'glass': 1.6531706987885433,
#    'cup': 1.380649005739692,
#    'wineglass': 1.7879633892415134,
#    'plate': 1.4459178173547762,
#    'spoon_small': 1.1582825994259778,
#    'plate_small': 1.368096623795264},
#   (0.513, -0.531): {'tray': 2.3654705561684763,
#    'glass': 2.08311358691767,
#    'cup': 1.9559625198275146,
#    'wineglass': 2.015545721357866,
#    'plate': 1.571425690218917,
#    'spoon_small': 1.628178220422138,
#    'plate_small': 1.6173697783747538}},
#  'a180': {(-0.451354, -0.413918): {'plate': 1.419893593743559,
#    'plate_small': 1.355424813506452,
#    'cup': 1.35337885269314,
#    'glass': 1.6916953788282927,
#    'knife': 1.234027146419397,
#    'fork': 1.183447393772955,
#    'spoon': 1.2727831868550903,
#    'spoon_small': 1.1582825994259778},
#   (0.513, -0.531): {'plate': 1.5454289235374106,
#    'plate_small': 1.605718381906678,
#    'cup': 1.8683849247307152,
#    'glass': 2.2219123065505983,
#    'knife': 1.363402755644861,
#    'fork': 1.4649661266432066,
#    'spoon': 1.3513424160829852,
#    'spoon_small': 1.628178220422138}},
#  'a185': {(-0.451354, -0.413918): {'plate': 1.419893593743559,
#    'glass': 1.668055398723016,
#    'cup': 1.3392278666492867,
#    'plate_small': 1.368096623795264,
#    'wineglass': 1.813044341665421},
#   (0.513, -0.531): {'plate': 1.5454289235374106,
#    'glass': 2.149923213070876,
#    'cup': 1.786728176343005,
#    'plate_small': 1.6173697783747538,
#    'wineglass': 1.9709434437408395}},
#  'a187': {(-0.451354, -0.413918): {'plate_small': 1.368096623795264,
#    'plate': 1.4459178173547762,
#    'wineglass': 1.7879633892415134,
#    'glass': 1.6531706987885433},
#   (0.513, -0.531): {'plate_small': 1.6173697783747538,
#    'plate': 1.571425690218917,
#    'wineglass': 2.015545721357866,
#    'glass': 2.08311358691767}},
#  'a191': {(-0.451354, -0.413918): {'wineglass': 1.7879633892415134,
#    'plate': 1.419893593743559,
#    'glass': 1.6531706987885433,
#    'cup': 1.35337885269314,
#    'plate_small': 1.355424813506452,
#    'fork': 1.1929871282612399,
#    'knife': 1.2219225591673148,
#    'spoon': 1.2890068799350918,
#    'spoon_small': 1.1582825994259778,
#    'fork_small': 1.1987604480316325},
#   (0.513, -0.531): {'wineglass': 2.015545721357866,
#    'plate': 1.5454289235374106,
#    'glass': 2.08311358691767,
#    'cup': 1.8683849247307152,
#    'plate_small': 1.605718381906678,
#    'fork': 1.444384509792666,
#    'knife': 1.3764788073116128,
#    'spoon': 1.339755543224211,
#    'spoon_small': 1.628178220422138,
#    'fork_small': 1.804998747452474}},
#  'a195': {(-0.451354, -0.413918): {'spoon_small': 1.1675352349787993,
#    'fork_small': 1.2064864899649725},
#   (0.513, -0.531): {'spoon_small': 1.695938442180317,
#    'fork_small': 1.8251410626524187}},
#  'a198': {(-0.451354, -0.413918): {'plate': 1.419893593743559,
#    'tray': 1.953333029511353,
#    'wineglass': 1.813044341665421,
#    'glass': 1.6531706987885433,
#    'fork': 1.183447393772955,
#    'knife': 1.2219225591673148,
#    'spoon': 1.2890068799350918},
#   (0.513, -0.531): {'plate': 1.5454289235374106,
#    'tray': 2.3654705561684763,
#    'wineglass': 1.9709434437408395,
#    'glass': 2.08311358691767,
#    'fork': 1.4649661266432066,
#    'knife': 1.3764788073116128,
#    'spoon': 1.339755543224211}},
#  'a201': {(-0.451354, -0.413918): {'plate': 1.419893593743559,
#    'plate_small': 1.355424813506452,
#    'cup': 1.35337885269314,
#    'spoon_small': 1.1675352349787993,
#    'fork': 1.183447393772955,
#    'knife': 1.2068731775513946},
#   (0.513, -0.531): {'plate': 1.5454289235374106,
#    'plate_small': 1.605718381906678,
#    'cup': 1.8683849247307152,
#    'spoon_small': 1.695938442180317,
#    'fork': 1.4649661266432066,
#    'knife': 1.3952996598182772}},
#  'a205': {(-0.451354, -0.413918): {'plate': 1.4459178173547762,
#    'plate_small': 1.355424813506452,
#    'cup': 1.35337885269314,
#    'knife': 1.2219225591673148,
#    'spoon_small': 1.1675352349787993},
#   (0.513, -0.531): {'plate': 1.571425690218917,
#    'plate_small': 1.605718381906678,
#    'cup': 1.8683849247307152,
#    'knife': 1.3764788073116128,
#    'spoon_small': 1.695938442180317}},
#  'a209': {(-0.451354, -0.413918): {'plate': 1.4204571030235302,
#    'plate_small': 1.35527047783828,
#    'cup': 1.380649005739692,
#    'knife': 1.2187970898049436,
#    'fork': 1.1980843166071409,
#    'spoon': 1.3034463442769713,
#    'wineglass': 1.8104746850936635,
#    'glass': 1.668055398723016,
#    'spoon_small': 1.1582825994259778,
#    'fork_small': 1.2064864899649725},
#   (0.513, -0.531): {'plate': 1.5454836388063122,
#    'plate_small': 1.6055840102903367,
#    'cup': 1.9559625198275146,
#    'knife': 1.380156497396219,
#    'fork': 1.4350343251100304,
#    'spoon': 1.3312722906982628,
#    'wineglass': 1.9744437724202226,
#    'glass': 2.149923213070876,
#    'spoon_small': 1.628178220422138,
#    'fork_small': 1.8251410626524187}},
#  'a212': {(-0.451354, -0.413918): {'tray': 1.959085564780926,
#    'glass': 1.6916953788282927,
#    'plate': 1.3939455194092056,
#    'cup': 1.380649005739692,
#    'plate_small': 1.3427718863559812,
#    'wineglass': 1.848554258971048},
#   (0.513, -0.531): {'tray': 2.3679782325538805,
#    'glass': 2.2219123065505983,
#    'plate': 1.5195357098656812,
#    'cup': 1.9559625198275146,
#    'plate_small': 1.5941044761758874,
#    'wineglass': 1.9351000900211852}},
#  'a215': {(-0.451354, -0.413918): {'glass': 1.6531706987885433,
#    'wineglass': 1.7879633892415134,
#    'plate': 1.4459178173547762,
#    'fork': 1.183447393772955,
#    'spoon_small': 1.1582825994259778,
#    'knife': 1.234027146419397,
#    'spoon': 1.2890068799350918,
#    'tray': 1.953333029511353},
#   (0.513, -0.531): {'glass': 2.08311358691767,
#    'wineglass': 2.015545721357866,
#    'plate': 1.571425690218917,
#    'fork': 1.4649661266432066,
#    'spoon_small': 1.628178220422138,
#    'knife': 1.363402755644861,
#    'spoon': 1.339755543224211,
#    'tray': 2.3654705561684763}},
#  'a218': {(-0.451354, -0.413918): {'plate': 1.419893593743559,
#    'fork': 1.183447393772955,
#    'knife': 1.2068731775513946,
#    'spoon': 1.2727831868550903,
#    'glass': 1.668055398723016},
#   (0.513, -0.531): {'plate': 1.5454289235374106,
#    'fork': 1.4649661266432066,
#    'knife': 1.3952996598182772,
#    'spoon': 1.3513424160829852,
#    'glass': 2.149923213070876}},
#  'a220': {(-0.451354, -0.413918): {'plate': 1.419893593743559,
#    'wineglass': 1.813044341665421,
#    'plate_small': 1.355424813506452,
#    'glass': 1.668055398723016,
#    'spoon': 1.3056068678932413,
#    'fork': 1.1929871282612399,
#    'knife': 1.2068731775513946},
#   (0.513, -0.531): {'plate': 1.5454289235374106,
#    'wineglass': 1.9709434437408395,
#    'plate_small': 1.605718381906678,
#    'glass': 2.149923213070876,
#    'spoon': 1.3292199950294157,
#    'fork': 1.444384509792666,
#    'knife': 1.3952996598182772}},
#  'a222': {(-0.451354, -0.413918): {'plate': 1.419893593743559,
#    'wineglass': 1.813044341665421,
#    'knife': 1.2219225591673148,
#    'fork': 1.1752257964906148},
#   (0.513, -0.531): {'plate': 1.5454289235374106,
#    'wineglass': 1.9709434437408395,
#    'knife': 1.3764788073116128,
#    'fork': 1.4870136654183783}},
#  'a223': {(-0.451354, -0.413918): {'glass': 1.6531706987885433,
#    'wineglass': 1.7879633892415134,
#    'plate': 1.4459178173547762,
#    'plate_small': 1.3427802115350076,
#    'cup': 1.35337885269314,
#    'spoon': 1.2890068799350918,
#    'knife': 1.2219225591673148,
#    'fork': 1.1752257964906148},
#   (0.513, -0.531): {'glass': 2.08311358691767,
#    'wineglass': 2.015545721357866,
#    'plate': 1.571425690218917,
#    'plate_small': 1.59419330545389,
#    'cup': 1.8683849247307152,
#    'spoon': 1.339755543224211,
#    'knife': 1.3764788073116128,
#    'fork': 1.4870136654183783}},
#  'a226': {(-0.451354, -0.413918): {'wineglass': 1.813044341665421,
#    'tray': 1.953333029511353,
#    'plate': 1.419893593743559,
#    'cup': 1.3392278666492867,
#    'plate_small': 1.355424813506452,
#    'knife': 1.2068731775513946,
#    'fork': 1.1929871282612399},
#   (0.513, -0.531): {'wineglass': 1.9709434437408395,
#    'tray': 2.3654705561684763,
#    'plate': 1.5454289235374106,
#    'cup': 1.786728176343005,
#    'plate_small': 1.605718381906678,
#    'knife': 1.3952996598182772,
#    'fork': 1.444384509792666}},
#  'a229': {(-0.451354, -0.413918): {'wineglass': 1.813044341665421,
#    'plate': 1.419893593743559,
#    'glass': 1.668055398723016,
#    'fork': 1.183447393772955,
#    'knife': 1.2219225591673148,
#    'spoon_small': 1.1582825994259778,
#    'fork_small': 1.2064864899649725},
#   (0.513, -0.531): {'wineglass': 1.9709434437408395,
#    'plate': 1.5454289235374106,
#    'glass': 2.149923213070876,
#    'fork': 1.4649661266432066,
#    'knife': 1.3764788073116128,
#    'spoon_small': 1.628178220422138,
#    'fork_small': 1.8251410626524187}},
#  'a231': {(-0.451354, -0.413918): {'plate': 1.419893593743559,
#    'plate_small': 1.355424813506452,
#    'cup': 1.35337885269314,
#    'wineglass': 1.813044341665421,
#    'tray': 1.953333029511353,
#    'spoon_small': 1.1675352349787993,
#    'fork': 1.183447393772955,
#    'knife': 1.2219225591673148,
#    'glass': 1.668055398723016},
#   (0.513, -0.531): {'plate': 1.5454289235374106,
#    'plate_small': 1.605718381906678,
#    'cup': 1.8683849247307152,
#    'wineglass': 1.9709434437408395,
#    'tray': 2.3654705561684763,
#    'spoon_small': 1.695938442180317,
#    'fork': 1.4649661266432066,
#    'knife': 1.3764788073116128,
#    'glass': 2.149923213070876}},
#  'a233': {(-0.451354, -0.413918): {'plate': 1.419893593743559,
#    'wineglass': 1.813044341665421,
#    'plate_small': 1.355424813506452,
#    'cup': 1.35337885269314,
#    'fork': 1.183447393772955,
#    'knife': 1.2219225591673148,
#    'spoon': 1.2727831868550903,
#    'spoon_small': 1.1582825994259778},
#   (0.513, -0.531): {'plate': 1.5454289235374106,
#    'wineglass': 1.9709434437408395,
#    'plate_small': 1.605718381906678,
#    'cup': 1.8683849247307152,
#    'fork': 1.4649661266432066,
#    'knife': 1.3764788073116128,
#    'spoon': 1.3513424160829852,
#    'spoon_small': 1.628178220422138}},
#  'a235': {(-0.451354, -0.413918): {'plate': 1.419893593743559,
#    'wineglass': 1.813044341665421,
#    'glass': 1.6531706987885433,
#    'fork_small': 1.2064864899649725,
#    'spoon_small': 1.1675352349787993,
#    'knife': 1.2068731775513946,
#    'spoon': 1.2890068799350918},
#   (0.513, -0.531): {'plate': 1.5454289235374106,
#    'wineglass': 1.9709434437408395,
#    'glass': 2.08311358691767,
#    'fork_small': 1.8251410626524187,
#    'spoon_small': 1.695938442180317,
#    'knife': 1.3952996598182772,
#    'spoon': 1.339755543224211}},
#  'a239': {(-0.451354, -0.413918): {'plate': 1.419893593743559,
#    'plate_small': 1.355424813506452,
#    'cup': 1.35337885269314,
#    'tray': 1.953333029511353,
#    'fork': 1.1929871282612399,
#    'knife': 1.2219225591673148,
#    'spoon_small': 1.1582825994259778,
#    'wineglass': 1.813044341665421,
#    'glass': 1.6531706987885433},
#   (0.513, -0.531): {'plate': 1.5454289235374106,
#    'plate_small': 1.605718381906678,
#    'cup': 1.8683849247307152,
#    'tray': 2.3654705561684763,
#    'fork': 1.444384509792666,
#    'knife': 1.3764788073116128,
#    'spoon_small': 1.628178220422138,
#    'wineglass': 1.9709434437408395,
#    'glass': 2.08311358691767}},
#  'a240': {(-0.451354, -0.413918): {'plate': 1.419893593743559,
#    'wineglass': 1.7879633892415134,
#    'fork': 1.1752257964906148,
#    'knife': 1.2068731775513946,
#    'spoon': 1.2727831868550903,
#    'plate_small': 1.368096623795264,
#    'cup': 1.35337885269314,
#    'spoon_small': 1.1675352349787993},
#   (0.513, -0.531): {'plate': 1.5454289235374106,
#    'wineglass': 2.015545721357866,
#    'fork': 1.4870136654183783,
#    'knife': 1.3952996598182772,
#    'spoon': 1.3513424160829852,
#    'plate_small': 1.6173697783747538,
#    'cup': 1.8683849247307152,
#    'spoon_small': 1.695938442180317}},
#  'T1': {(2, 1.5): {'tray': 1.118033988749895,
#    'napkin': 1.118033988749895,
#    'plate': 2.692582403567252,
#    'silverware': 1.118033988749895,
#    'cup': 2.692582403567252},
#   (4, 3): {'tray': 3.605551275463989,
#    'napkin': 3.605551275463989,
#    'plate': 3.1622776601683795,
#    'silverware': 3.1622776601683795,
#    'cup': 3.1622776601683795}},
#  'T14': {(2, 1.5): {'tray': 1.118033988749895,
#    'napkin': 1.118033988749895,
#    'plate': 2.692582403567252,
#    'cup': 2.692582403567252,
#    'silverware': 1.118033988749895},
#   (4, 1): {'tray': 3.0,
#    'napkin': 3.0,
#    'plate': 4.242640687119285,
#    'cup': 4.242640687119285,
#    'silverware': 3.1622776601683795}},
#  'T16': {(2, 1.5): {'tray': 1.118033988749895,
#    'napkin': 1.118033988749895,
#    'plate': 2.692582403567252,
#    'silverware': 1.118033988749895,
#    'cup': 2.692582403567252},
#   (4, 1): {'tray': 3.0,
#    'napkin': 3.0,
#    'plate': 4.242640687119285,
#    'silverware': 3.1622776601683795,
#    'cup': 4.242640687119285}},
#  'T18': {(2, 1.5): {'tray': 1.118033988749895,
#    'napkin': 1.118033988749895,
#    'silverware': 1.118033988749895,
#    'plate': 2.692582403567252,
#    'cup': 2.692582403567252},
#   (4, 1): {'tray': 3.0,
#    'napkin': 3.0,
#    'silverware': 3.1622776601683795,
#    'plate': 4.242640687119285,
#    'cup': 4.242640687119285}},
#  'E01_01': {(3, 3): {'plate': 2.23606797749979,
#    'placemat': 1.0,
#    'silverware': 1.0},
#   (2, 2): {'plate': 2.23606797749979,
#    'placemat': 2.23606797749979,
#    'silverware': 2.23606797749979},
#   (3, 0): {'plate': 1.4142135623730951,
#    'placemat': 3.1622776601683795,
#    'silverware': 3.1622776601683795}},
#  'E01_03': {(4, 5): {'tupperware': 4.0,
#    'placemat': 1.0,
#    'cup': 5.385164807134504,
#    'silverware': 2.0,
#    'cereal': 4.0},
#   (2, 2): {'tupperware': 3.605551275463989,
#    'placemat': 2.8284271247461903,
#    'cup': 2.0,
#    'silverware': 2.23606797749979,
#    'cereal': 2.23606797749979},
#   (0, 5): {'tupperware': 0.0,
#    'placemat': 4.123105625617661,
#    'cup': 5.385164807134504,
#    'silverware': 4.47213595499958,
#    'cereal': 5.656854249492381}},
#  'E01_05': {(2, 0): {'plate': 2.23606797749979,
#    'cutting_board': 2.23606797749979,
#    'placemat': 3.605551275463989,
#    'silverware': 3.605551275463989},
#   (3, 4): {'plate': 3.1622776601683795,
#    'cutting_board': 3.1622776601683795,
#    'placemat': 1.4142135623730951,
#    'silverware': 1.4142135623730951},
#   (3, 3): {'plate': 2.23606797749979,
#    'cutting_board': 2.23606797749979,
#    'placemat': 1.0,
#    'silverware': 1.0},
#   (2, 2): {'plate': 2.23606797749979,
#    'cutting_board': 2.23606797749979,
#    'placemat': 2.23606797749979,
#    'silverware': 2.23606797749979}},
#  'E01_09': {(0, 5): {'placemat': 4.47213595499958,
#    'silverware': 4.47213595499958,
#    'can': 0.0,
#    'plate': 5.656854249492381},
#   (2, 1): {'placemat': 2.8284271247461903,
#    'silverware': 2.8284271247461903,
#    'can': 4.47213595499958,
#    'plate': 2.0},
#   (3, 2): {'placemat': 1.4142135623730951,
#    'silverware': 1.4142135623730951,
#    'can': 4.242640687119285,
#    'plate': 1.4142135623730951}},
#  'E10_01': {(2, 3): {'plate': 0.0, 'bowl': 1.0, 'silverware': 1.0},
#   (2, 2): {'plate': 1.0, 'bowl': 0.0, 'silverware': 1.4142135623730951},
#   (1, 3): {'plate': 1.0, 'bowl': 1.4142135623730951, 'silverware': 0.0}},
#  'E12_01': {(0, 3): {'plate': 2.0,
#    'glass': 2.23606797749979,
#    'silverware': 2.0},
#   (2, 3): {'plate': 0.0, 'glass': 1.0, 'silverware': 0.0},
#   (2, 2): {'plate': 1.0, 'glass': 0.0, 'silverware': 1.0}},
#  'E12_06': {(0, 2): {'plate': 2.23606797749979,
#    'napkin': 2.0,
#    'silverware': 2.23606797749979,
#    'glass': 2.23606797749979,
#    'bottle': 1.0},
#   (2, 0): {'plate': 3.0,
#    'napkin': 2.0,
#    'silverware': 3.0,
#    'glass': 3.0,
#    'bottle': 3.605551275463989}},
#  'E21_01': {(0, 2): {'tomato_plate': 0.0,
#    'napkin': 1.0,
#    'silverware': 1.0,
#    'glass': 0.0,
#    'grapes': 0.0,
#    'milk': 0.0,
#    'plate': 1.0},
#   (0, 4): {'tomato_plate': 2.0,
#    'napkin': 3.0,
#    'silverware': 3.0,
#    'glass': 2.0,
#    'grapes': 2.0,
#    'milk': 2.0,
#    'plate': 3.0},
#   (0, 1): {'tomato_plate': 1.0,
#    'napkin': 0.0,
#    'silverware': 0.0,
#    'glass': 1.0,
#    'grapes': 1.0,
#    'milk': 1.0,
#    'plate': 0.0},
#   (1, 4): {'tomato_plate': 2.23606797749979,
#    'napkin': 3.1622776601683795,
#    'silverware': 3.1622776601683795,
#    'glass': 2.23606797749979,
#    'grapes': 2.23606797749979,
#    'milk': 2.23606797749979,
#    'plate': 3.1622776601683795}},
#  'E21_03': {(0, 2): {'plate': 0.0,
#    'napkin': 1.0,
#    'yoghurt': 1.0,
#    'silverware': 1.0},
#   (0, 3): {'plate': 1.0, 'napkin': 2.0, 'yoghurt': 0.0, 'silverware': 2.0},
#   (0, 1): {'plate': 1.0, 'napkin': 0.0, 'yoghurt': 2.0, 'silverware': 0.0},
#   (0, 4): {'plate': 2.0, 'napkin': 3.0, 'yoghurt': 1.0, 'silverware': 3.0}},
#  'E21_04': {(0, 4): {'napkin': 3.0,
#    'fork': 3.0,
#    'plate': 2.0,
#    'yoghurt': 0.0,
#    'milk': 2.0,
#    'blueberries': 2.0,
#    'spoon': 3.0},
#   (0, 0): {'napkin': 1.0,
#    'fork': 1.0,
#    'plate': 2.0,
#    'yoghurt': 4.0,
#    'milk': 2.0,
#    'blueberries': 2.0,
#    'spoon': 1.0},
#   (2, 4): {'napkin': 3.605551275463989,
#    'fork': 3.605551275463989,
#    'plate': 2.8284271247461903,
#    'yoghurt': 2.0,
#    'milk': 2.8284271247461903,
#    'blueberries': 2.8284271247461903,
#    'spoon': 3.605551275463989},
#   (0, 3): {'napkin': 2.0,
#    'fork': 2.0,
#    'plate': 1.0,
#    'yoghurt': 1.0,
#    'milk': 1.0,
#    'blueberries': 1.0,
#    'spoon': 2.0}},
#  'E22_12': {(0, 2): {'placemat': 2.0,
#    'cup': 2.0,
#    'bananas': 2.0,
#    'apricots': 2.0,
#    'tupperware': 2.0,
#    'plate': 2.0},
#   (1, 1): {'placemat': 1.4142135623730951,
#    'cup': 1.4142135623730951,
#    'bananas': 1.4142135623730951,
#    'apricots': 1.4142135623730951,
#    'tupperware': 1.4142135623730951,
#    'plate': 1.4142135623730951}},
#  'E22_16': {(0, 1): {'plate': 1.0,
#    'cup': 1.0,
#    'silverware': 1.0,
#    'bread': 1.0,
#    'salad': 1.0,
#    'oil': 1.0,
#    'water': 1.4142135623730951,
#    'beer': 1.4142135623730951,
#    'glass': 1.0},
#   (1, 1): {'plate': 1.4142135623730951,
#    'cup': 1.4142135623730951,
#    'silverware': 1.4142135623730951,
#    'bread': 1.4142135623730951,
#    'salad': 1.4142135623730951,
#    'oil': 1.4142135623730951,
#    'water': 1.0,
#    'beer': 1.0,
#    'glass': 1.4142135623730951}},
#  'E24_02': {(1, 2): {'salad': 1.4142135623730951,
#    'water': 2.23606797749979,
#    'glass': 1.0,
#    'plate': 1.4142135623730951,
#    'silverware': 1.0},
#   (1, 1): {'salad': 2.23606797749979,
#    'water': 3.1622776601683795,
#    'glass': 1.4142135623730951,
#    'plate': 2.23606797749979,
#    'silverware': 1.4142135623730951}},
#  'E24_04': {(1, 3.1): {'plate': 1.004987562112089, 'cup': 1.004987562112089},
#   (1, 0): {'plate': 3.1622776601683795, 'cup': 3.1622776601683795}},
#  'E24_05': {(1, 1): {'glass': 1.4142135623730951,
#    'silverware': 1.4142135623730951,
#    'water': 3.1622776601683795,
#    'salad': 2.23606797749979,
#    'plate': 2.23606797749979},
#   (1, 2): {'glass': 1.0,
#    'silverware': 1.0,
#    'water': 2.23606797749979,
#    'salad': 1.4142135623730951,
#    'plate': 1.4142135623730951}},
#  'E26_11': {(0, 1): {'plate': 0.0,
#    'silverware': 2.23606797749979,
#    'glass': 0.0,
#    'cheese': 1.0,
#    'spoon': 2.23606797749979},
# ...
#    'sugar': 2.23606797749979,
#    'spoon_small': 1.8027756377319946},
#   (0, 1.5): {'orange': 2.9154759474226504,
#    'cutting_board': 0.0,
#    'knife': 0.0,
#    'squeezer': 0.0,
#    'glass': 2.5,
#    'sugar': 2.0615528128088303,
#    'spoon_small': 0.0}},
#  's33-d27': {(1, 0): {'onion': 2.23606797749979,
#    'knife': 1.8027756377319946,
#    'cutting_board': 1.8027756377319946,
#    'pan': 1.0,
#    'oil': 2.23606797749979,
#    'spatula': 1.8027756377319946},
#   (0, 1.5): {'onion': 2.0615528128088303,
#    'knife': 0.0,
#    'cutting_board': 0.0,
#    'pan': 1.5,
#    'oil': 2.0615528128088303,
#    'spatula': 0.0}},
#  's33-d45': {(1, 0): {'pepper': 4.031128874149275,
#    'cutting_board': 1.8027756377319946,
#    'knife': 1.8027756377319946,
#    'plate': 3.1622776601683795},
#   (0, 1.5): {'pepper': 2.9154759474226504,
#    'cutting_board': 0.0,
#    'knife': 0.0,
#    'plate': 2.5}},
#  's33-d50': {(1, 0): {'eggs': 4.031128874149275,
#    'cup': 3.1622776601683795,
#    'egg_cup': 3.1622776601683795,
#    'spoon_small': 1.8027756377319946,
#    'plate': 3.1622776601683795},
#   (0, 1.5): {'eggs': 2.9154759474226504,
#    'cup': 2.5,
#    'egg_cup': 2.5,
#    'spoon_small': 0.0,
#    'plate': 2.5}},
#  's33-d54': {(1, 0): {'peeler': 1.8027756377319946,
#    'mango': 4.031128874149275,
#    'plate': 3.1622776601683795,
#    'knife': 1.8027756377319946},
#   (0, 1.5): {'peeler': 0.0,
#    'mango': 2.9154759474226504,
#    'plate': 2.5,
#    'knife': 0.0}},
#  's34-d28': {(1, 0): {'knife': 1.8027756377319946,
#    'cutting_board': 1.8027756377319946,
#    'bowl': 1.8027756377319946,
#    'orange': 4.031128874149275,
#    'sugar': 2.23606797749979,
#    'spoon_small': 1.8027756377319946,
#    'milk': 4.031128874149275,
#    'bottle': 4.031128874149275},
#   (0, 1.5): {'knife': 0.0,
#    'cutting_board': 0.0,
#    'bowl': 0.0,
#    'orange': 2.9154759474226504,
#    'sugar': 2.0615528128088303,
#    'spoon_small': 0.0,
#    'milk': 2.9154759474226504,
#    'bottle': 2.9154759474226504}},
#  's34-d34': {(1, 0): {'bowl': 1.8027756377319946,
#    'knife': 1.8027756377319946,
#    'peeler': 1.8027756377319946,
#    'ginger': 2.23606797749979,
#    'cutting_board': 1.8027756377319946,
#    'flat_grater': 1.8027756377319946,
#    'spice_shaker': 4.0,
#    'spoon_small': 1.8027756377319946},
#   (0, 1.5): {'bowl': 0.0,
#    'knife': 0.0,
#    'peeler': 0.0,
#    'ginger': 2.0615528128088303,
#    'cutting_board': 0.0,
#    'flat_grater': 0.0,
#    'spice_shaker': 2.692582403567252,
#    'spoon_small': 0.0}},
#  's34-d41': {(1, 0): {'pomegranate': 4.031128874149275,
#    'cutting_board': 1.8027756377319946,
#    'knife': 1.8027756377319946,
#    'bowl': 1.8027756377319946,
#    'spice_shaker': 4.0,
#    'spoon': 1.8027756377319946},
#   (0, 1.5): {'pomegranate': 2.9154759474226504,
#    'cutting_board': 0.0,
#    'knife': 0.0,
#    'bowl': 0.0,
#    'spice_shaker': 2.692582403567252,
#    'spoon': 0.0}},
#  's34-d69': {(1, 0): {'eggs': 4.031128874149275,
#    'pot': 1.0,
#    'butter': 4.031128874149275,
#    'spoon_small': 1.8027756377319946,
#    'spatula': 1.8027756377319946,
#    'spice_shaker': 4.0,
#    'ketchup': 4.031128874149275,
#    'plate': 3.1622776601683795,
#    'fork': 1.8027756377319946},
#   (0, 1.5): {'eggs': 2.9154759474226504,
#    'pot': 1.5,
#    'butter': 2.9154759474226504,
#    'spoon_small': 0.0,
#    'spatula': 0.0,
#    'spice_shaker': 2.692582403567252,
#    'ketchup': 2.9154759474226504,
#    'plate': 2.5,
#    'fork': 0.0}},
#  's35-d40': {(1, 0): {'lime': 4.031128874149275,
#    'bowl': 1.8027756377319946,
#    'squeezer': 1.8027756377319946,
#    'cutting_board': 1.8027756377319946,
#    'knife': 1.8027756377319946,
#    'glass': 3.1622776601683795},
#   (0, 1.5): {'lime': 2.9154759474226504,
#    'bowl': 0.0,
#    'squeezer': 0.0,
#    'cutting_board': 0.0,
#    'knife': 0.0,
#    'glass': 2.5}},
#  's35-d41': {(1, 0): {'pomegranate': 4.031128874149275,
#    'bowl': 3.1622776601683795,
#    'plate': 3.1622776601683795,
#    'cutting_board': 1.8027756377319946,
#    'knife': 1.8027756377319946,
#    'spoon': 1.8027756377319946},
#   (0, 1.5): {'pomegranate': 2.9154759474226504,
#    'bowl': 2.5,
#    'plate': 2.5,
#    'cutting_board': 0.0,
#    'knife': 0.0,
#    'spoon': 0.0}},
#  's35-d48': {(1, 0): {'chilli': 4.031128874149275,
#    'plate': 3.1622776601683795,
#    'cutting_board': 1.8027756377319946,
#    'knife': 1.8027756377319946},
#   (0, 1.5): {'chilli': 2.9154759474226504,
#    'plate': 2.5,
#    'cutting_board': 0.0,
#    'knife': 0.0}},
#  's35-d55': {(1, 0): {'figs': 4.031128874149275,
#    'plate': 3.1622776601683795,
#    'knife': 1.8027756377319946,
#    'cutting_board': 1.8027756377319946},
#   (0, 1.5): {'figs': 2.9154759474226504,
#    'plate': 2.5,
#    'knife': 0.0,
#    'cutting_board': 0.0}},
#  's36-d23': {(1, 0): {'carrot': 4.031128874149275,
#    'bowl': 1.8027756377319946,
#    'cutting_board': 1.8027756377319946,
#    'knife': 1.8027756377319946,
#    'pan': 1.0,
#    'oil': 2.23606797749979,
#    'spatula': 1.8027756377319946,
#    'spice_shaker': 4.0,
#    'jar': 2.23606797749979,
#    'spoon_small': 1.8027756377319946},
#   (0, 1.5): {'carrot': 2.9154759474226504,
#    'bowl': 0.0,
#    'cutting_board': 0.0,
#    'knife': 0.0,
#    'pan': 1.5,
#    'oil': 2.0615528128088303,
#    'spatula': 0.0,
#    'spice_shaker': 2.692582403567252,
#    'jar': 2.0615528128088303,
#    'spoon_small': 0.0}},
#  's36-d27': {(1, 0): {'onion': 2.23606797749979,
#    'cutting_board': 1.8027756377319946,
#    'knife': 1.8027756377319946,
#    'plate': 3.1622776601683795,
#    'lemon_juice': 2.23606797749979},
#   (0, 1.5): {'onion': 2.0615528128088303,
#    'cutting_board': 0.0,
#    'knife': 0.0,
#    'plate': 2.5,
#    'lemon_juice': 2.0615528128088303}},
#  's36-d31': {(1, 0): {'garlic': 2.23606797749979,
#    'cutting_board': 1.8027756377319946,
#    'knife': 1.8027756377319946},
#   (0, 1.5): {'garlic': 2.0615528128088303,
#    'cutting_board': 0.0,
#    'knife': 0.0}},
#  's36-d42': {(1, 0): {'cutting_board': 1.8027756377319946,
#    'bowl': 1.8027756377319946,
#    'knife': 1.8027756377319946,
#    'broccoli': 4.031128874149275,
#    'lid': 1.0,
#    'pot': 1.0,
#    'spice_shaker': 4.0,
#    'plate': 3.1622776601683795,
#    'fork': 1.8027756377319946},
#   (0, 1.5): {'cutting_board': 0.0,
#    'bowl': 0.0,
#    'knife': 0.0,
#    'broccoli': 2.9154759474226504,
#    'lid': 1.5,
#    'pot': 1.5,
#    'spice_shaker': 2.692582403567252,
#    'plate': 2.5,
#    'fork': 0.0}},
#  's36-d43': {(1, 0): {'potato': 2.23606797749979,
#    'knife': 1.8027756377319946,
#    'bowl': 1.8027756377319946,
#    'cutting_board': 1.8027756377319946,
#    'pot': 1.0,
#    'spice_shaker': 4.0,
#    'pan': 1.0,
#    'oil': 2.23606797749979,
#    'spatula': 1.8027756377319946,
#    'bowl2': 1.0},
#   (0, 1.5): {'potato': 2.0615528128088303,
#    'knife': 0.0,
#    'bowl': 0.0,
#    'cutting_board': 0.0,
#    'pot': 1.5,
#    'spice_shaker': 2.692582403567252,
#    'pan': 1.5,
#    'oil': 2.0615528128088303,
#    'spatula': 0.0,
#    'bowl2': 2.5}},
#  's36-d50': {(1, 0): {'bowl': 1.0,
#    'eggs': 4.031128874149275,
#    'spoon_small': 1.8027756377319946},
#   (0, 1.5): {'bowl': 2.5, 'eggs': 2.9154759474226504, 'spoon_small': 0.0}},
#  's36-d70': {(1, 0): {'squeezer': 1.8027756377319946,
#    'orange': 4.031128874149275,
#    'cutting_board': 1.8027756377319946,
#    'knife': 1.8027756377319946,
#    'glass': 3.1622776601683795},
#   (0, 1.5): {'squeezer': 0.0,
#    'orange': 2.9154759474226504,
#    'cutting_board': 0.0,
#    'knife': 0.0,
#    'glass': 2.5}},
#  's37-d21': {(1, 0): {'cucumber': 4.031128874149275,
#    'knife': 1.8027756377319946,
#    'cutting_board': 1.8027756377319946,
#    'plate': 3.1622776601683795,
#    'peeler': 1.8027756377319946,
#    'spice_shaker': 4.0},
#   (0, 1.5): {'cucumber': 2.9154759474226504,
#    'knife': 0.0,
#    'cutting_board': 0.0,
#    'plate': 2.5,
#    'peeler': 0.0,
#    'spice_shaker': 2.692582403567252}},
#  's37-d25': {(1, 0): {'bread': 4.031128874149275,
#    'cutting_board': 1.8027756377319946,
#    'knife': 1.8027756377319946},
#   (0, 1.5): {'bread': 2.9154759474226504, 'cutting_board': 0.0, 'knife': 0.0}},
#  's37-d29': {(1, 0): {'cutting_board': 1.8027756377319946,
#    'knife': 1.8027756377319946,
#    'herbs': 4.0,
#    'bowl': 1.0},
#   (0, 1.5): {'cutting_board': 0.0,
#    'knife': 0.0,
#    'herbs': 2.692582403567252,
#    'bowl': 2.5}},
#  's37-d39': {(1, 0): {'leek': 4.031128874149275,
#    'cutting_board': 1.8027756377319946,
#    'knife': 1.8027756377319946,
#    'pan': 1.0,
#    'oil': 2.23606797749979,
#    'spatula': 1.8027756377319946,
#    'spice_shaker': 4.0,
#    'plate': 3.1622776601683795},
#   (0, 1.5): {'leek': 2.9154759474226504,
#    'cutting_board': 0.0,
#    'knife': 0.0,
#    'pan': 1.5,
#    'oil': 2.0615528128088303,
#    'spatula': 0.0,
#    'spice_shaker': 2.692582403567252,
#    'plate': 2.5}},
#  's37-d46': {(1, 0): {'pineapple': 4.031128874149275,
#    'cutting_board': 1.8027756377319946,
#    'knife': 1.8027756377319946,
#    'plastic_box': 1.8027756377319946,
#    'spice_shaker': 4.0},
#   (0, 1.5): {'pineapple': 2.9154759474226504,
#    'cutting_board': 0.0,
#    'knife': 0.0,
#    'plastic_box': 0.0,
#    'spice_shaker': 2.692582403567252}},
#  'k01': {(2.0, 4.0): {'set_0': 2.23606797749979,
#    'silverware_3': 2.8284271247461903,
#    'set_2': 2.4037008503093262,
#    'set_3': 2.6874192494328497,
#    'set_4': 2.4037008503093262,
#    'set_5': 2.4037008503093262}},
#  'k04': {(3.5, 3.0): {'set_0': 0.5333333333333323,
#    'set_1': 0.8189169677079596,
#    'set_2': 0.6641619615057095,
#    'set_3': 1.6336734339790466,
#    'set_4': 1.1661903789690602},
#   (2.5, 4.5): {'set_0': 2.145020072426155,
#    'set_1': 1.6342046995404218,
#    'set_2': 2.087529108246824,
#    'set_3': 3.0472209561427537,
#    'set_4': 2.1931712199461306}},
#  'k06': {(2.5, 4.5): {'set_0': 2.63523138347365,
#    'set_1': 2.63523138347365,
#    'set_2': 2.926697038566779,
#    'set_3': 2.6641654936917445,
#    'set_4': 2.8567658481421105}},
#  'k08': {(2.5, 4.5): {'set_0': 2.9,
#    'set_1': 2.4413111231467406,
#    'set_2': 3.0516389039334255,
#    'set_3': 2.6248809496813372,
#    'plate_1': 2.6248809496813372,
#    'set_5': 2.98142396999972,
#    'set_6': 0.8544003745317532,
#    'glass_3': 3.2557641192199416}},
#  'k11': {(2.5, 4.5): {'set_0': 2.5044959572736385,
#    'silverware_3': 2.9,
#    'set_3': 2.5044959572736385,
#    'set_4': 2.6405491853021785,
#    'set_5': 3.181980515339464,
#    'set_6': 2.571478174124758,
#    'set_7': 2.6248809496813372,
#    'set_8': 3.323401871576773},
#   (2.4, 4.5): {'set_0': 2.5947061490658245,
#    'silverware_3': 2.9698484809834995,
#    'set_3': 2.5947061490658245,
#    'set_4': 2.735415873317986,
#    'set_5': 3.2534596969994882,
#    'set_6': 2.6612966764342527,
#    'set_7': 2.7202941017470885,
#    'set_8': 3.3948490393535904},
#   (3.9, 4.1): {'set_0': 1.1011357772772616,
#    'silverware_3': 1.8027756377319943,
#    'set_3': 1.1011357772772616,
#    'set_4': 1.1884864324004711,
#    'set_5': 2.035927307150233,
#    'set_6': 1.1715374513859977,
#    'set_7': 1.1704699910719623,
#    'set_8': 2.1691011963483855}},
#  'k12': {(3.0, 3.9): {'set_0': 2.5079872407968904,
#    'silverware_2': 1.5524174696260025,
#    'set_2': 1.6347782724271815,
#    'set_3': 2.0700241544484452,
#    'silverware_1': 2.5079872407968904,
#    'set_5': 2.0464060637561103,
#    'set_6': 2.49098374141623,
#    'set_7': 2.4413111231467406},
#   (2.5, 4.5): {'set_0': 3.104834939252005,
#    'silverware_2': 2.23606797749979,
#    'set_2': 2.358495283014151,
#    'set_3': 2.836370920736567,
#    'silverware_1': 3.104834939252005,
#    'set_5': 2.7051391420364643,
#    'set_6': 3.131293662370235,
#    'set_7': 3.2015621187164243}},
#  'k14': {(3.7, 4.2): {'set_0': 0.7071067811865476,
#    'set_1': 1.3313526955694346,
#    'bowl_1': 1.3892443989449808,
#    'silverware_1': 1.3928388277184118,
#    'set_4': 1.3928388277184118,
#    'dish_1': 1.7464249196572978,
#    'dish_2': 1.70293863659264,
#    'set_7': 1.7677669529663684,
#    'set_8': 2.198294793698061,
#    'bowl_3': 2.3323807579381204},
#   (2.5, 4.5): {'set_0': 1.8788294228055937,
#    'set_1': 2.528339375954106,
#    'bowl_1': 2.6,
#    'silverware_1': 2.6248809496813372,
#    'set_4': 2.6248809496813372,
#    'dish_1': 2.973213749463701,
#    'dish_2': 2.8653097563788803,
#    'set_7': 2.761340254296815,
#    'set_8': 3.0302640149003515,
#    'bowl_3': 3.3241540277189325}},
#  'k16': {(2.5, 4.5): {'set_0': 2.3119256043393785,
#    'set_1': 3.1081545971846376,
#    'silverware_3': 3.0,
#    'silverware_2': 2.0591260281974,
#    'silverware_1': 2.596150997149434,
#    'set_6': 2.625727412441064,
#    'set_7': 2.5733678754158382,
#    'set_8': 2.661296676434253}},
#  'k17': {(2.5, 4.5): {'bowl_1': 2.4041630560342613,
#    'set_1': 2.545584412271571,
#    'set_2': 2.253392504154075,
#    'set_3': 2.438237068047322,
#    'set_4': 3.104834939252005,
#    'silverware_3': 2.920616373302046,
#    'set_6': 3.1240998703626617,
#    'set_7': 3.4205262752974135}},
#  'k18': {(2.5, 4.5): {'set_0': 2.5235689013775713,
#    'set_1': 2.06155281280883,
#    'set_2': 2.8550394042814893,
#    'set_3': 2.758824226207808,
#    'set_4': 3.2526911934581184,
#    'set_5': 2.462214450449026},
#   (3.9, 4.1): {'set_0': 1.1456002793295752,
#    'set_1': 0.9219544457292882,
#    'set_2': 1.5878444508200413,
#    'set_3': 1.3703203194062978,
#    'set_4': 2.1023796041628633,
#    'set_5': 1.0404326023342405}},
#  'k19': {(4.0, 4.1): {'set_0': 1.2369316876852983,
#    'dish_1': 0.58309518948453,
#    'set_2': 1.5443445211480495,
#    'dish_2': 0.3605551275463989,
#    'silverware_2': 0.7810249675906652,
#    'silverware_3': 1.8681541692269403,
#    'dish_3': 2.4698178070456933,
#    'set_7': 0.9617692030835668,
#    'set_8': 1.7613914953808532,
#    'set_9': 1.7102631376487067},
#   (2.5, 4.5): {'set_0': 2.7892651361962706,
#    'dish_1': 2.118962010041709,
#    'set_2': 3.073271872125862,
#    'dish_2': 1.8384776310850237,
#    'silverware_2': 2.23606797749979,
#    'silverware_3': 2.973213749463701,
#    'dish_3': 3.753664875824692,
#    'set_7': 2.4989997999199596,
#    'set_8': 3.1100643080167973,
#    'set_9': 3.092733418838423}},
#  'k20': {(4.0, 1.9): {'silverware_3': 1.019803902718557,
#    'silverware_2': 0.4472135954999579,
#    'silverware_1': 1.726267650163207,
#    'set_4': 1.0381607668264958,
#    'set_5': 1.0413666234542207,
#    'set_6': 1.4267289706021795,
#    'set_7': 1.2265579661982726},
#   (2.5, 4.5): {'silverware_3': 3.4655446902326914,
#    'silverware_2': 2.780287754891569,
#    'silverware_1': 2.0124611797498106,
#    'set_4': 2.9576642435844165,
#    'set_5': 2.8168145917764,
#    'set_6': 2.7842812757015447,
#    'set_7': 2.980119311556353}},
#  'k21': {(4.0, 2.1): {'set_0': 0.7999999999999998,
#    'set_1': 0.40000000000000036,
#    'set_2': 0.8500000000000002,
#    'set_3': 1.3152946437965904,
#    'set_4': 1.6770509831248424,
#    'set_5': 2.055480479109446,
#    'set_6': 2.0248456731316584},
#   (2.5, 4.5): {'set_0': 3.324154027718932,
#    'set_1': 3.0610455730027937,
#    'set_2': 2.516445906432324,
#    'set_3': 2.024845673131659,
#    'set_4': 2.423324163210527,
#    'set_5': 2.97405447159261,
#    'set_6': 2.692582403567252}},
#  'k22': {(2.5, 4.5): {'silverware_1': 2.596150997149434,
#    'set_1': 3.297347418759509,
#    'set_2': 2.5,
#    'glass_3': 3.2015621187164243,
#    'set_4': 2.720294101747089,
#    'set_5': 2.9347061181658374,
#    'set_6': 3.297347418759509,
#    'set_7': 2.720294101747088}},
#  'k23': {(4.0, 4.1): {'silverware_1': 1.0440306508910548,
#    'set_1': 0.9340770846134705,
#    'set_2': 0.3771236166328253,
#    'set_3': 1.0041912168506557,
#    'set_4': 0.23333333333333384},
#   (2.5, 4.5): {'silverware_1': 2.596150997149434,
#    'set_1': 0.8845903006477067,
#    'set_2': 1.401982722987539,
#    'set_3': 2.4775794639123085,
#    'set_4': 1.3283239230114177}},
#  'k24': {(2.5, 4.5): {'silverware_3': 2.8017851452243794,
#    'silverware_2': 1.8357559750685815,
#    'silverware_1': 2.596150997149434,
#    'set_3': 2.2627416997969516,
#    'set_4': 2.1505813167606567,
#    'set_5': 2.842973795165899,
#    'set_6': 3.01537725666292,
#    'set_7': 2.459674775249769,
#    'set_8': 2.619637379485947}},
#  'k25': {(2.0, 4.5): {'set_0': 2.780287754891569,
#    'silverware_1': 3.104834939252005,
#    'set_2': 3.0675723300355937,
#    'set_3': 3.040148022712052,
#    'set_4': 3.138470965295043,
#    'set_5': 2.7681221071332813,
#    'set_6': 3.053686296920494,
#    'set_7': 3.244225639501667},
#   (2.5, 4.5): {'set_0': 2.4041630560342617,
#    'silverware_1': 2.6248809496813372,
#    'set_2': 2.6,
#    'set_3': 2.65377090194312,
#    'set_4': 2.7202941017470885,
#    'set_5': 2.3048861143232213,
#    'set_6': 2.6879360111431225,
#    'set_7': 2.815137652051849}}}

# %% [markdown]
# ### predict sequences

# %%
results = pd.DataFrame()

for row in range(0, len(data)):
        use_string_for_seq = False
        coordinates = {key: ast.literal_eval(value) for key, value in
                       (elem.split(': ') for elem in data.at[row, 'coordinates'].split(';'))}

        start_coordinates = list(ast.literal_eval(data.at[row, 'start_coordinates']))
        ID = str(data.at[row,'ID'])
        
        if use_string_for_seq == True:
            seq = str(data.at[row, 'sequence'])
            objects = list(data.at[row, 'sequence'])
        else:
            seq = [elem for elem in data.at[row, 'sequence'].split(',')]
            objects = [elem for elem in data.at[row, 'sequence'].split(',')]

        # get list of objects that have relational dependencies, if any (else set to empty list)
        try:
            strong_k = list(data.at[row, 'strong_k'].split(','))
        except AttributeError:
            strong_k = []

        try:
            mid_k = list(data.at[row, 'mid_k'].split(','))
        except AttributeError:
            mid_k = []

        try:
            food_k = list(data.at[row, 'food_k'].split(','))
        except AttributeError:
            food_k = []
            
        k1 = {obj: 1.7 if obj in food_k else 0.2 if obj in strong_k \
              else 0.3 if obj in mid_k else 1.0 for obj in objects}
        try:
            c1 = {obj: 1.8 if obj in data.at[row, 'containment'] else 1.0 for obj in objects}
        except:
            c1 = {obj: 1.0 for obj in objects}
            
        dim = [2, 'xy']
        
        predicted = prediction.predict_prequential(distances_dict, ID, objects, coordinates,
                                                  start_coordinates, c1, k1, dim)
        
        results.at[row, 'predicted'] = predicted
        results.at[row, 'observed'] = seq
        results.at[row, 'ID'] = ID
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[20], line 43
#      39     c1 = {obj: 1.0 for obj in objects}
#      41 dim = [2, 'xy']
# ---> 43 predicted = prediction.predict_prequential(distances_dict, ID, objects, coordinates,
#      44                                           start_coordinates, c1, k1, dim)
#      46 results.at[row, 'predicted'] = predicted
#      47 results.at[row, 'observed'] = seq
#
# File ~/personal/projects/phd thesis/cognitive model/model_package/opportunistic_planning/prediction.py:176, in predict_prequential(distances_dict, ID, objects, coordinates, start_coordinates, sequence, c, k, dimension)
#     173     except TypeError:
#     174         position = str(new_start_coords[coord_index])
# --> 176     possible_items[obj] = distances_dict[dimension[1]][ID][position][obj] ** k[obj] * c[obj]
#     178 minval = min(possible_items.values())
#     179 minval = [k for k, v in possible_items.items() if v == minval]
#
# IndexError: list index out of range

# %%
results
# Out:
#     median  median_normalized   ID
# 0      3.0           0.500000  k01
# 1      2.0           0.400000  k04
# 2      1.0           0.200000  k06
# 3      6.0           0.750000  k08
# 4      3.0           0.333333  k11
# 5      3.0           0.375000  k12
# 6      4.0           0.400000  k14
# 7      5.0           0.555556  k16
# 8      5.0           0.625000  k17
# 9      4.0           0.666667  k18
# 10     6.0           0.600000  k19
# 11     3.0           0.375000  k20
# 12     3.0           0.428571  k21
# 13     5.0           0.625000  k22
# 14     4.0           0.800000  k23
# 15     4.0           0.444444  k24
# 16     4.0           0.500000  k25

# %%
np.median(results['median'])
# Out:
# 4.0

# %%
results.to_csv('results/results_cleaning_2D_n100_fitted_to_ts_2023-01-20.csv', header=True, index=False)
