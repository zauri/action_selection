# %%
import pandas as pd
import numpy as np
import itertools
from scipy.spatial import distance

pd.set_option('display.max_rows', 2500)

# %% [markdown]
# ### Create inputs

# %%
objects = ['p', 'c', 's', 'b', 'a', 'o', 'w', 'e', 'g']
# p = plates (1+2), c = cups (1+2), s = silverware (2x), b = bread plate, a = salat bowl, o = oil
# w = water bottle, e = beer bottle, g = glass (2x)

# %%
coordinates = {'p': (0,2),
               'c': (0,0),
               's': (0,0),
               'b': (0,0),
               'a': (0,0),
               'o': (0,0),
               'w': (1,0),
               'e': (1,0),
               'g': (0,2),
              'start': (0,3),
              'table': (1,1)}

# %% [markdown]
# ### Populate dataframe

# %%
def fill_dataframe(objects, objects_at_once=2):
    df = pd.DataFrame(columns=['from_node', 'to_node', 'obj_at_once', 'dist', 'weight_new'])
    # Generate list of combinations w/o duplicates
    nodes = list(itertools.chain(*[itertools.combinations(objects, i+1) for i in range(len(objects))]))
    nodes = [''.join(node) for node in nodes]
    
    node_list = []
    for x in range(0, len(nodes)):
        if len(nodes[x]) <= 2:
            df.loc[x, 'from_node'] = 'z'
            df.loc[x, 'to_node'] = nodes[x]
            df.loc[x, 'obj_at_once'] = len(nodes[x])
    
        for y in range(x, len(nodes)):
            if 1 <= (len(nodes[y]) - len(nodes[x])) <= 2:
                if all(x in nodes[y] for x in nodes[x]):
                    node_list.append((nodes[y], nodes[x]))
    
    for tup in node_list:
        df = df.append({'from_node': tup[1], 'to_node': tup[0], 'obj_at_once': len(tup[0]) - len(tup[1])}, ignore_index=True)
    
    # No constraints for how many objects at once
    if objects_at_once == 2:
        df = df
    elif objects_at_once == 1:
        # Add constraint: Only 1 object at once
        df = df.loc[df['obj_at_once'] == 1]

    # Reset index
    df = df.reset_index(drop=True)
    
    return df

# %%
# %timeit -r 1 data = fill_dataframe(objects, objects_at_once=1)
# Out:
# 14.7 s ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)

# %% [markdown]
# ### Calculate distances

# %%
def calculate_distances(data):
    for row in range(0, len(data)):
        # Distance = start -> obj 1 -> table
        if data['from_node'][row] == 'z' and len(data['to_node'][row]) == 1:
            data.loc[row, 'dist'] = (distance.euclidean(
                        coordinates['start'], 
                        coordinates[data['to_node'][row]]) +
                    distance.euclidean(
                        coordinates[data['to_node'][row]], 
                        coordinates['table'])
                    )
    
        # Distance = start -> obj 1 -> obj 2 -> table
        elif data['from_node'][row] == 'z' and len(data['to_node'][row]) != 1:
            data.loc[row, 'dist'] = (distance.euclidean(
                        coordinates['start'], 
                        coordinates[data['to_node'][row][0]]) +
                    distance.euclidean(
                        coordinates[data['to_node'][row][0]], 
                        coordinates[data['to_node'][row][1]]) +
                    distance.euclidean(
                        coordinates[data['to_node'][row][1]], 
                        coordinates['table'])
                    )
    # Distance = table -> obj 1 -> (obj 2) -> table
        else:
            # Get difference between sequences (from_node, to_node)
            diff = [x for x in data['to_node'][row] if x not in data['from_node'][row]]
        
            if len(diff) == 1:
                data.loc[row, 'dist'] = distance.euclidean(
                        coordinates['table'], 
                        coordinates[diff[0]]) * 2
        
            elif len(diff) == 2:
                data.loc[row, 'dist'] = (distance.euclidean(
                        coordinates['table'], 
                        coordinates[diff[0]]) +
                    distance.euclidean(
                        coordinates[diff[0]], 
                        coordinates[diff[1]]) +
                    distance.euclidean(
                        coordinates[diff[1]], 
                        coordinates['table'])
                    )
    return data

# %%
#data = calculate_distances(data)
#data

# %%
c1 = {'p': 1.2,
    'c': 1.2,
    's': 1.2,
    'b': 1.0,
    'a': 1.0,
    'o': 1.0,
    'w': 1.2,
    'e': 1.2,
    'g': 1.2}

# %%
k1 = {'p': 0.95,
     'c': 1.0,
     's': 1.0,
     'b': 1.0,
     'a': 1.0,
     'o': 1.0,
     'w': 1.0,
     'e': 1.0,
     'g': 1.0}

# %%
c0 = {'p': 1.0,
    'c': 1.0,
    's': 1.0,
    'b': 1.0,
    'a': 1.0,
    'o': 1.0,
    'w': 1.0,
    'e': 1.0,
    'g': 1.0}

k0 = {'p': 1.0,
     'c': 1.0,
     's': 1.0,
     'b': 1.0,
     'a': 1.0,
     'o': 1.0,
     'w': 1.0,
     'e': 1.0,
     'g': 1.0}

# %%
def calculate_edge_weights_params(data, objects, c, k):
    # Reset weights according to weight parameters
    for row in range(0, len(data)):
        diff = [x for x in data['to_node'][row] if x not in data['from_node'][row]]
        
        for obj in objects:
            if len(diff) == 1 and obj in diff:
                data.loc[row, 'weight_new'] = (data['dist'][row] ** k[diff[0]]) * c[diff[0]]
                
            elif len(diff) == 2 and obj in diff:
                data.loc[row, 'weight_new'] = (data['dist'][row] ** k[diff[0]]) * c[diff[0]]
                data.loc[row, 'weight_new'] = (data['weight_new'][row] ** k[diff[1]]) * c[diff[1]]
                
    return data

# %%
#all(data['weight_new'] == data2['weight_new'])

# %% [markdown]
# ### Dijkstra + graph classes

# %%
class Node:
    def __init__(self, label):
        self.label = label

class Edge:
    def __init__(self, to_node, length):
        self.to_node = to_node
        self.length = length


class Graph:
    def __init__(self):
        self.nodes = set()
        self.edges = dict()

    def add_node(self, node):
        self.nodes.add(node)

    def add_edge(self, from_node, to_node, length):
        edge = Edge(to_node, length)
        if from_node.label in self.edges:
            from_node_edges = self.edges[from_node.label]
        else:
            self.edges[from_node.label] = dict()
            from_node_edges = self.edges[from_node.label]
        from_node_edges[to_node.label] = edge


def min_dist(q, dist):
    """
    Returns the node with the smallest distance in q.
    Implemented to keep the main algorithm clean.
    """
    min_node = None
    for node in q:
        if min_node == None:
            min_node = node
        elif dist[node] < dist[min_node]:
            min_node = node

    return min_node

def dijkstra(graph, source):
    q = set()
    dist = {}
    prev = {}

    for v in graph.nodes:           # initialization
        dist[v] = float('inf')      # unknown distance from source to v
        prev[v] = float('inf')      # previous node in optimal path from source
        q.add(v)                    # all nodes initially in q (unvisited nodes)

    # distance from source to source
    dist[source] = 0

    while q:
        # node with the least distance selected first
        u = min_dist(q, dist)

        q.remove(u)

        if u.label in graph.edges:
            for _, v in graph.edges[u.label].items():
                alt = dist[u] + v.length
                if alt < dist[v.to_node]:
                    # a shorter path to v has been found
                    dist[v.to_node] = alt
                    prev[v.to_node] = u

    return dist, prev


def to_array(prev, from_node):
    """Creates an ordered list of labels as a route."""
    previous_node = prev[from_node]
    route = [from_node.label]
    while previous_node != float('inf'):
        route.append(previous_node.label)
        temp = previous_node
        previous_node = prev[temp]

    route.reverse()
    return route

# %% [markdown]
# ### Create nodes + edges

# %%
def create_nodes_edges(graph, data):
    # Create sorted set of nodes from to_nodes and from_nodes
    nodes = sorted(pd.unique(data[['from_node', 'to_node']].values.ravel()))

    # Create nodes from set
    for x in range(0, len(nodes)):
        globals()[nodes[x]] = Node(nodes[x])    # Create node as global variable
        graph.add_node(globals()[nodes[x]])     # Add node to graph

    # Add edge for row in csv -> from_node, to_node, weight
    for row in range(0, len(data)):
        to_node = globals()[data['to_node'][row]]
        from_node = globals()[data['from_node'][row]]
        graph.add_edge(from_node, to_node, data['weight_new'][row])
    
    return graph

# %%
#create_nodes_edges(graph, data)

# %% [markdown]
# ### Print function

# %%
def print_result(dist, prev, start, target):
    print("The quickest path from {} to {} is [{}] with a distance of {}".format(
        start.label,
        target.label,
        " -> ".join(to_array(prev, target)),
        str(round(dist[target], 2))
        )
    )

# %% [markdown]
# ### Define main function

# %%
def main():
    graph = Graph()
    data = fill_dataframe(objects, objects_at_once=1)
    data = calculate_distances(data)
    data = calculate_edge_weights_params(data, objects, c0, k0)
    create_nodes_edges(graph, data)
    dist, prev = dijkstra(graph, z)
    print_result(dist, prev, z, pcsbaoweg)

# %%
main()
# Out:
# The quickest path from z to pcsbaoweg is [z -> p -> pe -> pwe -> pcwe -> pcswe -> pcsawe -> pcsaowe -> pcsaoweg -> pcsbaoweg] with a distance of 23.38

# %%
data2 = fill_dataframe(objects, objects_at_once=1)
data2 = calculate_distances(data2)
data2 = calculate_edge_weights_params(data2, objects, c0, k1)
data2
# Out:
#      from_node    to_node obj_at_once     dist weight_new
# 0            z          p           1  2.41421    2.31013
# 1            z          c           1  4.41421    4.41421
# 2            z          s           1  4.41421    4.41421
# 3            z          b           1  4.41421    4.41421
# 4            z          a           1  4.41421    4.41421
# 5            z          o           1  4.41421    4.41421
# 6            z          w           1  4.16228    4.16228
# 7            z          e           1  4.16228    4.16228
# 8            z          g           1  2.41421    2.41421
# 9            p         pc           1  2.82843    2.82843
# 10           p         ps           1  2.82843    2.82843
# 11           p         pb           1  2.82843    2.82843
# 12           p         pa           1  2.82843    2.82843
# 13           p         po           1  2.82843    2.82843
# 14           p         pw           1        2          2
# 15           p         pe           1        2          2
# 16           p         pg           1  2.82843    2.82843
# 17           c         pc           1  2.82843    2.68515
# 18           c         cs           1  2.82843    2.82843
# 19           c         cb           1  2.82843    2.82843
# 20           c         ca           1  2.82843    2.82843
# 21           c         co           1  2.82843    2.82843
# 22           c         cw           1        2          2
# 23           c         ce           1        2          2
# 24           c         cg           1  2.82843    2.82843
# 25           s         ps           1  2.82843    2.68515
# 26           s         cs           1  2.82843    2.82843
# 27           s         sb           1  2.82843    2.82843
# 28           s         sa           1  2.82843    2.82843
# 29           s         so           1  2.82843    2.82843
# 30           s         sw           1        2          2
# 31           s         se           1        2          2
# 32           s         sg           1  2.82843    2.82843
# 33           b         pb           1  2.82843    2.68515
# 34           b         cb           1  2.82843    2.82843
# 35           b         sb           1  2.82843    2.82843
# 36           b         ba           1  2.82843    2.82843
# 37           b         bo           1  2.82843    2.82843
# 38           b         bw           1        2          2
# 39           b         be           1        2          2
# 40           b         bg           1  2.82843    2.82843
# 41           a         pa           1  2.82843    2.68515
# 42           a         ca           1  2.82843    2.82843
# 43           a         sa           1  2.82843    2.82843
# 44           a         ba           1  2.82843    2.82843
# 45           a         ao           1  2.82843    2.82843
# 46           a         aw           1        2          2
# 47           a         ae           1        2          2
# 48           a         ag           1  2.82843    2.82843
# 49           o         po           1  2.82843    2.68515
# 50           o         co           1  2.82843    2.82843
# 51           o         so           1  2.82843    2.82843
# 52           o         bo           1  2.82843    2.82843
# 53           o         ao           1  2.82843    2.82843
# 54           o         ow           1        2          2
# 55           o         oe           1        2          2
# 56           o         og           1  2.82843    2.82843
# 57           w         pw           1  2.82843    2.68515
# 58           w         cw           1  2.82843    2.82843
# 59           w         sw           1  2.82843    2.82843
# 60           w         bw           1  2.82843    2.82843
# 61           w         aw           1  2.82843    2.82843
# 62           w         ow           1  2.82843    2.82843
# 63           w         we           1        2          2
# 64           w         wg           1  2.82843    2.82843
# 65           e         pe           1  2.82843    2.68515
# 66           e         ce           1  2.82843    2.82843
# 67           e         se           1  2.82843    2.82843
# 68           e         be           1  2.82843    2.82843
# 69           e         ae           1  2.82843    2.82843
# 70           e         oe           1  2.82843    2.82843
# 71           e         we           1        2          2
# 72           e         eg           1  2.82843    2.82843
# 73           g         pg           1  2.82843    2.68515
# 74           g         cg           1  2.82843    2.82843
# 75           g         sg           1  2.82843    2.82843
# 76           g         bg           1  2.82843    2.82843
# 77           g         ag           1  2.82843    2.82843
# 78           g         og           1  2.82843    2.82843
# 79           g         wg           1        2          2
# 80           g         eg           1        2          2
# 81          pc        pcs           1  2.82843    2.82843
# 82          pc        pcb           1  2.82843    2.82843
# 83          pc        pca           1  2.82843    2.82843
# 84          pc        pco           1  2.82843    2.82843
# 85          pc        pcw           1        2          2
# 86          pc        pce           1        2          2
# 87          pc        pcg           1  2.82843    2.82843
# 88          ps        pcs           1  2.82843    2.82843
# 89          ps        psb           1  2.82843    2.82843
# 90          ps        psa           1  2.82843    2.82843
# 91          ps        pso           1  2.82843    2.82843
# 92          ps        psw           1        2          2
# 93          ps        pse           1        2          2
# 94          ps        psg           1  2.82843    2.82843
# 95          pb        pcb           1  2.82843    2.82843
# 96          pb        psb           1  2.82843    2.82843
# 97          pb        pba           1  2.82843    2.82843
# 98          pb        pbo           1  2.82843    2.82843
# 99          pb        pbw           1        2          2
# 100         pb        pbe           1        2          2
# 101         pb        pbg           1  2.82843    2.82843
# 102         pa        pca           1  2.82843    2.82843
# 103         pa        psa           1  2.82843    2.82843
# 104         pa        pba           1  2.82843    2.82843
# 105         pa        pao           1  2.82843    2.82843
# 106         pa        paw           1        2          2
# 107         pa        pae           1        2          2
# 108         pa        pag           1  2.82843    2.82843
# 109         po        pco           1  2.82843    2.82843
# 110         po        pso           1  2.82843    2.82843
# 111         po        pbo           1  2.82843    2.82843
# 112         po        pao           1  2.82843    2.82843
# 113         po        pow           1        2          2
# 114         po        poe           1        2          2
# 115         po        pog           1  2.82843    2.82843
# 116         pw        pcw           1  2.82843    2.82843
# 117         pw        psw           1  2.82843    2.82843
# 118         pw        pbw           1  2.82843    2.82843
# 119         pw        paw           1  2.82843    2.82843
# 120         pw        pow           1  2.82843    2.82843
# 121         pw        pwe           1        2          2
# 122         pw        pwg           1  2.82843    2.82843
# 123         pe        pce           1  2.82843    2.82843
# 124         pe        pse           1  2.82843    2.82843
# 125         pe        pbe           1  2.82843    2.82843
# 126         pe        pae           1  2.82843    2.82843
# 127         pe        poe           1  2.82843    2.82843
# 128         pe        pwe           1        2          2
# 129         pe        peg           1  2.82843    2.82843
# 130         pg        pcg           1  2.82843    2.82843
# 131         pg        psg           1  2.82843    2.82843
# 132         pg        pbg           1  2.82843    2.82843
# 133         pg        pag           1  2.82843    2.82843
# 134         pg        pog           1  2.82843    2.82843
# 135         pg        pwg           1        2          2
# 136         pg        peg           1        2          2
# 137         cs        pcs           1  2.82843    2.68515
# 138         cs        csb           1  2.82843    2.82843
# 139         cs        csa           1  2.82843    2.82843
# 140         cs        cso           1  2.82843    2.82843
# 141         cs        csw           1        2          2
# 142         cs        cse           1        2          2
# 143         cs        csg           1  2.82843    2.82843
# 144         cb        pcb           1  2.82843    2.68515
# 145         cb        csb           1  2.82843    2.82843
# 146         cb        cba           1  2.82843    2.82843
# 147         cb        cbo           1  2.82843    2.82843
# 148         cb        cbw           1        2          2
# 149         cb        cbe           1        2          2
# 150         cb        cbg           1  2.82843    2.82843
# 151         ca        pca           1  2.82843    2.68515
# 152         ca        csa           1  2.82843    2.82843
# 153         ca        cba           1  2.82843    2.82843
# 154         ca        cao           1  2.82843    2.82843
# 155         ca        caw           1        2          2
# 156         ca        cae           1        2          2
# 157         ca        cag           1  2.82843    2.82843
# 158         co        pco           1  2.82843    2.68515
# 159         co        cso           1  2.82843    2.82843
# 160         co        cbo           1  2.82843    2.82843
# 161         co        cao           1  2.82843    2.82843
# 162         co        cow           1        2          2
# 163         co        coe           1        2          2
# 164         co        cog           1  2.82843    2.82843
# 165         cw        pcw           1  2.82843    2.68515
# 166         cw        csw           1  2.82843    2.82843
# 167         cw        cbw           1  2.82843    2.82843
# 168         cw        caw           1  2.82843    2.82843
# 169         cw        cow           1  2.82843    2.82843
# 170         cw        cwe           1        2          2
# 171         cw        cwg           1  2.82843    2.82843
# 172         ce        pce           1  2.82843    2.68515
# 173         ce        cse           1  2.82843    2.82843
# 174         ce        cbe           1  2.82843    2.82843
# 175         ce        cae           1  2.82843    2.82843
# 176         ce        coe           1  2.82843    2.82843
# 177         ce        cwe           1        2          2
# 178         ce        ceg           1  2.82843    2.82843
# 179         cg        pcg           1  2.82843    2.68515
# 180         cg        csg           1  2.82843    2.82843
# 181         cg        cbg           1  2.82843    2.82843
# 182         cg        cag           1  2.82843    2.82843
# 183         cg        cog           1  2.82843    2.82843
# 184         cg        cwg           1        2          2
# 185         cg        ceg           1        2          2
# 186         sb        psb           1  2.82843    2.68515
# 187         sb        csb           1  2.82843    2.82843
# 188         sb        sba           1  2.82843    2.82843
# 189         sb        sbo           1  2.82843    2.82843
# 190         sb        sbw           1        2          2
# 191         sb        sbe           1        2          2
# 192         sb        sbg           1  2.82843    2.82843
# 193         sa        psa           1  2.82843    2.68515
# 194         sa        csa           1  2.82843    2.82843
# 195         sa        sba           1  2.82843    2.82843
# 196         sa        sao           1  2.82843    2.82843
# 197         sa        saw           1        2          2
# 198         sa        sae           1        2          2
# 199         sa        sag           1  2.82843    2.82843
# 200         so        pso           1  2.82843    2.68515
# 201         so        cso           1  2.82843    2.82843
# 202         so        sbo           1  2.82843    2.82843
# 203         so        sao           1  2.82843    2.82843
# 204         so        sow           1        2          2
# 205         so        soe           1        2          2
# 206         so        sog           1  2.82843    2.82843
# 207         sw        psw           1  2.82843    2.68515
# 208         sw        csw           1  2.82843    2.82843
# 209         sw        sbw           1  2.82843    2.82843
# 210         sw        saw           1  2.82843    2.82843
# 211         sw        sow           1  2.82843    2.82843
# 212         sw        swe           1        2          2
# 213         sw        swg           1  2.82843    2.82843
# 214         se        pse           1  2.82843    2.68515
# 215         se        cse           1  2.82843    2.82843
# 216         se        sbe           1  2.82843    2.82843
# 217         se        sae           1  2.82843    2.82843
# 218         se        soe           1  2.82843    2.82843
# 219         se        swe           1        2          2
# 220         se        seg           1  2.82843    2.82843
# 221         sg        psg           1  2.82843    2.68515
# 222         sg        csg           1  2.82843    2.82843
# 223         sg        sbg           1  2.82843    2.82843
# 224         sg        sag           1  2.82843    2.82843
# 225         sg        sog           1  2.82843    2.82843
# 226         sg        swg           1        2          2
# 227         sg        seg           1        2          2
# 228         ba        pba           1  2.82843    2.68515
# 229         ba        cba           1  2.82843    2.82843
# 230         ba        sba           1  2.82843    2.82843
# 231         ba        bao           1  2.82843    2.82843
# 232         ba        baw           1        2          2
# 233         ba        bae           1        2          2
# 234         ba        bag           1  2.82843    2.82843
# 235         bo        pbo           1  2.82843    2.68515
# 236         bo        cbo           1  2.82843    2.82843
# 237         bo        sbo           1  2.82843    2.82843
# 238         bo        bao           1  2.82843    2.82843
# 239         bo        bow           1        2          2
# 240         bo        boe           1        2          2
# 241         bo        bog           1  2.82843    2.82843
# 242         bw        pbw           1  2.82843    2.68515
# 243         bw        cbw           1  2.82843    2.82843
# 244         bw        sbw           1  2.82843    2.82843
# 245         bw        baw           1  2.82843    2.82843
# 246         bw        bow           1  2.82843    2.82843
# 247         bw        bwe           1        2          2
# 248         bw        bwg           1  2.82843    2.82843
# 249         be        pbe           1  2.82843    2.68515
# 250         be        cbe           1  2.82843    2.82843
# 251         be        sbe           1  2.82843    2.82843
# 252         be        bae           1  2.82843    2.82843
# 253         be        boe           1  2.82843    2.82843
# 254         be        bwe           1        2          2
# 255         be        beg           1  2.82843    2.82843
# 256         bg        pbg           1  2.82843    2.68515
# 257         bg        cbg           1  2.82843    2.82843
# 258         bg        sbg           1  2.82843    2.82843
# 259         bg        bag           1  2.82843    2.82843
# 260         bg        bog           1  2.82843    2.82843
# 261         bg        bwg           1        2          2
# 262         bg        beg           1        2          2
# 263         ao        pao           1  2.82843    2.68515
# 264         ao        cao           1  2.82843    2.82843
# 265         ao        sao           1  2.82843    2.82843
# 266         ao        bao           1  2.82843    2.82843
# 267         ao        aow           1        2          2
# 268         ao        aoe           1        2          2
# 269         ao        aog           1  2.82843    2.82843
# 270         aw        paw           1  2.82843    2.68515
# 271         aw        caw           1  2.82843    2.82843
# 272         aw        saw           1  2.82843    2.82843
# 273         aw        baw           1  2.82843    2.82843
# 274         aw        aow           1  2.82843    2.82843
# 275         aw        awe           1        2          2
# 276         aw        awg           1  2.82843    2.82843
# 277         ae        pae           1  2.82843    2.68515
# 278         ae        cae           1  2.82843    2.82843
# 279         ae        sae           1  2.82843    2.82843
# 280         ae        bae           1  2.82843    2.82843
# 281         ae        aoe           1  2.82843    2.82843
# 282         ae        awe           1        2          2
# 283         ae        aeg           1  2.82843    2.82843
# 284         ag        pag           1  2.82843    2.68515
# 285         ag        cag           1  2.82843    2.82843
# 286         ag        sag           1  2.82843    2.82843
# 287         ag        bag           1  2.82843    2.82843
# 288         ag        aog           1  2.82843    2.82843
# 289         ag        awg           1        2          2
# 290         ag        aeg           1        2          2
# 291         ow        pow           1  2.82843    2.68515
# 292         ow        cow           1  2.82843    2.82843
# 293         ow        sow           1  2.82843    2.82843
# 294         ow        bow           1  2.82843    2.82843
# 295         ow        aow           1  2.82843    2.82843
# 296         ow        owe           1        2          2
# 297         ow        owg           1  2.82843    2.82843
# 298         oe        poe           1  2.82843    2.68515
# 299         oe        coe           1  2.82843    2.82843
# 300         oe        soe           1  2.82843    2.82843
# 301         oe        boe           1  2.82843    2.82843
# 302         oe        aoe           1  2.82843    2.82843
# 303         oe        owe           1        2          2
# 304         oe        oeg           1  2.82843    2.82843
# 305         og        pog           1  2.82843    2.68515
# 306         og        cog           1  2.82843    2.82843
# 307         og        sog           1  2.82843    2.82843
# 308         og        bog           1  2.82843    2.82843
# 309         og        aog           1  2.82843    2.82843
# 310         og        owg           1        2          2
# 311         og        oeg           1        2          2
# 312         we        pwe           1  2.82843    2.68515
# 313         we        cwe           1  2.82843    2.82843
# 314         we        swe           1  2.82843    2.82843
# 315         we        bwe           1  2.82843    2.82843
# 316         we        awe           1  2.82843    2.82843
# 317         we        owe           1  2.82843    2.82843
# 318         we        weg           1  2.82843    2.82843
# 319         wg        pwg           1  2.82843    2.68515
# 320         wg        cwg           1  2.82843    2.82843
# 321         wg        swg           1  2.82843    2.82843
# 322         wg        bwg           1  2.82843    2.82843
# 323         wg        awg           1  2.82843    2.82843
# 324         wg        owg           1  2.82843    2.82843
# 325         wg        weg           1        2          2
# 326         eg        peg           1  2.82843    2.68515
# 327         eg        ceg           1  2.82843    2.82843
# 328         eg        seg           1  2.82843    2.82843
# 329         eg        beg           1  2.82843    2.82843
# 330         eg        aeg           1  2.82843    2.82843
# 331         eg        oeg           1  2.82843    2.82843
# 332         eg        weg           1        2          2
# 333        pcs       pcsb           1  2.82843    2.82843
# 334        pcs       pcsa           1  2.82843    2.82843
# 335        pcs       pcso           1  2.82843    2.82843
# 336        pcs       pcsw           1        2          2
# 337        pcs       pcse           1        2          2
# 338        pcs       pcsg           1  2.82843    2.82843
# 339        pcb       pcsb           1  2.82843    2.82843
# 340        pcb       pcba           1  2.82843    2.82843
# 341        pcb       pcbo           1  2.82843    2.82843
# 342        pcb       pcbw           1        2          2
# 343        pcb       pcbe           1        2          2
# 344        pcb       pcbg           1  2.82843    2.82843
# 345        pca       pcsa           1  2.82843    2.82843
# 346        pca       pcba           1  2.82843    2.82843
# 347        pca       pcao           1  2.82843    2.82843
# 348        pca       pcaw           1        2          2
# 349        pca       pcae           1        2          2
# 350        pca       pcag           1  2.82843    2.82843
# 351        pco       pcso           1  2.82843    2.82843
# 352        pco       pcbo           1  2.82843    2.82843
# 353        pco       pcao           1  2.82843    2.82843
# 354        pco       pcow           1        2          2
# 355        pco       pcoe           1        2          2
# 356        pco       pcog           1  2.82843    2.82843
# 357        pcw       pcsw           1  2.82843    2.82843
# 358        pcw       pcbw           1  2.82843    2.82843
# 359        pcw       pcaw           1  2.82843    2.82843
# 360        pcw       pcow           1  2.82843    2.82843
# 361        pcw       pcwe           1        2          2
# 362        pcw       pcwg           1  2.82843    2.82843
# 363        pce       pcse           1  2.82843    2.82843
# 364        pce       pcbe           1  2.82843    2.82843
# 365        pce       pcae           1  2.82843    2.82843
# 366        pce       pcoe           1  2.82843    2.82843
# 367        pce       pcwe           1        2          2
# 368        pce       pceg           1  2.82843    2.82843
# 369        pcg       pcsg           1  2.82843    2.82843
# 370        pcg       pcbg           1  2.82843    2.82843
# 371        pcg       pcag           1  2.82843    2.82843
# 372        pcg       pcog           1  2.82843    2.82843
# 373        pcg       pcwg           1        2          2
# 374        pcg       pceg           1        2          2
# 375        psb       pcsb           1  2.82843    2.82843
# 376        psb       psba           1  2.82843    2.82843
# 377        psb       psbo           1  2.82843    2.82843
# 378        psb       psbw           1        2          2
# 379        psb       psbe           1        2          2
# 380        psb       psbg           1  2.82843    2.82843
# 381        psa       pcsa           1  2.82843    2.82843
# 382        psa       psba           1  2.82843    2.82843
# 383        psa       psao           1  2.82843    2.82843
# 384        psa       psaw           1        2          2
# 385        psa       psae           1        2          2
# 386        psa       psag           1  2.82843    2.82843
# 387        pso       pcso           1  2.82843    2.82843
# 388        pso       psbo           1  2.82843    2.82843
# 389        pso       psao           1  2.82843    2.82843
# 390        pso       psow           1        2          2
# 391        pso       psoe           1        2          2
# 392        pso       psog           1  2.82843    2.82843
# 393        psw       pcsw           1  2.82843    2.82843
# 394        psw       psbw           1  2.82843    2.82843
# 395        psw       psaw           1  2.82843    2.82843
# 396        psw       psow           1  2.82843    2.82843
# 397        psw       pswe           1        2          2
# 398        psw       pswg           1  2.82843    2.82843
# 399        pse       pcse           1  2.82843    2.82843
# 400        pse       psbe           1  2.82843    2.82843
# 401        pse       psae           1  2.82843    2.82843
# 402        pse       psoe           1  2.82843    2.82843
# 403        pse       pswe           1        2          2
# 404        pse       pseg           1  2.82843    2.82843
# 405        psg       pcsg           1  2.82843    2.82843
# 406        psg       psbg           1  2.82843    2.82843
# 407        psg       psag           1  2.82843    2.82843
# 408        psg       psog           1  2.82843    2.82843
# 409        psg       pswg           1        2          2
# 410        psg       pseg           1        2          2
# 411        pba       pcba           1  2.82843    2.82843
# 412        pba       psba           1  2.82843    2.82843
# 413        pba       pbao           1  2.82843    2.82843
# 414        pba       pbaw           1        2          2
# 415        pba       pbae           1        2          2
# 416        pba       pbag           1  2.82843    2.82843
# 417        pbo       pcbo           1  2.82843    2.82843
# 418        pbo       psbo           1  2.82843    2.82843
# 419        pbo       pbao           1  2.82843    2.82843
# 420        pbo       pbow           1        2          2
# 421        pbo       pboe           1        2          2
# 422        pbo       pbog           1  2.82843    2.82843
# 423        pbw       pcbw           1  2.82843    2.82843
# 424        pbw       psbw           1  2.82843    2.82843
# 425        pbw       pbaw           1  2.82843    2.82843
# 426        pbw       pbow           1  2.82843    2.82843
# 427        pbw       pbwe           1        2          2
# 428        pbw       pbwg           1  2.82843    2.82843
# 429        pbe       pcbe           1  2.82843    2.82843
# 430        pbe       psbe           1  2.82843    2.82843
# 431        pbe       pbae           1  2.82843    2.82843
# 432        pbe       pboe           1  2.82843    2.82843
# 433        pbe       pbwe           1        2          2
# 434        pbe       pbeg           1  2.82843    2.82843
# 435        pbg       pcbg           1  2.82843    2.82843
# 436        pbg       psbg           1  2.82843    2.82843
# 437        pbg       pbag           1  2.82843    2.82843
# 438        pbg       pbog           1  2.82843    2.82843
# 439        pbg       pbwg           1        2          2
# 440        pbg       pbeg           1        2          2
# 441        pao       pcao           1  2.82843    2.82843
# 442        pao       psao           1  2.82843    2.82843
# 443        pao       pbao           1  2.82843    2.82843
# 444        pao       paow           1        2          2
# 445        pao       paoe           1        2          2
# 446        pao       paog           1  2.82843    2.82843
# 447        paw       pcaw           1  2.82843    2.82843
# 448        paw       psaw           1  2.82843    2.82843
# 449        paw       pbaw           1  2.82843    2.82843
# 450        paw       paow           1  2.82843    2.82843
# 451        paw       pawe           1        2          2
# 452        paw       pawg           1  2.82843    2.82843
# 453        pae       pcae           1  2.82843    2.82843
# 454        pae       psae           1  2.82843    2.82843
# 455        pae       pbae           1  2.82843    2.82843
# 456        pae       paoe           1  2.82843    2.82843
# 457        pae       pawe           1        2          2
# 458        pae       paeg           1  2.82843    2.82843
# 459        pag       pcag           1  2.82843    2.82843
# 460        pag       psag           1  2.82843    2.82843
# 461        pag       pbag           1  2.82843    2.82843
# 462        pag       paog           1  2.82843    2.82843
# 463        pag       pawg           1        2          2
# 464        pag       paeg           1        2          2
# 465        pow       pcow           1  2.82843    2.82843
# 466        pow       psow           1  2.82843    2.82843
# 467        pow       pbow           1  2.82843    2.82843
# 468        pow       paow           1  2.82843    2.82843
# 469        pow       powe           1        2          2
# 470        pow       powg           1  2.82843    2.82843
# 471        poe       pcoe           1  2.82843    2.82843
# 472        poe       psoe           1  2.82843    2.82843
# 473        poe       pboe           1  2.82843    2.82843
# 474        poe       paoe           1  2.82843    2.82843
# 475        poe       powe           1        2          2
# 476        poe       poeg           1  2.82843    2.82843
# 477        pog       pcog           1  2.82843    2.82843
# 478        pog       psog           1  2.82843    2.82843
# 479        pog       pbog           1  2.82843    2.82843
# 480        pog       paog           1  2.82843    2.82843
# 481        pog       powg           1        2          2
# 482        pog       poeg           1        2          2
# 483        pwe       pcwe           1  2.82843    2.82843
# 484        pwe       pswe           1  2.82843    2.82843
# 485        pwe       pbwe           1  2.82843    2.82843
# 486        pwe       pawe           1  2.82843    2.82843
# 487        pwe       powe           1  2.82843    2.82843
# 488        pwe       pweg           1  2.82843    2.82843
# 489        pwg       pcwg           1  2.82843    2.82843
# 490        pwg       pswg           1  2.82843    2.82843
# 491        pwg       pbwg           1  2.82843    2.82843
# 492        pwg       pawg           1  2.82843    2.82843
# 493        pwg       powg           1  2.82843    2.82843
# 494        pwg       pweg           1        2          2
# 495        peg       pceg           1  2.82843    2.82843
# 496        peg       pseg           1  2.82843    2.82843
# 497        peg       pbeg           1  2.82843    2.82843
# 498        peg       paeg           1  2.82843    2.82843
# 499        peg       poeg           1  2.82843    2.82843
# 500        peg       pweg           1        2          2
# 501        csb       pcsb           1  2.82843    2.68515
# 502        csb       csba           1  2.82843    2.82843
# 503        csb       csbo           1  2.82843    2.82843
# 504        csb       csbw           1        2          2
# 505        csb       csbe           1        2          2
# 506        csb       csbg           1  2.82843    2.82843
# 507        csa       pcsa           1  2.82843    2.68515
# 508        csa       csba           1  2.82843    2.82843
# 509        csa       csao           1  2.82843    2.82843
# 510        csa       csaw           1        2          2
# 511        csa       csae           1        2          2
# 512        csa       csag           1  2.82843    2.82843
# 513        cso       pcso           1  2.82843    2.68515
# 514        cso       csbo           1  2.82843    2.82843
# 515        cso       csao           1  2.82843    2.82843
# 516        cso       csow           1        2          2
# 517        cso       csoe           1        2          2
# 518        cso       csog           1  2.82843    2.82843
# 519        csw       pcsw           1  2.82843    2.68515
# 520        csw       csbw           1  2.82843    2.82843
# 521        csw       csaw           1  2.82843    2.82843
# 522        csw       csow           1  2.82843    2.82843
# 523        csw       cswe           1        2          2
# 524        csw       cswg           1  2.82843    2.82843
# 525        cse       pcse           1  2.82843    2.68515
# 526        cse       csbe           1  2.82843    2.82843
# 527        cse       csae           1  2.82843    2.82843
# 528        cse       csoe           1  2.82843    2.82843
# 529        cse       cswe           1        2          2
# 530        cse       cseg           1  2.82843    2.82843
# 531        csg       pcsg           1  2.82843    2.68515
# 532        csg       csbg           1  2.82843    2.82843
# 533        csg       csag           1  2.82843    2.82843
# 534        csg       csog           1  2.82843    2.82843
# 535        csg       cswg           1        2          2
# 536        csg       cseg           1        2          2
# 537        cba       pcba           1  2.82843    2.68515
# 538        cba       csba           1  2.82843    2.82843
# 539        cba       cbao           1  2.82843    2.82843
# 540        cba       cbaw           1        2          2
# 541        cba       cbae           1        2          2
# 542        cba       cbag           1  2.82843    2.82843
# 543        cbo       pcbo           1  2.82843    2.68515
# 544        cbo       csbo           1  2.82843    2.82843
# 545        cbo       cbao           1  2.82843    2.82843
# 546        cbo       cbow           1        2          2
# 547        cbo       cboe           1        2          2
# 548        cbo       cbog           1  2.82843    2.82843
# 549        cbw       pcbw           1  2.82843    2.68515
# 550        cbw       csbw           1  2.82843    2.82843
# 551        cbw       cbaw           1  2.82843    2.82843
# 552        cbw       cbow           1  2.82843    2.82843
# 553        cbw       cbwe           1        2          2
# 554        cbw       cbwg           1  2.82843    2.82843
# 555        cbe       pcbe           1  2.82843    2.68515
# 556        cbe       csbe           1  2.82843    2.82843
# 557        cbe       cbae           1  2.82843    2.82843
# 558        cbe       cboe           1  2.82843    2.82843
# 559        cbe       cbwe           1        2          2
# 560        cbe       cbeg           1  2.82843    2.82843
# 561        cbg       pcbg           1  2.82843    2.68515
# 562        cbg       csbg           1  2.82843    2.82843
# 563        cbg       cbag           1  2.82843    2.82843
# 564        cbg       cbog           1  2.82843    2.82843
# 565        cbg       cbwg           1        2          2
# 566        cbg       cbeg           1        2          2
# 567        cao       pcao           1  2.82843    2.68515
# 568        cao       csao           1  2.82843    2.82843
# 569        cao       cbao           1  2.82843    2.82843
# 570        cao       caow           1        2          2
# 571        cao       caoe           1        2          2
# 572        cao       caog           1  2.82843    2.82843
# 573        caw       pcaw           1  2.82843    2.68515
# 574        caw       csaw           1  2.82843    2.82843
# 575        caw       cbaw           1  2.82843    2.82843
# 576        caw       caow           1  2.82843    2.82843
# 577        caw       cawe           1        2          2
# 578        caw       cawg           1  2.82843    2.82843
# 579        cae       pcae           1  2.82843    2.68515
# 580        cae       csae           1  2.82843    2.82843
# 581        cae       cbae           1  2.82843    2.82843
# 582        cae       caoe           1  2.82843    2.82843
# 583        cae       cawe           1        2          2
# 584        cae       caeg           1  2.82843    2.82843
# 585        cag       pcag           1  2.82843    2.68515
# 586        cag       csag           1  2.82843    2.82843
# 587        cag       cbag           1  2.82843    2.82843
# 588        cag       caog           1  2.82843    2.82843
# 589        cag       cawg           1        2          2
# 590        cag       caeg           1        2          2
# 591        cow       pcow           1  2.82843    2.68515
# 592        cow       csow           1  2.82843    2.82843
# 593        cow       cbow           1  2.82843    2.82843
# 594        cow       caow           1  2.82843    2.82843
# 595        cow       cowe           1        2          2
# 596        cow       cowg           1  2.82843    2.82843
# 597        coe       pcoe           1  2.82843    2.68515
# 598        coe       csoe           1  2.82843    2.82843
# 599        coe       cboe           1  2.82843    2.82843
# 600        coe       caoe           1  2.82843    2.82843
# 601        coe       cowe           1        2          2
# 602        coe       coeg           1  2.82843    2.82843
# 603        cog       pcog           1  2.82843    2.68515
# 604        cog       csog           1  2.82843    2.82843
# 605        cog       cbog           1  2.82843    2.82843
# 606        cog       caog           1  2.82843    2.82843
# 607        cog       cowg           1        2          2
# 608        cog       coeg           1        2          2
# 609        cwe       pcwe           1  2.82843    2.68515
# 610        cwe       cswe           1  2.82843    2.82843
# 611        cwe       cbwe           1  2.82843    2.82843
# 612        cwe       cawe           1  2.82843    2.82843
# 613        cwe       cowe           1  2.82843    2.82843
# 614        cwe       cweg           1  2.82843    2.82843
# 615        cwg       pcwg           1  2.82843    2.68515
# 616        cwg       cswg           1  2.82843    2.82843
# 617        cwg       cbwg           1  2.82843    2.82843
# 618        cwg       cawg           1  2.82843    2.82843
# 619        cwg       cowg           1  2.82843    2.82843
# 620        cwg       cweg           1        2          2
# 621        ceg       pceg           1  2.82843    2.68515
# 622        ceg       cseg           1  2.82843    2.82843
# 623        ceg       cbeg           1  2.82843    2.82843
# 624        ceg       caeg           1  2.82843    2.82843
# 625        ceg       coeg           1  2.82843    2.82843
# 626        ceg       cweg           1        2          2
# 627        sba       psba           1  2.82843    2.68515
# 628        sba       csba           1  2.82843    2.82843
# 629        sba       sbao           1  2.82843    2.82843
# 630        sba       sbaw           1        2          2
# 631        sba       sbae           1        2          2
# 632        sba       sbag           1  2.82843    2.82843
# 633        sbo       psbo           1  2.82843    2.68515
# 634        sbo       csbo           1  2.82843    2.82843
# 635        sbo       sbao           1  2.82843    2.82843
# 636        sbo       sbow           1        2          2
# 637        sbo       sboe           1        2          2
# 638        sbo       sbog           1  2.82843    2.82843
# 639        sbw       psbw           1  2.82843    2.68515
# 640        sbw       csbw           1  2.82843    2.82843
# 641        sbw       sbaw           1  2.82843    2.82843
# 642        sbw       sbow           1  2.82843    2.82843
# 643        sbw       sbwe           1        2          2
# 644        sbw       sbwg           1  2.82843    2.82843
# 645        sbe       psbe           1  2.82843    2.68515
# 646        sbe       csbe           1  2.82843    2.82843
# 647        sbe       sbae           1  2.82843    2.82843
# 648        sbe       sboe           1  2.82843    2.82843
# 649        sbe       sbwe           1        2          2
# 650        sbe       sbeg           1  2.82843    2.82843
# 651        sbg       psbg           1  2.82843    2.68515
# 652        sbg       csbg           1  2.82843    2.82843
# 653        sbg       sbag           1  2.82843    2.82843
# 654        sbg       sbog           1  2.82843    2.82843
# 655        sbg       sbwg           1        2          2
# 656        sbg       sbeg           1        2          2
# 657        sao       psao           1  2.82843    2.68515
# 658        sao       csao           1  2.82843    2.82843
# 659        sao       sbao           1  2.82843    2.82843
# 660        sao       saow           1        2          2
# 661        sao       saoe           1        2          2
# 662        sao       saog           1  2.82843    2.82843
# 663        saw       psaw           1  2.82843    2.68515
# 664        saw       csaw           1  2.82843    2.82843
# 665        saw       sbaw           1  2.82843    2.82843
# 666        saw       saow           1  2.82843    2.82843
# 667        saw       sawe           1        2          2
# 668        saw       sawg           1  2.82843    2.82843
# 669        sae       psae           1  2.82843    2.68515
# 670        sae       csae           1  2.82843    2.82843
# 671        sae       sbae           1  2.82843    2.82843
# 672        sae       saoe           1  2.82843    2.82843
# 673        sae       sawe           1        2          2
# 674        sae       saeg           1  2.82843    2.82843
# 675        sag       psag           1  2.82843    2.68515
# 676        sag       csag           1  2.82843    2.82843
# 677        sag       sbag           1  2.82843    2.82843
# 678        sag       saog           1  2.82843    2.82843
# 679        sag       sawg           1        2          2
# 680        sag       saeg           1        2          2
# 681        sow       psow           1  2.82843    2.68515
# 682        sow       csow           1  2.82843    2.82843
# 683        sow       sbow           1  2.82843    2.82843
# 684        sow       saow           1  2.82843    2.82843
# 685        sow       sowe           1        2          2
# 686        sow       sowg           1  2.82843    2.82843
# 687        soe       psoe           1  2.82843    2.68515
# 688        soe       csoe           1  2.82843    2.82843
# 689        soe       sboe           1  2.82843    2.82843
# 690        soe       saoe           1  2.82843    2.82843
# 691        soe       sowe           1        2          2
# 692        soe       soeg           1  2.82843    2.82843
# 693        sog       psog           1  2.82843    2.68515
# 694        sog       csog           1  2.82843    2.82843
# 695        sog       sbog           1  2.82843    2.82843
# 696        sog       saog           1  2.82843    2.82843
# 697        sog       sowg           1        2          2
# 698        sog       soeg           1        2          2
# 699        swe       pswe           1  2.82843    2.68515
# 700        swe       cswe           1  2.82843    2.82843
# 701        swe       sbwe           1  2.82843    2.82843
# 702        swe       sawe           1  2.82843    2.82843
# 703        swe       sowe           1  2.82843    2.82843
# 704        swe       sweg           1  2.82843    2.82843
# 705        swg       pswg           1  2.82843    2.68515
# 706        swg       cswg           1  2.82843    2.82843
# 707        swg       sbwg           1  2.82843    2.82843
# 708        swg       sawg           1  2.82843    2.82843
# 709        swg       sowg           1  2.82843    2.82843
# 710        swg       sweg           1        2          2
# 711        seg       pseg           1  2.82843    2.68515
# 712        seg       cseg           1  2.82843    2.82843
# 713        seg       sbeg           1  2.82843    2.82843
# 714        seg       saeg           1  2.82843    2.82843
# 715        seg       soeg           1  2.82843    2.82843
# 716        seg       sweg           1        2          2
# 717        bao       pbao           1  2.82843    2.68515
# 718        bao       cbao           1  2.82843    2.82843
# 719        bao       sbao           1  2.82843    2.82843
# 720        bao       baow           1        2          2
# 721        bao       baoe           1        2          2
# 722        bao       baog           1  2.82843    2.82843
# 723        baw       pbaw           1  2.82843    2.68515
# 724        baw       cbaw           1  2.82843    2.82843
# 725        baw       sbaw           1  2.82843    2.82843
# 726        baw       baow           1  2.82843    2.82843
# 727        baw       bawe           1        2          2
# 728        baw       bawg           1  2.82843    2.82843
# 729        bae       pbae           1  2.82843    2.68515
# 730        bae       cbae           1  2.82843    2.82843
# 731        bae       sbae           1  2.82843    2.82843
# 732        bae       baoe           1  2.82843    2.82843
# 733        bae       bawe           1        2          2
# 734        bae       baeg           1  2.82843    2.82843
# 735        bag       pbag           1  2.82843    2.68515
# 736        bag       cbag           1  2.82843    2.82843
# 737        bag       sbag           1  2.82843    2.82843
# 738        bag       baog           1  2.82843    2.82843
# 739        bag       bawg           1        2          2
# 740        bag       baeg           1        2          2
# 741        bow       pbow           1  2.82843    2.68515
# 742        bow       cbow           1  2.82843    2.82843
# 743        bow       sbow           1  2.82843    2.82843
# 744        bow       baow           1  2.82843    2.82843
# 745        bow       bowe           1        2          2
# 746        bow       bowg           1  2.82843    2.82843
# 747        boe       pboe           1  2.82843    2.68515
# 748        boe       cboe           1  2.82843    2.82843
# 749        boe       sboe           1  2.82843    2.82843
# 750        boe       baoe           1  2.82843    2.82843
# 751        boe       bowe           1        2          2
# 752        boe       boeg           1  2.82843    2.82843
# 753        bog       pbog           1  2.82843    2.68515
# 754        bog       cbog           1  2.82843    2.82843
# 755        bog       sbog           1  2.82843    2.82843
# 756        bog       baog           1  2.82843    2.82843
# 757        bog       bowg           1        2          2
# 758        bog       boeg           1        2          2
# 759        bwe       pbwe           1  2.82843    2.68515
# 760        bwe       cbwe           1  2.82843    2.82843
# 761        bwe       sbwe           1  2.82843    2.82843
# 762        bwe       bawe           1  2.82843    2.82843
# 763        bwe       bowe           1  2.82843    2.82843
# 764        bwe       bweg           1  2.82843    2.82843
# 765        bwg       pbwg           1  2.82843    2.68515
# 766        bwg       cbwg           1  2.82843    2.82843
# 767        bwg       sbwg           1  2.82843    2.82843
# 768        bwg       bawg           1  2.82843    2.82843
# 769        bwg       bowg           1  2.82843    2.82843
# 770        bwg       bweg           1        2          2
# 771        beg       pbeg           1  2.82843    2.68515
# 772        beg       cbeg           1  2.82843    2.82843
# 773        beg       sbeg           1  2.82843    2.82843
# 774        beg       baeg           1  2.82843    2.82843
# 775        beg       boeg           1  2.82843    2.82843
# 776        beg       bweg           1        2          2
# 777        aow       paow           1  2.82843    2.68515
# 778        aow       caow           1  2.82843    2.82843
# 779        aow       saow           1  2.82843    2.82843
# 780        aow       baow           1  2.82843    2.82843
# 781        aow       aowe           1        2          2
# 782        aow       aowg           1  2.82843    2.82843
# 783        aoe       paoe           1  2.82843    2.68515
# 784        aoe       caoe           1  2.82843    2.82843
# 785        aoe       saoe           1  2.82843    2.82843
# 786        aoe       baoe           1  2.82843    2.82843
# 787        aoe       aowe           1        2          2
# 788        aoe       aoeg           1  2.82843    2.82843
# 789        aog       paog           1  2.82843    2.68515
# 790        aog       caog           1  2.82843    2.82843
# 791        aog       saog           1  2.82843    2.82843
# 792        aog       baog           1  2.82843    2.82843
# 793        aog       aowg           1        2          2
# 794        aog       aoeg           1        2          2
# 795        awe       pawe           1  2.82843    2.68515
# 796        awe       cawe           1  2.82843    2.82843
# 797        awe       sawe           1  2.82843    2.82843
# 798        awe       bawe           1  2.82843    2.82843
# 799        awe       aowe           1  2.82843    2.82843
# 800        awe       aweg           1  2.82843    2.82843
# 801        awg       pawg           1  2.82843    2.68515
# 802        awg       cawg           1  2.82843    2.82843
# 803        awg       sawg           1  2.82843    2.82843
# 804        awg       bawg           1  2.82843    2.82843
# 805        awg       aowg           1  2.82843    2.82843
# 806        awg       aweg           1        2          2
# 807        aeg       paeg           1  2.82843    2.68515
# 808        aeg       caeg           1  2.82843    2.82843
# 809        aeg       saeg           1  2.82843    2.82843
# 810        aeg       baeg           1  2.82843    2.82843
# 811        aeg       aoeg           1  2.82843    2.82843
# 812        aeg       aweg           1        2          2
# 813        owe       powe           1  2.82843    2.68515
# 814        owe       cowe           1  2.82843    2.82843
# 815        owe       sowe           1  2.82843    2.82843
# 816        owe       bowe           1  2.82843    2.82843
# 817        owe       aowe           1  2.82843    2.82843
# 818        owe       oweg           1  2.82843    2.82843
# 819        owg       powg           1  2.82843    2.68515
# 820        owg       cowg           1  2.82843    2.82843
# 821        owg       sowg           1  2.82843    2.82843
# 822        owg       bowg           1  2.82843    2.82843
# 823        owg       aowg           1  2.82843    2.82843
# 824        owg       oweg           1        2          2
# 825        oeg       poeg           1  2.82843    2.68515
# ...
# 2029    pcsweg    pcsaweg           1  2.82843    2.82843
# 2030    pcsweg    pcsoweg           1  2.82843    2.82843
# 2031    pcbaow    pcsbaow           1  2.82843    2.82843
# 2032    pcbaow    pcbaowe           1        2          2
# 2033    pcbaow    pcbaowg           1  2.82843    2.82843
# 2034    pcbaoe    pcsbaoe           1  2.82843    2.82843
# 2035    pcbaoe    pcbaowe           1        2          2
# 2036    pcbaoe    pcbaoeg           1  2.82843    2.82843
# 2037    pcbaog    pcsbaog           1  2.82843    2.82843
# 2038    pcbaog    pcbaowg           1        2          2
# 2039    pcbaog    pcbaoeg           1        2          2
# 2040    pcbawe    pcsbawe           1  2.82843    2.82843
# 2041    pcbawe    pcbaowe           1  2.82843    2.82843
# 2042    pcbawe    pcbaweg           1  2.82843    2.82843
# 2043    pcbawg    pcsbawg           1  2.82843    2.82843
# 2044    pcbawg    pcbaowg           1  2.82843    2.82843
# 2045    pcbawg    pcbaweg           1        2          2
# 2046    pcbaeg    pcsbaeg           1  2.82843    2.82843
# 2047    pcbaeg    pcbaoeg           1  2.82843    2.82843
# 2048    pcbaeg    pcbaweg           1        2          2
# 2049    pcbowe    pcsbowe           1  2.82843    2.82843
# 2050    pcbowe    pcbaowe           1  2.82843    2.82843
# 2051    pcbowe    pcboweg           1  2.82843    2.82843
# 2052    pcbowg    pcsbowg           1  2.82843    2.82843
# 2053    pcbowg    pcbaowg           1  2.82843    2.82843
# 2054    pcbowg    pcboweg           1        2          2
# 2055    pcboeg    pcsboeg           1  2.82843    2.82843
# 2056    pcboeg    pcbaoeg           1  2.82843    2.82843
# 2057    pcboeg    pcboweg           1        2          2
# 2058    pcbweg    pcsbweg           1  2.82843    2.82843
# 2059    pcbweg    pcbaweg           1  2.82843    2.82843
# 2060    pcbweg    pcboweg           1  2.82843    2.82843
# 2061    pcaowe    pcsaowe           1  2.82843    2.82843
# 2062    pcaowe    pcbaowe           1  2.82843    2.82843
# 2063    pcaowe    pcaoweg           1  2.82843    2.82843
# 2064    pcaowg    pcsaowg           1  2.82843    2.82843
# 2065    pcaowg    pcbaowg           1  2.82843    2.82843
# 2066    pcaowg    pcaoweg           1        2          2
# 2067    pcaoeg    pcsaoeg           1  2.82843    2.82843
# 2068    pcaoeg    pcbaoeg           1  2.82843    2.82843
# 2069    pcaoeg    pcaoweg           1        2          2
# 2070    pcaweg    pcsaweg           1  2.82843    2.82843
# 2071    pcaweg    pcbaweg           1  2.82843    2.82843
# 2072    pcaweg    pcaoweg           1  2.82843    2.82843
# 2073    pcoweg    pcsoweg           1  2.82843    2.82843
# 2074    pcoweg    pcboweg           1  2.82843    2.82843
# 2075    pcoweg    pcaoweg           1  2.82843    2.82843
# 2076    psbaow    pcsbaow           1  2.82843    2.82843
# 2077    psbaow    psbaowe           1        2          2
# 2078    psbaow    psbaowg           1  2.82843    2.82843
# 2079    psbaoe    pcsbaoe           1  2.82843    2.82843
# 2080    psbaoe    psbaowe           1        2          2
# 2081    psbaoe    psbaoeg           1  2.82843    2.82843
# 2082    psbaog    pcsbaog           1  2.82843    2.82843
# 2083    psbaog    psbaowg           1        2          2
# 2084    psbaog    psbaoeg           1        2          2
# 2085    psbawe    pcsbawe           1  2.82843    2.82843
# 2086    psbawe    psbaowe           1  2.82843    2.82843
# 2087    psbawe    psbaweg           1  2.82843    2.82843
# 2088    psbawg    pcsbawg           1  2.82843    2.82843
# 2089    psbawg    psbaowg           1  2.82843    2.82843
# 2090    psbawg    psbaweg           1        2          2
# 2091    psbaeg    pcsbaeg           1  2.82843    2.82843
# 2092    psbaeg    psbaoeg           1  2.82843    2.82843
# 2093    psbaeg    psbaweg           1        2          2
# 2094    psbowe    pcsbowe           1  2.82843    2.82843
# 2095    psbowe    psbaowe           1  2.82843    2.82843
# 2096    psbowe    psboweg           1  2.82843    2.82843
# 2097    psbowg    pcsbowg           1  2.82843    2.82843
# 2098    psbowg    psbaowg           1  2.82843    2.82843
# 2099    psbowg    psboweg           1        2          2
# 2100    psboeg    pcsboeg           1  2.82843    2.82843
# 2101    psboeg    psbaoeg           1  2.82843    2.82843
# 2102    psboeg    psboweg           1        2          2
# 2103    psbweg    pcsbweg           1  2.82843    2.82843
# 2104    psbweg    psbaweg           1  2.82843    2.82843
# 2105    psbweg    psboweg           1  2.82843    2.82843
# 2106    psaowe    pcsaowe           1  2.82843    2.82843
# 2107    psaowe    psbaowe           1  2.82843    2.82843
# 2108    psaowe    psaoweg           1  2.82843    2.82843
# 2109    psaowg    pcsaowg           1  2.82843    2.82843
# 2110    psaowg    psbaowg           1  2.82843    2.82843
# 2111    psaowg    psaoweg           1        2          2
# 2112    psaoeg    pcsaoeg           1  2.82843    2.82843
# 2113    psaoeg    psbaoeg           1  2.82843    2.82843
# 2114    psaoeg    psaoweg           1        2          2
# 2115    psaweg    pcsaweg           1  2.82843    2.82843
# 2116    psaweg    psbaweg           1  2.82843    2.82843
# 2117    psaweg    psaoweg           1  2.82843    2.82843
# 2118    psoweg    pcsoweg           1  2.82843    2.82843
# 2119    psoweg    psboweg           1  2.82843    2.82843
# 2120    psoweg    psaoweg           1  2.82843    2.82843
# 2121    pbaowe    pcbaowe           1  2.82843    2.82843
# 2122    pbaowe    psbaowe           1  2.82843    2.82843
# 2123    pbaowe    pbaoweg           1  2.82843    2.82843
# 2124    pbaowg    pcbaowg           1  2.82843    2.82843
# 2125    pbaowg    psbaowg           1  2.82843    2.82843
# 2126    pbaowg    pbaoweg           1        2          2
# 2127    pbaoeg    pcbaoeg           1  2.82843    2.82843
# 2128    pbaoeg    psbaoeg           1  2.82843    2.82843
# 2129    pbaoeg    pbaoweg           1        2          2
# 2130    pbaweg    pcbaweg           1  2.82843    2.82843
# 2131    pbaweg    psbaweg           1  2.82843    2.82843
# 2132    pbaweg    pbaoweg           1  2.82843    2.82843
# 2133    pboweg    pcboweg           1  2.82843    2.82843
# 2134    pboweg    psboweg           1  2.82843    2.82843
# 2135    pboweg    pbaoweg           1  2.82843    2.82843
# 2136    paoweg    pcaoweg           1  2.82843    2.82843
# 2137    paoweg    psaoweg           1  2.82843    2.82843
# 2138    paoweg    pbaoweg           1  2.82843    2.82843
# 2139    csbaow    pcsbaow           1  2.82843    2.68515
# 2140    csbaow    csbaowe           1        2          2
# 2141    csbaow    csbaowg           1  2.82843    2.82843
# 2142    csbaoe    pcsbaoe           1  2.82843    2.68515
# 2143    csbaoe    csbaowe           1        2          2
# 2144    csbaoe    csbaoeg           1  2.82843    2.82843
# 2145    csbaog    pcsbaog           1  2.82843    2.68515
# 2146    csbaog    csbaowg           1        2          2
# 2147    csbaog    csbaoeg           1        2          2
# 2148    csbawe    pcsbawe           1  2.82843    2.68515
# 2149    csbawe    csbaowe           1  2.82843    2.82843
# 2150    csbawe    csbaweg           1  2.82843    2.82843
# 2151    csbawg    pcsbawg           1  2.82843    2.68515
# 2152    csbawg    csbaowg           1  2.82843    2.82843
# 2153    csbawg    csbaweg           1        2          2
# 2154    csbaeg    pcsbaeg           1  2.82843    2.68515
# 2155    csbaeg    csbaoeg           1  2.82843    2.82843
# 2156    csbaeg    csbaweg           1        2          2
# 2157    csbowe    pcsbowe           1  2.82843    2.68515
# 2158    csbowe    csbaowe           1  2.82843    2.82843
# 2159    csbowe    csboweg           1  2.82843    2.82843
# 2160    csbowg    pcsbowg           1  2.82843    2.68515
# 2161    csbowg    csbaowg           1  2.82843    2.82843
# 2162    csbowg    csboweg           1        2          2
# 2163    csboeg    pcsboeg           1  2.82843    2.68515
# 2164    csboeg    csbaoeg           1  2.82843    2.82843
# 2165    csboeg    csboweg           1        2          2
# 2166    csbweg    pcsbweg           1  2.82843    2.68515
# 2167    csbweg    csbaweg           1  2.82843    2.82843
# 2168    csbweg    csboweg           1  2.82843    2.82843
# 2169    csaowe    pcsaowe           1  2.82843    2.68515
# 2170    csaowe    csbaowe           1  2.82843    2.82843
# 2171    csaowe    csaoweg           1  2.82843    2.82843
# 2172    csaowg    pcsaowg           1  2.82843    2.68515
# 2173    csaowg    csbaowg           1  2.82843    2.82843
# 2174    csaowg    csaoweg           1        2          2
# 2175    csaoeg    pcsaoeg           1  2.82843    2.68515
# 2176    csaoeg    csbaoeg           1  2.82843    2.82843
# 2177    csaoeg    csaoweg           1        2          2
# 2178    csaweg    pcsaweg           1  2.82843    2.68515
# 2179    csaweg    csbaweg           1  2.82843    2.82843
# 2180    csaweg    csaoweg           1  2.82843    2.82843
# 2181    csoweg    pcsoweg           1  2.82843    2.68515
# 2182    csoweg    csboweg           1  2.82843    2.82843
# 2183    csoweg    csaoweg           1  2.82843    2.82843
# 2184    cbaowe    pcbaowe           1  2.82843    2.68515
# 2185    cbaowe    csbaowe           1  2.82843    2.82843
# 2186    cbaowe    cbaoweg           1  2.82843    2.82843
# 2187    cbaowg    pcbaowg           1  2.82843    2.68515
# 2188    cbaowg    csbaowg           1  2.82843    2.82843
# 2189    cbaowg    cbaoweg           1        2          2
# 2190    cbaoeg    pcbaoeg           1  2.82843    2.68515
# 2191    cbaoeg    csbaoeg           1  2.82843    2.82843
# 2192    cbaoeg    cbaoweg           1        2          2
# 2193    cbaweg    pcbaweg           1  2.82843    2.68515
# 2194    cbaweg    csbaweg           1  2.82843    2.82843
# 2195    cbaweg    cbaoweg           1  2.82843    2.82843
# 2196    cboweg    pcboweg           1  2.82843    2.68515
# 2197    cboweg    csboweg           1  2.82843    2.82843
# 2198    cboweg    cbaoweg           1  2.82843    2.82843
# 2199    caoweg    pcaoweg           1  2.82843    2.68515
# 2200    caoweg    csaoweg           1  2.82843    2.82843
# 2201    caoweg    cbaoweg           1  2.82843    2.82843
# 2202    sbaowe    psbaowe           1  2.82843    2.68515
# 2203    sbaowe    csbaowe           1  2.82843    2.82843
# 2204    sbaowe    sbaoweg           1  2.82843    2.82843
# 2205    sbaowg    psbaowg           1  2.82843    2.68515
# 2206    sbaowg    csbaowg           1  2.82843    2.82843
# 2207    sbaowg    sbaoweg           1        2          2
# 2208    sbaoeg    psbaoeg           1  2.82843    2.68515
# 2209    sbaoeg    csbaoeg           1  2.82843    2.82843
# 2210    sbaoeg    sbaoweg           1        2          2
# 2211    sbaweg    psbaweg           1  2.82843    2.68515
# 2212    sbaweg    csbaweg           1  2.82843    2.82843
# 2213    sbaweg    sbaoweg           1  2.82843    2.82843
# 2214    sboweg    psboweg           1  2.82843    2.68515
# 2215    sboweg    csboweg           1  2.82843    2.82843
# 2216    sboweg    sbaoweg           1  2.82843    2.82843
# 2217    saoweg    psaoweg           1  2.82843    2.68515
# 2218    saoweg    csaoweg           1  2.82843    2.82843
# 2219    saoweg    sbaoweg           1  2.82843    2.82843
# 2220    baoweg    pbaoweg           1  2.82843    2.68515
# 2221    baoweg    cbaoweg           1  2.82843    2.82843
# 2222    baoweg    sbaoweg           1  2.82843    2.82843
# 2223   pcsbaow   pcsbaowe           1        2          2
# 2224   pcsbaow   pcsbaowg           1  2.82843    2.82843
# 2225   pcsbaoe   pcsbaowe           1        2          2
# 2226   pcsbaoe   pcsbaoeg           1  2.82843    2.82843
# 2227   pcsbaog   pcsbaowg           1        2          2
# 2228   pcsbaog   pcsbaoeg           1        2          2
# 2229   pcsbawe   pcsbaowe           1  2.82843    2.82843
# 2230   pcsbawe   pcsbaweg           1  2.82843    2.82843
# 2231   pcsbawg   pcsbaowg           1  2.82843    2.82843
# 2232   pcsbawg   pcsbaweg           1        2          2
# 2233   pcsbaeg   pcsbaoeg           1  2.82843    2.82843
# 2234   pcsbaeg   pcsbaweg           1        2          2
# 2235   pcsbowe   pcsbaowe           1  2.82843    2.82843
# 2236   pcsbowe   pcsboweg           1  2.82843    2.82843
# 2237   pcsbowg   pcsbaowg           1  2.82843    2.82843
# 2238   pcsbowg   pcsboweg           1        2          2
# 2239   pcsboeg   pcsbaoeg           1  2.82843    2.82843
# 2240   pcsboeg   pcsboweg           1        2          2
# 2241   pcsbweg   pcsbaweg           1  2.82843    2.82843
# 2242   pcsbweg   pcsboweg           1  2.82843    2.82843
# 2243   pcsaowe   pcsbaowe           1  2.82843    2.82843
# 2244   pcsaowe   pcsaoweg           1  2.82843    2.82843
# 2245   pcsaowg   pcsbaowg           1  2.82843    2.82843
# 2246   pcsaowg   pcsaoweg           1        2          2
# 2247   pcsaoeg   pcsbaoeg           1  2.82843    2.82843
# 2248   pcsaoeg   pcsaoweg           1        2          2
# 2249   pcsaweg   pcsbaweg           1  2.82843    2.82843
# 2250   pcsaweg   pcsaoweg           1  2.82843    2.82843
# 2251   pcsoweg   pcsboweg           1  2.82843    2.82843
# 2252   pcsoweg   pcsaoweg           1  2.82843    2.82843
# 2253   pcbaowe   pcsbaowe           1  2.82843    2.82843
# 2254   pcbaowe   pcbaoweg           1  2.82843    2.82843
# 2255   pcbaowg   pcsbaowg           1  2.82843    2.82843
# 2256   pcbaowg   pcbaoweg           1        2          2
# 2257   pcbaoeg   pcsbaoeg           1  2.82843    2.82843
# 2258   pcbaoeg   pcbaoweg           1        2          2
# 2259   pcbaweg   pcsbaweg           1  2.82843    2.82843
# 2260   pcbaweg   pcbaoweg           1  2.82843    2.82843
# 2261   pcboweg   pcsboweg           1  2.82843    2.82843
# 2262   pcboweg   pcbaoweg           1  2.82843    2.82843
# 2263   pcaoweg   pcsaoweg           1  2.82843    2.82843
# 2264   pcaoweg   pcbaoweg           1  2.82843    2.82843
# 2265   psbaowe   pcsbaowe           1  2.82843    2.82843
# 2266   psbaowe   psbaoweg           1  2.82843    2.82843
# 2267   psbaowg   pcsbaowg           1  2.82843    2.82843
# 2268   psbaowg   psbaoweg           1        2          2
# 2269   psbaoeg   pcsbaoeg           1  2.82843    2.82843
# 2270   psbaoeg   psbaoweg           1        2          2
# 2271   psbaweg   pcsbaweg           1  2.82843    2.82843
# 2272   psbaweg   psbaoweg           1  2.82843    2.82843
# 2273   psboweg   pcsboweg           1  2.82843    2.82843
# 2274   psboweg   psbaoweg           1  2.82843    2.82843
# 2275   psaoweg   pcsaoweg           1  2.82843    2.82843
# 2276   psaoweg   psbaoweg           1  2.82843    2.82843
# 2277   pbaoweg   pcbaoweg           1  2.82843    2.82843
# 2278   pbaoweg   psbaoweg           1  2.82843    2.82843
# 2279   csbaowe   pcsbaowe           1  2.82843    2.68515
# 2280   csbaowe   csbaoweg           1  2.82843    2.82843
# 2281   csbaowg   pcsbaowg           1  2.82843    2.68515
# 2282   csbaowg   csbaoweg           1        2          2
# 2283   csbaoeg   pcsbaoeg           1  2.82843    2.68515
# 2284   csbaoeg   csbaoweg           1        2          2
# 2285   csbaweg   pcsbaweg           1  2.82843    2.68515
# 2286   csbaweg   csbaoweg           1  2.82843    2.82843
# 2287   csboweg   pcsboweg           1  2.82843    2.68515
# 2288   csboweg   csbaoweg           1  2.82843    2.82843
# 2289   csaoweg   pcsaoweg           1  2.82843    2.68515
# 2290   csaoweg   csbaoweg           1  2.82843    2.82843
# 2291   cbaoweg   pcbaoweg           1  2.82843    2.68515
# 2292   cbaoweg   csbaoweg           1  2.82843    2.82843
# 2293   sbaoweg   psbaoweg           1  2.82843    2.68515
# 2294   sbaoweg   csbaoweg           1  2.82843    2.82843
# 2295  pcsbaowe  pcsbaoweg           1  2.82843    2.82843
# 2296  pcsbaowg  pcsbaoweg           1        2          2
# 2297  pcsbaoeg  pcsbaoweg           1        2          2
# 2298  pcsbaweg  pcsbaoweg           1  2.82843    2.82843
# 2299  pcsboweg  pcsbaoweg           1  2.82843    2.82843
# 2300  pcsaoweg  pcsbaoweg           1  2.82843    2.82843
# 2301  pcbaoweg  pcsbaoweg           1  2.82843    2.82843
# 2302  psbaoweg  pcsbaoweg           1  2.82843    2.82843
# 2303  csbaoweg  pcsbaoweg           1  2.82843    2.68515
