# %%
import pandas as pd
import numpy as np
import itertools
import random
import ast
import matplotlib
import matplotlib.pyplot as plt
from scipy.stats import spearmanr, wilcoxon, friedmanchisquare, kendalltau, pearsonr
from matplotlib import animation
from mpl_toolkits import mplot3d
from scipy.spatial import distance
from pyxdameraulevenshtein import damerau_levenshtein_distance

pd.set_option('display.max_rows', 500)

# %% [markdown]
# ### Prepare Data

# %%
# read data, skip row that can't be clustered

df = pd.read_csv('automatica_task_environments_clustered_drawers.csv', header=0,
                 skiprows=[29,49,57], skip_blank_lines=True ,nrows=80)

# %%
df
# Out:
#      ID              sequence_original  \
# 0     1                         pocgkr
# 1     3                    cgwpcffkkss
# 2     5                  kfsfksppwwggg
# 3    11              ppfkswwkfsococggg
# 4    13                      wptgkfsoc
# 5    16                pppwwwfffkkkggg
# 6    19                   ppoowwcceerr
# 7    22                    cooppreerkk
# 8    26                wwoppoffkkssskf
# 9    29                      opwpwgcoc
# 10   31                 ppooccrrfksfks
# 11   35                       cgpogpoc
# 12   37           ppwwooccggfkkfssrere
# 13   39                         ocwgrk
# 14   40                         wpgsfk
# 15   43                         pwofsg
# 16   45             ppocpocwwwgggkkkfs
# 17   47                     ppooccgwwg
# 18   51          ppwwggoocckfsfksrreet
# 19   55           ooccppwwggfkskfsrere
# 20   56              cccoooppwwgwpresk
# 21   59                  ppwwteerrfkkf
# 22   60           pooccwwggpfkfkssreer
# 23   61             wpofcgkrpwgfkssocr
# 24   69               ccwwppffkkssoorr
# 25   73               ppwwffkkssoorrcc
# 26   76           ppooccggwwkfkfsseerr
# 27   77                    ppowwctgcog
# 28   80                   ppoowwggccpo
# 29   85                      ppwwffkkt
# 30   87                 ppwwookffkrrgg
# 31   89             copcogpgwwffkkssrr
# 32   93                     ppgsfkskfg
# 33   99               wgptocccooppwwgg
# 34  100                 ppoowwccggrree
# 35  102                     perkscwgtf
# 36  106             ppccggwwoorrkfkfss
# 37  108                   popoccggkkrr
# 38  109                pwtggccfkfkssrr
# 39  114                   ppooccwwkkff
# 40  116                      ppgggkfkf
# 41  118                          cwopg
# 42  120               ppoowwccggkfkfrr
# 43  128                   wwppggffkssk
# 44  131                    pocwcpoerre
# 45  137                           pwkf
# 46  142                          cptgo
# 47  149             ppooccffkksswwggrr
# 48  152                   ppoowwccfkfk
# 49  153                   ppwwggfkssfk
# 50  156                   ggppwwffkkss
# 51  158                          cgwpw
# 52  161  cccwwwooopppgggtrreekfkskssff
# 53  164                        pocsfkw
# 54  172                 ooccppwwggfkkf
# 55  174          ppwwggteerrkkffssoocc
# 56  177                      pocgwrkfs
# 57  178                        tgcwpro
# 58  180              ppooccgggkfsskfrr
# 59  185                     ppggccooww
# 60  187                           opwg
# 61  191                 wpgcoowpcfksre
# 62  195                             re
# 63  198                  pptwwggffkkss
# 64  201                   ppooccrrfkfk
# 65  205                     ppoocckkrr
# 66  209           ppoocckfskfswwggrree
# 67  212               tgpcowpgpwwccoog
# 68  215                       gwpfrkst
# 69  218                     ppfkfkssgg
# 70  220                 ppwwoogssffkkg
# 71  222                       ppwwkkff
# 72  223               gwwppooccoskfsfk
# 73  226                  wwtppcoockfkf
# 74  229                 wwppggfkfkrree
# 75  231              ppococwwtrrfkfkgg
# 76  233               ppwwooccfksfksrr
# 77  235                 ppwwggeerrkkss
# 78  239               ppoocctfkfkrrwwg
# 79  240               ppwwffkkssooccrr
#
#                                      objects_original sequence_no_duplicates  \
# 0                                         p,o,c,g,k,r                 pocgkr
# 1                               c,g,w,p,c,f,f,k,k,s,s               cgwpcfks
# 2                           k,f,s,f,k,s,p,p,w,w,g,g,g              kfsfkspwg
# 3                   p,p,f,k,s,w,w,k,f,s,o,c,o,c,g,g,g          pfkswkfsococg
# 4                                   w,p,t,g,k,f,s,o,c              wptgkfsoc
# 5                                           p,w,f,k,g                  pwfkg
# 6                                         p,o,w,c,e,r                 powcer
# 7                               c,o,o,p,p,r,e,e,r,k,k                coprerk
# 8                       w,w,o,p,p,o,f,f,k,k,s,s,s,k,f             wopofkkskf
# 9                                   o,p,w,p,w,g,c,o,c              opwpwgcoc
# 10                        p,p,o,o,c,c,r,r,f,k,s,f,k,s             pocrfksfks
# 11                                    c,g,p,o,g,p,o,c               cgpogpoc
# 12            p,p,w,w,o,o,c,c,g,g,f,k,k,f,s,s,r,e,r,e          pwocgfkfsrere
# 13                                        o,c,w,g,r,k                 ocwgrk
# 14                                        w,p,g,s,f,k                 wpgsfk
# 15                                        p,w,o,f,s,g                 pwofsg
# 16                p,p,o,c,p,o,c,w,w,w,g,g,g,k,k,k,f,s            pocpocwgkfs
# 17                                p,p,o,o,c,c,g,w,w,g                 pocgwg
# 18          p,p,w,w,g,g,o,o,c,c,k,f,s,f,k,s,r,r,e,e,t         pwgockfsfksret
# 19            o,o,c,c,p,p,w,w,g,g,f,k,s,k,f,s,r,e,r,e        ocpwgfkskfsrere
# 20                  c,c,c,o,o,o,p,p,w,w,g,w,p,r,e,s,k            copwgwpresk
# 21                          p,p,w,w,t,e,e,r,r,f,k,k,f               pwterfkf
# 22            p,o,o,c,c,w,w,g,g,p,f,k,f,k,s,s,r,e,e,r        pocwggpfkfksrer
# 23                w,p,o,f,c,g,k,r,p,w,g,f,k,s,s,o,c,r      wpofcgkrpwgfksocr
# 24                                    c,w,p,f,k,s,o,r               cwpfksor
# 25                                    p,w,f,k,s,o,r,c               pwfksorc
# 26            p,p,o,o,c,c,g,g,w,w,k,f,k,f,s,s,e,e,r,r           pocgwkfkfser
# 27                              p,p,o,w,w,c,t,g,c,o,g              powctgcog
# 28                            p,p,o,o,w,w,g,g,c,c,p,o                powgcpo
# 29                                          p,w,f,k,t                  pwfkt
# 30                        p,p,w,w,o,o,k,f,f,k,r,r,g,g               pwokfkrg
# 31                c,o,p,c,o,g,p,g,w,w,f,f,k,k,s,s,r,r          copcogpgwfksr
# 32                                p,p,g,s,f,k,s,k,f,g              pgsfkskfg
# 33                    w,g,p,t,o,c,c,c,o,o,p,p,w,w,g,g             wgptocopwg
# 34                                      p,o,w,c,g,r,e                powcgre
# 35                                p,e,r,k,s,c,w,g,t,f             perkscwgtf
# 36                p,p,c,c,g,g,w,w,o,o,r,r,k,f,k,f,s,s            pcgworkfkfs
# 37                            p,o,p,o,c,c,g,g,k,k,r,r               popocgkr
# 38                      p,w,t,g,g,c,c,f,k,f,k,s,s,r,r            pwtgcfkfksr
# 39                                        p,o,c,w,k,f                 pocwkf
# 40                                  p,p,g,g,g,k,f,k,f                 pgkfkf
# 41                                          c,w,o,p,g                  cwopg
# 42                    p,p,o,o,w,w,c,c,g,g,k,f,k,f,r,r             powcgkfkfr
# 43                            w,w,p,p,g,g,f,f,k,s,s,k                wpgfksk
# 44                              p,o,c,w,c,p,o,e,r,r,e             pocwcpoere
# 45                                            p,w,k,f                   pwkf
# 46                                          c,p,t,g,o                  cptgo
# 47                p,p,o,o,c,c,f,f,k,k,s,s,w,w,g,g,r,r              pocfkswgr
# 48                            p,p,o,o,w,w,c,c,f,k,f,k               powcfkfk
# 49                            p,p,w,w,g,g,f,k,s,s,f,k               pwgfksfk
# 50                                        g,p,w,f,k,s                 gpwfks
# 51                                          c,g,w,p,w                  cgwpw
# 52  c,c,c,w,w,w,o,o,o,p,p,p,g,g,g,t,r,r,e,e,k,f,k,...        cwopgtrekfksksf
# 53                                      p,o,c,s,f,k,w                pocsfkw
# 54                        o,o,c,c,p,p,w,w,g,g,f,k,k,f               ocpwgfkf
# 55          p,p,w,w,g,g,t,e,e,r,r,k,k,f,f,s,s,o,o,c,c            pwgterkfsoc
# 56                                  p,o,c,g,w,r,k,f,s              pocgwrkfs
# 57                                      t,g,c,w,p,r,o                tgcwpro
# 58                  p,p,o,o,c,c,g,g,g,k,f,s,s,k,f,r,r             pocgkfskfr
# 59                                          p,g,c,o,w                  pgcow
# 60                                            o,p,w,g                   opwg
# 61                        w,p,g,c,o,o,w,p,c,f,k,s,r,e          wpgcowpcfksre
# 62                                                r,e                     re
# 63                                      p,t,w,g,f,k,s                ptwgfks
# 64                            p,p,o,o,c,c,r,r,f,k,f,k               pocrfkfk
# 65                                          p,o,c,k,r                  pockr
# 66            p,p,o,o,c,c,k,f,s,k,f,s,w,w,g,g,r,r,e,e          pockfskfswgre
# 67                    t,g,p,c,o,w,p,g,p,w,w,c,c,o,o,g          tgpcowpgpwcog
# 68                                    g,w,p,f,r,k,s,t               gwpfrkst
# 69                                p,p,f,k,f,k,s,s,g,g                pfkfksg
# 70                        p,p,w,w,o,o,g,s,s,f,f,k,k,g               pwogsfkg
# 71                                            p,w,k,f                   pwkf
# 72                    g,w,w,p,p,o,o,c,c,o,s,k,f,s,f,k           gwpocoskfsfk
# 73                          w,w,t,p,p,c,o,o,c,k,f,k,f             wtpcockfkf
# 74                        w,w,p,p,g,g,f,k,f,k,r,r,e,e              wpgfkfkre
# 75                  p,p,o,c,o,c,w,w,t,r,r,f,k,f,k,g,g          pococwtrfkfkg
# 76                    p,p,w,w,o,o,c,c,f,k,s,f,k,s,r,r            pwocfksfksr
# 77                                      p,w,g,e,r,k,s                pwgerks
# 78                    p,p,o,o,c,c,t,f,k,f,k,r,r,w,w,g            poctfkfkrwg
# 79                                    p,w,f,k,s,o,c,r               pwfksocr
#
#    objects_no_duplicates target_clustered_multiple_items  \
# 0                 pocgkr                           pocgz
# 1               cgwpcfks                          cgwpdz
# 2              kfsfkspwg                            zpwg
# 3          pfkswkfsococg             pzwyocndg,pywzocndg
# 4              wptgkfsoc                         wptgzoc
# 5                  pwfkg                            pwzg
# 6                 powcer                           powcz
# 7                coprerk                            copz
# 8             wopofkkskf                           wopnz
# 9              opwpwgcoc                       opwqxgcnd
# 10            pocrfksfks                            pocz
# 11              cgpogpoc                        cgpohqnd
# 12         pwocgfkfsrere                          pwocgz
# 13                ocwgrk                           ocwgz
# 14                wpgsfk                            wpgz
# 15                pwofsg                           pwozg
# 16           pocpocwgkfs                       pocqndwgz
# 17                pocgwg                          pocgwh
# 18        pwgockfsfksret                         pwgoczt
# 19       ocpwgfkskfsrere                          ocpwgz
# 20           copwgwpresk                        copwgxqz
# 21              pwterfkf                            pwtz
# 22       pocwggpfkfksrer                         pocwgqz
# 23     wpofcgkrpwgfksocr  wpozcgyqxhandb,wpoycgzqxhandb
# 24              cwpfksor                   cwpzoy,cwpyoz
# 25              pwfksorc                   pwzoyc,pwyozc
# 26          pocgwkfkfser                          pocgwz
# 27             powctgcog                       powctgdnh
# 28               powgcpo                         powgcqn
# 29                 pwfkt                            pwzt
# 30              pwokfkrg                           pwozg
# 31         copcogpgwfksr                      copdngqhwz
# 32             pgsfkskfg                            pgzh
# 33            wgptocopwg                      wgptocnqxh
# 34               powcgre                          powcgz
# 35            perkscwgtf                 pzcwgty,pycwgtz
# 36           pcgworkfkfs                          pcgwoz
# 37              popocgkr                         poqncgz
# 38           pwtgcfkfksr                          pwtgcz
# 39                pocwkf                           pocwz
# 40                pgkfkf                             pgz
# 41                 cwopg                           cwopg
# 42            powcgkfkfr                          powcgz
# 43               wpgfksk                            wpgz
# 44            pocwcpoere                        pocwdqnz
# 45                  pwkf                             pwz
# 46                 cptgo                           cptgo
# 47             pocfkswgr                 poczwgy,pocywgz
# 48              powcfkfk                           powcz
# 49              pwgfksfk                            pwgz
# 50                gpwfks                            gpwz
# 51                 cgwpw                           cgwpx
# 52       cwopgtrekfksksf                         cwopgtz
# 53               pocsfkw                           poczw
# 54              ocpwgfkf                          ocpwgz
# 55           pwgterkfsoc                         pwgtzoc
# 56             pocgwrkfs                          pocgwz
# 57               tgcwpro                         tgcwpzo
# 58            pocgkfskfr                           pocgz
# 59                 pgcow                           pgcow
# 60                  opwg                            opwg
# 61         wpgcowpcfksre                       wpgcoxqdz
# 62                    re                              re
# 63               ptwgfks                           ptwgz
# 64              pocrfkfk                            pocz
# 65                 pockr                            pocz
# 66         pockfskfswgre                 poczwgy,pocywgz
# 67         tgpcowpgpwcog                   tgpcowqhmxdni
# 68              gwpfrkst                           gwpzt
# 69               pfkfksg                             pzg
# 70              pwogsfkg                          pwogzh
# 71                  pwkf                             pwz
# 72          gwpocoskfsfk                         gwpocnz
# 73            wtpcockfkf                         wtpcodz
# 74             wpgfkfkre                            wpgz
# 75         pococwtrfkfkg                       pocndwtzg
# 76           pwocfksfksr                           pwocz
# 77               pwgerks                            pwgz
# 78           poctfkfkrwg                         poctzwg
# 79              pwfksocr                   pwzocy,pwyocz
#
#    sequence_clustered_silverware objects_clustered_silverware  \
# 0                          pocgz                    p,o,c,g,z
# 1                         cgwpdz                  c,g,w,p,d,z
# 2                           zpwg                      z,p,w,g
# 3                      pzwyocndg            p,z,w,y,o,c,n,d,g
# 4                        wptgzoc                w,p,t,g,z,o,c
# 5                           pwzg                      p,w,z,g
# 6                          powcz                    p,o,w,c,z
# 7                           copz                      c,o,p,z
# 8                          wopnz                    w,o,p,n,z
# 9                      opwqxgcnd            o,p,w,q,x,g,c,n,d
# 10                          pocz                      p,o,c,z
# 11                      cgpohqnd              c,g,p,o,h,q,n,d
# 12                        pwocgz                  p,w,o,c,g,z
# 13                         ocwgz                    o,c,w,g,z
# 14                          wpgz                      w,p,g,z
# 15                         pwozg                    p,w,o,z,g
# 16                     pocqndwgz            p,o,c,q,n,d,w,g,z
# 17                        pocgwh                  p,o,c,g,w,h
# 18                       pwgoczt                p,w,g,o,c,z,t
# 19                        ocpwgz                  o,c,p,w,g,z
# 20                      copwgxqz              c,o,p,w,g,x,q,z
# 21                          pwtz                      p,w,t,z
# 22                       pocwgqz                p,o,c,w,g,q,z
# 23                wpozcgyqxhandb  w,p,o,z,c,g,y,q,x,h,a,n,d,b
# 24                        cwpzoy                  c,w,p,z,o,y
# 25                        pwzoyc                  p,w,z,o,y,c
# 26                        pocgwz                  p,o,c,g,w,z
# 27                     powctgdnh            p,o,w,c,t,g,d,n,h
# 28                       powgcqn                p,o,w,g,c,q,n
# 29                          pwzt                      p,w,z,t
# 30                         pwozg                    p,w,o,z,g
# 31                    copdngqhwz          c,o,p,d,n,g,q,h,w,z
# 32                          pgzh                      p,g,z,h
# 33                    wgptocnqxh          w,g,p,t,o,c,n,q,x,h
# 34                        powcgz                  p,o,w,c,g,z
# 35                       pzcwgty                p,z,c,w,g,t,y
# 36                        pcgwoz                  p,c,g,w,o,z
# 37                       poqncgz                p,o,q,n,c,g,z
# 38                        pwtgcz                  p,w,t,g,c,z
# 39                         pocwz                    p,o,c,w,z
# 40                           pgz                        p,g,z
# 41                         cwopg                    c,w,o,p,g
# 42                        powcgz                  p,o,w,c,g,z
# 43                          wpgz                      w,p,g,z
# 44                      pocwdqnz              p,o,c,w,d,q,n,z
# 45                           pwz                        p,w,z
# 46                         cptgo                    c,p,t,g,o
# 47                       poczwgy                p,o,c,z,w,g,y
# 48                         powcz                    p,o,w,c,z
# 49                          pwgz                      p,w,g,z
# 50                          gpwz                      g,p,w,z
# 51                         cgwpx                    c,g,w,p,x
# 52                       cwopgtz                c,w,o,p,g,t,z
# 53                         poczw                    p,o,c,z,w
# 54                        ocpwgz                  o,c,p,w,g,z
# 55                       pwgtzoc                p,w,g,t,z,o,c
# 56                        pocgwz                  p,o,c,g,w,z
# 57                       tgcwpzo                t,g,c,w,p,z,o
# 58                         pocgz                    p,o,c,g,z
# 59                         pgcow                    p,g,c,o,w
# 60                          opwg                      o,p,w,g
# 61                     wpgcoxqdz            w,p,g,c,o,x,q,d,z
# 62                            re                          r,e
# 63                         ptwgz                    p,t,w,g,z
# 64                          pocz                      p,o,c,z
# 65                          pocz                      p,o,c,z
# 66                       poczwgy                p,o,c,z,w,g,y
# 67                 tgpcowqhmxdni    t,g,p,c,o,w,q,h,m,x,d,n,i
# 68                         gwpzt                    g,w,p,z,t
# 69                           pzg                        p,z,g
# 70                        pwogzh                  p,w,o,g,z,h
# 71                           pwz                        p,w,z
# 72                       gwpocnz                g,w,p,o,c,n,z
# 73                       wtpcodz                w,t,p,c,o,d,z
# 74                          wpgz                      w,p,g,z
# 75                     pocndwtzg            p,o,c,n,d,w,t,z,g
# 76                         pwocz                    p,w,o,c,z
# 77                          pwgz                      p,w,g,z
# 78                       poctzwg                p,o,c,t,z,w,g
# 79                        pwzocy                  p,w,z,o,c,y
#
#    sequence_clustered_drawers      objects_clustered_drawers  ... strong_k  \
# 0                      pocgba                    p,o,c,g,b,a  ...        t
# 1                      cgwpdb                    c,g,w,p,d,b  ...        t
# 2                        bpwg                        b,p,w,g  ...        t
# 3                   pbwbocndg              p,b,w,b,o,c,n,d,g  ...        t
# 4                     wptgboc                  w,p,t,g,b,o,c  ...        t
# 5                        pwbg                        p,w,b,g  ...        t
# 6                       powca                      p,o,w,c,a  ...        t
# 7                       copab                      c,o,p,a,b  ...        t
# 8                       wopnb                      w,o,p,n,b  ...        t
# 9                   opwqxgcnd              o,p,w,q,x,g,c,n,d  ...        t
# 10                      pocab                      p,o,c,a,b  ...        t
# 11                   cgpohqnd                c,g,p,o,h,q,n,d  ...        t
# 12                    pwocgba                  p,w,o,c,g,b,a  ...        t
# 13                     ocwgab                    o,c,w,g,a,b  ...        t
# 14                       wpgb                        w,p,g,b  ...        t
# 15                      pwobg                      p,w,o,b,g  ...        t
# 16                  pocqndwgb              p,o,c,q,n,d,w,g,b  ...        t
# 17                     pocgwh                    p,o,c,g,w,h  ...        t
# 18                   pwgocbat                p,w,g,o,c,b,a,t  ...        t
# 19                    ocpwgba                  o,c,p,w,g,b,a  ...        t
# 20                  copwgxqab              c,o,p,w,g,x,q,a,b  ...        t
# 21                      pwtab                      p,w,t,a,b  ...        t
# 22                   pocwgqba                p,o,c,w,g,q,b,a  ...        t
# 23            wpobcgbaqxhbnda  w,p,o,b,c,g,b,a,q,x,h,b,n,d,a  ...        t
# 24                     cwpboa                    c,w,p,b,o,a  ...        t
# 25                     pwboac                    p,w,b,o,a,c  ...        t
# 26                    pocgwba                  p,o,c,g,w,b,a  ...        t
# 27                  powctgdnh              p,o,w,c,t,g,d,n,h  ...        t
# 28                    powgcqn                  p,o,w,g,c,q,n  ...        t
# 29                       pwbt                        p,w,b,t  ...        t
# 30                     pwobag                    p,w,o,b,a,g  ...        t
# 31                copdngqhwba          c,o,p,d,n,g,q,h,w,b,a  ...        t
# 32                       pgbh                        p,g,b,h  ...        t
# 33                 wgptocnqxh            w,g,p,t,o,c,n,q,x,h  ...        t
# 34                     powcga                    p,o,w,c,g,a  ...        t
# 35                   pabcwgtb                p,a,b,c,w,g,t,b  ...        t
# 36                    pcgwoab                  p,c,g,w,o,a,b  ...        t
# 37                   poqncgba                p,o,q,n,c,g,b,a  ...        t
# 38                    pwtgcba                  p,w,t,g,c,b,a  ...        t
# 39                      pocwb                      p,o,c,w,b  ...        t
# 40                       pgbh                          p,g,b  ...        t
# 41                      cwopg                      c,w,o,p,g  ...        t
# 42                    powcgba                  p,o,w,c,g,b,a  ...        t
# 43                       wpgb                        w,p,g,b  ...        t
# 44                   pocwdqna                p,o,c,w,d,q,n,a  ...        t
# 45                        pwb                          p,w,b  ...        t
# 46                      cptgo                      c,p,t,g,o  ...        t
# 47                    pocbwga                  p,o,c,b,w,g,a  ...        t
# 48                      powcb                      p,o,w,c,b  ...        t
# 49                       pwgb                        p,w,g,b  ...        t
# 50                       gpwb                        g,p,w,b  ...        t
# 51                      cgwpx                      c,g,w,p,x  ...        t
# 52                   cwopgtab                c,w,o,p,g,t,a,b  ...        t
# 53                      pocbw                      p,o,c,b,w  ...        t
# 54                    ocpwgba                  o,c,p,w,g,b,a  ...        t
# 55                   pwgtaboc                p,w,g,t,a,b,o,c  ...        t
# 56                    pocgwab                  p,o,c,g,w,a,b  ...        t
# 57                    tgcwpao                  t,g,c,w,p,a,o  ...        t
# 58                     pocgba                    p,o,c,g,b,a  ...        t
# 59                      pgcow                      p,g,c,o,w  ...        t
# 60                       opwg                        o,p,w,g  ...        t
# 61                 wpgcoxqdba            w,p,g,c,o,x,q,d,b,a  ...        t
# 62                          a                              a  ...        t
# 63                      ptwgb                      p,t,w,g,b  ...        t
# 64                      pocab                      p,o,c,a,b  ...        t
# 65                      pocba                      p,o,c,b,a  ...        t
# 66                    pocbwga                  p,o,c,b,w,g,a  ...        t
# 67              tgpcowqhmxdni      t,g,p,c,o,w,q,h,m,x,d,n,i  ...        t
# 68                    gwpbabt                  g,w,p,b,a,b,t  ...        t
# 69                        pbg                          p,b,g  ...        t
# 70                     pwogbh                    p,w,o,g,b,h  ...        t
# 71                        pwb                          p,w,b  ...        t
# 72                    gwpocnb                  g,w,p,o,c,n,b  ...        t
# 73                    wtpcodb                  w,t,p,c,o,d,b  ...        t
# 74                      wpgba                      w,p,g,b,a  ...        t
# 75                 pocndwtabg            p,o,c,n,d,w,t,a,b,g  ...        t
# 76                     pwocba                    p,w,o,c,b,a  ...        t
# 77                      pwgab                      p,w,g,a,b  ...        t
# 78                   poctbawg                p,o,c,t,b,a,w,g  ...        t
# 79                     pwboca                    p,w,b,o,c,a  ...        t
#
#    mid_k food_k containment  error length  error_clustered_silverware  \
# 0    p,o      0           0  0.723      6                       0.666
# 1    p,o      0           0  0.785      8                       0.723
# 2    p,o      0           0  0.806      9                       0.605
# 3    p,o      0           0  0.862     13                       0.806
# 4    p,o      0           0  0.806      9                       0.756
# 5    p,o      0           0  0.666      5                       0.605
# 6    p,o      0           0  0.723      6                       0.666
# 7    p,o      0           0  0.756      7                       0.605
# 75   p,o      0           0  0.862     13                       0.806
# 76   p,o      0           0  0.838     11                       0.666
# 77   p,o      0           0  0.756      7                       0.605
# 78   p,o      0           0  0.838     11                       0.756
# 79   p,o      0           0  0.785      8                       0.723
#
#     length_clustered_silverware  error_clustered_drawers  \
# 0                             5                    0.723
# 1                             6                    0.723
# 2                             4                    0.605
# 3                             9                    0.806
# 4                             7                    0.756
# 5                             4                    0.605
# 6                             5                    0.666
# 7                             4                    0.666
# 8                             5                    0.666
# 9                             9                    0.806
# 10                            4                    0.666
# 11                            8                    0.785
# 12                            6                    0.756
# 13                            5                    0.723
# 14                            4                    0.605
# 15                            5                    0.666
# 16                            9                    0.806
# 17                            6                    0.723
# 18                            7                    0.785
# 19                            6                    0.756
# 20                            8                    0.806
# 21                            4                    0.666
# 22                            7                    0.785
# 23                           14                    0.878
# 24                            6                    0.723
# 25                            6                    0.723
# 26                            6                    0.756
# 27                            9                    0.806
# 28                            7                    0.756
# 29                            4                    0.605
# 30                            5                    0.723
# 31                           10                    0.838
# 32                            4                    0.605
# 33                           10                    0.824
# 34                            6                    0.723
# 35                            7                    0.785
# 36                            6                    0.756
# 37                            7                    0.785
# 38                            6                    0.756
# 39                            5                    0.666
# 40                            3                    0.605
# 41                            5                    0.666
# 42                            6                    0.756
# 43                            4                    0.605
# 44                            8                    0.785
# 45                            3                    0.605
# 46                            5                    0.666
# 47                            7                    0.756
# 48                            5                    0.666
# 49                            4                    0.605
# 50                            4                    0.605
# 51                            5                    0.666
# 52                            7                    0.785
# 53                            5                    0.666
# 54                            6                    0.756
# 55                            7                    0.785
# 56                            6                    0.756
# 57                            7                    0.756
# 58                            5                    0.723
# 59                            5                    0.666
# 60                            4                    0.605
# 61                            9                    0.824
# 62                            2                      NaN
# 63                            5                    0.666
# 64                            4                    0.666
# 65                            4                    0.666
# 66                            7                    0.756
# 67                           13                    0.862
# 68                            5                    0.756
# 69                            3                    0.440
# 70                            6                    0.723
# 71                            3                    0.440
# 72                            7                    0.756
# 73                            7                    0.756
# 74                            4                    0.666
# 75                            9                    0.824
# 76                            5                    0.723
# 77                            4                    0.666
# 78                            7                    0.785
# 79                            6                    0.723
#
#     length_clustered_drawers
# 0                          5
# 1                          6
# 2                          4
# 3                          9
# 4                          7
# 5                          4
# 6                          5
# 7                          4
# 8                          5
# 9                          9
# 10                         4
# 11                         8
# 12                         6
# 13                         5
# 14                         4
# 15                         5
# 16                         9
# 17                         6
# 18                         7
# 19                         6
# 20                         8
# 21                         4
# 22                         7
# 23                        14
# 24                         6
# 25                         6
# 26                         6
# 27                         9
# 28                         7
# 29                         4
# 30                         5
# 31                        10
# 32                         4
# 33                        10
# 34                         6
# 35                         7
# 36                         6
# 37                         7
# 38                         6
# 39                         5
# 40                         3
# 41                         5
# 42                         6
# 43                         4
# 44                         8
# 45                         3
# 46                         5
# 47                         7
# 48                         5
# 49                         4
# 50                         4
# 51                         5
# 52                         7
# 53                         5
# 54                         6
# 55                         7
# 56                         6
# 57                         7
# 58                         5
# 59                         5
# 60                         4
# 61                         9
# 62                         2
# 63                         5
# 64                         4
# 65                         4
# 66                         7
# 67                        13
# 68                         5
# 69                         3
# 70                         6
# 71                         3
# 72                         7
# 73                         7
# 74                         4
# 75                         9
# 76                         5
# 77                         4
# 78                         7
# 79                         6
#
# [80 rows x 24 columns]

# %% [markdown]
# ### Define functions for prediction

# %%
def predict_sequence(objects, coordinates, start_coordinates, c, k, dimension=[3,]):
    ''' Predicts sequence based on required objects, object coordinates, start coordinates of subject,
        parameters (c+k) and dimensionality.
        Input: Objects, object coordinates, start coordinates, c, k, dimension
        Output: Sequence of objects as str
    '''
    prediction = []
    possible_items = dict.fromkeys(objects, 0) # generate dict from object list
    coord_index = 0
    start_coords = start_coordinates
    coords = coordinates
    new_coords = {}
    new_start_coords = []
    
    if dimension[0] == 3: # no changes if 3D
        new_coords = coords
        new_start_coords = start_coords
        
    elif dimension[0] == 2: # 2D: remove obsolete coordinate
        if dimension[1] == 'xy':
            new_coords = {key: value[:-1] for key, value in coords.items()}
            new_start_coords = [x[:-1] for x in start_coords]
                
        elif dimension[1] == 'xz':
            new_start_coords = [[x[0], x[-1]] for x in start_coords]
            
            for key, value in coords.items():
                new_value = (value[0], value[-1])
                new_coords[key] = new_value
        
        elif dimension[1] == 'yz':
            new_coords = {key: value[1:] for key, value in coords.items()}
            new_start_coords = [x[1:] for x in start_coords]
                
    elif dimension[0] == 1: # 1D: choose appropriate coordinate
        if dimension[1] == 'x':
            new_coords = {key: value[0] for key, value in coords.items()}
            new_start_coords = [x[0] for x in start_coords]
        
        elif dimension[1] == 'y':
            new_coords = {key: value[1] for key, value in coords.items()}
            new_start_coords = [x[1] for x in start_coords]
        
        elif dimension[1] == 'z':
            new_coords = {key: value[2] for key, value in coords.items()}
            new_start_coords = [x[2] for x in start_coords]
    
    while bool(possible_items) == True: # while dict not empty
        for obj in possible_items.keys():
            possible_items[obj] = ((distance.euclidean(
                                new_start_coords[coord_index], 
                                new_coords[obj])
                                ) ** k[obj]) * c[obj]
        #print(possible_items)                      
        minval = min(possible_items.values())
        minval = [k for k, v in possible_items.items() if v == minval]
        minval = random.choice(minval) # choose prediction randomly if multiple items have same cost
        prediction.append(minval)
        del possible_items[minval]
        coord_index += 1
        
    return prediction

# %%
def get_median(objects, coordinates, start_coordinates, c, k, dimension, sequence,n=10):
    ''' Returns average edit distance (Damerau-Levenshtein) for 100 trials of sequence prediction.
    '''
    edit_list = []

    for x in range(0,n):
        result = ''.join(predict_sequence(objects, coordinates, start_coordinates, c, k, dimension))
        dl = damerau_levenshtein_distance(sequence,result)
        edit_list.append(dl)
    
    #avg = np.mean(edit_list)
    median = np.median(edit_list)
    return median

# %%
def get_avg_editdist(data, dimensions=[[1,'x'],[1,'y'],[1,'z'],[2,'xy'],[2,'xz'],[2,'yz'],[3,'xyz']],n=10):
    ''' Calculates average edit distance for all combinations of parameters (c, k, dimension).
        Input: Dataframe with objects, coordinates, start coordinates, object categories
        Output: Dataframe with edit distance results (col name: parameters used)
    '''
    results = pd.DataFrame()
        
    for row in range(0,len(data)):
        objects = list(data.at[row,'sequence_no_duplicates'])
        strong_k = list(data.at[row,'strong_k'].split(','))
        mid_k = list(data.at[row,'mid_k'].split(','))
        #food_k = list(data.at[row,'food_k'].split(','))
        food_k = []
        coordinates = {key: ast.literal_eval(value) for key, value in (elem.split(': ') for elem in data.at[row,'coordinates_clustered_silverware'].split(';'))}
        #print(coordinates)
        start_coordinates = list(ast.literal_eval(data.at[row, 'start_coordinates']))
        sequence = str(data.at[row,'sequence_no_duplicates'])
        c1 = {obj: 1.2 for obj in objects}
        k1 = {obj: 1.0 for obj in objects}
        
        #for k2 in np.arange(1.1,2.0,0.1):
            #k_food = round(k2,2)
            #k1 = {obj: k_food if obj in food_k else 1.0 for obj in objects}
        
        for k in np.arange(0,0.9,0.1):
            k_strong = round(k,2)
            k_mid = round(k + 0.1,2)
            k1 = {obj: k_strong if obj in strong_k else k_mid if obj in mid_k else round(k1[obj],2) for obj in objects}
            
                #for c in np.arange(1.0,2.0,0.1):
                #    c = round(c, 1)
                #    c1 = {obj: 1.2 for obj in objects}
                
            for dim in dimensions:                
                # get average edit distance
                median = get_median(objects, coordinates, start_coordinates, c1, k1, dim, sequence, n)
                median = median / len(sequence)
                #params = 'c: ' + str(c) + '; k: ' + str(k_strong) + ',' + str(k_mid) + ',' + str(k_food) + '; ' + str(dim[1])
                params = 'c: 1.2' + '; k: ' + str(k_strong) + ',' + str(k_mid) + '; ' + str(dim[1])
                results.at[row,params] = median
                        
        results.at[row,'sequence'] = sequence
        results.at[row,'error'] = data.at[row,'error']
                    
    return results

# %% [markdown]
# ### Calculate edit distances, create df

# %%
# ~3 min for n=100
# %time results_new = get_avg_editdist(df,n=100)
# Out:
# CPU times: user 3min 39s, sys: 83.8 ms, total: 3min 39s
# Wall time: 3min 39s

# %%
results_new
# Out:
#     c: 1.2; k: 0.0,0.1; x  c: 1.2; k: 0.0,0.1; y  c: 1.2; k: 0.0,0.1; z  \
# 0                0.666667               0.833333               0.833333
# 1                0.750000               0.875000               0.875000
# 2                0.777778               0.666667               0.666667
# 3                0.615385               0.692308               0.692308
# 4                0.888889               0.777778               0.888889
# 5                0.800000               0.600000               0.400000
# 6                0.666667               0.833333               1.000000
# 7                0.714286               0.428571               0.571429
# 8                0.800000               0.600000               0.600000
# 9                0.666667               0.666667               0.666667
# 10               0.800000               0.600000               0.700000
# 11               0.500000               0.750000               0.500000
# 12               0.692308               0.769231               0.769231
# 13               0.666667               0.833333               0.833333
# 14               0.833333               0.833333               0.666667
# 15               1.000000               0.666667               0.666667
# 16               0.818182               0.727273               0.818182
# 17               0.833333               0.333333               0.666667
# 18               0.714286               0.714286               0.785714
# 19               0.666667               0.666667               0.800000
# 20               0.818182               0.818182               0.727273
# 21               1.000000               0.625000               0.750000
# 22               0.733333               0.800000               0.866667
# 23               0.705882               0.705882               0.705882
# 24               0.625000               0.875000               0.750000
# 25               0.750000               0.875000               0.750000
# 26               0.583333               0.750000               0.833333
# 27               0.777778               0.666667               0.777778
# 16               0.818182  ...                 0.545455
# 17               0.666667  ...                 0.333333
# 18               0.857143  ...                 0.857143
# 19               0.800000  ...                 0.800000
# 20               0.727273  ...                 0.909091
# 21               0.750000  ...                 0.875000
# 22               0.866667  ...                 0.866667
# 23               0.705882  ...                 0.764706
# 24               0.750000  ...                 0.875000
# 25               0.750000  ...                 0.875000
# 26               0.833333  ...                 0.916667
# 27               0.666667  ...                 0.555556
# 28               0.571429  ...                 0.714286
# 29               0.400000  ...                 0.800000
# 30               0.625000  ...                 0.750000
# 31               0.846154  ...                 0.846154
# 32               0.555556  ...                 0.555556
# 33               0.700000  ...                 0.600000
# 34               1.000000  ...                 0.714286
# 35               0.700000  ...                 0.900000
# 36               0.818182  ...                 0.818182
# 37               0.875000  ...                 0.500000
# 38               0.909091  ...                 0.909091
# 39               0.833333  ...                 0.666667
# 40               0.500000  ...                 0.833333
# 41               0.200000  ...                 0.800000
# 42               0.900000  ...                 0.900000
# 43               0.571429  ...                 1.000000
# 44               0.700000  ...                 0.700000
# 45               0.750000  ...                 1.000000
# 46               0.400000  ...                 0.600000
# 47               0.666667  ...                 0.777778
# 48               0.750000  ...                 0.875000
# 49               0.500000  ...                 0.875000
# 50               0.666667  ...                 1.000000
# 51               0.200000  ...                 0.600000
# 52               0.866667  ...                 0.866667
# 53               0.857143  ...                 0.857143
# 54               0.750000  ...                 0.875000
# 55               0.909091  ...                 1.000000
# 56               1.000000  ...                 1.000000
# 57               0.571429  ...                 1.000000
# 58               0.700000  ...                 0.900000
# 59               0.800000  ...                 0.800000
# 60               1.000000  ...                 0.000000
# 61               0.923077  ...                 0.923077
# 62               0.500000  ...                 0.000000
# 63               0.857143  ...                 0.857143
# 64               0.750000  ...                 0.875000
# 65               0.800000  ...                 0.800000
# 66               0.769231  ...                 0.769231
# 67               0.692308  ...                 0.692308
# 68               0.625000  ...                 0.875000
# 69               0.571429  ...                 0.571429
# 70               0.750000  ...                 0.875000
# 71               0.750000  ...                 1.000000
# 72               0.833333  ...                 0.833333
# 73               0.900000  ...                 0.800000
# 74               0.666667  ...                 0.888889
# 75               0.846154  ...                 0.769231
# 76               0.727273  ...                 0.818182
# 77               1.000000  ...                 1.000000
# 78               0.818182  ...                 0.727273
# 79               0.750000  ...                 0.750000
#
#     c: 1.2; k: 0.8,0.9; x  c: 1.2; k: 0.8,0.9; y  c: 1.2; k: 0.8,0.9; z  \
# 0                0.666667               0.833333               0.833333
# 1                0.750000               0.750000               0.625000
# 2                0.666667               0.444444               0.555556
# 3                0.692308               0.615385               0.692308
# 4                0.777778               0.888889               0.666667
# 5                0.800000               0.800000               0.200000
# 6                0.500000               0.833333               1.000000
# 7                0.857143               0.857143               0.571429
# 8                0.700000               0.900000               0.500000
# 9                0.666667               0.666667               0.666667
# 10               0.700000               0.700000               0.700000
# 11               0.500000               0.750000               0.500000
# 12               0.692308               0.923077               0.692308
# 13               0.666667               0.833333               0.833333
# 14               0.833333               1.000000               0.666667
# 15               0.833333               0.833333               0.500000
# 16               0.818182               0.727273               0.727273
# 11                 0.750000           cgpogpoc  0.785
# 12                 0.846154      pwocgfkfsrere  0.862
# 13                 0.666667             ocwgrk  0.723
# 14                 1.000000             wpgsfk  0.723
# 15                 0.833333             pwofsg  0.723
# 16                 0.545455        pocpocwgkfs  0.838
# 17                 0.333333             pocgwg  0.723
# 18                 0.857143     pwgockfsfksret  0.878
# 19                 0.800000    ocpwgfkskfsrere  0.878
# 20                 0.909091        copwgwpresk  0.838
# 21                 1.000000           pwterfkf  0.785
# 22                 0.866667    pocwggpfkfksrer  0.878
# 23                 0.823529  wpofcgkrpwgfksocr  0.892
# 24                 0.875000           cwpfksor  0.785
# 25                 0.750000           pwfksorc  0.785
# 26                 0.833333       pocgwkfkfser  0.851
# 27                 0.555556          powctgcog  0.806
# 28                 0.714286            powgcpo  0.756
# 29                 0.800000              pwfkt  0.666
# 30                 0.750000           pwokfkrg  0.785
# 31                 0.846154      copcogpgwfksr  0.862
# 32                 0.555556          pgsfkskfg  0.806
# 33                 0.700000         wgptocopwg  0.824
# 34                 0.714286            powcgre  0.756
# 35                 0.900000         perkscwgtf  0.824
# 36                 1.000000        pcgworkfkfs  0.838
# 37                 0.500000           popocgkr  0.785
# 38                 0.909091        pwtgcfkfksr  0.838
# 39                 0.666667             pocwkf  0.723
# 40                 0.833333             pgkfkf  0.723
# 41                 0.800000              cwopg  0.666
# 42                 0.900000         powcgkfkfr  0.824
# 43                 1.000000            wpgfksk  0.756
# 44                 0.700000         pocwcpoere  0.824
# 45                 1.000000               pwkf  0.605
# 46                 0.600000              cptgo  0.666
# 47                 0.777778          pocfkswgr  0.806
# 48                 0.875000           powcfkfk  0.785
# 49                 0.875000           pwgfksfk  0.785
# 50                 1.000000             gpwfks  0.723
# 51                 0.600000              cgwpw  0.666
# 52                 0.866667    cwopgtrekfksksf  0.878
# 53                 0.857143            pocsfkw  0.756
# 54                 0.875000           ocpwgfkf  0.785
# 55                 1.000000        pwgterkfsoc  0.838
# 56                 1.000000          pocgwrkfs  0.806
# 57                 1.000000            tgcwpro  0.756
# 58                 0.800000         pocgkfskfr  0.824
# 59                 0.800000              pgcow  0.666
# 60                 0.000000               opwg  0.605
# 61                 0.923077      wpgcowpcfksre  0.862
# 62                 0.000000                 re  0.250
# 63                 0.857143            ptwgfks  0.756
# 64                 0.875000           pocrfkfk  0.785
# 65                 0.800000              pockr  0.666
# 66                 0.692308      pockfskfswgre  0.862
# 67                 0.692308      tgpcowpgpwcog  0.862
# 68                 0.875000           gwpfrkst  0.785
# 69                 0.571429            pfkfksg  0.756
# 70                 0.875000           pwogsfkg  0.785
# 71                 1.000000               pwkf  0.605
# 72                 0.833333       gwpocoskfsfk  0.851
# 73                 0.700000         wtpcockfkf  0.824
# 74                 0.888889          wpgfkfkre  0.806
# 75                 0.769231      pococwtrfkfkg  0.862
# 76                 0.909091        pwocfksfksr  0.838
# 77                 1.000000            pwgerks  0.756
# 78                 0.727273        poctfkfkrwg  0.838
# 79                 0.625000           pwfksocr  0.785
#
# [80 rows x 65 columns]

# %% [markdown]
# ### Get lowest error, compare edit distances

# %%
def get_lowest_error(results):
    ''' Returns lowest error in dataframe and index of lowest error.
    '''
    for col in list(results):
        if col != 'sequence':
            results.loc['mean',col] = results[col].mean()
            #results.loc['median',col] = results[col].median()
    lowest = min(results.loc['mean'])
    mean = list(results.loc['mean'])
    
    return lowest, results.columns[(results.loc['mean'] == lowest)], mean, results

# %%
lowest, lowest_idx, list_mean, results_mean = get_lowest_error(results_new)
lowest, lowest_idx
# Out:
# (0.6623728497809379, Index(['c: 1.2; k: 0.2,0.3; xy'], dtype='object'))

# %%
np.nanmean(list_mean), np.nanmedian(list_mean)
# Out:
# (0.7271845784003068, 0.7318256488201341)

# %%
# Compare avg edit distance for xy and xyz
list_xy = []
list_xyz = []

for col in results_mean:
    if col != 'sequence' and col != 'error' and col.split(';')[2].strip() == 'xy':
        list_xy.append(results_mean.at['mean',col])
    elif col != 'sequence' and col != 'error' and col.split(';')[2].strip() == 'xyz':
        list_xyz.append(results_mean.at['mean',col])
        
avg_xy = np.mean(list_xy)
med_xy = np.median(list_xy)
std_xy = np.std(list_xy)
print('Average xy: ' + str(avg_xy)  + ', stdev: ' + str(std_xy) + ', median: ' + str(med_xy))
        
avg_xyz = np.mean(list_xyz)
med_xyz = np.median(list_xyz)
std_xyz = np.std(list_xyz)
print('Average xyz: ' + str(avg_xyz) + ', stdev: ' + str(std_xyz) + ', median: ' + str(med_xyz))
# Out:
# Average xy: 0.7121043349352172, stdev: 0.04348021604246889, median: 0.7045369479376833
# Average xyz: 0.7079662532910082, stdev: 0.04250967284196799, median: 0.6837772093102975

# %%
# Compare avg edit distances for x, y, z
list_x = []
list_y = []
list_z = []
list_xz = []
list_yz = []

for col in results_mean:
    if col != 'sequence' and col != 'error' and col.split(';')[2].strip() == 'x':
        list_x.append(results_mean.at['mean',col])
    elif col != 'sequence' and col != 'error' and col.split(';')[2].strip() == 'y':
        list_y.append(results_mean.at['mean',col])
    elif col != 'sequence' and col != 'error' and col.split(';')[2].strip() == 'z':
        list_z.append(results_mean.at['mean',col])
    elif col != 'sequence' and col != 'error' and col.split(';')[2].strip() == 'xz':
        list_xz.append(results_mean.at['mean',col])
    elif col != 'sequence' and col != 'error' and col.split(';')[2].strip() == 'yz':
        list_yz.append(results_mean.at['mean',col])

avg_xz = np.mean(list_xz)
avg_yz = np.mean(list_yz)
        
avg_x = np.mean(list_x)
lowest_x = min(list_x)
print('Average x: ' + str(avg_x) + ', min: ' + str(lowest_x)) 
        
avg_y = np.mean(list_y)
lowest_y = min(list_y)
print('Average y: ' + str(avg_y) + ', min: ' + str(lowest_y)) 
        
avg_z = np.mean(list_z)
lowest_z = min(list_z)
print('Average z: ' + str(avg_z) + ', min: ' + str(lowest_z)) 

print('Average xz: ' + str(avg_xz)) 
print('Average yz: ' + str(avg_yz))
# Out:
# Average x: 0.7498375927358771, min: 0.7318037783295136
# Average y: 0.7421498567699547, min: 0.6913928004185357
# Average z: 0.7050042112480838, min: 0.6701913752097576
# Average xz: 0.7278062553368927
# Average yz: 0.7400079420851479

# %% [markdown]
# ### Statistical analysis

# %%
# Compare all error predictions for dimensions
stat, p = friedmanchisquare(list_x,list_y,list_z,list_xy,list_xz,list_yz,list_xyz)
print('Friedman: stat = %.3f, p = % 10.3E' % (stat, p))
# Out:
# Friedman: stat = 17.619, p =  7.258E-03

# %%
# 2D vs 3D median
stat, p = wilcoxon(list_xy, list_xyz, zero_method='wilcox')
print('Wilcoxon: W = %.3f, p = %.5f' % (stat, p))
# Out:
# Wilcoxon: W = 9.000, p = 0.12891

# %% [markdown]
# ### Plots for dataframe

# %%
# Define input for plots

c = [float(x[3:6]) for x in results_new.columns.tolist() if x != 'sequence' and x != 'error']
#k = [float(x[11:14]) for x in results_new.columns.tolist() if x != 'sequence']
k_strong = [float(x[11:14]) for x in results_new.columns.tolist() if x != 'sequence' and x != 'error']
k_mid = [float(x[15:18]) for x in results_new.columns.tolist() if x != 'sequence' and x != 'error']
dim = [x.strip() for x in results_new.columns[:-2].str.split(';').str[2]]
median = [x for x in results_mean.loc['mean'][:-1].tolist() if pd.notnull(x) and x != 'error']

len(median)
# Out:
# 63

# %%
# %matplotlib qt

cm = ['red','blue','green','magenta','cyan','orange','grey']
dim_num = [0 if x=='x' else 1 if x=='y' else 2 if x=='z' else 3 if x=='xy' else 4 if x=='xz' else 5 if x=='yz' else 6 for x in dim]

cmap = matplotlib.colors.ListedColormap(cm)

ticks = ['x', 'y', 'z', 'xy', 'xz', 'yz', 'xyz']
norm = matplotlib.colors.BoundaryNorm(ticks, cmap.N)

# create figure, 3d grid, set background to white
fig2 = plt.figure(figsize=(12,8))
ax2 = fig2.add_subplot(111, projection='3d')
ax2.w_xaxis.set_pane_color((1.0,1.0,1.0,1.0))
ax2.w_yaxis.set_pane_color((1.0,1.0,1.0,1.0))
ax2.w_zaxis.set_pane_color((1.0,1.0,1.0,1.0))

# create plot w/ median edit distance
#img = ax2.scatter(c, k, median, alpha=0.5, s=38, c=dim_num, cmap=cmap)
img = ax2.scatter(k_strong, k_mid, median, alpha=0.5, s=38, c=dim_num, cmap=cmap)

# plot horizontal plane for baseline
#xx, yy = np.meshgrid(np.linspace(1,1.9), np.linspace(0,0.9))
xx, yy = np.meshgrid(np.linspace(0,0.9), np.linspace(0,0.9))
#yy = np.meshgrid(range(2), range(2))
zz = xx * 0 + 0.776
ax2.plot_surface(xx, yy, zz, alpha=0.5)

# set labels
ax2.set_ylabel('strong k', fontsize=20, labelpad=10)
ax2.set_xlabel('mid k', fontsize=20, labelpad=10)
ax2.set_zlabel('normalized edit distance', fontsize=20, labelpad=7)
#plt.title('Average edit distance (1 step)', fontsize=24)

# create colorbar
cb = plt.colorbar(img, cax = fig2.add_axes([0.9,0.3,0.03,0.4]))
cb.ax.set_yticklabels(ticks, fontsize=16)
plt.show()
# Out:
# /home/zauri/files/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:37: UserWarning: FixedFormatter should only be used together with FixedLocator

# %% [markdown]
# ### Check for sequences worse than baseline

# %%
# get sequences from best model where performance worse than baseline
results_new['c: 1.2; k: 0.2,0.3; xy'].loc[results_new['c: 1.2; k: 0.2,0.3; xy'] >= 0.776]

print('Higher than avg. error: ' +
    str(len(results_new['c: 1.2; k: 0.2,0.3; xy'].loc[results_new['c: 1.2; k: 0.2,0.3; xy'] >= results_new['error']]))
    + ' of ' + \
    str(len(results_new['c: 1.2; k: 0.2,0.3; xy'])) + ' sequences')
# Out:
# Higher than avg. error: 12 of 81 sequences

# %%
worse_than_baseline = results_new['c: 1.2; k: 0.2,0.3; xy'].loc[results_new['c: 1.2; k: 0.2,0.3; xy'] >= results_new['error']]

worse_than_baseline
# Out:
# 0     0.833333
# 1     0.875000
# 14    0.833333
# 24    0.875000
# 36    0.909091
# 39    0.833333
# 41    0.800000
# 50    0.833333
# 51    0.800000
# 57    0.857143
# 59    0.800000
# 68    0.875000
# Name: c: 1.2; k: 0.2,0.3; xy, dtype: float64

# %%
# create list of sequences where performance worse than baseline

rows_sequences = []

for x in range(0,len(worse_than_baseline)):
    rows_sequences.append(results_new['sequence'].iloc[x])

rows_sequences
# Out:
# ['pocgkr',
#  'cgwpcfks',
#  'kfsfkspwg',
#  'pfkswkfsococg',
#  'wptgkfsoc',
#  'pwfkg',
#  'powcer',
#  'coprerk',
#  'wopofkkskf',
#  'opwpwgcoc',
#  'pocrfksfks',
#  'cgpogpoc']

# %%
#%matplotlib inline

error_individual = df['error']
seqs = results_mean['sequence'][:-1].values
res = results_new['c: 1.2; k: 0.2,0.3; xy'][:-1].values
x = [x for x in range (0,len(seqs))]

plt.figure(figsize=(18,6))
plt.scatter(x, res, marker='o', label='model-generated sequences')
plt.scatter(x, error_individual, c='red', marker='o', linewidth=2, label='baseline for sequence length')
plt.plot(x, error_individual, c='red', alpha=0.5)
plt.plot((x,x),(error_individual,res), '--', c='black', alpha=0.6)


plt.title('same item type clustered, 0.662, c: 1.2; k: 0.2,0.3; xy], n=100', fontsize=16)
plt.xticks(x, seqs, rotation=90)
plt.ylabel('median edit distance', fontsize=14)
plt.xlabel('sequence', fontsize=14)
plt.legend()

#plt.savefig('plot_median_editdist_individualerrors_diff.png', bbox_inches='tight')
plt.show()

# %%
# Define input for 2D/3D plots

c2 = [float(x[3:6]) for x in results_new.columns.tolist() if x != 'sequence']
k2 = [float(x[11:14]) for x in results_new.columns.tolist() if x != 'sequence']
dim2 = [x.strip() for x in results_new.columns[:-1].str.split(';').str[2]]
median2 = [x for x in results_mean.loc['mean'].tolist() if pd.notnull(x)]

# %%
# Plot scatterplots for xy, xyz only

# %matplotlib qt

cm2 = ['blue','green']
dim_num2 = [0 if x=='xy' else 1 for x in dim]

cmap2 = matplotlib.colors.ListedColormap(cm2)

ticks2 = ['xy', 'xyz']
norm = matplotlib.colors.BoundaryNorm(ticks2, cmap2.N)

# create figure, 3d grid, set background to white
fig3 = plt.figure(figsize=(12,8))
ax3 = fig3.add_subplot(111, projection='3d')
ax3.w_xaxis.set_pane_color((1.0,1.0,1.0,1.0))
ax3.w_yaxis.set_pane_color((1.0,1.0,1.0,1.0))
ax3.w_zaxis.set_pane_color((1.0,1.0,1.0,1.0))

# create plot w/ median edit distance
img2 = ax3.scatter(c2, k2, median2, alpha=0.5, s=38, c=dim_num2, cmap=cmap2)

# plot horizontal plane for baseline
xx, yy = np.meshgrid(np.linspace(1,1.9), np.linspace(0,0.9))
zz = xx * 0 + 0.603
ax3.plot_surface(xx, yy, zz, alpha=1.0)

# set labels
ax3.set_ylabel('parameter k', fontsize=20, labelpad=10)
ax3.set_xlabel('parameter c', fontsize=20, labelpad=10)
ax3.set_zlabel('normalized edit distance', fontsize=20, labelpad=7)

cb = plt.colorbar(img2, cax = fig3.add_axes([0.9,0.3,0.03,0.1]))
cb.ax.set_yticklabels(ticks2, fontsize=16)

plt.show()
