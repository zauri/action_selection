# %%
import pandas as pd

# %%
df = pd.read_csv('h03_task_environments.csv', header=0)

# %%
df
# Out:
#      ID  sequence                                        coordinates  \
# 0    h0  ocsfgkbp  o: (6,8,2);c: (4,8,2);s: (3,8,2);f: (5,8,2);g:...
# 1    h1  posfkcgb  p: (6,8,2);o: (5,8,2);s: (3,8,2);f: (4,8,2);k:...
# 2    h2  pogbfkcs  p: (2,8,2);o: (5,8,2);g: (3,8,2);b: (4,8,2);f:...
# 3    h3  gpocksfb  g: (4,8,2);p: (8,8,2);o: (7,8,2);c: (6,8,2);k:...
# 4    h4  pofkscgb  p: (5,8,2);o: (8,8,2);f: (7,8,2);k: (4,8,2);s:...
# ..  ...       ...                                                ...
# 63  h63  pkfsbcgo  p: (3,8,2);k: (8,8,2);f: (6,8,2);s: (4,8,2);b:...
# 64  h64  pkfsocgb  p: (5,8,2);k: (4,8,2);f: (2,8,2);s: (7,8,2);o:...
# 65  h65  pfskocgb  p: (9,8,2);f: (6,8,2);s: (2,8,2);k: (8,8,2);o:...
# 66  h66  pokfscgb  p: (6,8,2);o: (2,8,2);k: (3,8,2);f: (9,8,2);s:...
# 67  h67  pfskogcb  p: (2,8,2);f: (8,8,2);s: (4,8,2);k: (5,8,2);o:...
#
#                                     start_coordinates  length  error strong_k  \
# ...

# %%
df2 = df['sequence'].apply(lambda x: pd.Series(list(x)))

# %%
df2.to_csv('h03_train.csv', header=True, index=False)

# %%
df2.loc[:, 0:2].to_csv('h03_test.csv', header=False, index=False)
