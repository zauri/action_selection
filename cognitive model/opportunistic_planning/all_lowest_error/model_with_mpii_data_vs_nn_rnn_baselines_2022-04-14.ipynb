# %%
import ast
import cmasher as cmr
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from opportunistic_planning import processing, visualization
from scipy.stats import friedmanchisquare, wilcoxon

# %%
df = processing.read_data('all_task_environments_list_2022-04-01.csv', use_string_for_seq=False)

# %%
df
# Out:
#           ID                                           sequence  \
# 0         a1      plate,plate_small,cup,glass,knife,spoon_small
# 1         a3     cup,glass,wineglass,plate,cup,fork,knife,spoon
# 2         a5  knife,fork,spoon,fork,knife,spoon,plate,winegl...
# 3        a11  plate,fork,knife,spoon,wineglass,knife,fork,sp...
# 4        a13  wineglass,plate,tray,glass,knife,fork,spoon,pl...
# ..       ...                                                ...
# 309  s37-d21  cucumber,knife,cutting_board,plate,peeler,spic...
# 310  s37-d25                          bread,cutting_board,knife
# 311  s37-d29                     cutting_board,knife,herbs,bowl
# 312  s37-d39  leek,cutting_board,knife,pan,oil,spatula,spice...
# 313  s37-d46  pineapple,cutting_board,knife,plastic_box,spic...
#
#                                            coordinates  \
# 0    plate: (0.008034,0.957082,0.6890539999999999);...
# 1    cup: (-0.525007,0.923283,0.438);glass: (-0.595...
# 2    knife: (-0.07699199999999999,0.733425,0.531662...
# 3    plate: (0.008034,0.957082,0.6890539999999999);...
# 4    wineglass: (-0.196022,1.35572,0.466005);plate:...
# ..                                                 ...
# 309  cucumber: (1.5,4,3);knife: (0,1.5,2);cutting_b...
# 310  bread: (1.5,4,2.5);cutting_board: (0,1.5,1);kn...
# 311  cutting_board: (0,1.5,1);knife: (0,1.5,2);herb...
# 312  leek: (1.5,4,2);cutting_board: (0,1.5,1);knife...
# 313  pineapple: (1.5,4,3);cutting_board: (0,1.5,1);...
#
#                                      start_coordinates       strong_k  \
# 0    [-0.451354,-0.413918,0.156247],[0.513,-0.531,0...           tray
# 1    [-0.451354,-0.413918,0.156247],[0.513,-0.531,0...           tray
# 2    [-0.451354,-0.413918,0.156247],[0.513,-0.531,0...           tray
# 3    [-0.451354,-0.413918,0.156247],[0.513,-0.531,0...           tray
# 4    [-0.451354,-0.413918,0.156247],[0.513,-0.531,0...           tray
# ..                                                 ...            ...
# 309  [1,0,2],[0,1.5,2],[0,1.5,2],[0,1.5,2],[0,1.5,2...  cutting_board
# 310                        [1,0,2],[0,1.5,2],[0,1.5,2]  cutting_board
# 311              [1,0,2],[0,1.5,2],[0,1.5,2],[0,1.5,2]  cutting_board
# 312  [1,0,2],[0,1.5,2],[0,1.5,2],[0,1.5,2],[0,1.5,2...  cutting_board
# 313    [1,0,2],[0,1.5,2],[0,1.5,2],[0,1.5,2],[0,1.5,2]  cutting_board
#
#                  mid_k food_k  \
# 0    plate,plate_small      0
# 1    plate,plate_small      0
# 2    plate,plate_small      0
# 3    plate,plate_small      0
# 4    plate,plate_small      0
# ..                 ...    ...
# 309                NaN  plate
# 310                NaN  plate
# 311                NaN  plate
# 312                NaN  plate
# 313                NaN  plate
#
#                                            containment  error
# 0                                                    0  0.723
# 1                                                    0  0.785
# 2                                                    0  0.806
# 3                                                    0  0.862
# 4                                                    0  0.806
# ..                                                 ...    ...
# 309          cucumber,knife,cutting_board,plate,peeler    NaN
# 310                          bread,cutting_board,knife    NaN
# 311                           cutting_board,knife,bowl    NaN
# 312  leek,cutting_board,knife,pan,bottle,spatula,plate    NaN
# 313          pineapple,cutting_board,knife,plastic_box    NaN
#
# [314 rows x 9 columns]

# %%
with open ('../../model_evaluation/neural_net/results/nn_spatialinfo_prequential_summed_2022-04-14.txt', 'r') as file:
    nn_results = ast.literal_eval(file.read())

# %%
len(nn_results)
# Out:
# 314

# %%
# %time distances_dict = processing.generate_distances_dict(df)
# Out:
# CPU times: user 1.22 s, sys: 64.9 ms, total: 1.28 s
# Wall time: 1.21 s

# %%
# %time results_sum = processing.calculate_prediction_error(df, distances_dict, error_function='prequential', n=100, dimensions=[[2, 'xy']])
# Out:
# /home/zauri/personal/projects/phd_thesis/cognitive model/model_package/opportunistic_planning/processing.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   results.at[row, params] = median
# /home/zauri/personal/projects/phd_thesis/cognitive model/model_package/opportunistic_planning/processing.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   results.at[row, params] = median
# /home/zauri/personal/projects/phd_thesis/cognitive model/model_package/opportunistic_planning/processing.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   results.at[row, params] = median
# /home/zauri/personal/projects/phd_thesis/cognitive model/model_package/opportunistic_planning/processing.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   results.at[row, params] = median
# /home/zauri/personal/projects/phd_thesis/cognitive model/model_package/opportunistic_planning/processing.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   results.at[row, params] = median
# /home/zauri/personal/projects/phd_thesis/cognitive model/model_package/opportunistic_planning/processing.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   results.at[row, params] = median
# /home/zauri/personal/projects/phd_thesis/cognitive model/model_package/opportunistic_planning/processing.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   results.at[row, params] = median
# /home/zauri/personal/projects/phd_thesis/cognitive model/model_package/opportunistic_planning/processing.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   results.at[row, params] = median
# /home/zauri/personal/projects/phd_thesis/cognitive model/model_package/opportunistic_planning/processing.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   results.at[row, params] = median
# /home/zauri/personal/projects/phd_thesis/cognitive model/model_package/opportunistic_planning/processing.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   results.at[row, params] = median
# /home/zauri/personal/projects/phd_thesis/cognitive model/model_package/opportunistic_planning/processing.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   results.at[row, params] = median
# /home/zauri/personal/projects/phd_thesis/cognitive model/model_package/opportunistic_planning/processing.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   results.at[row, params] = median
# /home/zauri/personal/projects/phd_thesis/cognitive model/model_package/opportunistic_planning/processing.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   results.at[row, params] = median
# /home/zauri/personal/projects/phd_thesis/cognitive model/model_package/opportunistic_planning/processing.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   results.at[row, params] = median
# /home/zauri/personal/projects/phd_thesis/cognitive model/model_package/opportunistic_planning/processing.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   results.at[row, params] = median
# /home/zauri/personal/projects/phd_thesis/cognitive model/model_package/opportunistic_planning/processing.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   results.at[row, params] = median
# /home/zauri/personal/projects/phd_thesis/cognitive model/model_package/opportunistic_planning/processing.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   results.at[row, params] = median
# /home/zauri/personal/projects/phd_thesis/cognitive model/model_package/opportunistic_planning/processing.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   results.at[row, params] = median
# /home/zauri/personal/projects/phd_thesis/cognitive model/model_package/opportunistic_planning/processing.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   results.at[row, params] = median
# /home/zauri/personal/projects/phd_thesis/cognitive model/model_package/opportunistic_planning/processing.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   results.at[row, params] = median
# /home/zauri/personal/projects/phd_thesis/cognitive model/model_package/opportunistic_planning/processing.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   results.at[row, params] = median
# /home/zauri/personal/projects/phd_thesis/cognitive model/model_package/opportunistic_planning/processing.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   results.at[row, params] = median
# /home/zauri/personal/projects/phd_thesis/cognitive model/model_package/opportunistic_planning/processing.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   results.at[row, params] = median
# /home/zauri/personal/projects/phd_thesis/cognitive model/model_package/opportunistic_planning/processing.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   results.at[row, params] = median
# /home/zauri/personal/projects/phd_thesis/cognitive model/model_package/opportunistic_planning/processing.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   results.at[row, params] = median
# /home/zauri/personal/projects/phd_thesis/cognitive model/model_package/opportunistic_planning/processing.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   results.at[row, params] = median
# /home/zauri/personal/projects/phd_thesis/cognitive model/model_package/opportunistic_planning/processing.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   results.at[row, params] = median
# /home/zauri/personal/projects/phd_thesis/cognitive model/model_package/opportunistic_planning/processing.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   results.at[row, params] = median
# /home/zauri/personal/projects/phd_thesis/cognitive model/model_package/opportunistic_planning/processing.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   results.at[row, params] = median
# /home/zauri/personal/projects/phd_thesis/cognitive model/model_package/opportunistic_planning/processing.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   results.at[row, params] = median
# /home/zauri/personal/projects/phd_thesis/cognitive model/model_package/opportunistic_planning/processing.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   results.at[row, params] = median
# /home/zauri/personal/projects/phd_thesis/cognitive model/model_package/opportunistic_planning/processing.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   results.at[row, params] = median
# /home/zauri/personal/projects/phd_thesis/cognitive model/model_package/opportunistic_planning/processing.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   results.at[row, params] = median
# /home/zauri/personal/projects/phd_thesis/cognitive model/model_package/opportunistic_planning/processing.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   results.at[row, params] = median
# /home/zauri/personal/projects/phd_thesis/cognitive model/model_package/opportunistic_planning/processing.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   results.at[row, params] = median
# /home/zauri/personal/projects/phd_thesis/cognitive model/model_package/opportunistic_planning/processing.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   results.at[row, params] = median
# /home/zauri/personal/projects/phd_thesis/cognitive model/model_package/opportunistic_planning/processing.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   results.at[row, params] = median
# /home/zauri/personal/projects/phd_thesis/cognitive model/model_package/opportunistic_planning/processing.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   results.at[row, params] = median
# /home/zauri/personal/projects/phd_thesis/cognitive model/model_package/opportunistic_planning/processing.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   results.at[row, params] = median
# /home/zauri/personal/projects/phd_thesis/cognitive model/model_package/opportunistic_planning/processing.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   results.at[row, params] = median
# /home/zauri/personal/projects/phd_thesis/cognitive model/model_package/opportunistic_planning/processing.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   results.at[row, params] = median
# /home/zauri/personal/projects/phd_thesis/cognitive model/model_package/opportunistic_planning/processing.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   results.at[row, params] = median
# /home/zauri/personal/projects/phd_thesis/cognitive model/model_package/opportunistic_planning/processing.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   results.at[row, params] = median
# /home/zauri/personal/projects/phd_thesis/cognitive model/model_package/opportunistic_planning/processing.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   results.at[row, params] = median
# /home/zauri/personal/projects/phd_thesis/cognitive model/model_package/opportunistic_planning/processing.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   results.at[row, params] = median
# /home/zauri/personal/projects/phd_thesis/cognitive model/model_package/opportunistic_planning/processing.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   results.at[row, params] = median
# /home/zauri/personal/projects/phd_thesis/cognitive model/model_package/opportunistic_planning/processing.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   results.at[row, params] = median
# /home/zauri/personal/projects/phd_thesis/cognitive model/model_package/opportunistic_planning/processing.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   results.at[row, params] = median
# /home/zauri/personal/projects/phd_thesis/cognitive model/model_package/opportunistic_planning/processing.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   results.at[row, params] = median
# /home/zauri/personal/projects/phd_thesis/cognitive model/model_package/opportunistic_planning/processing.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   results.at[row, params] = median
# /home/zauri/personal/projects/phd_thesis/cognitive model/model_package/opportunistic_planning/processing.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   results.at[row, params] = median
# /home/zauri/personal/projects/phd_thesis/cognitive model/model_package/opportunistic_planning/processing.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   results.at[row, params] = median
# /home/zauri/personal/projects/phd_thesis/cognitive model/model_package/opportunistic_planning/processing.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   results.at[row, params] = median
# /home/zauri/personal/projects/phd_thesis/cognitive model/model_package/opportunistic_planning/processing.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   results.at[row, params] = median
# /home/zauri/personal/projects/phd_thesis/cognitive model/model_package/opportunistic_planning/processing.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   results.at[row, params] = median
# /home/zauri/personal/projects/phd_thesis/cognitive model/model_package/opportunistic_planning/processing.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   results.at[row, params] = median
# /home/zauri/personal/projects/phd_thesis/cognitive model/model_package/opportunistic_planning/processing.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   results.at[row, params] = median
# /home/zauri/personal/projects/phd_thesis/cognitive model/model_package/opportunistic_planning/processing.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   results.at[row, params] = median
# /home/zauri/personal/projects/phd_thesis/cognitive model/model_package/opportunistic_planning/processing.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   results.at[row, params] = median
# /home/zauri/personal/projects/phd_thesis/cognitive model/model_package/opportunistic_planning/processing.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   results.at[row, params] = median
# /home/zauri/personal/projects/phd_thesis/cognitive model/model_package/opportunistic_planning/processing.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   results.at[row, params] = median
# /home/zauri/personal/projects/phd_thesis/cognitive model/model_package/opportunistic_planning/processing.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   results.at[row, params] = median
# /home/zauri/personal/projects/phd_thesis/cognitive model/model_package/opportunistic_planning/processing.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   results.at[row, params] = median
# /home/zauri/personal/projects/phd_thesis/cognitive model/model_package/opportunistic_planning/processing.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   results.at[row, params] = median
# /home/zauri/personal/projects/phd_thesis/cognitive model/model_package/opportunistic_planning/processing.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   results.at[row, params] = median
# /home/zauri/personal/projects/phd_thesis/cognitive model/model_package/opportunistic_planning/processing.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   results.at[row, params] = median
# /home/zauri/personal/projects/phd_thesis/cognitive model/model_package/opportunistic_planning/processing.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   results.at[row, params] = median
# /home/zauri/personal/projects/phd_thesis/cognitive model/model_package/opportunistic_planning/processing.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   results.at[row, params] = median
# /home/zauri/personal/projects/phd_thesis/cognitive model/model_package/opportunistic_planning/processing.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   results.at[row, params] = median
# /home/zauri/personal/projects/phd_thesis/cognitive model/model_package/opportunistic_planning/processing.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   results.at[row, params] = median
# /home/zauri/personal/projects/phd_thesis/cognitive model/model_package/opportunistic_planning/processing.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   results.at[row, params] = median
# /home/zauri/personal/projects/phd_thesis/cognitive model/model_package/opportunistic_planning/processing.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   results.at[row, params] = median
# /home/zauri/personal/projects/phd_thesis/cognitive model/model_package/opportunistic_planning/processing.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   results.at[row, params] = median
# /home/zauri/personal/projects/phd_thesis/cognitive model/model_package/opportunistic_planning/processing.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   results.at[row, params] = median
# /home/zauri/personal/projects/phd_thesis/cognitive model/model_package/opportunistic_planning/processing.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   results.at[row, params] = median
# /home/zauri/personal/projects/phd_thesis/cognitive model/model_package/opportunistic_planning/processing.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   results.at[row, params] = median
# /home/zauri/personal/projects/phd_thesis/cognitive model/model_package/opportunistic_planning/processing.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   results.at[row, params] = median
# /home/zauri/personal/projects/phd_thesis/cognitive model/model_package/opportunistic_planning/processing.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   results.at[row, params] = median
# /home/zauri/personal/projects/phd_thesis/cognitive model/model_package/opportunistic_planning/processing.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   results.at[row, params] = median
# /home/zauri/personal/projects/phd_thesis/cognitive model/model_package/opportunistic_planning/processing.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   results.at[row, params] = median
# /home/zauri/personal/projects/phd_thesis/cognitive model/model_package/opportunistic_planning/processing.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   results.at[row, params] = median
# /home/zauri/personal/projects/phd_thesis/cognitive model/model_package/opportunistic_planning/processing.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   results.at[row, params] = median
# /home/zauri/personal/projects/phd_thesis/cognitive model/model_package/opportunistic_planning/processing.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   results.at[row, params] = median
# /home/zauri/personal/projects/phd_thesis/cognitive model/model_package/opportunistic_planning/processing.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   results.at[row, params] = median
# /home/zauri/personal/projects/phd_thesis/cognitive model/model_package/opportunistic_planning/processing.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   results.at[row, params] = median
# /home/zauri/personal/projects/phd_thesis/cognitive model/model_package/opportunistic_planning/processing.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   results.at[row, params] = median
# /home/zauri/personal/projects/phd_thesis/cognitive model/model_package/opportunistic_planning/processing.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   results.at[row, params] = median
# /home/zauri/personal/projects/phd_thesis/cognitive model/model_package/opportunistic_planning/processing.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   results.at[row, params] = median
# /home/zauri/personal/projects/phd_thesis/cognitive model/model_package/opportunistic_planning/processing.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   results.at[row, params] = median
# /home/zauri/personal/projects/phd_thesis/cognitive model/model_package/opportunistic_planning/processing.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   results.at[row, params] = median
# /home/zauri/personal/projects/phd_thesis/cognitive model/model_package/opportunistic_planning/processing.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   results.at[row, params] = median
# /home/zauri/personal/projects/phd_thesis/cognitive model/model_package/opportunistic_planning/processing.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   results.at[row, params] = median
# /home/zauri/personal/projects/phd_thesis/cognitive model/model_package/opportunistic_planning/processing.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   results.at[row, params] = median
# /home/zauri/personal/projects/phd_thesis/cognitive model/model_package/opportunistic_planning/processing.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   results.at[row, params] = median
# /home/zauri/personal/projects/phd_thesis/cognitive model/model_package/opportunistic_planning/processing.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   results.at[row, params] = median
# /home/zauri/personal/projects/phd_thesis/cognitive model/model_package/opportunistic_planning/processing.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   results.at[row, params] = median
# /home/zauri/personal/projects/phd_thesis/cognitive model/model_package/opportunistic_planning/processing.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   results.at[row, params] = median
# /home/zauri/personal/projects/phd_thesis/cognitive model/model_package/opportunistic_planning/processing.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   results.at[row, params] = median
# /home/zauri/personal/projects/phd_thesis/cognitive model/model_package/opportunistic_planning/processing.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   results.at[row, params] = median
# /home/zauri/personal/projects/phd_thesis/cognitive model/model_package/opportunistic_planning/processing.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   results.at[row, params] = median
# /home/zauri/personal/projects/phd_thesis/cognitive model/model_package/opportunistic_planning/processing.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   results.at[row, params] = median
# /home/zauri/personal/projects/phd_thesis/cognitive model/model_package/opportunistic_planning/processing.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   results.at[row, params] = median
# /home/zauri/personal/projects/phd_thesis/cognitive model/model_package/opportunistic_planning/processing.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   results.at[row, params] = median
# /home/zauri/personal/projects/phd_thesis/cognitive model/model_package/opportunistic_planning/processing.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   results.at[row, params] = median
# /home/zauri/personal/projects/phd_thesis/cognitive model/model_package/opportunistic_planning/processing.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   results.at[row, params] = median
# /home/zauri/personal/projects/phd_thesis/cognitive model/model_package/opportunistic_planning/processing.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   results.at[row, params] = median
# /home/zauri/personal/projects/phd_thesis/cognitive model/model_package/opportunistic_planning/processing.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   results.at[row, params] = median
# /home/zauri/personal/projects/phd_thesis/cognitive model/model_package/opportunistic_planning/processing.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   results.at[row, params] = median
# /home/zauri/personal/projects/phd_thesis/cognitive model/model_package/opportunistic_planning/processing.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   results.at[row, params] = median
# /home/zauri/personal/projects/phd_thesis/cognitive model/model_package/opportunistic_planning/processing.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   results.at[row, params] = median
# /home/zauri/personal/projects/phd_thesis/cognitive model/model_package/opportunistic_planning/processing.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   results.at[row, params] = median
# /home/zauri/personal/projects/phd_thesis/cognitive model/model_package/opportunistic_planning/processing.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   results.at[row, params] = median
# /home/zauri/personal/projects/phd_thesis/cognitive model/model_package/opportunistic_planning/processing.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# ...
#   results.at[row, params] = median
# /home/zauri/personal/projects/phd_thesis/cognitive model/model_package/opportunistic_planning/processing.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   results.at[row, params] = median
# /home/zauri/personal/projects/phd_thesis/cognitive model/model_package/opportunistic_planning/processing.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   results.at[row, params] = median
# /home/zauri/personal/projects/phd_thesis/cognitive model/model_package/opportunistic_planning/processing.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   results.at[row, params] = median
# /home/zauri/personal/projects/phd_thesis/cognitive model/model_package/opportunistic_planning/processing.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   results.at[row, params] = median
# /home/zauri/personal/projects/phd_thesis/cognitive model/model_package/opportunistic_planning/processing.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   results.at[row, params] = median
# /home/zauri/personal/projects/phd_thesis/cognitive model/model_package/opportunistic_planning/processing.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   results.at[row, params] = median
# /home/zauri/personal/projects/phd_thesis/cognitive model/model_package/opportunistic_planning/processing.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   results.at[row, params] = median
# /home/zauri/personal/projects/phd_thesis/cognitive model/model_package/opportunistic_planning/processing.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   results.at[row, params] = median
# /home/zauri/personal/projects/phd_thesis/cognitive model/model_package/opportunistic_planning/processing.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   results.at[row, params] = median
# /home/zauri/personal/projects/phd_thesis/cognitive model/model_package/opportunistic_planning/processing.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   results.at[row, params] = median
# /home/zauri/personal/projects/phd_thesis/cognitive model/model_package/opportunistic_planning/processing.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   results.at[row, params] = median
# /home/zauri/personal/projects/phd_thesis/cognitive model/model_package/opportunistic_planning/processing.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   results.at[row, params] = median
# /home/zauri/personal/projects/phd_thesis/cognitive model/model_package/opportunistic_planning/processing.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   results.at[row, params] = median
# /home/zauri/personal/projects/phd_thesis/cognitive model/model_package/opportunistic_planning/processing.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   results.at[row, params] = median
# /home/zauri/personal/projects/phd_thesis/cognitive model/model_package/opportunistic_planning/processing.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   results.at[row, params] = median
# /home/zauri/personal/projects/phd_thesis/cognitive model/model_package/opportunistic_planning/processing.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   results.at[row, params] = median
# /home/zauri/personal/projects/phd_thesis/cognitive model/model_package/opportunistic_planning/processing.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   results.at[row, params] = median
# /home/zauri/personal/projects/phd_thesis/cognitive model/model_package/opportunistic_planning/processing.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   results.at[row, params] = median
# /home/zauri/personal/projects/phd_thesis/cognitive model/model_package/opportunistic_planning/processing.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   results.at[row, params] = median
# /home/zauri/personal/projects/phd_thesis/cognitive model/model_package/opportunistic_planning/processing.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   results.at[row, params] = median
# /home/zauri/personal/projects/phd_thesis/cognitive model/model_package/opportunistic_planning/processing.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   results.at[row, params] = median
# /home/zauri/personal/projects/phd_thesis/cognitive model/model_package/opportunistic_planning/processing.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   results.at[row, params] = median
# /home/zauri/personal/projects/phd_thesis/cognitive model/model_package/opportunistic_planning/processing.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   results.at[row, params] = median
# /home/zauri/personal/projects/phd_thesis/cognitive model/model_package/opportunistic_planning/processing.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   results.at[row, params] = median
# /home/zauri/personal/projects/phd_thesis/cognitive model/model_package/opportunistic_planning/processing.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   results.at[row, params] = median
# /home/zauri/personal/projects/phd_thesis/cognitive model/model_package/opportunistic_planning/processing.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   results.at[row, params] = median
# /home/zauri/personal/projects/phd_thesis/cognitive model/model_package/opportunistic_planning/processing.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   results.at[row, params] = median
# /home/zauri/personal/projects/phd_thesis/cognitive model/model_package/opportunistic_planning/processing.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   results.at[row, params] = median
# /home/zauri/personal/projects/phd_thesis/cognitive model/model_package/opportunistic_planning/processing.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   results.at[row, params] = median
# /home/zauri/personal/projects/phd_thesis/cognitive model/model_package/opportunistic_planning/processing.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   results.at[row, params] = median
# /home/zauri/personal/projects/phd_thesis/cognitive model/model_package/opportunistic_planning/processing.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   results.at[row, params] = median
# /home/zauri/personal/projects/phd_thesis/cognitive model/model_package/opportunistic_planning/processing.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   results.at[row, params] = median
# /home/zauri/personal/projects/phd_thesis/cognitive model/model_package/opportunistic_planning/processing.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   results.at[row, params] = median
# /home/zauri/personal/projects/phd_thesis/cognitive model/model_package/opportunistic_planning/processing.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   results.at[row, params] = median
# /home/zauri/personal/projects/phd_thesis/cognitive model/model_package/opportunistic_planning/processing.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   results.at[row, params] = median
# /home/zauri/personal/projects/phd_thesis/cognitive model/model_package/opportunistic_planning/processing.py:114: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   results.at[row, 'error'] = data.at[row, error]
# /home/zauri/personal/projects/phd_thesis/cognitive model/model_package/opportunistic_planning/processing.py:115: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   results.at[row, 'ID'] = ID
# CPU times: user 12min 27s, sys: 776 ms, total: 12min 27s
# Wall time: 12min 27s

# %%
results_sum
# Out:
#      c: 1.0; k: 0.0,0.1,1.1; xy  c: 1.1; k: 0.0,0.1,1.1; xy  \
# 0                           3.0                         3.0
# 1                           6.0                         6.0
# 2                           6.0                         6.0
# 3                           9.0                         9.0
# 4                           6.0                         6.0
# ..                          ...                         ...
# 309                         4.0                         4.0
# 310                         2.0                         2.0
# 311                         1.0                         1.0
# 312                         4.0                         5.0
# 313                         3.0                         3.0
#
#      c: 1.2; k: 0.0,0.1,1.1; xy  c: 1.3; k: 0.0,0.1,1.1; xy  \
# 0                           3.0                         3.0
# 1                           6.0                         6.0
# 2                           6.0                         6.0
# 3                           9.0                         9.0
# 4                           6.0                         6.0
# ..                          ...                         ...
# 309                         4.0                         4.0
# 310                         2.0                         2.0
# 311                         1.0                         1.0
# 312                         5.0                         4.0
# 313                         3.0                         2.0
#
#      c: 1.4; k: 0.0,0.1,1.1; xy  c: 1.5; k: 0.0,0.1,1.1; xy  \
# 0                           3.0                         3.0
# 1                           6.0                         6.0
# 2                           6.0                         6.0
# 3                           9.0                         9.0
# 4                           6.0                         6.0
# ..                          ...                         ...
# 309                         3.5                         3.0
# 310                         2.0                         2.0
# 311                         0.0                         0.0
# 312                         5.0                         5.0
# 313                         2.5                         3.0
#
#      c: 1.6; k: 0.0,0.1,1.1; xy  c: 1.7; k: 0.0,0.1,1.1; xy  \
# 0                           3.0                         3.0
# 1                           6.0                         6.0
# 2                           6.0                         6.0
# 3                           9.0                         9.0
# 4                           6.0                         6.0
# ..                          ...                         ...
# 309                         4.0                         3.0
# 310                         2.0                         2.0
# 311                         1.0                         0.0
# 312                         4.0                         4.0
# 313                         2.0                         2.5
#
#      c: 1.8; k: 0.0,0.1,1.1; xy  c: 1.9; k: 0.0,0.1,1.1; xy  ...  \
# 0                           3.0                         3.0  ...
# 1                           6.0                         6.0  ...
# 2                           6.0                         6.0  ...
# 3                           9.0                         9.0  ...
# 4                           6.0                         6.0  ...
# ..                          ...                         ...  ...
# 309                         4.0                         4.0  ...
# 310                         2.0                         2.0  ...
# 311                         1.0                         0.0  ...
# 312                         4.0                         4.0  ...
# 313                         2.0                         2.0  ...
#
#      c: 1.2; k: 0.8,0.9,1.9; xy  c: 1.3; k: 0.8,0.9,1.9; xy  \
# 0                           4.0                         4.0
# 1                           7.0                         7.0
# 2                           4.0                         4.0
# 3                           7.0                         7.0
# 4                           6.0                         6.0
# ..                          ...                         ...
# 309                         3.0                         3.0
# 310                         2.0                         2.0
# 311                         1.0                         1.0
# 312                         4.0                         4.0
# 313                         2.0                         2.0
#
#      c: 1.4; k: 0.8,0.9,1.9; xy  c: 1.5; k: 0.8,0.9,1.9; xy  \
# 0                           4.0                         4.0
# 1                           7.0                         7.0
# 2                           4.0                         4.0
# 3                           7.0                         7.0
# 4                           6.0                         6.0
# ..                          ...                         ...
# 309                         3.0                         3.0
# 310                         1.0                         2.0
# 311                         1.0                         1.0
# 312                         4.0                         4.0
# 313                         2.0                         2.0
#
#      c: 1.6; k: 0.8,0.9,1.9; xy  c: 1.7; k: 0.8,0.9,1.9; xy  \
# 0                           4.0                         4.0
# 1                           7.0                         7.0
# 2                           4.0                         4.0
# 3                           7.0                         7.0
# 4                           6.0                         6.0
# ..                          ...                         ...
# 309                         3.0                         3.0
# 310                         2.0                         1.0
# 311                         1.0                         1.0
# 312                         4.0                         4.0
# 313                         2.0                         2.0
#
#      c: 1.8; k: 0.8,0.9,1.9; xy  c: 1.9; k: 0.8,0.9,1.9; xy  error       ID
# 0                           4.0                         4.0  0.723       a1
# 1                           7.0                         7.0  0.785       a3
# 2                           4.0                         4.0  0.806       a5
# 3                           7.0                         7.0  0.862      a11
# 4                           6.0                         6.0  0.806      a13
# ..                          ...                         ...    ...      ...
# 309                         3.0                         3.0    NaN  s37-d21
# 310                         1.0                         1.0    NaN  s37-d25
# 311                         1.0                         1.0    NaN  s37-d29
# 312                         4.0                         4.0    NaN  s37-d39
# 313                         2.0                         2.0    NaN  s37-d46
#
# [314 rows x 812 columns]

# %%
lowest_mean, lowest_mean_idx, lowest_median, results_median = processing.get_lowest_error(results_sum)

# %% [markdown]
# ### Plot best model with baselines

# %%
#%matplotlib inline
# %matplotlib qt

IDs = df['ID']

error = df['error']

#seqs= results_sum['sequence'][:-2].values

res = results_sum[lowest_mean_idx[0]][:-2].values
median = [np.nanmedian(res)] * len(res)

x = [x for x in range (0,len(res))]

# plot CPT baseline
#plt.scatter(x, cpt, marker='o', s=20, c='dodgerblue', alpha=0.3, 
#            label=str('CPT baseline median: ') + str(round(np.median(cpt),3)))
#plt.plot(x, [np.median(cpt)] * len(x), '-', c='dodgerblue', alpha=0.9, linewidth=2)
#plt.plot((x_original,x_original),(res_original,distances), '--', c='darkgreen', alpha=0.6)
#plt.fill_between(x, cpt, alpha=0.3, color='dodgerblue')


# plot NN baseline
plt.scatter(x, nn_results, marker='o', s=20, c='navy', alpha=0.8, 
            label=str('NN baseline median: ') + str(round(np.median(nn_results),3)))
plt.plot(x, [np.median(nn_results)] * len(x), '-', c='dodgerblue', alpha=0.9, linewidth=2)
#plt.plot((x_original,x_original),(res_original,distances), '--', c='darkgreen', alpha=0.6)
plt.fill_between(x, nn_results, alpha=0.3, color='dodgerblue')


# plot scatter + lines for simulations
plt.scatter(x, res, marker='o', s=26, c='darkred', alpha=0.8, 
            label=str('model-generated median: ') + str(round(lowest_median,3)))
#plt.plot(x, res, c='blue', alpha=0.6)
plt.plot(x, median, c='darkred', alpha=0.95, linewidth=2)
#plt.fill_between(x, res, alpha=0.3, color='darkviolet')


plt.xticks(x, labels=IDs, rotation=90, fontsize=5)
#plt.xticklabels(IDs, rotation=90, fontsize=6)

plt.ylabel('accumulated prediction error', fontsize=22)
plt.xlabel('sequence', fontsize=22)
#plt.ylim(0.0, 0.51)
plt.title('best model: ' + str(lowest_mean_idx[0]), fontsize=24, pad=20)
plt.margins(0.01)

lgnd = plt.legend(fontsize=20, framealpha=0.8, loc='upper right', markerscale=2.5)
lgnd.legendHandles[0]._sizes = [70]
lgnd.legendHandles[1]._sizes = [70]

#plt.savefig('plot_median_editdist_individualerrors_diff.png', bbox_inches='tight')
plt.show()

# %% [markdown]
# ### second version

# %%
#%matplotlib inline
# %matplotlib qt

IDs = df['ID']
error = df['error']
res = results_sum[lowest_mean_idx[0]][:-2].values
median = [np.nanmedian(res)] * len(res)
x = [x for x in range (0,len(res))]

cmap_blue = cmr.get_sub_cmap('Blues', 0.5, 0.95)
cmap_red = cmr.get_sub_cmap('Reds', 0.5, 0.95)

# plot CPT baseline
#plt.scatter(x, cpt, marker='o', s=20, c='dodgerblue', alpha=0.3, 
#            label=str('CPT baseline median: ') + str(round(np.median(cpt),3)))
#plt.plot(x, [np.median(cpt)] * len(x), '-', c='dodgerblue', alpha=0.9, linewidth=2)
#plt.plot((x_original,x_original),(res_original,distances), '--', c='darkgreen', alpha=0.6)
#plt.fill_between(x, cpt, alpha=0.3, color='dodgerblue')


# plot NN baseline
plt.scatter(x, nn_results, marker='o', s=[(item+1)*6 for item in nn_results], 
            c=nn_results, cmap=cmap_blue, alpha=0.8,
            label=str('NN baseline median: ') + str(round(np.median(nn_results),3)))
plt.plot(x, [np.median(nn_results)] * len(x), '-', c='dodgerblue', alpha=0.9, linewidth=2)
#plt.plot((x_original,x_original),(res_original,distances), '--', c='darkgreen', alpha=0.6)
#plt.fill_between(x, nn_results, alpha=0.3, color='dodgerblue')


# plot scatter + lines for simulations
plt.scatter(x, res, marker='o', s=[(item+1)*6 for item in res], 
            c=res, alpha=0.8, cmap=cmap_red,
            label=str('model-generated median: ') + str(round(lowest_median,3)))
#plt.plot(x, res, c='blue', alpha=0.6)
plt.plot(x, median, c='darkred', alpha=0.95, linewidth=2)
#plt.fill_between(x, res, alpha=0.3, color='darkviolet')


plt.xticks(x, labels=IDs, rotation=90, fontsize=5)
#plt.xticklabels(IDs, rotation=90, fontsize=6)

plt.ylabel('accumulated prediction error', fontsize=22)
plt.xlabel('sequence', fontsize=22)
#plt.ylim(0.0, 0.51)
plt.title('best model: ' + str(lowest_mean_idx[0]), fontsize=24, pad=20)
plt.margins(0.01)

lgnd = plt.legend(fontsize=20, framealpha=0.8, loc='upper right', markerscale=2.5)
lgnd.legendHandles[0]._sizes = [70]
lgnd.legendHandles[1]._sizes = [70]

#plt.savefig('plot_median_editdist_individualerrors_diff.png', bbox_inches='tight')
plt.show()

# %% [markdown]
# ### Prep data for stat analysis

# %%
# Get errors for model
list_xy = []

for col in results_sum:
    if col != 'sequence' and col != 'ID' and col != 'error' and col.split(';')[2].strip() == 'xy':
        list_xy.append(results_sum.at['mean',col])
        
avg_xy = np.mean(list_xy)
med_xy = np.median(list_xy)
std_xy = np.std(list_xy)
print('Average xy: ' + str(avg_xy)  + ', stdev: ' + str(std_xy) + ', median: ' + str(med_xy))
# Out:
# Average xy: 4.271179337231969, stdev: 0.20150529419847138, median: 4.213157894736842

# %%
# model vs NN
stat, p = wilcoxon(res, nn_results, zero_method='wilcox')
print('Wilcoxon: W = %.3f, p = %.5f' % (stat, p))
# Out:
# Wilcoxon: W = 1544.500, p = 0.00000

# %%
# get sequences where OPM performs worse than baseline

worse_than_nn = results_sum[lowest_mean_idx[0]].loc[results_sum[lowest_mean_idx[0]] >= 4.0]
worse_than_nn_sequences = [results_sum.at[x, 'sequence'] for x in worse_than_nn.index]

len(worse_than_nn_sequences)
# Out:
# 105

# %%
# get sequences where NN performs worse than baseline

worse_than_opm = [i for i in nn_results if i > 4.0]

len(worse_than_opm)
# Out:
# 18
