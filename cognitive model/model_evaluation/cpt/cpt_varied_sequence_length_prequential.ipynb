# %%
import pandas as pd
import numpy as np
from fastDamerauLevenshtein import damerauLevenshtein
import ast
import math

# %%
class Prediction():
    Item = None
    Parent = None
    Children = None

    def __init__(self, itemValue=None):
        self.Item = itemValue
        self.Children = []
        self.Parent = None

    def get_child(self, target):
        for chld in self.Children:
            if chld.Item == target:
                return chld
        return None

    def get_children(self):
        return self.Children

    def has_child(self, target):
        found = self.get_child(target)
        if found is not None:
            return True
        else:
            return False

    def add_new_child(self, child):
        newchild = Prediction(child)
        newchild.Parent = self
        self.Children.append(newchild)

    def remove_child(self, child):
        for chld in self.Children:
            if chld.Item == child:
                self.Children.remove(chld)

# %%
class CPT():
    alphabet = None
    root = None
    II = None
    LT = None
    def __init__(self):
        self.alphabet = set()
        self.root = Prediction()
        self.II = {}
        self.LT = {}

    def load_files(self, train_file, test_file=None):
        """
        This function reads in the wide csv file of sequences separated by commas and returns a list of list of 
        those sequences. The sequences are defined as below.
        seq1 = A,B,C,D
        seq2  B,C,E
        Returns: [[A,B,C,D],[B,C,E]]
        """
        
        data = []
        target = []

        if train_file is None:
            return train_file

        train = pd.read_csv(train_file, header=0)

        for index, row in train.iterrows():
            data.append(row.values)

        if test_file is not None:

            test = pd.read_csv(test_file, header=None)

            for index, row in test.iterrows():
                data.append(row.values)
                target.append(list(row.values))

            return data, target

        return data


    def train(self, data):
        """
         This functions populates the Prediction Tree, Inverted Index and LookUp Table for the algorithm.
         Input: The list of list training data
         Output : Boolean True
         """

        cursornode = self.root

        for seqid, row in enumerate(data):
            for element in row:
                if element == element: # different sequence length support
                    
                    if cursornode.has_child(element) == False:
                        cursornode.add_new_child(element)
                        cursornode = cursornode.get_child(element)
                    else:
                        cursornode = cursornode.get_child(element)

                # adding to the inverted index

                    if self.II.get(element) is None:
                        self.II[element] = set()

                    self.II[element].add(seqid)

                    self.alphabet.add(element)

            self.LT[seqid] = cursornode

            cursornode = self.root

        return True

    def score(self, counttable, key, length, target_size, number_of_similar_sequences, number_items_counttable):
        """
         This functions populates the Prediction Tree, Inverted Index and LookUp Table for the algorithm.
         Input: The list of list training data
         Output : Boolean True
         """
        
        weight_level = 1 / number_of_similar_sequences
        weight_distance = 1 / number_items_counttable
        score = 1 + weight_level + weight_distance * 0.001

        if counttable.get(key) is None:
            counttable[key] = score
        else:
            counttable[key] = score * counttable.get(key)

        return counttable

    def predict(self, data, target, k, n):
        """
        Here target is the test dataset in the form of list of list,
        k is the number of last elements that will be used to find similar sequences and,
        n is the number of predictions required.
        Input: training list of list, target list of list, k,n
        Output: max n predictions for each sequence
        """

        predictions = []

        for index, each_target in enumerate(target):
            #n = int(n_list[index])
            
            # different sequence length support
            i = 0
            while i < len(each_target) and each_target[i] == each_target[i]:  # find NaN start
                i = i + 1
            l = i - k - 1
            if l < 0:
                l = 0
            
            each_target = each_target[l:i]

            intersection = set(range(0, len(data)))

            for element in each_target:
                if self.II.get(element) is None:
                    continue
                intersection = intersection & self.II.get(element)

            similar_sequences = []

            for element in intersection:
                currentnode = self.LT.get(element)
                tmp = []
                while currentnode.Item is not None:
                    tmp.append(currentnode.Item)
                    currentnode = currentnode.Parent
                similar_sequences.append(tmp)

            for sequence in similar_sequences:
                sequence.reverse()

            counttable = {}

            for sequence in similar_sequences:
                try:
                    index = next(
                        i for i, v in zip(range(len(sequence) - 1, 0, -1), reversed(sequence)) if v == each_target[-1])
                except:
                    index = None
                if index is not None:
                    count = 1
                    for element in sequence[index + 1:]:
                        if element in each_target:
                            continue

                        counttable = self.score(counttable, element, len(each_target), len(each_target),
                                                len(similar_sequences), count)
                        count += 1

            pred = self.get_n_largest(counttable, n)
            predictions.append(pred)

        return predictions

    def get_n_largest(self, dictionary, n):

        largest = sorted(dictionary.items(), key=lambda t: t[1], reverse=True)[:n]
        return [key for key, _ in largest]

# %%
model = CPT()

# %%
data, target = model.load_files('data/all_data_train.csv', 'data/all_data_test_7.csv')

# %%
model.train(data)
# Out:
# True

# %%
# get length of each sequence (ignoring nan) minus given sequence in test
n_list = [np.count_nonzero(~pd.isnull(x)) - 1 for x in data]
n_list = [x if x > 0 else 0 for x in n_list]

# %%
predictions = model.predict(data, target, 7, n_list)

# %%
i = 0
distances = []

for elem in predictions:
    pred = [x for x in target[i] if str(x) != 'nan']
    dat = [x for x in data[i] if str(x) != 'nan']
    predicted = str(''.join(pred) + ''.join(elem))
    observed = ''.join(dat)
    dl = 1 - damerauLevenshtein(predicted, observed)
    distances.append(dl)
    print(target[i])
    print('for sequence {0} prediction is {1}'.format(i, elem))
    print('edit distance between {0} and {1}: {2}'.format(observed, predicted, dl))
    i += 1
    print('----------')

print('Average similarity: {0}'.format(np.mean(distances)))
print('Median similarity: {0}'.format(np.median(distances)))
# Out:
# ['p', 'o', 'c', 'g', 'k', 'r', nan]
# for sequence 0 prediction is ['f', 'e', 's', 'w', 't']
# edit distance between pocgkr and pocgkrfeswt: 0.4545454545454546
# ----------
# ['c', 'g', 'w', 'p', 'c', 'f', 'k']
# for sequence 1 prediction is ['s', 'r', 'e', 'o', 't']
# edit distance between cgwpcfks and cgwpcfksreot: 0.33333333333333337
# ----------
# ['k', 'f', 's', 'f', 'k', 's', 'p']
# for sequence 2 prediction is ['g', 'c', 'a', 'b', 'r', 'o', 'w', 'e']
# edit distance between kfsfkspwg and kfsfkspgcabrowe: 0.4666666666666667
# ----------
# ['p', 'f', 'k', 's', 'w', 'k', 'f']
# for sequence 3 prediction is ['r', 'o', 'e', 'c', 'g', 't']
# edit distance between pfkswkfsococg and pfkswkfroecgt: 0.3076923076923077
# ----------
# ['w', 'p', 't', 'g', 'k', 'f', 's']
# for sequence 4 prediction is ['c', 'o', 'r', 'e']
# edit distance between wptgkfsoc and wptgkfscore: 0.2727272727272727
# ----------
# ['p', 'w', 'f', 'k', 'g', nan, nan]
# for sequence 5 prediction is ['s', 'r', 'e', 'c']
# edit distance between pwfkg and pwfkgsrec: 0.4444444444444444
# ----------
# ['p', 'o', 'w', 'c', 'e', 'r', nan]
# for sequence 6 prediction is ['k', 's', 'f', 't']
# edit distance between powcer and powcerksft: 0.4
# ----------
# ['c', 'o', 'p', 'r', 'e', 'r', 'k']
# for sequence 7 prediction is ['s', 'f', 't', 'w', 'g']
# edit distance between coprerk and coprerksftwg: 0.41666666666666663
# ----------
# ['w', 'o', 'p', 'o', 'f', 'k', 'k']
# for sequence 8 prediction is ['s', 'r', 'e', 'c', 'g', 't']
# edit distance between wopofkkskf and wopofkksrecgt: 0.3846153846153846
# ----------
# ['o', 'p', 'w', 'p', 'w', 'g', 'c']
# for sequence 9 prediction is ['k', 'f', 'r', 's', 'e', 't']
# edit distance between opwpwgcoc and opwpwgckfrset: 0.46153846153846156
# ----------
# ['p', 'o', 'c', 'r', 'f', 'k', 's']
# for sequence 10 prediction is ['e', 'w', 'g', 't']
# edit distance between pocrfksfks and pocrfksewgt: 0.36363636363636365
# ----------
# ['c', 'g', 'p', 'o', 'g', 'p', 'o']
# for sequence 11 prediction is ['k', 'f', 'w', 'r', 's', 'e', 't']
# edit distance between cgpogpoc and cgpogpokfwrset: 0.5
# ----------
# ['p', 'w', 'o', 'c', 'g', 'f', 'k']
# for sequence 12 prediction is ['s', 'r', 'e', 't']
# edit distance between pwocgfkfsrere and pwocgfksret: 0.23076923076923073
# ----------
# ['o', 'c', 'w', 'g', 'r', 'k', nan]
# for sequence 13 prediction is ['s', 'f', 'e', 't']
# edit distance between ocwgrk and ocwgrksfet: 0.4
# ----------
# ['w', 'p', 'g', 's', 'f', 'k', nan]
# for sequence 14 prediction is ['r', 'e', 'c', 'o', 't']
# edit distance between wpgsfk and wpgsfkrecot: 0.4545454545454546
# ----------
# ['p', 'w', 'o', 'f', 's', 'g', nan]
# for sequence 15 prediction is ['k', 'r', 'e', 'c', 't']
# edit distance between pwofsg and pwofsgkrect: 0.4545454545454546
# ----------
# ['p', 'o', 'c', 'p', 'o', 'c', 'w']
# for sequence 16 prediction is ['k', 'f', 'g', 'r', 's', 'e', 't']
# edit distance between pocpocwgkfs and pocpocwkfgrset: 0.3571428571428571
# ----------
# ['p', 'o', 'c', 'g', 'w', 'g', nan]
# for sequence 17 prediction is ['k', 'f', 'r', 's', 'e']
# edit distance between pocgwg and pocgwgkfrse: 0.4545454545454546
# ----------
# ['p', 'w', 'g', 'o', 'c', 'k', 'f']
# for sequence 18 prediction is ['s', 'r', 'e', 't']
# edit distance between pwgockfsfksret and pwgockfsret: 0.2142857142857143
# ----------
# ['o', 'c', 'p', 'w', 'g', 'f', 'k']
# for sequence 19 prediction is ['s', 'r', 'e', 't']
# edit distance between ocpwgfkskfsrere and ocpwgfksret: 0.33333333333333337
# ----------
# ['c', 'o', 'p', 'w', 'g', 'w', 'p']
# for sequence 20 prediction is ['k', 'f', 's', 'r', 'e', 't']
# edit distance between copwgwpresk and copwgwpkfsret: 0.3846153846153846
# ----------
# ['p', 'w', 't', 'e', 'r', 'f', 'k']
# for sequence 21 prediction is ['s', 'c', 'o', 'g']
# edit distance between pwterfkf and pwterfkscog: 0.36363636363636365
# ----------
# ['p', 'o', 'c', 'w', 'g', 'g', 'p']
# for sequence 22 prediction is ['k', 'f', 's', 'r', 'e', 't']
# edit distance between pocwggpfkfksrer and pocwggpkfsret: 0.19999999999999996
# ----------
# ['w', 'p', 'o', 'f', 'c', 'g', 'k']
# for sequence 23 prediction is ['s', 'r', 'e', 't']
# edit distance between wpofcgkrpwgfksocr and wpofcgksret: 0.5294117647058824
# ----------
# ['c', 'w', 'p', 'f', 'k', 's', 'o']
# for sequence 24 prediction is ['r', 'g', 'e', 't']
# edit distance between cwpfksor and cwpfksorget: 0.2727272727272727
# ----------
# ['p', 'w', 'f', 'k', 's', 'o', 'r']
# for sequence 25 prediction is ['e', 'c', 't']
# edit distance between pwfksorc and pwfksorect: 0.19999999999999996
# ----------
# ['p', 'o', 'c', 'g', 'w', 'k', 'f']
# for sequence 26 prediction is ['s', 'r', 'e', 't']
# edit distance between pocgwkfkfser and pocgwkfsret: 0.33333333333333337
# ----------
# ['p', 'o', 'w', 'c', 't', 'g', 'c']
# for sequence 27 prediction is ['f', 'k', 'r', 's', 'e']
# edit distance between powctgcog and powctgcfkrse: 0.41666666666666663
# ----------
# ['p', 'o', 'w', 'g', 'c', 'p', 'o']
# for sequence 28 prediction is ['k', 'f', 'r', 's', 'e', 't']
# edit distance between powgcpo and powgcpokfrset: 0.46153846153846156
# ----------
# ['p', 'w', 'f', 'k', 't', nan, nan]
# for sequence 29 prediction is ['g', 's', 'r', 'c']
# edit distance between pwfkt and pwfktgsrc: 0.4444444444444444
# ----------
# ['p', 'w', 'o', 'k', 'f', 'k', 'r']
# for sequence 30 prediction is ['e', 's', 'g', 'c', 't']
# edit distance between pwokfkrg and pwokfkresgct: 0.33333333333333337
# ----------
# ['c', 'o', 'p', 'c', 'o', 'g', 'p']
# for sequence 31 prediction is ['k', 'f', 's', 'r', 'w', 't', 'e', 'b']
# edit distance between copcogpgwfksr and copcogpkfsrwteb: 0.4666666666666667
# ----------
# ['p', 'g', 's', 'f', 'k', 's', 'k']
# for sequence 32 prediction is ['c', 'a', 'b', 'r', 'e', 'o', 'w', 't']
# edit distance between pgsfkskfg and pgsfkskcabreowt: 0.5333333333333333
# ----------
# ['w', 'g', 'p', 't', 'o', 'c', 'o']
# for sequence 33 prediction is ['k', 'f', 'r', 's', 'e']
# edit distance between wgptocopwg and wgptocokfrse: 0.41666666666666663
# ----------
# ['p', 'o', 'w', 'c', 'g', 'r', 'e']
# for sequence 34 prediction is ['k', 's', 'f', 't']
# edit distance between powcgre and powcgreksft: 0.36363636363636365
# ----------
# ['p', 'e', 'r', 'k', 's', 'c', 'w']
# for sequence 35 prediction is ['f', 'g', 'o', 't']
# edit distance between perkscwgtf and perkscwfgot: 0.2727272727272727
# ----------
# ['p', 'c', 'g', 'w', 'o', 'r', 'k']
# for sequence 36 prediction is ['s', 'f', 'e', 't']
# edit distance between pcgworkfkfs and pcgworksfet: 0.36363636363636365
# ----------
# ['p', 'o', 'p', 'o', 'c', 'g', 'k']
# for sequence 37 prediction is ['r', 'f', 's', 'e', 'w', 'b', 't']
# edit distance between popocgkr and popocgkrfsewbt: 0.4285714285714286
# ----------
# ['p', 'w', 't', 'g', 'c', 'f', 'k']
# for sequence 38 prediction is ['s', 'r', 'o', 'e']
# edit distance between pwtgcfkfksr and pwtgcfksroe: 0.36363636363636365
# ----------
# ['p', 'o', 'c', 'w', 'k', 'f', nan]
# for sequence 39 prediction is ['s', 'r', 'e', 'g', 't']
# edit distance between pocwkf and pocwkfsregt: 0.4545454545454546
# ----------
# ['p', 'g', 'k', 'f', 'k', 'f', nan]
# for sequence 40 prediction is ['s', 'c', 'a', 'b', 'r']
# edit distance between pgkfkf and pgkfkfscabr: 0.4545454545454546
# ----------
# ['c', 'w', 'o', 'p', 'g', nan, nan]
# for sequence 41 prediction is ['k', 'f', 'r', 's']
# edit distance between cwopg and cwopgkfrs: 0.4444444444444444
# ----------
# ['p', 'o', 'w', 'c', 'g', 'k', 'f']
# for sequence 42 prediction is ['s', 'r', 'e', 't']
# edit distance between powcgkfkfr and powcgkfsret: 0.36363636363636365
# ----------
# ['w', 'p', 'g', 'f', 'k', 's', 'k']
# for sequence 43 prediction is ['r', 'e', 'c', 'o', 't']
# edit distance between wpgfksk and wpgfkskrecot: 0.41666666666666663
# ----------
# ['p', 'o', 'c', 'w', 'c', 'p', 'o']
# for sequence 44 prediction is ['k', 'f', 'g', 'r', 's', 'e', 't']
# edit distance between pocwcpoere and pocwcpokfgrset: 0.3571428571428571
# ----------
# ['p', 'w', 'k', 'f', nan, nan, nan]
# for sequence 45 prediction is ['s', 'r', 'g']
# edit distance between pwkf and pwkfsrg: 0.4285714285714286
# ----------
# ['c', 'p', 't', 'g', 'o', nan, nan]
# for sequence 46 prediction is ['k', 'f', 'w', 'r']
# edit distance between cptgo and cptgokfwr: 0.4444444444444444
# ----------
# ['p', 'o', 'c', 'f', 'k', 's', 'w']
# for sequence 47 prediction is ['r', 'g', 'e', 't']
# edit distance between pocfkswgr and pocfkswrget: 0.2727272727272727
# ----------
# ['p', 'o', 'w', 'c', 'f', 'k', 'f']
# for sequence 48 prediction is ['s', 'r', 'e', 'g', 't']
# edit distance between powcfkfk and powcfkfsregt: 0.41666666666666663
# ----------
# ['p', 'w', 'g', 'f', 'k', 's', 'f']
# for sequence 49 prediction is ['r', 'e', 'o', 'c', 't']
# edit distance between pwgfksfk and pwgfksfreoct: 0.41666666666666663
# ----------
# ['g', 'p', 'w', 'f', 'k', 's', nan]
# for sequence 50 prediction is ['r', 'e', 'c', 'o', 't']
# edit distance between gpwfks and gpwfksrecot: 0.4545454545454546
# ----------
# ['c', 'g', 'w', 'p', 'w', nan, nan]
# for sequence 51 prediction is ['k', 'f', 'r', 'o']
# edit distance between cgwpw and cgwpwkfro: 0.4444444444444444
# ----------
# ['c', 'w', 'o', 'p', 'g', 't', 'r']
# for sequence 52 prediction is ['k', 'f', 's', 'e']
# edit distance between cwopgtrekfksksf and cwopgtrkfse: 0.33333333333333337
# ----------
# ['p', 'o', 'c', 's', 'f', 'k', 'w']
# for sequence 53 prediction is ['r', 'g', 'e', 't']
# edit distance between pocsfkw and pocsfkwrget: 0.36363636363636365
# ----------
# ['o', 'c', 'p', 'w', 'g', 'f', 'k']
# for sequence 54 prediction is ['s', 'r', 'e', 't']
# edit distance between ocpwgfkf and ocpwgfksret: 0.36363636363636365
# ----------
# ['p', 'w', 'g', 't', 'e', 'r', 'k']
# for sequence 55 prediction is ['s', 'f', 'c', 'o']
# edit distance between pwgterkfsoc and pwgterksfco: 0.18181818181818177
# ----------
# ['p', 'o', 'c', 'g', 'w', 'r', 'k']
# for sequence 56 prediction is ['s', 'f', 'e', 't']
# edit distance between pocgwrkfs and pocgwrksfet: 0.2727272727272727
# ----------
# ['t', 'g', 'c', 'w', 'p', 'r', 'o']
# for sequence 57 prediction is ['k', 'f', 's', 'e']
# edit distance between tgcwpro and tgcwprokfse: 0.36363636363636365
# ----------
# ['p', 'o', 'c', 'g', 'k', 'f', 's']
# for sequence 58 prediction is ['r', 'e', 'w', 'b', 't']
# edit distance between pocgkfskfr and pocgkfsrewbt: 0.41666666666666663
# ----------
# ['p', 'g', 'c', 'o', 'w', nan, nan]
# for sequence 59 prediction is ['k', 'f', 'r', 's']
# edit distance between pgcow and pgcowkfrs: 0.4444444444444444
# ----------
# ['o', 'p', 'w', 'g', nan, nan, nan]
# for sequence 60 prediction is ['k', 'f', 'r']
# edit distance between opwg and opwgkfr: 0.4285714285714286
# ----------
# ['w', 'p', 'g', 'c', 'o', 'w', 'p']
# for sequence 61 prediction is ['k', 'f', 's', 'r', 'e', 't']
# edit distance between wpgcowpcfksre and wpgcowpkfsret: 0.23076923076923073
# ----------
# ['r', 'e', nan, nan, nan, nan, nan]
# for sequence 62 prediction is ['k']
# edit distance between re and rek: 0.33333333333333337
# ----------
# ['p', 't', 'w', 'g', 'f', 'k', 's']
# for sequence 63 prediction is ['c', 'o', 'r', 'e']
# edit distance between ptwgfks and ptwgfkscore: 0.36363636363636365
# ----------
# ['p', 'o', 'c', 'r', 'f', 'k', 'f']
# for sequence 64 prediction is ['s', 'e', 'g', 'w', 't']
# edit distance between pocrfkfk and pocrfkfsegwt: 0.41666666666666663
# ----------
# ['p', 'o', 'c', 'k', 'r', nan, nan]
# for sequence 65 prediction is ['f', 's', 'e', 'g']
# edit distance between pockr and pockrfseg: 0.4444444444444444
# ----------
# ['p', 'o', 'c', 'k', 'f', 's', 'k']
# for sequence 66 prediction is ['r', 'e', 'w', 'g', 'b', 't']
# edit distance between pockfskfswgre and pockfskrewgbt: 0.3076923076923077
# ----------
# ['t', 'g', 'p', 'c', 'o', 'w', 'p']
# for sequence 67 prediction is ['r', 'k', 'f', 's', 'e']
# edit distance between tgpcowpgpwcog and tgpcowprkfse: 0.46153846153846156
# ----------
# ['g', 'w', 'p', 'f', 'r', 'k', 's']
# for sequence 68 prediction is ['e', 'c', 't', 'o']
# edit distance between gwpfrkst and gwpfrksecto: 0.2727272727272727
# ----------
# ['p', 'f', 'k', 'f', 'k', 's', 'g']
# for sequence 69 prediction is ['a', 'c', 'b', 'r', 'e', 'w']
# edit distance between pfkfksg and pfkfksgacbrew: 0.46153846153846156
# ----------
# ['p', 'w', 'o', 'g', 's', 'f', 'k']
# for sequence 70 prediction is ['r', 'e', 'c', 't']
# edit distance between pwogsfkg and pwogsfkrect: 0.36363636363636365
# ----------
# ['p', 'w', 'k', 'f', nan, nan, nan]
# for sequence 71 prediction is ['s', 'r', 'g']
# edit distance between pwkf and pwkfsrg: 0.4285714285714286
# ----------
# ['g', 'w', 'p', 'o', 'c', 'o', 's']
# for sequence 72 prediction is ['r', 'e', 'f', 'k', 't']
# edit distance between gwpocoskfsfk and gwpocosrefkt: 0.33333333333333337
# ----------
# ['w', 't', 'p', 'c', 'o', 'c', 'k']
# for sequence 73 prediction is ['f', 's', 'g', 'r', 'e']
# edit distance between wtpcockfkf and wtpcockfsgre: 0.33333333333333337
# ----------
# ['w', 'p', 'g', 'f', 'k', 'f', 'k']
# for sequence 74 prediction is ['s', 'r', 'e', 'c', 'o', 't']
# edit distance between wpgfkfkre and wpgfkfksrecot: 0.3076923076923077
# ----------
# ['p', 'o', 'c', 'o', 'c', 'w', 't']
# for sequence 75 prediction is ['k', 'f', 'g', 'r', 's', 'e']
# edit distance between pococwtrfkfkg and pococwtkfgrse: 0.3846153846153846
# ----------
# ['p', 'w', 'o', 'c', 'f', 'k', 's']
# for sequence 76 prediction is ['r', 'e', 'g', 't']
# edit distance between pwocfksfksr and pwocfksregt: 0.36363636363636365
# ----------
# ['p', 'w', 'g', 'e', 'r', 'k', 's']
# for sequence 77 prediction is ['c', 't', 'f', 'o']
# edit distance between pwgerks and pwgerksctfo: 0.36363636363636365
# ----------
# ['p', 'o', 'c', 't', 'f', 'k', 'f']
# for sequence 78 prediction is ['s', 'r', 'g', 'w', 'e']
# edit distance between poctfkfkrwg and poctfkfsrgwe: 0.25
# ----------
# ['p', 'w', 'f', 'k', 's', 'o', 'c']
# for sequence 79 prediction is ['r', 'g', 'e', 't']
# edit distance between pwfksocr and pwfksocrget: 0.2727272727272727
# ----------
# ['t', 'n', 'p', 'z', 'c', nan, nan]
# for sequence 80 prediction is []
# edit distance between tnpzc and tnpzc: 0.0
# ----------
# ['t', 'n', 'p', 'c', 'z', nan, nan]
# for sequence 81 prediction is []
# edit distance between tnpcz and tnpcz: 0.0
# ----------
# ['t', 'n', 'p', 'z', 'c', nan, nan]
# for sequence 82 prediction is []
# edit distance between tnpzc and tnpzc: 0.0
# ----------
# ['t', 'n', 'z', 'p', 'c', nan, nan]
# for sequence 83 prediction is []
# edit distance between tnzpc and tnzpc: 0.0
# ----------
# ['p', 'm', 'z', nan, nan, nan, nan]
# for sequence 84 prediction is ['x']
# edit distance between pmz and pmzx: 0.25
# ----------
# ['x', 'm', 'b', 'z', 'd', nan, nan]
# for sequence 85 prediction is []
# edit distance between xmbzd and xmbzd: 0.0
# ----------
# ['p', 'I', 'm', 'z', nan, nan, nan]
# for sequence 86 prediction is []
# edit distance between pImz and pImz: 0.0
# ----------
# ['m', 'z', 'x', 'p', nan, nan, nan]
# for sequence 87 prediction is []
# edit distance between mzxp and mzxp: 0.0
# ----------
# ['p', 'b', 'z', nan, nan, nan, nan]
# for sequence 88 prediction is []
# edit distance between pbz and pbz: 0.0
# ----------
# ['p', 'g', 'z', nan, nan, nan, nan]
# for sequence 89 prediction is ['d', 'a']
# edit distance between pgz and pgzda: 0.4
# ----------
# ['p', 'n', 'z', 'g', 'a', nan, nan]
# for sequence 90 prediction is []
# edit distance between pnzga and pnzga: 0.0
# ----------
# ['d', 'n', 'z', 'g', 'd', 'p', nan]
# for sequence 91 prediction is ['s']
# edit distance between dnzgdp and dnzgdps: 0.1428571428571429
# ----------
# ['p', 'n', 'd', 'z', nan, nan, nan]
# for sequence 92 prediction is ['g', 's']
# edit distance between pndz and pndzgs: 0.33333333333333337
# ----------
# ['n', 'z', 'p', 'd', 'g', 'd', 's']
# for sequence 93 prediction is []
# edit distance between nzpdgds and nzpdgds: 0.0
# ----------
# ['m', 'c', 'd', 'd', 'x', 'p', nan]
# for sequence 94 prediction is []
# edit distance between mcddxp and mcddxp: 0.0
# ----------
# ['p', 'c', 'f', 'k', 'd', 'd', 'd']
# for sequence 95 prediction is ['a', 'g']
# edit distance between pcfkdddaag and pcfkdddag: 0.09999999999999998
# ----------
# ['d', 'a', 'g', 'p', 'k', nan, nan]
# for sequence 96 prediction is ['f']
# edit distance between dagpk and dagpkf: 0.16666666666666663
# ----------
# ['p', 'c', nan, nan, nan, nan, nan]
# for sequence 97 prediction is ['g']
# edit distance between pc and pcg: 0.33333333333333337
# ----------
# ['g', 'k', 'f', 'a', 'd', 'p', nan]
# for sequence 98 prediction is []
# edit distance between gkfadp and gkfadp: 0.0
# ----------
# ['p', 'f', 'g', 'd', 's', nan, nan]
# for sequence 99 prediction is []
# edit distance between pfgds and pfgds: 0.0
# ----------
# ['b', 'c', 's', 'f', 'g', 'k', 'a']
# for sequence 100 prediction is ['p']
# edit distance between bcsfgkap and bcsfgkap: 0.0
# ----------
# ['p', 'b', 's', 'f', 'k', 'c', 'g']
# for sequence 101 prediction is ['a']
# edit distance between pbsfkcga and pbsfkcga: 0.0
# ----------
# ['p', 'b', 'g', 'a', 'f', 'k', 'c']
# for sequence 102 prediction is ['s']
# edit distance between pbgafkcs and pbgafkcs: 0.0
# ----------
# ['g', 'p', 'b', 'c', 'k', 's', 'f']
# for sequence 103 prediction is ['a', 'o']
# edit distance between gpbcksfa and gpbcksfao: 0.11111111111111116
# ----------
# ['p', 'b', 'f', 'k', 's', 'c', 'g']
# for sequence 104 prediction is ['a']
# edit distance between pbfkscga and pbfkscga: 0.0
# ----------
# ['p', 'b', 's', 'g', 'k', 'a', 'f']
# for sequence 105 prediction is ['c']
# edit distance between pbsgkafc and pbsgkafc: 0.0
# ----------
# ['p', 'b', 'c', 's', 'k', 'f', 'g']
# for sequence 106 prediction is ['a']
# edit distance between pbcskfga and pbcskfga: 0.0
# ----------
# ['p', 's', 'f', 'k', 'a', 'g', 'c']
# for sequence 107 prediction is ['b']
# edit distance between psfkagcb and psfkagcb: 0.0
# ----------
# ['p', 'f', 'k', 's', 'c', 'a', 'g']
# for sequence 108 prediction is ['b']
# edit distance between pfkscagb and pfkscagb: 0.0
# ----------
# ['p', 'f', 's', 'k', 'a', 'g', 'c']
# for sequence 109 prediction is ['b']
# edit distance between pfskagcb and pfskagcb: 0.0
# ----------
# ['p', 's', 'k', 'f', 'c', 'a', 'g']
# for sequence 110 prediction is ['b']
# edit distance between pskfcagb and pskfcagb: 0.0
# ----------
# ['p', 'f', 'k', 's', 'c', 'a', 'g']
# for sequence 111 prediction is ['b']
# edit distance between pfkscagb and pfkscagb: 0.0
# ----------
# ['p', 's', 'f', 'k', 'g', 'a', 'c']
# for sequence 112 prediction is ['b']
# edit distance between psfkgacb and psfkgacb: 0.0
# ----------
# ['p', 'f', 'k', 'b', 's', 'c', 'g']
# for sequence 113 prediction is ['a']
# edit distance between pfkbscga and pfkbscga: 0.0
# ----------
# ['p', 'c', 'g', 'a', 'f', 'k', 'b']
# for sequence 114 prediction is ['s']
# edit distance between pcgafkbs and pcgafkbs: 0.0
# ----------
# ['g', 'p', 'a', 'b', 'k', 'f', 's']
# for sequence 115 prediction is ['c']
# edit distance between gpabkfsc and gpabkfsc: 0.0
# ----------
# ['p', 'a', 'b', 'k', 'g', 'c', 'f']
# for sequence 116 prediction is ['s']
# edit distance between pabkgcfs and pabkgcfs: 0.0
# ----------
# ['g', 'c', 'p', 'a', 'b', 'k', 'f']
# for sequence 117 prediction is ['s']
# edit distance between gcpabkfs and gcpabkfs: 0.0
# ----------
# ['p', 'a', 's', 'b', 'k', 'f', 'g']
# for sequence 118 prediction is ['c']
# edit distance between pasbkfgc and pasbkfgc: 0.0
# ----------
# ['p', 'a', 'b', 'c', 'g', 'k', 's']
# for sequence 119 prediction is ['f']
# edit distance between pabcgksf and pabcgksf: 0.0
# ----------
# ['s', 'f', 'k', 'p', 'c', 'g', 'a']
# for sequence 120 prediction is ['b']
# edit distance between sfkpcgab and sfkpcgab: 0.0
# ----------
# ['s', 'p', 'g', 'b', 'k', 'f', 'c']
# for sequence 121 prediction is ['a', 'o']
# edit distance between spgbkfca and spgbkfcao: 0.11111111111111116
# ----------
# ['s', 'p', 'a', 'k', 'g', 'f', 'c']
# for sequence 122 prediction is ['b']
# edit distance between spakgfcb and spakgfcb: 0.0
# ----------
# ['c', 'g', 'b', 'k', 'p', 'a', 's']
# for sequence 123 prediction is ['f']
# edit distance between cgbkpasf and cgbkpasf: 0.0
# ----------
# ['f', 'k', 's', 'p', 'c', 'b', 'a']
# for sequence 124 prediction is ['g']
# edit distance between fkspcbag and fkspcbag: 0.0
# ----------
# ['p', 'k', 'f', 's', 'b', 'g', 'c']
# for sequence 125 prediction is ['a', 'o']
# edit distance between pkfsbgca and pkfsbgcao: 0.11111111111111116
# ----------
# ['c', 'p', 'k', 'f', 'g', 's', 'b']
# for sequence 126 prediction is ['a']
# edit distance between cpkfgsba and cpkfgsba: 0.0
# ----------
# ['c', 'b', 'g', 's', 'f', 'a', 'p']
# for sequence 127 prediction is ['k']
# edit distance between cbgsfapk and cbgsfapk: 0.0
# ----------
# ['c', 'g', 'p', 's', 'a', 'k', 'f']
# for sequence 128 prediction is ['b']
# edit distance between cgpsakfb and cgpsakfb: 0.0
# ----------
# ['p', 'f', 'k', 's', 'g', 'c', 'a']
# for sequence 129 prediction is ['b']
# edit distance between pfksgcab and pfksgcab: 0.0
# ----------
# ['p', 'c', 's', 'k', 'f', 'b', 'g']
# for sequence 130 prediction is ['a']
# edit distance between pcskfbga and pcskfbga: 0.0
# ----------
# ['s', 'b', 'k', 'p', 'f', 'c', 'a']
# for sequence 131 prediction is ['g']
# edit distance between sbkpfcag and sbkpfcag: 0.0
# ----------
# ['f', 'p', 'k', 'g', 'b', 's', 'a']
# for sequence 132 prediction is ['c']
# edit distance between fpkgbsac and fpkgbsac: 0.0
# ----------
# ['p', 'a', 'b', 'f', 'g', 's', 'c']
# for sequence 133 prediction is ['k']
# edit distance between pabfgsck and pabfgsck: 0.0
# ----------
# ['c', 'p', 'g', 'f', 'k', 's', 'a']
# for sequence 134 prediction is ['b']
# edit distance between cpgfksab and cpgfksab: 0.0
# ----------
# ['g', 'f', 'c', 's', 'p', 'k', 'o']
# for sequence 135 prediction is ['r', 'w', 'e', 't', 'b']
# edit distance between gfcspkob and gfcspkorwetb: 0.33333333333333337
# ----------
# ['p', 'k', 'f', 's', 'b', 'a', 'g']
# for sequence 136 prediction is ['c']
# edit distance between pkfsbagc and pkfsbagc: 0.0
# ----------
# ['p', 'k', 'f', 's', 'b', 'g', 'a']
# for sequence 137 prediction is ['c']
# edit distance between pkfsbgac and pkfsbgac: 0.0
# ----------
# ['p', 'b', 'f', 'k', 's', 'c', 'g']
# for sequence 138 prediction is ['a']
# edit distance between pbfkscga and pbfkscga: 0.0
# ----------
# ['b', 'p', 'k', 's', 'f', 'c', 'g']
# for sequence 139 prediction is ['a']
# edit distance between bpksfcga and bpksfcga: 0.0
# ----------
# ['p', 'a', 'g', 'b', 'k', 'f', 's']
# for sequence 140 prediction is ['c']
# edit distance between pagbkfsc and pagbkfsc: 0.0
# ----------
# ['p', 'c', 'g', 'a', 'f', 'k', 's']
# for sequence 141 prediction is ['b']
# edit distance between pcgafksb and pcgafksb: 0.0
# ----------
# ['p', 'c', 's', 'b', 'f', 'k', 'g']
# for sequence 142 prediction is ['a']
# edit distance between pcsbfkga and pcsbfkga: 0.0
# ----------
# ['p', 'b', 's', 'k', 'f', 'g', 'c']
# for sequence 143 prediction is ['a', 'o']
# edit distance between pbskfgca and pbskfgcao: 0.11111111111111116
# ----------
# ['p', 's', 'c', 'g', 'f', 'b', 'a']
# for sequence 144 prediction is ['k']
# edit distance between pscgfbak and pscgfbak: 0.0
# ----------
# ['p', 'f', 'k', 'c', 'b', 'g', 's']
# for sequence 145 prediction is ['a', 'o']
# edit distance between pfkcbgsa and pfkcbgsao: 0.11111111111111116
# ----------
# ['p', 'k', 'f', 's', 'g', 'c', 'b']
# for sequence 146 prediction is ['a']
# edit distance between pkfsgcba and pkfsgcba: 0.0
# ----------
# ['p', 'c', 'f', 'k', 's', 'a', 'g']
# for sequence 147 prediction is ['b']
# edit distance between pcfksagb and pcfksagb: 0.0
# ----------
# ['p', 'b', 'c', 'f', 's', 'k', 'g']
# for sequence 148 prediction is ['a']
# edit distance between pbcfskga and pbcfskga: 0.0
# ----------
# ['p', 'b', 'f', 'k', 'c', 's', 'g']
# for sequence 149 prediction is ['a']
# edit distance between pbfkcsga and pbfkcsga: 0.0
# ----------
# ['p', 'c', 's', 'f', 'k', 'b', 'g']
# for sequence 150 prediction is ['a']
# edit distance between pcsfkbga and pcsfkbga: 0.0
# ----------
# ['p', 'k', 'f', 's', 'a', 'b', 'g']
# for sequence 151 prediction is ['c']
# edit distance between pkfsabgc and pkfsabgc: 0.0
# ----------
# ['p', 'k', 'f', 's', 'g', 'c', 'b']
# for sequence 152 prediction is ['a']
# edit distance between pkfsgcba and pkfsgcba: 0.0
# ----------
# ['p', 'k', 'f', 's', 'g', 'c', 'b']
# for sequence 153 prediction is ['a']
# edit distance between pkfsgcba and pkfsgcba: 0.0
# ----------
# ['p', 'k', 'f', 's', 'g', 'c', 'a']
# for sequence 154 prediction is ['b']
# edit distance between pkfsgcab and pkfsgcab: 0.0
# ----------
# ['p', 'k', 'f', 'b', 's', 'c', 'a']
# for sequence 155 prediction is ['g']
# edit distance between pkfbscag and pkfbscag: 0.0
# ----------
# ['p', 'k', 'b', 's', 'f', 'g', 'c']
# for sequence 156 prediction is ['a', 'o']
# edit distance between pkbsfgca and pkbsfgcao: 0.11111111111111116
# ----------
# ['p', 'k', 'f', 'b', 's', 'c', 'g']
# for sequence 157 prediction is ['a']
# edit distance between pkfbscga and pkfbscga: 0.0
# ----------
# ['p', 'k', 'f', 's', 'b', 'g', 'a']
# for sequence 158 prediction is ['c']
# edit distance between pkfsbgac and pkfsbgac: 0.0
# ----------
# ['p', 'k', 'f', 's', 'a', 'g', 'b']
# for sequence 159 prediction is ['c']
# edit distance between pkfsagbc and pkfsagbc: 0.0
# ----------
# ['p', 'k', 'f', 's', 'g', 'c', 'a']
# for sequence 160 prediction is ['b']
# edit distance between pkfsgcab and pkfsgcab: 0.0
# ----------
# ['p', 'k', 'f', 's', 'g', 'c', 'b']
# for sequence 161 prediction is ['a']
# edit distance between pkfsgcba and pkfsgcba: 0.0
# ----------
# ['p', 'k', 'f', 's', 'g', 'c', 'a']
# for sequence 162 prediction is ['b']
# edit distance between pkfsgcab and pkfsgcab: 0.0
# ----------
# ['p', 'k', 'f', 's', 'a', 'c', 'g']
# for sequence 163 prediction is ['b']
# edit distance between pkfsacgb and pkfsacgb: 0.0
# ----------
# ['p', 'k', 'f', 's', 'b', 'c', 'g']
# for sequence 164 prediction is ['a']
# edit distance between pkfsbcga and pkfsbcga: 0.0
# ----------
# ['p', 'f', 's', 'k', 'b', 'c', 'g']
# for sequence 165 prediction is ['a']
# edit distance between pfskbcga and pfskbcga: 0.0
# ----------
# ['p', 'b', 'k', 'f', 's', 'c', 'g']
# for sequence 166 prediction is ['a']
# edit distance between pbkfscga and pbkfscga: 0.0
# ----------
# ['p', 'f', 's', 'k', 'b', 'g', 'c']
# for sequence 167 prediction is ['a', 'o']
# edit distance between pfskbgca and pfskbgcao: 0.11111111111111116
# ----------
# ['h', 'h', 's', 'd', 'b', nan, nan]
# for sequence 168 prediction is ['g']
# edit distance between hhsdb and hhsdbg: 0.16666666666666663
# ----------
# ['h', 'h', 'h', 'd', 's', 'g', 'b']
# for sequence 169 prediction is []
# edit distance between hhhdsgb and hhhdsgb: 0.0
# ----------
# ['h', 'h', 's', 'g', 'd', 'b', nan]
# for sequence 170 prediction is []
# edit distance between hhsgdb and hhsgdb: 0.0
# ----------
# ['h', 'h', 'd', 's', 'b', 'g', nan]
# for sequence 171 prediction is []
# edit distance between hhdsbg and hhdsbg: 0.0
# ----------
# ['h', 'h', 's', 'g', 'd', 'b', nan]
# for sequence 172 prediction is []
# edit distance between hhsgdb and hhsgdb: 0.0
# ----------
# ['h', 'h', 'd', 's', 'g', 'b', nan]
# for sequence 173 prediction is []
# edit distance between hhdsgb and hhdsgb: 0.0
# ----------
# ['d', 's', 'g', 'b', 'h', 'h', nan]
# for sequence 174 prediction is []
# edit distance between dsgbhh and dsgbhh: 0.0
# ----------
# ['h', 'h', 's', 'd', 'b', 'g', nan]
# for sequence 175 prediction is []
# edit distance between hhsdbg and hhsdbg: 0.0
# ----------
# ['h', 'h', 's', 'd', 'g', 'b', nan]
# for sequence 176 prediction is []
# edit distance between hhsdgb and hhsdgb: 0.0
# ----------
# ['h', 'h', 's', 'g', 'd', 'b', nan]
# for sequence 177 prediction is []
# edit distance between hhsgdb and hhsgdb: 0.0
# ----------
# ['h', 'h', 's', 'g', 'd', 'b', nan]
# for sequence 178 prediction is []
# edit distance between hhsgdb and hhsgdb: 0.0
# ----------
# ['h', 'h', 's', 'd', 'g', 'b', nan]
# for sequence 179 prediction is []
# edit distance between hhsdgb and hhsdgb: 0.0
# ----------
# Average similarity: 0.18382572402180244
# Median similarity: 0.11111111111111116

# %% [markdown]
# ### Prequential method

# %%
ones = [1 for x in data]

# %%
predictions = model.predict(data, target, 7, 1)

# %%
def get_string(string):
    output = ''
    for lst in string:
        for elem in lst:
            output += elem
    return output

# %%
errors = [[] for x in range(0,len(data)//2)]

for seq in range(0,len(data)//2):
    i = 1
    while i <= n_list[seq]:
        next_char = model.predict(data, target[seq][:1], 3, 1)
        #print('next char: ' , next_char)
        next_char = get_string(next_char)
        predicted = str(''.join(data[seq][:i]) + next_char)
        #print('pred: ', predicted)
        observed = ''.join(data[seq][:i+1])
        #print('observed: ', observed)
        error = 1 - damerauLevenshtein(predicted, observed)
        #print(error, '\n' , '____________')
        
        errors[seq].append(error)
        
        i += 1

# %%
error_list = [np.median(error) for error in errors]

# %%
summed_error = [sum(error) for error in errors]
np.mean(summed_error)
# Out:
# 1.4130067486072386

# %%
np.mean([np.median(error) for error in errors])
# Out:
# 0.19557890412057072

# %%
np.median([np.median(error) for error in errors])
# Out:
# 0.16666666666666663

# %%
with open('results/cpt_prequential.txt', 'w') as f:
    f.write(str(error_list))
