# %%
import pandas as pd
import numpy as np
from fastDamerauLevenshtein import damerauLevenshtein
import ast

# %%
class Prediction():
    Item = None
    Parent = None
    Children = None

    def __init__(self, itemValue=None):
        self.Item = itemValue
        self.Children = []
        self.Parent = None

    def get_child(self, target):
        for chld in self.Children:
            if chld.Item == target:
                return chld
        return None

    def get_children(self):
        return self.Children

    def has_child(self, target):
        found = self.get_child(target)
        if found is not None:
            return True
        else:
            return False

    def add_new_child(self, child):
        newchild = Prediction(child)
        newchild.Parent = self
        self.Children.append(newchild)

    def remove_child(self, child):
        for chld in self.Children:
            if chld.Item == child:
                self.Children.remove(chld)

# %%
class CPT():
    alphabet = None
    root = None
    II = None
    LT = None
    def __init__(self):
        self.alphabet = set()
        self.root = Prediction()
        self.II = {}
        self.LT = {}

    def load_files(self, train_file, test_file=None):
        """
        This function reads in the wide csv file of sequences separated by commas and returns a list of list of those
        sequences. The sequences are defined as below.
        seq1 = A,B,C,D
        seq2  B,C,E
        Returns: [[A,B,C,D],[B,C,E]]
        """
        
        data = []
        target = []

        if train_file is None:
            return train_file

        train = pd.read_csv(train_file, header=0)

        for index, row in train.iterrows():
            data.append(row.values)

        if test_file is not None:

            test = pd.read_csv(test_file, header=None)

            for index, row in test.iterrows():
                data.append(row.values)
                target.append(list(row.values))

            return data, target

        return data


    def train(self, data):
        """
         This functions populates the Prediction Tree, Inverted Index and LookUp Table for the algorithm.
         Input: The list of list training data
         Output : Boolean True
         """

        cursornode = self.root

        for seqid, row in enumerate(data):
            for element in row:
                if element == element: # different sequence length support
                    
                    if cursornode.has_child(element) == False:
                        cursornode.add_new_child(element)
                        cursornode = cursornode.get_child(element)
                    else:
                        cursornode = cursornode.get_child(element)

                # adding to the inverted index

                    if self.II.get(element) is None:
                        self.II[element] = set()

                    self.II[element].add(seqid)

                    self.alphabet.add(element)

            self.LT[seqid] = cursornode

            cursornode = self.root

        return True

    def score(self, counttable, key, length, target_size, number_of_similar_sequences, number_items_counttable):
        """
         This functions populates the Prediction Tree, Inverted Index and LookUp Table for the algorithm.
         Input: The list of list training data
         Output : Boolean True
         """
        
        weight_level = 1 / number_of_similar_sequences
        weight_distance = 1 / number_items_counttable
        score = 1 + weight_level + weight_distance * 0.001

        if counttable.get(key) is None:
            counttable[key] = score
        else:
            counttable[key] = score * counttable.get(key)

        return counttable

    def predict(self, data, target, k, n_list):
        """
        Here target is the test dataset in the form of list of list,
        k is the number of last elements that will be used to find similar sequences and,
        n is the number of predictions required.
        Input: training list of list, target list of list, k,n
        Output: max n predictions for each sequence
        """

        predictions = []

        for index, each_target in enumerate(target):
            n = int(n_list[index])
            
            # different sequence length support
            i = 0
            while i < len(each_target) and each_target[i] == each_target[i]:  # find NaN start
                i = i + 1
            l = i - k - 1
            if l < 0:
                l = 0
            
            each_target = each_target[l:i]

            intersection = set(range(0, len(data)))

            for element in each_target:
                if self.II.get(element) is None:
                    continue
                intersection = intersection & self.II.get(element)

            similar_sequences = []

            for element in intersection:
                currentnode = self.LT.get(element)
                tmp = []
                while currentnode.Item is not None:
                    tmp.append(currentnode.Item)
                    currentnode = currentnode.Parent
                similar_sequences.append(tmp)

            for sequence in similar_sequences:
                sequence.reverse()

            counttable = {}

            for sequence in similar_sequences:
                try:
                    index = next(
                        i for i, v in zip(range(len(sequence) - 1, 0, -1), reversed(sequence)) if v == each_target[-1])
                except:
                    index = None
                if index is not None:
                    count = 1
                    for element in sequence[index + 1:]:
                        if element in each_target:
                            continue

                        counttable = self.score(counttable, element, len(each_target), len(each_target),
                                                len(similar_sequences), count)
                        count += 1

            pred = self.get_n_largest(counttable, n)
            predictions.append(pred)

        return predictions

    def get_n_largest(self, dictionary, n):

        largest = sorted(dictionary.items(), key=lambda t: t[1], reverse=True)[:n]
        return [key for key, _ in largest]

# %%
model = CPT()

# %%
data, target = model.load_files('data/all_data_train.csv', 'data/all_data_test_3.csv')

# %%
model.train(data)
# Out:
# True

# %%
# get length of each sequence (ignoring nan) minus given sequence in test
n_list = [np.count_nonzero(~pd.isnull(x)) - 3 for x in data]
n_list = [x if x > 0 else 0 for x in n_list]

# %%
predictions = model.predict(data, target, 7, n_list)

# %%
i = 0
distances = []

for elem in predictions:
    pred = [x for x in target[i] if str(x) != 'nan']
    dat = [x for x in data[i] if str(x) != 'nan']
    predicted = str(''.join(pred) + ''.join(elem))
    observed = ''.join(dat)
    dl = 1 - damerauLevenshtein(predicted, observed)
    distances.append(dl)
    print(target[i])
    print('for sequence {0} prediction is {1}'.format(i, elem))
    print('edit distance between {0} and {1}: {2}'.format(observed, predicted, dl))
    i += 1
    print('----------')

print('Average similarity: {0}'.format(np.mean(distances)))
print('Median similarity: {0}'.format(np.median(distances)))
# Out:
# ['p', 'o', 'c']
# for sequence 0 prediction is ['k', 'f', 'r']
# edit distance between pocgkr and pockfr: 0.33333333333333337
# ----------
# ['c', 'g', 'w']
# for sequence 1 prediction is ['f', 'k', 'r', 's', 'o']
# edit distance between cgwpcfks and cgwfkrso: 0.5
# ----------
# ['k', 'f', 's']
# for sequence 2 prediction is ['g', 'a', 'c', 'b', 'r', 'o']
# edit distance between kfsfkspwg and kfsgacbro: 0.6666666666666667
# ----------
# ['p', 'f', 'k']
# for sequence 3 prediction is ['s', 'g', 'c', 'a', 'b', 'r', 'e', 'o', 'w', 'd']
# edit distance between pfkswkfsococg and pfksgcabreowd: 0.6153846153846154
# ----------
# ['w', 'p', 't']
# for sequence 4 prediction is ['f', 'k', 'g', 'c', 'r', 'o']
# edit distance between wptgkfsoc and wptfkgcro: 0.5555555555555556
# ----------
# ['p', 'w', 'f']
# for sequence 5 prediction is ['k', 's']
# edit distance between pwfkg and pwfks: 0.19999999999999996
# ----------
# ['p', 'o', 'w']
# for sequence 6 prediction is ['f', 'k', 'g']
# edit distance between powcer and powfkg: 0.5
# ----------
# ['c', 'o', 'p']
# for sequence 7 prediction is ['k', 'f', 'r', 's']
# edit distance between coprerk and copkfrs: 0.4285714285714286
# ----------
# ['w', 'o', 'p']
# for sequence 8 prediction is ['k', 'f', 's', 'g', 'r', 'c', 'e']
# edit distance between wopofkkskf and wopkfsgrce: 0.6
# ----------
# ['o', 'p', 'w']
# for sequence 9 prediction is ['f', 'k', 'g', 'r', 's', 'c']
# edit distance between opwpwgcoc and opwfkgrsc: 0.4444444444444444
# ----------
# ['p', 'o', 'c']
# for sequence 10 prediction is ['k', 'f', 'r', 'g', 's', 'w', 'e']
# edit distance between pocrfksfks and pockfrgswe: 0.6
# ----------
# ['c', 'g', 'p']
# for sequence 11 prediction is ['k', 'f', 's', 'a', 'o']
# edit distance between cgpogpoc and cgpkfsao: 0.625
# ----------
# ['p', 'w', 'o']
# for sequence 12 prediction is ['k', 'f', 'c', 'g', 'r', 's', 'e', 't']
# edit distance between pwocgfkfsrere and pwokfcgrset: 0.5384615384615384
# ----------
# ['o', 'c', 'w']
# for sequence 13 prediction is ['k', 'f', 'r']
# edit distance between ocwgrk and ocwkfr: 0.5
# ----------
# ['w', 'p', 'g']
# for sequence 14 prediction is ['k', 'f', 's']
# edit distance between wpgsfk and wpgkfs: 0.33333333333333337
# ----------
# ['p', 'w', 'o']
# for sequence 15 prediction is ['k', 'f', 'c']
# edit distance between pwofsg and pwokfc: 0.5
# ----------
# ['p', 'o', 'c']
# for sequence 16 prediction is ['k', 'f', 'r', 'g', 's', 'w', 'e', 't']
# edit distance between pocpocwgkfs and pockfrgswet: 0.7272727272727273
# ----------
# ['p', 'o', 'c']
# for sequence 17 prediction is ['k', 'f', 'r']
# edit distance between pocgwg and pockfr: 0.5
# ----------
# ['p', 'w', 'g']
# for sequence 18 prediction is ['k', 'f', 's', 'r', 'e', 'c', 'o', 't']
# edit distance between pwgockfsfksret and pwgkfsrecot: 0.5
# ----------
# ['o', 'c', 'p']
# for sequence 19 prediction is ['k', 'f', 'r', 's', 'g', 'e', 'w', 't', 'b']
# edit distance between ocpwgfkskfsrere and ocpkfrsgewtb: 0.6666666666666667
# ----------
# ['c', 'o', 'p']
# for sequence 20 prediction is ['k', 'f', 'r', 's', 'g', 'e', 'w', 't']
# edit distance between copwgwpresk and copkfrsgewt: 0.6363636363636364
# ----------
# ['p', 'w', 't']
# for sequence 21 prediction is ['f', 'k', 'g', 'c', 'r']
# edit distance between pwterfkf and pwtfkgcr: 0.625
# ----------
# ['p', 'o', 'c']
# for sequence 22 prediction is ['k', 'f', 'r', 'g', 's', 'w', 'e', 't', 'b']
# edit distance between pocwggpfkfksrer and pockfrgswetb: 0.6666666666666667
# ----------
# ['w', 'p', 'o']
# for sequence 23 prediction is ['k', 'f', 'c', 'g', 'r', 's', 'e', 't']
# edit distance between wpofcgkrpwgfksocr and wpokfcgrset: 0.5882352941176471
# ----------
# ['c', 'w', 'p']
# for sequence 24 prediction is ['k', 'f', 's', 'o', 'r']
# edit distance between cwpfksor and cwpkfsor: 0.125
# ----------
# ['p', 'w', 'f']
# for sequence 25 prediction is ['k', 's', 'r', 'g', 'e']
# edit distance between pwfksorc and pwfksrge: 0.375
# ----------
# ['p', 'o', 'c']
# for sequence 26 prediction is ['k', 'f', 'r', 'g', 's', 'w', 'e', 't', 'b']
# edit distance between pocgwkfkfser and pockfrgswetb: 0.5833333333333333
# ----------
# ['p', 'o', 'w']
# for sequence 27 prediction is ['f', 'k', 'g', 'r', 's', 'c']
# edit distance between powctgcog and powfkgrsc: 0.5555555555555556
# ----------
# ['p', 'o', 'w']
# for sequence 28 prediction is ['f', 'k', 'g', 'r']
# edit distance between powgcpo and powfkgr: 0.5714285714285714
# ----------
# ['p', 'w', 'f']
# for sequence 29 prediction is ['k', 's']
# edit distance between pwfkt and pwfks: 0.19999999999999996
# ----------
# ['p', 'w', 'o']
# for sequence 30 prediction is ['k', 'f', 'c', 'g', 'r']
# edit distance between pwokfkrg and pwokfcgr: 0.25
# ----------
# ['c', 'o', 'p']
# for sequence 31 prediction is ['k', 'f', 'r', 's', 'g', 'e', 'w', 't', 'b']
# edit distance between copcogpgwfksr and copkfrsgewtb: 0.6923076923076923
# ----------
# ['p', 'g', 's']
# for sequence 32 prediction is ['a', 'c', 'b', 'k', 'f', 'r']
# edit distance between pgsfkskfg and pgsacbkfr: 0.4444444444444444
# ----------
# ['w', 'g', 'p']
# for sequence 33 prediction is ['k', 'f', 's', 'r', 'c', 'o', 'e']
# edit distance between wgptocopwg and wgpkfsrcoe: 0.7
# ----------
# ['p', 'o', 'w']
# for sequence 34 prediction is ['f', 'k', 'g', 'r']
# edit distance between powcgre and powfkgr: 0.4285714285714286
# ----------
# ['p', 'e', 'r']
# for sequence 35 prediction is ['k', 's', 'f', 't', 'c', 'w', 'o']
# edit distance between perkscwgtf and perksftcwo: 0.5
# ----------
# ['p', 'c', 'g']
# for sequence 36 prediction is ['a', 'k', 'f', 's', 'b', 'r', 'e', 'o']
# edit distance between pcgworkfkfs and pcgakfsbreo: 0.7272727272727273
# ----------
# ['p', 'o', 'p']
# for sequence 37 prediction is ['k', 'f', 'r', 's', 'g']
# edit distance between popocgkr and popkfrsg: 0.625
# ----------
# ['p', 'w', 't']
# for sequence 38 prediction is ['f', 'k', 'g', 'c', 'r', 'o', 's', 'e']
# edit distance between pwtgcfkfksr and pwtfkgcrose: 0.6363636363636364
# ----------
# ['p', 'o', 'c']
# for sequence 39 prediction is ['k', 'f', 'r']
# edit distance between pocwkf and pockfr: 0.33333333333333337
# ----------
# ['p', 'g', 'k']
# for sequence 40 prediction is ['s', 'f', 'a']
# edit distance between pgkfkf and pgksfa: 0.5
# ----------
# ['c', 'w', 'o']
# for sequence 41 prediction is ['k', 'f']
# edit distance between cwopg and cwokf: 0.4
# ----------
# ['p', 'o', 'w']
# for sequence 42 prediction is ['f', 'k', 'g', 'r', 's', 'c', 'e']
# edit distance between powcgkfkfr and powfkgrsce: 0.6
# ----------
# ['w', 'p', 'g']
# for sequence 43 prediction is ['k', 'f', 's', 'r']
# edit distance between wpgfksk and wpgkfsr: 0.2857142857142857
# ----------
# ['p', 'o', 'c']
# for sequence 44 prediction is ['k', 'f', 'r', 'g', 's', 'w', 'e']
# edit distance between pocwcpoere and pockfrgswe: 0.6
# ----------
# ['p', 'w', 'k']
# for sequence 45 prediction is ['s']
# edit distance between pwkf and pwks: 0.25
# ----------
# ['c', 'p', 't']
# for sequence 46 prediction is ['f', 'k']
# edit distance between cptgo and cptfk: 0.4
# ----------
# ['p', 'o', 'c']
# for sequence 47 prediction is ['k', 'f', 'r', 'g', 's', 'w']
# edit distance between pocfkswgr and pockfrgsw: 0.5555555555555556
# ----------
# ['p', 'o', 'w']
# for sequence 48 prediction is ['f', 'k', 'g', 'r', 's']
# edit distance between powcfkfk and powfkgrs: 0.5
# ----------
# ['p', 'w', 'g']
# for sequence 49 prediction is ['k', 'f', 's', 'r', 'e']
# edit distance between pwgfksfk and pwgkfsre: 0.375
# ----------
# ['g', 'p', 'w']
# for sequence 50 prediction is ['f', 'k', 's']
# edit distance between gpwfks and gpwfks: 0.0
# ----------
# ['c', 'g', 'w']
# for sequence 51 prediction is ['f', 'k']
# edit distance between cgwpw and cgwfk: 0.4
# ----------
# ['c', 'w', 'o']
# for sequence 52 prediction is ['k', 'f', 'r', 'g', 's', 'e', 'p', 't']
# edit distance between cwopgtrekfksksf and cwokfrgsept: 0.6666666666666667
# ----------
# ['p', 'o', 'c']
# for sequence 53 prediction is ['k', 'f', 'r', 'g']
# edit distance between pocsfkw and pockfrg: 0.4285714285714286
# ----------
# ['o', 'c', 'p']
# for sequence 54 prediction is ['k', 'f', 'r', 's', 'g']
# edit distance between ocpwgfkf and ocpkfrsg: 0.625
# ----------
# ['p', 'w', 'g']
# for sequence 55 prediction is ['k', 'f', 's', 'r', 'e', 'c', 'o', 't']
# edit distance between pwgterkfsoc and pwgkfsrecot: 0.6363636363636364
# ----------
# ['p', 'o', 'c']
# for sequence 56 prediction is ['k', 'f', 'r', 'g', 's', 'w']
# edit distance between pocgwrkfs and pockfrgsw: 0.5555555555555556
# ----------
# ['t', 'g', 'c']
# for sequence 57 prediction is ['f', 'k', 'w', 'r']
# edit distance between tgcwpro and tgcfkwr: 0.5714285714285714
# ----------
# ['p', 'o', 'c']
# for sequence 58 prediction is ['k', 'f', 'r', 'g', 's', 'w', 'e']
# edit distance between pocgkfskfr and pockfrgswe: 0.6
# ----------
# ['p', 'g', 'c']
# for sequence 59 prediction is ['f', 'k']
# edit distance between pgcow and pgcfk: 0.4
# ----------
# ['o', 'p', 'w']
# for sequence 60 prediction is ['f']
# edit distance between opwg and opwf: 0.25
# ----------
# ['w', 'p', 'g']
# for sequence 61 prediction is ['k', 'f', 's', 'r', 'e', 'c', 'o', 't']
# edit distance between wpgcowpcfksre and wpgkfsrecot: 0.6923076923076923
# ----------
# ['r', 'e', nan]
# for sequence 62 prediction is []
# edit distance between re and re: 0.0
# ----------
# ['p', 't', 'w']
# for sequence 63 prediction is ['f', 'k', 'g', 'r']
# edit distance between ptwgfks and ptwfkgr: 0.4285714285714286
# ----------
# ['p', 'o', 'c']
# for sequence 64 prediction is ['k', 'f', 'r', 'g', 's']
# edit distance between pocrfkfk and pockfrgs: 0.5
# ----------
# ['p', 'o', 'c']
# for sequence 65 prediction is ['k', 'f']
# edit distance between pockr and pockf: 0.19999999999999996
# ----------
# ['p', 'o', 'c']
# for sequence 66 prediction is ['k', 'f', 'r', 'g', 's', 'w', 'e', 't', 'b']
# edit distance between pockfskfswgre and pockfrgswetb: 0.46153846153846156
# ----------
# ['t', 'g', 'p']
# for sequence 67 prediction is ['k', 'o', 'f', 's', 'r', 'w', 'c', 'e']
# edit distance between tgpcowpgpwcog and tgpkofsrwce: 0.5384615384615384
# ----------
# ['g', 'w', 'p']
# for sequence 68 prediction is ['k', 'f', 's', 'r', 'c']
# edit distance between gwpfrkst and gwpkfsrc: 0.5
# ----------
# ['p', 'f', 'k']
# for sequence 69 prediction is ['s', 'g', 'c', 'a']
# edit distance between pfkfksg and pfksgca: 0.5714285714285714
# ----------
# ['p', 'w', 'o']
# for sequence 70 prediction is ['k', 'f', 'c', 'g', 'r']
# edit distance between pwogsfkg and pwokfcgr: 0.5
# ----------
# ['p', 'w', 'k']
# for sequence 71 prediction is ['s']
# edit distance between pwkf and pwks: 0.25
# ----------
# ['g', 'w', 'p']
# for sequence 72 prediction is ['k', 'f', 's', 'r', 'c', 'o', 'e', 't']
# edit distance between gwpocoskfsfk and gwpkfsrcoet: 0.6666666666666667
# ----------
# ['w', 't', 'p']
# for sequence 73 prediction is ['k', 'f', 'g', 'c', 'o', 's', 'r']
# edit distance between wtpcockfkf and wtpkfgcosr: 0.7
# ----------
# ['w', 'p', 'g']
# for sequence 74 prediction is ['k', 'f', 's', 'r', 'e', 'c']
# edit distance between wpgfkfkre and wpgkfsrec: 0.33333333333333337
# ----------
# ['p', 'o', 'c']
# for sequence 75 prediction is ['k', 'f', 'r', 'g', 's', 'w', 'e', 't', 'b']
# edit distance between pococwtrfkfkg and pockfrgswetb: 0.7692307692307692
# ----------
# ['p', 'w', 'o']
# for sequence 76 prediction is ['k', 'f', 'c', 'g', 'r', 's', 'e', 't']
# edit distance between pwocfksfksr and pwokfcgrset: 0.6363636363636364
# ----------
# ['p', 'w', 'g']
# for sequence 77 prediction is ['k', 'f', 's', 'r']
# edit distance between pwgerks and pwgkfsr: 0.5714285714285714
# ----------
# ['p', 'o', 'c']
# for sequence 78 prediction is ['k', 'f', 'r', 'g', 's', 'w', 'e', 't']
# edit distance between poctfkfkrwg and pockfrgswet: 0.6363636363636364
# ----------
# ['p', 'w', 'f']
# for sequence 79 prediction is ['k', 's', 'r', 'g', 'e']
# edit distance between pwfksocr and pwfksrge: 0.375
# ----------
# ['t', 'n', 'p']
# for sequence 80 prediction is ['c', 'z']
# edit distance between tnpzc and tnpcz: 0.19999999999999996
# ----------
# ['t', 'n', 'p']
# for sequence 81 prediction is ['c', 'z']
# edit distance between tnpcz and tnpcz: 0.0
# ----------
# ['t', 'n', 'p']
# for sequence 82 prediction is ['c', 'z']
# edit distance between tnpzc and tnpcz: 0.19999999999999996
# ----------
# ['t', 'n', 'z']
# for sequence 83 prediction is ['c', 'p']
# edit distance between tnzpc and tnzcp: 0.19999999999999996
# ----------
# ['p', 'm', 'z']
# for sequence 84 prediction is []
# edit distance between pmz and pmz: 0.0
# ----------
# ['x', 'm', 'b']
# for sequence 85 prediction is ['z', 'd']
# edit distance between xmbzd and xmbzd: 0.0
# ----------
# ['p', 'I', 'm']
# for sequence 86 prediction is ['z']
# edit distance between pImz and pImz: 0.0
# ----------
# ['m', 'z', 'x']
# for sequence 87 prediction is ['p']
# edit distance between mzxp and mzxp: 0.0
# ----------
# ['p', 'b', 'z']
# for sequence 88 prediction is []
# edit distance between pbz and pbz: 0.0
# ----------
# ['p', 'g', 'z']
# for sequence 89 prediction is []
# edit distance between pgz and pgz: 0.0
# ----------
# ['p', 'n', 'z']
# for sequence 90 prediction is ['c', 'g']
# edit distance between pnzga and pnzcg: 0.4
# ----------
# ['d', 'n', 'z']
# for sequence 91 prediction is ['g', 'p', 's']
# edit distance between dnzgdp and dnzgps: 0.33333333333333337
# ----------
# ['p', 'n', 'd']
# for sequence 92 prediction is ['z']
# edit distance between pndz and pndz: 0.0
# ----------
# ['n', 'z', 'p']
# for sequence 93 prediction is ['c', 'd', 'g', 's']
# edit distance between nzpdgds and nzpcdgs: 0.2857142857142857
# ----------
# ['m', 'c', 'd']
# for sequence 94 prediction is ['x', 'p']
# edit distance between mcddxp and mcdxp: 0.16666666666666663
# ----------
# ['p', 'c', 'f']
# for sequence 95 prediction is ['s', 'g', 'a', 'k', 'b', 'r', 'o']
# edit distance between pcfkdddaag and pcfsgakbro: 0.7
# ----------
# ['d', 'a', 'g']
# for sequence 96 prediction is ['p', 'k']
# edit distance between dagpk and dagpk: 0.0
# ----------
# ['p', 'c', nan]
# for sequence 97 prediction is []
# edit distance between pc and pc: 0.0
# ----------
# ['g', 'k', 'f']
# for sequence 98 prediction is ['s', 'a', 'c']
# edit distance between gkfadp and gkfsac: 0.5
# ----------
# ['p', 'f', 'g']
# for sequence 99 prediction is ['k', 'a']
# edit distance between pfgds and pfgka: 0.4
# ----------
# ['b', 'c', 's']
# for sequence 100 prediction is ['a', 'g', 'k', 'f', 'p']
# edit distance between bcsfgkap and bcsagkfp: 0.25
# ----------
# ['p', 'b', 's']
# for sequence 101 prediction is ['a', 'g', 'c', 'k', 'f']
# edit distance between pbsfkcga and pbsagckf: 0.5
# ----------
# ['p', 'b', 'g']
# for sequence 102 prediction is ['a', 'c', 'k', 's', 'f']
# edit distance between pbgafkcs and pbgacksf: 0.375
# ----------
# ['g', 'p', 'b']
# for sequence 103 prediction is ['a', 'c', 's', 'k', 'f']
# edit distance between gpbcksfa and gpbacskf: 0.375
# ----------
# ['p', 'b', 'f']
# for sequence 104 prediction is ['a', 'g', 'c', 's', 'k']
# edit distance between pbfkscga and pbfagcsk: 0.5
# ----------
# ['p', 'b', 's']
# for sequence 105 prediction is ['a', 'g', 'c', 'k', 'f']
# edit distance between pbsgkafc and pbsagckf: 0.5
# ----------
# ['p', 'b', 'c']
# for sequence 106 prediction is ['a', 'g', 's', 'k', 'f']
# edit distance between pbcskfga and pbcagskf: 0.5
# ----------
# ['p', 's', 'f']
# for sequence 107 prediction is ['g', 'k', 'c', 'a', 'b']
# edit distance between psfkagcb and psfgkcab: 0.375
# ----------
# ['p', 'f', 'k']
# for sequence 108 prediction is ['s', 'g', 'c', 'a', 'b']
# edit distance between pfkscagb and pfksgcab: 0.25
# ----------
# ['p', 'f', 's']
# for sequence 109 prediction is ['g', 'a', 'c', 'b', 'k']
# edit distance between pfskagcb and pfsgacbk: 0.375
# ----------
# ['p', 's', 'k']
# for sequence 110 prediction is ['g', 'c', 'f', 'a', 'b']
# edit distance between pskfcagb and pskgcfab: 0.375
# ----------
# ['p', 'f', 'k']
# for sequence 111 prediction is ['s', 'g', 'c', 'a', 'b']
# edit distance between pfkscagb and pfksgcab: 0.25
# ----------
# ['p', 's', 'f']
# for sequence 112 prediction is ['g', 'k', 'c', 'a', 'b']
# edit distance between psfkgacb and psfgkcab: 0.25
# ----------
# ['p', 'f', 'k']
# for sequence 113 prediction is ['s', 'g', 'c', 'a', 'b']
# edit distance between pfkbscga and pfksgcab: 0.375
# ----------
# ['p', 'c', 'g']
# for sequence 114 prediction is ['a', 'k', 'f', 's', 'b']
# edit distance between pcgafkbs and pcgakfsb: 0.25
# ----------
# ['g', 'p', 'a']
# for sequence 115 prediction is ['b', 'c', 'k', 'f', 's']
# edit distance between gpabkfsc and gpabckfs: 0.25
# ----------
# ['p', 'a', 'b']
# for sequence 116 prediction is ['g', 'c', 's', 'k', 'f']
# edit distance between pabkgcfs and pabgcskf: 0.375
# ----------
# ['g', 'c', 'p']
# for sequence 117 prediction is ['k', 'f', 's', 'a', 'o']
# edit distance between gcpabkfs and gcpkfsao: 0.5
# ----------
# ['p', 'a', 's']
# for sequence 118 prediction is ['g', 'c', 'b', 'f', 'k']
# edit distance between pasbkfgc and pasgcbfk: 0.625
# ----------
# ['p', 'a', 'b']
# for sequence 119 prediction is ['g', 'c', 's', 'k', 'f']
# edit distance between pabcgksf and pabgcskf: 0.25
# ----------
# ['s', 'f', 'k']
# for sequence 120 prediction is ['g', 'c', 'a', 'b', 'r']
# edit distance between sfkpcgab and sfkgcabr: 0.375
# ----------
# ['s', 'p', 'g']
# for sequence 121 prediction is ['k', 'a', 'f', 'c', 'b']
# edit distance between spgbkfca and spgkafcb: 0.375
# ----------
# ['s', 'p', 'a']
# for sequence 122 prediction is ['b', 'g', 'c', 'k', 'f']
# edit distance between spakgfcb and spabgckf: 0.5
# ----------
# ['c', 'g', 'b']
# for sequence 123 prediction is ['a', 's', 'k', 'f', 'p']
# edit distance between cgbkpasf and cgbaskfp: 0.5
# ----------
# ['f', 'k', 's']
# for sequence 124 prediction is ['g', 'a', 'c', 'b', 'r']
# edit distance between fkspcbag and fksgacbr: 0.5
# ----------
# ['p', 'k', 'f']
# for sequence 125 prediction is ['s', 'g', 'c', 'a', 'b']
# edit distance between pkfsbgca and pkfsgcab: 0.25
# ----------
# ['c', 'p', 'k']
# for sequence 126 prediction is ['s', 'f', 'g', 'a', 'b']
# edit distance between cpkfgsba and cpksfgab: 0.375
# ----------
# ['c', 'b', 'g']
# for sequence 127 prediction is ['a', 'k', 's', 'f', 'p']
# edit distance between cbgsfapk and cbgaksfp: 0.5
# ----------
# ['c', 'g', 'p']
# for sequence 128 prediction is ['k', 'f', 's', 'a', 'o']
# edit distance between cgpsakfb and cgpkfsao: 0.625
# ----------
# ['p', 'f', 'k']
# for sequence 129 prediction is ['s', 'g', 'c', 'a', 'b']
# edit distance between pfksgcab and pfksgcab: 0.0
# ----------
# ['p', 'c', 's']
# for sequence 130 prediction is ['a', 'g', 'b', 'f', 'k']
# edit distance between pcskfbga and pcsagbfk: 0.5
# ----------
# ['s', 'b', 'k']
# for sequence 131 prediction is ['a', 'g', 'c', 'f', 'p']
# edit distance between sbkpfcag and sbkagcfp: 0.5
# ----------
# ['f', 'p', 'k']
# for sequence 132 prediction is ['s', 'g', 'c', 'a', 'b']
# edit distance between fpkgbsac and fpksgcab: 0.5
# ----------
# ['p', 'a', 'b']
# for sequence 133 prediction is ['g', 'c', 's', 'k', 'f']
# edit distance between pabfgsck and pabgcskf: 0.375
# ----------
# ['c', 'p', 'g']
# for sequence 134 prediction is ['a', 'k', 'f', 's', 'b']
# edit distance between cpgfksab and cpgakfsb: 0.375
# ----------
# ['g', 'f', 'c']
# for sequence 135 prediction is ['k', 'a', 's', 'b', 'r']
# edit distance between gfcspkob and gfckasbr: 0.625
# ----------
# ['p', 'k', 'f']
# for sequence 136 prediction is ['s', 'g', 'c', 'a', 'b']
# edit distance between pkfsbagc and pkfsgcab: 0.5
# ----------
# ['p', 'k', 'f']
# for sequence 137 prediction is ['s', 'g', 'c', 'a', 'b']
# edit distance between pkfsbgac and pkfsgcab: 0.375
# ----------
# ['p', 'b', 'f']
# for sequence 138 prediction is ['a', 'g', 'c', 's', 'k']
# edit distance between pbfkscga and pbfagcsk: 0.5
# ----------
# ['b', 'p', 'k']
# for sequence 139 prediction is ['a', 'g', 'c', 's', 'f']
# edit distance between bpksfcga and bpkagcsf: 0.5
# ----------
# ['p', 'a', 'g']
# for sequence 140 prediction is ['c', 'b', 'k', 'f', 's']
# edit distance between pagbkfsc and pagcbkfs: 0.25
# ----------
# ['p', 'c', 'g']
# for sequence 141 prediction is ['a', 'k', 'f', 's', 'b']
# edit distance between pcgafksb and pcgakfsb: 0.125
# ----------
# ['p', 'c', 's']
# for sequence 142 prediction is ['a', 'g', 'b', 'f', 'k']
# edit distance between pcsbfkga and pcsagbfk: 0.5
# ----------
# ['p', 'b', 's']
# for sequence 143 prediction is ['a', 'g', 'c', 'k', 'f']
# edit distance between pbskfgca and pbsagckf: 0.5
# ----------
# ['p', 's', 'c']
# for sequence 144 prediction is ['f', 'g', 'k', 'a', 'b']
# edit distance between pscgfbak and pscfgkab: 0.375
# ----------
# ['p', 'f', 'k']
# for sequence 145 prediction is ['s', 'g', 'c', 'a', 'b']
# edit distance between pfkcbgsa and pfksgcab: 0.5
# ----------
# ['p', 'k', 'f']
# for sequence 146 prediction is ['s', 'g', 'c', 'a', 'b']
# edit distance between pkfsgcba and pkfsgcab: 0.125
# ----------
# ['p', 'c', 'f']
# for sequence 147 prediction is ['s', 'g', 'a', 'k', 'b']
# edit distance between pcfksagb and pcfsgakb: 0.375
# ----------
# ['p', 'b', 'c']
# for sequence 148 prediction is ['a', 'g', 's', 'k', 'f']
# edit distance between pbcfskga and pbcagskf: 0.5
# ----------
# ['p', 'b', 'f']
# for sequence 149 prediction is ['a', 'g', 'c', 's', 'k']
# edit distance between pbfkcsga and pbfagcsk: 0.5
# ----------
# ['p', 'c', 's']
# for sequence 150 prediction is ['a', 'g', 'b', 'f', 'k']
# edit distance between pcsfkbga and pcsagbfk: 0.5
# ----------
# ['p', 'k', 'f']
# for sequence 151 prediction is ['s', 'g', 'c', 'a', 'b']
# edit distance between pkfsabgc and pkfsgcab: 0.5
# ----------
# ['p', 'k', 'f']
# for sequence 152 prediction is ['s', 'g', 'c', 'a', 'b']
# edit distance between pkfsgcba and pkfsgcab: 0.125
# ----------
# ['p', 'k', 'f']
# for sequence 153 prediction is ['s', 'g', 'c', 'a', 'b']
# edit distance between pkfsgcba and pkfsgcab: 0.125
# ----------
# ['p', 'k', 'f']
# for sequence 154 prediction is ['s', 'g', 'c', 'a', 'b']
# edit distance between pkfsgcab and pkfsgcab: 0.0
# ----------
# ['p', 'k', 'f']
# for sequence 155 prediction is ['s', 'g', 'c', 'a', 'b']
# edit distance between pkfbscag and pkfsgcab: 0.375
# ----------
# ['p', 'k', 'b']
# for sequence 156 prediction is ['a', 'g', 'c', 's', 'f']
# edit distance between pkbsfgca and pkbagcsf: 0.5
# ----------
# ['p', 'k', 'f']
# for sequence 157 prediction is ['s', 'g', 'c', 'a', 'b']
# edit distance between pkfbscga and pkfsgcab: 0.375
# ----------
# ['p', 'k', 'f']
# for sequence 158 prediction is ['s', 'g', 'c', 'a', 'b']
# edit distance between pkfsbgac and pkfsgcab: 0.375
# ----------
# ['p', 'k', 'f']
# for sequence 159 prediction is ['s', 'g', 'c', 'a', 'b']
# edit distance between pkfsagbc and pkfsgcab: 0.375
# ----------
# ['p', 'k', 'f']
# for sequence 160 prediction is ['s', 'g', 'c', 'a', 'b']
# edit distance between pkfsgcab and pkfsgcab: 0.0
# ----------
# ['p', 'k', 'f']
# for sequence 161 prediction is ['s', 'g', 'c', 'a', 'b']
# edit distance between pkfsgcba and pkfsgcab: 0.125
# ----------
# ['p', 'k', 'f']
# for sequence 162 prediction is ['s', 'g', 'c', 'a', 'b']
# edit distance between pkfsgcab and pkfsgcab: 0.0
# ----------
# ['p', 'k', 'f']
# for sequence 163 prediction is ['s', 'g', 'c', 'a', 'b']
# edit distance between pkfsacgb and pkfsgcab: 0.25
# ----------
# ['p', 'k', 'f']
# for sequence 164 prediction is ['s', 'g', 'c', 'a', 'b']
# edit distance between pkfsbcga and pkfsgcab: 0.375
# ----------
# ['p', 'f', 's']
# for sequence 165 prediction is ['g', 'a', 'c', 'b', 'k']
# edit distance between pfskbcga and pfsgacbk: 0.5
# ----------
# ['p', 'b', 'k']
# for sequence 166 prediction is ['a', 'g', 'c', 's', 'f']
# edit distance between pbkfscga and pbkagcsf: 0.5
# ----------
# ['p', 'f', 's']
# for sequence 167 prediction is ['g', 'a', 'c', 'b', 'k']
# edit distance between pfskbgca and pfsgacbk: 0.625
# ----------
# ['h', 'h', 's']
# for sequence 168 prediction is ['b', 'g']
# edit distance between hhsdb and hhsbg: 0.4
# ----------
# ['h', 'h', 'h']
# for sequence 169 prediction is ['s', 'd', 'b', 'g']
# edit distance between hhhdsgb and hhhsdbg: 0.2857142857142857
# ----------
# ['h', 'h', 's']
# for sequence 170 prediction is ['b', 'g', 'd']
# edit distance between hhsgdb and hhsbgd: 0.33333333333333337
# ----------
# ['h', 'h', 'd']
# for sequence 171 prediction is ['b', 'g', 's']
# edit distance between hhdsbg and hhdbgs: 0.33333333333333337
# ----------
# ['h', 'h', 's']
# for sequence 172 prediction is ['b', 'g', 'd']
# edit distance between hhsgdb and hhsbgd: 0.33333333333333337
# ----------
# ['h', 'h', 'd']
# for sequence 173 prediction is ['b', 'g', 's']
# edit distance between hhdsgb and hhdbgs: 0.33333333333333337
# ----------
# ['d', 's', 'g']
# for sequence 174 prediction is ['b', 'h']
# edit distance between dsgbhh and dsgbh: 0.16666666666666663
# ----------
# ['h', 'h', 's']
# for sequence 175 prediction is ['b', 'g', 'd']
# edit distance between hhsdbg and hhsbgd: 0.33333333333333337
# ----------
# ['h', 'h', 's']
# for sequence 176 prediction is ['b', 'g', 'd']
# edit distance between hhsdgb and hhsbgd: 0.33333333333333337
# ----------
# ['h', 'h', 's']
# for sequence 177 prediction is ['b', 'g', 'd']
# edit distance between hhsgdb and hhsbgd: 0.33333333333333337
# ----------
# ['h', 'h', 's']
# for sequence 178 prediction is ['b', 'g', 'd']
# edit distance between hhsgdb and hhsbgd: 0.33333333333333337
# ----------
# ['h', 'h', 's']
# for sequence 179 prediction is ['b', 'g', 'd']
# edit distance between hhsdgb and hhsbgd: 0.33333333333333337
# ----------
# Average similarity: 0.40217895485052346
# Median similarity: 0.4

# %%
with open('results/all_vr_cpt_7.txt', 'w') as f:
    f.write(str(distances))

# %%
# check how many sequences have 8+ items

length = [np.count_nonzero(~pd.isnull(x)) for x in data]
over_8 = [x for x in length if x >= 8 ]
len(over_8)/len(length) * 100
# Out:
# 33.33333333333333

# %% [markdown]
# ### calculate median over all input variations (1-7 items given)

# %%
with open('results/all_vr_cpt_1.txt', 'r') as f:
    distances1 = f.read()
    distances1 = ast.literal_eval(distances1)

# %%
with open('results/all_vr_cpt_2.txt', 'r') as f:
    distances2 = f.read()
    distances2 = ast.literal_eval(distances2)

# %%
with open('results/all_vr_cpt_3.txt', 'r') as f:
    distances3 = f.read()
    distances3 = ast.literal_eval(distances3)

# %%
with open('results/all_vr_cpt_4.txt', 'r') as f:
    distances4 = f.read()
    distances4 = ast.literal_eval(distances4)

# %%
with open('results/all_vr_cpt_5.txt', 'r') as f:
    distances5 = f.read()
    distances5 = ast.literal_eval(distances5)

# %%
with open('results/all_vr_cpt_6.txt', 'r') as f:
    distances6 = f.read()
    distances6 = ast.literal_eval(distances6)

# %%
with open('results/all_vr_cpt_7.txt', 'r') as f:
    distances7 = f.read()
    distances7 = ast.literal_eval(distances7)

# %%
avg1 = np.mean(distances1)
avg2 = np.mean(distances2)
avg3 = np.mean(distances3)
avg4 = np.mean(distances4)
avg5 = np.mean(distances5)
avg6 = np.mean(distances6)
avg7 = np.mean(distances7)

# %%
np.mean([avg1, avg2, avg2, avg3, avg4, avg5, avg6, avg7])
# Out:
# 0.3473871429723146

# %%
np.median([np.median(distances1), np.median(distances2), np.median(distances3), 
           np.median(distances4), np.median(distances5), np.median(distances6),
          np.median(distances7)])
# Out:
# 0.33333333333333337
