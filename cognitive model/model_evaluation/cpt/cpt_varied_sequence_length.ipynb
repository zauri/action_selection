# %%
import pandas as pd
import numpy as np
from fastDamerauLevenshtein import damerauLevenshtein
import ast

# %%
class Prediction():
    Item = None
    Parent = None
    Children = None

    def __init__(self, itemValue=None):
        self.Item = itemValue
        self.Children = []
        self.Parent = None

    def get_child(self, target):
        for chld in self.Children:
            if chld.Item == target:
                return chld
        return None

    def get_children(self):
        return self.Children

    def has_child(self, target):
        found = self.get_child(target)
        if found is not None:
            return True
        else:
            return False

    def add_new_child(self, child):
        newchild = Prediction(child)
        newchild.Parent = self
        self.Children.append(newchild)

    def remove_child(self, child):
        for chld in self.Children:
            if chld.Item == child:
                self.Children.remove(chld)

# %%
class CPT():
    alphabet = None
    root = None
    II = None
    LT = None
    def __init__(self):
        self.alphabet = set()
        self.root = Prediction()
        self.II = {}
        self.LT = {}

    def load_files(self, train_file, test_file=None):
        """
        This function reads in the wide csv file of sequences separated by commas and returns a list of list of those
        sequences. The sequences are defined as below.
        seq1 = A,B,C,D
        seq2  B,C,E
        Returns: [[A,B,C,D],[B,C,E]]
        """
        
        data = []
        target = []

        if train_file is None:
            return train_file

        train = pd.read_csv(train_file, header=0)

        for index, row in train.iterrows():
            data.append(row.values)

        if test_file is not None:

            test = pd.read_csv(test_file, header=None)

            for index, row in test.iterrows():
                data.append(row.values)
                target.append(list(row.values))

            return data, target

        return data


    def train(self, data):
        """
         This functions populates the Prediction Tree, Inverted Index and LookUp Table for the algorithm.
         Input: The list of list training data
         Output : Boolean True
         """

        cursornode = self.root

        for seqid, row in enumerate(data):
            for element in row:
                if element == element: # different sequence length support
                    
                    if cursornode.has_child(element) == False:
                        cursornode.add_new_child(element)
                        cursornode = cursornode.get_child(element)
                    else:
                        cursornode = cursornode.get_child(element)

                # adding to the inverted index

                    if self.II.get(element) is None:
                        self.II[element] = set()

                    self.II[element].add(seqid)

                    self.alphabet.add(element)

            self.LT[seqid] = cursornode

            cursornode = self.root

        return True

    def score(self, counttable, key, length, target_size, number_of_similar_sequences, number_items_counttable):
        """
         This functions populates the Prediction Tree, Inverted Index and LookUp Table for the algorithm.
         Input: The list of list training data
         Output : Boolean True
         """
        
        weight_level = 1 / number_of_similar_sequences
        weight_distance = 1 / number_items_counttable
        score = 1 + weight_level + weight_distance * 0.001

        if counttable.get(key) is None:
            counttable[key] = score
        else:
            counttable[key] = score * counttable.get(key)

        return counttable

    def predict(self, data, target, k, n_list):
        """
        Here target is the test dataset in the form of list of list,
        k is the number of last elements that will be used to find similar sequences and,
        n is the number of predictions required.
        Input: training list of list, target list of list, k,n
        Output: max n predictions for each sequence
        """

        predictions = []

        for index, each_target in enumerate(target):
            n = int(n_list[index])
            
            # different sequence length support
            i = 0
            while i < len(each_target) and each_target[i] == each_target[i]:  # find NaN start
                i = i + 1
            l = i - k - 1
            if l < 0:
                l = 0
            
            each_target = each_target[l:i]

            intersection = set(range(0, len(data)))

            for element in each_target:
                if self.II.get(element) is None:
                    continue
                intersection = intersection & self.II.get(element)

            similar_sequences = []

            for element in intersection:
                currentnode = self.LT.get(element)
                tmp = []
                while currentnode.Item is not None:
                    tmp.append(currentnode.Item)
                    currentnode = currentnode.Parent
                similar_sequences.append(tmp)

            for sequence in similar_sequences:
                sequence.reverse()

            counttable = {}

            for sequence in similar_sequences:
                try:
                    index = next(
                        i for i, v in zip(range(len(sequence) - 1, 0, -1), reversed(sequence)) if v == each_target[-1])
                except:
                    index = None
                if index is not None:
                    count = 1
                    for element in sequence[index + 1:]:
                        if element in each_target:
                            continue

                        counttable = self.score(counttable, element, len(each_target), len(each_target),
                                                len(similar_sequences), count)
                        count += 1

            pred = self.get_n_largest(counttable, n)
            predictions.append(pred)

        return predictions

    def get_n_largest(self, dictionary, n):

        largest = sorted(dictionary.items(), key=lambda t: t[1], reverse=True)[:n]
        return [key for key, _ in largest]

# %%
model = CPT()

# %%
data, target = model.load_files('data/all_data_train.csv', 'data/all_data_test_7.csv')

# %%
model.train(data)
# Out:
# True

# %%
# get length of each sequence (ignoring nan) minus given sequence in test
n_list = [np.count_nonzero(~pd.isnull(x)) - 7 for x in data]
n_list = [x if x > 0 else 0 for x in n_list]

# %%
predictions = model.predict(data, target, 7, n_list)

# %%
i = 0
distances = []

for elem in predictions:
    pred = [x for x in target[i] if str(x) != 'nan']
    dat = [x for x in data[i] if str(x) != 'nan']
    predicted = str(''.join(pred) + ''.join(elem))
    observed = ''.join(dat)
    dl = 1 - damerauLevenshtein(predicted, observed)
    distances.append(dl)
    print(target[i])
    print('for sequence {0} prediction is {1}'.format(i, elem))
    print('edit distance between {0} and {1}: {2}'.format(observed, predicted, dl))
    i += 1
    print('----------')

print('Average similarity: {0}'.format(np.mean(distances)))
print('Median similarity: {0}'.format(np.median(distances)))
# Out:
# ['p', 'o', 'c', 'g', 'k', 'r', nan]
# for sequence 0 prediction is []
# edit distance between pocgkr and pocgkr: 0.0
# ----------
# ['c', 'g', 'w', 'p', 'c', 'f', 'k']
# for sequence 1 prediction is ['s']
# edit distance between cgwpcfks and cgwpcfks: 0.0
# ----------
# ['k', 'f', 's', 'f', 'k', 's', 'p']
# for sequence 2 prediction is ['g', 'c']
# edit distance between kfsfkspwg and kfsfkspgc: 0.2222222222222222
# ----------
# ['p', 'f', 'k', 's', 'w', 'k', 'f']
# for sequence 3 prediction is ['r', 'o', 'e', 'c', 'g', 't']
# edit distance between pfkswkfsococg and pfkswkfroecgt: 0.3076923076923077
# ----------
# ['w', 'p', 't', 'g', 'k', 'f', 's']
# for sequence 4 prediction is ['c', 'o']
# edit distance between wptgkfsoc and wptgkfsco: 0.11111111111111116
# ----------
# ['p', 'w', 'f', 'k', 'g', nan, nan]
# for sequence 5 prediction is []
# edit distance between pwfkg and pwfkg: 0.0
# ----------
# ['p', 'o', 'w', 'c', 'e', 'r', nan]
# for sequence 6 prediction is []
# edit distance between powcer and powcer: 0.0
# ----------
# ['c', 'o', 'p', 'r', 'e', 'r', 'k']
# for sequence 7 prediction is []
# edit distance between coprerk and coprerk: 0.0
# ----------
# ['w', 'o', 'p', 'o', 'f', 'k', 'k']
# for sequence 8 prediction is ['s', 'r', 'e']
# edit distance between wopofkkskf and wopofkksre: 0.19999999999999996
# ----------
# ['o', 'p', 'w', 'p', 'w', 'g', 'c']
# for sequence 9 prediction is ['k', 'f']
# edit distance between opwpwgcoc and opwpwgckf: 0.2222222222222222
# ----------
# ['p', 'o', 'c', 'r', 'f', 'k', 's']
# for sequence 10 prediction is ['e', 'w', 'g']
# edit distance between pocrfksfks and pocrfksewg: 0.30000000000000004
# ----------
# ['c', 'g', 'p', 'o', 'g', 'p', 'o']
# for sequence 11 prediction is ['k']
# edit distance between cgpogpoc and cgpogpok: 0.125
# ----------
# ['p', 'w', 'o', 'c', 'g', 'f', 'k']
# for sequence 12 prediction is ['s', 'r', 'e', 't']
# edit distance between pwocgfkfsrere and pwocgfksret: 0.23076923076923073
# ----------
# ['o', 'c', 'w', 'g', 'r', 'k', nan]
# for sequence 13 prediction is []
# edit distance between ocwgrk and ocwgrk: 0.0
# ----------
# ['w', 'p', 'g', 's', 'f', 'k', nan]
# for sequence 14 prediction is []
# edit distance between wpgsfk and wpgsfk: 0.0
# ----------
# ['p', 'w', 'o', 'f', 's', 'g', nan]
# for sequence 15 prediction is []
# edit distance between pwofsg and pwofsg: 0.0
# ----------
# ['p', 'o', 'c', 'p', 'o', 'c', 'w']
# for sequence 16 prediction is ['k', 'f', 'g', 'r']
# edit distance between pocpocwgkfs and pocpocwkfgr: 0.2727272727272727
# ----------
# ['p', 'o', 'c', 'g', 'w', 'g', nan]
# for sequence 17 prediction is []
# edit distance between pocgwg and pocgwg: 0.0
# ----------
# ['p', 'w', 'g', 'o', 'c', 'k', 'f']
# for sequence 18 prediction is ['s', 'r', 'e', 't']
# edit distance between pwgockfsfksret and pwgockfsret: 0.2142857142857143
# ----------
# ['o', 'c', 'p', 'w', 'g', 'f', 'k']
# for sequence 19 prediction is ['s', 'r', 'e', 't']
# edit distance between ocpwgfkskfsrere and ocpwgfksret: 0.33333333333333337
# ----------
# ['c', 'o', 'p', 'w', 'g', 'w', 'p']
# for sequence 20 prediction is ['k', 'f', 's', 'r']
# edit distance between copwgwpresk and copwgwpkfsr: 0.2727272727272727
# ----------
# ['p', 'w', 't', 'e', 'r', 'f', 'k']
# for sequence 21 prediction is ['s']
# edit distance between pwterfkf and pwterfks: 0.125
# ----------
# ['p', 'o', 'c', 'w', 'g', 'g', 'p']
# for sequence 22 prediction is ['k', 'f', 's', 'r', 'e', 't']
# edit distance between pocwggpfkfksrer and pocwggpkfsret: 0.19999999999999996
# ----------
# ['w', 'p', 'o', 'f', 'c', 'g', 'k']
# for sequence 23 prediction is ['s', 'r', 'e', 't']
# edit distance between wpofcgkrpwgfksocr and wpofcgksret: 0.5294117647058824
# ----------
# ['c', 'w', 'p', 'f', 'k', 's', 'o']
# for sequence 24 prediction is ['r']
# edit distance between cwpfksor and cwpfksor: 0.0
# ----------
# ['p', 'w', 'f', 'k', 's', 'o', 'r']
# for sequence 25 prediction is ['e']
# edit distance between pwfksorc and pwfksore: 0.125
# ----------
# ['p', 'o', 'c', 'g', 'w', 'k', 'f']
# for sequence 26 prediction is ['s', 'r', 'e', 't']
# edit distance between pocgwkfkfser and pocgwkfsret: 0.33333333333333337
# ----------
# ['p', 'o', 'w', 'c', 't', 'g', 'c']
# for sequence 27 prediction is ['f', 'k']
# edit distance between powctgcog and powctgcfk: 0.2222222222222222
# ----------
# ['p', 'o', 'w', 'g', 'c', 'p', 'o']
# for sequence 28 prediction is []
# edit distance between powgcpo and powgcpo: 0.0
# ----------
# ['p', 'w', 'f', 'k', 't', nan, nan]
# for sequence 29 prediction is []
# edit distance between pwfkt and pwfkt: 0.0
# ----------
# ['p', 'w', 'o', 'k', 'f', 'k', 'r']
# for sequence 30 prediction is ['e']
# edit distance between pwokfkrg and pwokfkre: 0.125
# ----------
# ['c', 'o', 'p', 'c', 'o', 'g', 'p']
# for sequence 31 prediction is ['k', 'f', 's', 'r', 'w', 't']
# edit distance between copcogpgwfksr and copcogpkfsrwt: 0.3846153846153846
# ----------
# ['p', 'g', 's', 'f', 'k', 's', 'k']
# for sequence 32 prediction is ['c', 'a']
# edit distance between pgsfkskfg and pgsfkskca: 0.2222222222222222
# ----------
# ['w', 'g', 'p', 't', 'o', 'c', 'o']
# for sequence 33 prediction is ['k', 'f', 'r']
# edit distance between wgptocopwg and wgptocokfr: 0.30000000000000004
# ----------
# ['p', 'o', 'w', 'c', 'g', 'r', 'e']
# for sequence 34 prediction is []
# edit distance between powcgre and powcgre: 0.0
# ----------
# ['p', 'e', 'r', 'k', 's', 'c', 'w']
# for sequence 35 prediction is ['f', 'g', 'o']
# edit distance between perkscwgtf and perkscwfgo: 0.30000000000000004
# ----------
# ['p', 'c', 'g', 'w', 'o', 'r', 'k']
# for sequence 36 prediction is ['s', 'f', 'e', 't']
# edit distance between pcgworkfkfs and pcgworksfet: 0.36363636363636365
# ----------
# ['p', 'o', 'p', 'o', 'c', 'g', 'k']
# for sequence 37 prediction is ['r']
# edit distance between popocgkr and popocgkr: 0.0
# ----------
# ['p', 'w', 't', 'g', 'c', 'f', 'k']
# for sequence 38 prediction is ['s', 'r', 'o', 'e']
# edit distance between pwtgcfkfksr and pwtgcfksroe: 0.36363636363636365
# ----------
# ['p', 'o', 'c', 'w', 'k', 'f', nan]
# for sequence 39 prediction is []
# edit distance between pocwkf and pocwkf: 0.0
# ----------
# ['p', 'g', 'k', 'f', 'k', 'f', nan]
# for sequence 40 prediction is []
# edit distance between pgkfkf and pgkfkf: 0.0
# ----------
# ['c', 'w', 'o', 'p', 'g', nan, nan]
# for sequence 41 prediction is []
# edit distance between cwopg and cwopg: 0.0
# ----------
# ['p', 'o', 'w', 'c', 'g', 'k', 'f']
# for sequence 42 prediction is ['s', 'r', 'e']
# edit distance between powcgkfkfr and powcgkfsre: 0.30000000000000004
# ----------
# ['w', 'p', 'g', 'f', 'k', 's', 'k']
# for sequence 43 prediction is []
# edit distance between wpgfksk and wpgfksk: 0.0
# ----------
# ['p', 'o', 'c', 'w', 'c', 'p', 'o']
# for sequence 44 prediction is ['k', 'f', 'g']
# edit distance between pocwcpoere and pocwcpokfg: 0.30000000000000004
# ----------
# ['p', 'w', 'k', 'f', nan, nan, nan]
# for sequence 45 prediction is []
# edit distance between pwkf and pwkf: 0.0
# ----------
# ['c', 'p', 't', 'g', 'o', nan, nan]
# for sequence 46 prediction is []
# edit distance between cptgo and cptgo: 0.0
# ----------
# ['p', 'o', 'c', 'f', 'k', 's', 'w']
# for sequence 47 prediction is ['r', 'g']
# edit distance between pocfkswgr and pocfkswrg: 0.11111111111111116
# ----------
# ['p', 'o', 'w', 'c', 'f', 'k', 'f']
# for sequence 48 prediction is ['s']
# edit distance between powcfkfk and powcfkfs: 0.125
# ----------
# ['p', 'w', 'g', 'f', 'k', 's', 'f']
# for sequence 49 prediction is ['r']
# edit distance between pwgfksfk and pwgfksfr: 0.125
# ----------
# ['g', 'p', 'w', 'f', 'k', 's', nan]
# for sequence 50 prediction is []
# edit distance between gpwfks and gpwfks: 0.0
# ----------
# ['c', 'g', 'w', 'p', 'w', nan, nan]
# for sequence 51 prediction is []
# edit distance between cgwpw and cgwpw: 0.0
# ----------
# ['c', 'w', 'o', 'p', 'g', 't', 'r']
# for sequence 52 prediction is ['k', 'f', 's', 'e']
# edit distance between cwopgtrekfksksf and cwopgtrkfse: 0.33333333333333337
# ----------
# ['p', 'o', 'c', 's', 'f', 'k', 'w']
# for sequence 53 prediction is []
# edit distance between pocsfkw and pocsfkw: 0.0
# ----------
# ['o', 'c', 'p', 'w', 'g', 'f', 'k']
# for sequence 54 prediction is ['s']
# edit distance between ocpwgfkf and ocpwgfks: 0.125
# ----------
# ['p', 'w', 'g', 't', 'e', 'r', 'k']
# for sequence 55 prediction is ['s', 'f', 'c', 'o']
# edit distance between pwgterkfsoc and pwgterksfco: 0.18181818181818177
# ----------
# ['p', 'o', 'c', 'g', 'w', 'r', 'k']
# for sequence 56 prediction is ['s', 'f']
# edit distance between pocgwrkfs and pocgwrksf: 0.11111111111111116
# ----------
# ['t', 'g', 'c', 'w', 'p', 'r', 'o']
# for sequence 57 prediction is []
# edit distance between tgcwpro and tgcwpro: 0.0
# ----------
# ['p', 'o', 'c', 'g', 'k', 'f', 's']
# for sequence 58 prediction is ['r', 'e', 'w']
# edit distance between pocgkfskfr and pocgkfsrew: 0.30000000000000004
# ----------
# ['p', 'g', 'c', 'o', 'w', nan, nan]
# for sequence 59 prediction is []
# edit distance between pgcow and pgcow: 0.0
# ----------
# ['o', 'p', 'w', 'g', nan, nan, nan]
# for sequence 60 prediction is []
# edit distance between opwg and opwg: 0.0
# ----------
# ['w', 'p', 'g', 'c', 'o', 'w', 'p']
# for sequence 61 prediction is ['k', 'f', 's', 'r', 'e', 't']
# edit distance between wpgcowpcfksre and wpgcowpkfsret: 0.23076923076923073
# ----------
# ['r', 'e', nan, nan, nan, nan, nan]
# for sequence 62 prediction is []
# edit distance between re and re: 0.0
# ----------
# ['p', 't', 'w', 'g', 'f', 'k', 's']
# for sequence 63 prediction is []
# edit distance between ptwgfks and ptwgfks: 0.0
# ----------
# ['p', 'o', 'c', 'r', 'f', 'k', 'f']
# for sequence 64 prediction is ['s']
# edit distance between pocrfkfk and pocrfkfs: 0.125
# ----------
# ['p', 'o', 'c', 'k', 'r', nan, nan]
# for sequence 65 prediction is []
# edit distance between pockr and pockr: 0.0
# ----------
# ['p', 'o', 'c', 'k', 'f', 's', 'k']
# for sequence 66 prediction is ['r', 'e', 'w', 'g', 'b', 't']
# edit distance between pockfskfswgre and pockfskrewgbt: 0.3076923076923077
# ----------
# ['t', 'g', 'p', 'c', 'o', 'w', 'p']
# for sequence 67 prediction is ['r', 'k', 'f', 's', 'e']
# edit distance between tgpcowpgpwcog and tgpcowprkfse: 0.46153846153846156
# ----------
# ['g', 'w', 'p', 'f', 'r', 'k', 's']
# for sequence 68 prediction is ['e']
# edit distance between gwpfrkst and gwpfrkse: 0.125
# ----------
# ['p', 'f', 'k', 'f', 'k', 's', 'g']
# for sequence 69 prediction is []
# edit distance between pfkfksg and pfkfksg: 0.0
# ----------
# ['p', 'w', 'o', 'g', 's', 'f', 'k']
# for sequence 70 prediction is ['r']
# edit distance between pwogsfkg and pwogsfkr: 0.125
# ----------
# ['p', 'w', 'k', 'f', nan, nan, nan]
# for sequence 71 prediction is []
# edit distance between pwkf and pwkf: 0.0
# ----------
# ['g', 'w', 'p', 'o', 'c', 'o', 's']
# for sequence 72 prediction is ['r', 'e', 'f', 'k', 't']
# edit distance between gwpocoskfsfk and gwpocosrefkt: 0.33333333333333337
# ----------
# ['w', 't', 'p', 'c', 'o', 'c', 'k']
# for sequence 73 prediction is ['f', 's', 'g']
# edit distance between wtpcockfkf and wtpcockfsg: 0.19999999999999996
# ----------
# ['w', 'p', 'g', 'f', 'k', 'f', 'k']
# for sequence 74 prediction is ['s', 'r']
# edit distance between wpgfkfkre and wpgfkfksr: 0.2222222222222222
# ----------
# ['p', 'o', 'c', 'o', 'c', 'w', 't']
# for sequence 75 prediction is ['k', 'f', 'g', 'r', 's', 'e']
# edit distance between pococwtrfkfkg and pococwtkfgrse: 0.3846153846153846
# ----------
# ['p', 'w', 'o', 'c', 'f', 'k', 's']
# for sequence 76 prediction is ['r', 'e', 'g', 't']
# edit distance between pwocfksfksr and pwocfksregt: 0.36363636363636365
# ----------
# ['p', 'w', 'g', 'e', 'r', 'k', 's']
# for sequence 77 prediction is []
# edit distance between pwgerks and pwgerks: 0.0
# ----------
# ['p', 'o', 'c', 't', 'f', 'k', 'f']
# for sequence 78 prediction is ['s', 'r', 'g', 'w']
# edit distance between poctfkfkrwg and poctfkfsrgw: 0.18181818181818177
# ----------
# ['p', 'w', 'f', 'k', 's', 'o', 'c']
# for sequence 79 prediction is ['r']
# edit distance between pwfksocr and pwfksocr: 0.0
# ----------
# ['t', 'n', 'p', 'z', 'c', nan, nan]
# for sequence 80 prediction is []
# edit distance between tnpzc and tnpzc: 0.0
# ----------
# ['t', 'n', 'p', 'c', 'z', nan, nan]
# for sequence 81 prediction is []
# edit distance between tnpcz and tnpcz: 0.0
# ----------
# ['t', 'n', 'p', 'z', 'c', nan, nan]
# for sequence 82 prediction is []
# edit distance between tnpzc and tnpzc: 0.0
# ----------
# ['t', 'n', 'z', 'p', 'c', nan, nan]
# for sequence 83 prediction is []
# edit distance between tnzpc and tnzpc: 0.0
# ----------
# ['p', 'm', 'z', nan, nan, nan, nan]
# for sequence 84 prediction is []
# edit distance between pmz and pmz: 0.0
# ----------
# ['x', 'm', 'b', 'z', 'd', nan, nan]
# for sequence 85 prediction is []
# edit distance between xmbzd and xmbzd: 0.0
# ----------
# ['p', 'I', 'm', 'z', nan, nan, nan]
# for sequence 86 prediction is []
# edit distance between pImz and pImz: 0.0
# ----------
# ['m', 'z', 'x', 'p', nan, nan, nan]
# for sequence 87 prediction is []
# edit distance between mzxp and mzxp: 0.0
# ----------
# ['p', 'b', 'z', nan, nan, nan, nan]
# for sequence 88 prediction is []
# edit distance between pbz and pbz: 0.0
# ----------
# ['p', 'g', 'z', nan, nan, nan, nan]
# for sequence 89 prediction is []
# edit distance between pgz and pgz: 0.0
# ----------
# ['p', 'n', 'z', 'g', 'a', nan, nan]
# for sequence 90 prediction is []
# edit distance between pnzga and pnzga: 0.0
# ----------
# ['d', 'n', 'z', 'g', 'd', 'p', nan]
# for sequence 91 prediction is []
# edit distance between dnzgdp and dnzgdp: 0.0
# ----------
# ['p', 'n', 'd', 'z', nan, nan, nan]
# for sequence 92 prediction is []
# edit distance between pndz and pndz: 0.0
# ----------
# ['n', 'z', 'p', 'd', 'g', 'd', 's']
# for sequence 93 prediction is []
# edit distance between nzpdgds and nzpdgds: 0.0
# ----------
# ['m', 'c', 'd', 'd', 'x', 'p', nan]
# for sequence 94 prediction is []
# edit distance between mcddxp and mcddxp: 0.0
# ----------
# ['p', 'c', 'f', 'k', 'd', 'd', 'd']
# for sequence 95 prediction is ['a', 'g']
# edit distance between pcfkdddaag and pcfkdddag: 0.09999999999999998
# ----------
# ['d', 'a', 'g', 'p', 'k', nan, nan]
# for sequence 96 prediction is []
# edit distance between dagpk and dagpk: 0.0
# ----------
# ['p', 'c', nan, nan, nan, nan, nan]
# for sequence 97 prediction is []
# edit distance between pc and pc: 0.0
# ----------
# ['g', 'k', 'f', 'a', 'd', 'p', nan]
# for sequence 98 prediction is []
# edit distance between gkfadp and gkfadp: 0.0
# ----------
# ['p', 'f', 'g', 'd', 's', nan, nan]
# for sequence 99 prediction is []
# edit distance between pfgds and pfgds: 0.0
# ----------
# ['b', 'c', 's', 'f', 'g', 'k', 'a']
# for sequence 100 prediction is ['p']
# edit distance between bcsfgkap and bcsfgkap: 0.0
# ----------
# ['p', 'b', 's', 'f', 'k', 'c', 'g']
# for sequence 101 prediction is ['a']
# edit distance between pbsfkcga and pbsfkcga: 0.0
# ----------
# ['p', 'b', 'g', 'a', 'f', 'k', 'c']
# for sequence 102 prediction is ['s']
# edit distance between pbgafkcs and pbgafkcs: 0.0
# ----------
# ['g', 'p', 'b', 'c', 'k', 's', 'f']
# for sequence 103 prediction is ['a']
# edit distance between gpbcksfa and gpbcksfa: 0.0
# ----------
# ['p', 'b', 'f', 'k', 's', 'c', 'g']
# for sequence 104 prediction is ['a']
# edit distance between pbfkscga and pbfkscga: 0.0
# ----------
# ['p', 'b', 's', 'g', 'k', 'a', 'f']
# for sequence 105 prediction is ['c']
# edit distance between pbsgkafc and pbsgkafc: 0.0
# ----------
# ['p', 'b', 'c', 's', 'k', 'f', 'g']
# for sequence 106 prediction is ['a']
# edit distance between pbcskfga and pbcskfga: 0.0
# ----------
# ['p', 's', 'f', 'k', 'a', 'g', 'c']
# for sequence 107 prediction is ['b']
# edit distance between psfkagcb and psfkagcb: 0.0
# ----------
# ['p', 'f', 'k', 's', 'c', 'a', 'g']
# for sequence 108 prediction is ['b']
# edit distance between pfkscagb and pfkscagb: 0.0
# ----------
# ['p', 'f', 's', 'k', 'a', 'g', 'c']
# for sequence 109 prediction is ['b']
# edit distance between pfskagcb and pfskagcb: 0.0
# ----------
# ['p', 's', 'k', 'f', 'c', 'a', 'g']
# for sequence 110 prediction is ['b']
# edit distance between pskfcagb and pskfcagb: 0.0
# ----------
# ['p', 'f', 'k', 's', 'c', 'a', 'g']
# for sequence 111 prediction is ['b']
# edit distance between pfkscagb and pfkscagb: 0.0
# ----------
# ['p', 's', 'f', 'k', 'g', 'a', 'c']
# for sequence 112 prediction is ['b']
# edit distance between psfkgacb and psfkgacb: 0.0
# ----------
# ['p', 'f', 'k', 'b', 's', 'c', 'g']
# for sequence 113 prediction is ['a']
# edit distance between pfkbscga and pfkbscga: 0.0
# ----------
# ['p', 'c', 'g', 'a', 'f', 'k', 'b']
# for sequence 114 prediction is ['s']
# edit distance between pcgafkbs and pcgafkbs: 0.0
# ----------
# ['g', 'p', 'a', 'b', 'k', 'f', 's']
# for sequence 115 prediction is ['c']
# edit distance between gpabkfsc and gpabkfsc: 0.0
# ----------
# ['p', 'a', 'b', 'k', 'g', 'c', 'f']
# for sequence 116 prediction is ['s']
# edit distance between pabkgcfs and pabkgcfs: 0.0
# ----------
# ['g', 'c', 'p', 'a', 'b', 'k', 'f']
# for sequence 117 prediction is ['s']
# edit distance between gcpabkfs and gcpabkfs: 0.0
# ----------
# ['p', 'a', 's', 'b', 'k', 'f', 'g']
# for sequence 118 prediction is ['c']
# edit distance between pasbkfgc and pasbkfgc: 0.0
# ----------
# ['p', 'a', 'b', 'c', 'g', 'k', 's']
# for sequence 119 prediction is ['f']
# edit distance between pabcgksf and pabcgksf: 0.0
# ----------
# ['s', 'f', 'k', 'p', 'c', 'g', 'a']
# for sequence 120 prediction is ['b']
# edit distance between sfkpcgab and sfkpcgab: 0.0
# ----------
# ['s', 'p', 'g', 'b', 'k', 'f', 'c']
# for sequence 121 prediction is ['a']
# edit distance between spgbkfca and spgbkfca: 0.0
# ----------
# ['s', 'p', 'a', 'k', 'g', 'f', 'c']
# for sequence 122 prediction is ['b']
# edit distance between spakgfcb and spakgfcb: 0.0
# ----------
# ['c', 'g', 'b', 'k', 'p', 'a', 's']
# for sequence 123 prediction is ['f']
# edit distance between cgbkpasf and cgbkpasf: 0.0
# ----------
# ['f', 'k', 's', 'p', 'c', 'b', 'a']
# for sequence 124 prediction is ['g']
# edit distance between fkspcbag and fkspcbag: 0.0
# ----------
# ['p', 'k', 'f', 's', 'b', 'g', 'c']
# for sequence 125 prediction is ['a']
# edit distance between pkfsbgca and pkfsbgca: 0.0
# ----------
# ['c', 'p', 'k', 'f', 'g', 's', 'b']
# for sequence 126 prediction is ['a']
# edit distance between cpkfgsba and cpkfgsba: 0.0
# ----------
# ['c', 'b', 'g', 's', 'f', 'a', 'p']
# for sequence 127 prediction is ['k']
# edit distance between cbgsfapk and cbgsfapk: 0.0
# ----------
# ['c', 'g', 'p', 's', 'a', 'k', 'f']
# for sequence 128 prediction is ['b']
# edit distance between cgpsakfb and cgpsakfb: 0.0
# ----------
# ['p', 'f', 'k', 's', 'g', 'c', 'a']
# for sequence 129 prediction is ['b']
# edit distance between pfksgcab and pfksgcab: 0.0
# ----------
# ['p', 'c', 's', 'k', 'f', 'b', 'g']
# for sequence 130 prediction is ['a']
# edit distance between pcskfbga and pcskfbga: 0.0
# ----------
# ['s', 'b', 'k', 'p', 'f', 'c', 'a']
# for sequence 131 prediction is ['g']
# edit distance between sbkpfcag and sbkpfcag: 0.0
# ----------
# ['f', 'p', 'k', 'g', 'b', 's', 'a']
# for sequence 132 prediction is ['c']
# edit distance between fpkgbsac and fpkgbsac: 0.0
# ----------
# ['p', 'a', 'b', 'f', 'g', 's', 'c']
# for sequence 133 prediction is ['k']
# edit distance between pabfgsck and pabfgsck: 0.0
# ----------
# ['c', 'p', 'g', 'f', 'k', 's', 'a']
# for sequence 134 prediction is ['b']
# edit distance between cpgfksab and cpgfksab: 0.0
# ----------
# ['g', 'f', 'c', 's', 'p', 'k', 'o']
# for sequence 135 prediction is ['r']
# edit distance between gfcspkob and gfcspkor: 0.125
# ----------
# ['p', 'k', 'f', 's', 'b', 'a', 'g']
# for sequence 136 prediction is ['c']
# edit distance between pkfsbagc and pkfsbagc: 0.0
# ----------
# ['p', 'k', 'f', 's', 'b', 'g', 'a']
# for sequence 137 prediction is ['c']
# edit distance between pkfsbgac and pkfsbgac: 0.0
# ----------
# ['p', 'b', 'f', 'k', 's', 'c', 'g']
# for sequence 138 prediction is ['a']
# edit distance between pbfkscga and pbfkscga: 0.0
# ----------
# ['b', 'p', 'k', 's', 'f', 'c', 'g']
# for sequence 139 prediction is ['a']
# edit distance between bpksfcga and bpksfcga: 0.0
# ----------
# ['p', 'a', 'g', 'b', 'k', 'f', 's']
# for sequence 140 prediction is ['c']
# edit distance between pagbkfsc and pagbkfsc: 0.0
# ----------
# ['p', 'c', 'g', 'a', 'f', 'k', 's']
# for sequence 141 prediction is ['b']
# edit distance between pcgafksb and pcgafksb: 0.0
# ----------
# ['p', 'c', 's', 'b', 'f', 'k', 'g']
# for sequence 142 prediction is ['a']
# edit distance between pcsbfkga and pcsbfkga: 0.0
# ----------
# ['p', 'b', 's', 'k', 'f', 'g', 'c']
# for sequence 143 prediction is ['a']
# edit distance between pbskfgca and pbskfgca: 0.0
# ----------
# ['p', 's', 'c', 'g', 'f', 'b', 'a']
# for sequence 144 prediction is ['k']
# edit distance between pscgfbak and pscgfbak: 0.0
# ----------
# ['p', 'f', 'k', 'c', 'b', 'g', 's']
# for sequence 145 prediction is ['a']
# edit distance between pfkcbgsa and pfkcbgsa: 0.0
# ----------
# ['p', 'k', 'f', 's', 'g', 'c', 'b']
# for sequence 146 prediction is ['a']
# edit distance between pkfsgcba and pkfsgcba: 0.0
# ----------
# ['p', 'c', 'f', 'k', 's', 'a', 'g']
# for sequence 147 prediction is ['b']
# edit distance between pcfksagb and pcfksagb: 0.0
# ----------
# ['p', 'b', 'c', 'f', 's', 'k', 'g']
# for sequence 148 prediction is ['a']
# edit distance between pbcfskga and pbcfskga: 0.0
# ----------
# ['p', 'b', 'f', 'k', 'c', 's', 'g']
# for sequence 149 prediction is ['a']
# edit distance between pbfkcsga and pbfkcsga: 0.0
# ----------
# ['p', 'c', 's', 'f', 'k', 'b', 'g']
# for sequence 150 prediction is ['a']
# edit distance between pcsfkbga and pcsfkbga: 0.0
# ----------
# ['p', 'k', 'f', 's', 'a', 'b', 'g']
# for sequence 151 prediction is ['c']
# edit distance between pkfsabgc and pkfsabgc: 0.0
# ----------
# ['p', 'k', 'f', 's', 'g', 'c', 'b']
# for sequence 152 prediction is ['a']
# edit distance between pkfsgcba and pkfsgcba: 0.0
# ----------
# ['p', 'k', 'f', 's', 'g', 'c', 'b']
# for sequence 153 prediction is ['a']
# edit distance between pkfsgcba and pkfsgcba: 0.0
# ----------
# ['p', 'k', 'f', 's', 'g', 'c', 'a']
# for sequence 154 prediction is ['b']
# edit distance between pkfsgcab and pkfsgcab: 0.0
# ----------
# ['p', 'k', 'f', 'b', 's', 'c', 'a']
# for sequence 155 prediction is ['g']
# edit distance between pkfbscag and pkfbscag: 0.0
# ----------
# ['p', 'k', 'b', 's', 'f', 'g', 'c']
# for sequence 156 prediction is ['a']
# edit distance between pkbsfgca and pkbsfgca: 0.0
# ----------
# ['p', 'k', 'f', 'b', 's', 'c', 'g']
# for sequence 157 prediction is ['a']
# edit distance between pkfbscga and pkfbscga: 0.0
# ----------
# ['p', 'k', 'f', 's', 'b', 'g', 'a']
# for sequence 158 prediction is ['c']
# edit distance between pkfsbgac and pkfsbgac: 0.0
# ----------
# ['p', 'k', 'f', 's', 'a', 'g', 'b']
# for sequence 159 prediction is ['c']
# edit distance between pkfsagbc and pkfsagbc: 0.0
# ----------
# ['p', 'k', 'f', 's', 'g', 'c', 'a']
# for sequence 160 prediction is ['b']
# edit distance between pkfsgcab and pkfsgcab: 0.0
# ----------
# ['p', 'k', 'f', 's', 'g', 'c', 'b']
# for sequence 161 prediction is ['a']
# edit distance between pkfsgcba and pkfsgcba: 0.0
# ----------
# ['p', 'k', 'f', 's', 'g', 'c', 'a']
# for sequence 162 prediction is ['b']
# edit distance between pkfsgcab and pkfsgcab: 0.0
# ----------
# ['p', 'k', 'f', 's', 'a', 'c', 'g']
# for sequence 163 prediction is ['b']
# edit distance between pkfsacgb and pkfsacgb: 0.0
# ----------
# ['p', 'k', 'f', 's', 'b', 'c', 'g']
# for sequence 164 prediction is ['a']
# edit distance between pkfsbcga and pkfsbcga: 0.0
# ----------
# ['p', 'f', 's', 'k', 'b', 'c', 'g']
# for sequence 165 prediction is ['a']
# edit distance between pfskbcga and pfskbcga: 0.0
# ----------
# ['p', 'b', 'k', 'f', 's', 'c', 'g']
# for sequence 166 prediction is ['a']
# edit distance between pbkfscga and pbkfscga: 0.0
# ----------
# ['p', 'f', 's', 'k', 'b', 'g', 'c']
# for sequence 167 prediction is ['a']
# edit distance between pfskbgca and pfskbgca: 0.0
# ----------
# Average similarity: 0.06966766407417668
# Median similarity: 0.0

# %%
with open('results/all_cpt_7.txt', 'w') as f:
    f.write(str(distances))

# %%
# check how many sequences have 8+ items

length = [np.count_nonzero(~pd.isnull(x)) for x in data]
over_8 = [x for x in length if x >= 8 ]
len(over_8)/len(length) * 100
# Out:
# 35.714285714285715

# %% [markdown]
# ### calculate median over all input variations (1-7 items given)

# %%
with open('results/all_cpt_1.txt', 'r') as f:
    distances1 = f.read()
    distances1 = ast.literal_eval(distances1)

# %%
with open('results/all_cpt_2.txt', 'r') as f:
    distances2 = f.read()
    distances2 = ast.literal_eval(distances2)

# %%
with open('results/all_cpt_3.txt', 'r') as f:
    distances3 = f.read()
    distances3 = ast.literal_eval(distances3)

# %%
with open('results/all_cpt_4.txt', 'r') as f:
    distances4 = f.read()
    distances4 = ast.literal_eval(distances4)

# %%
with open('results/all_cpt_5.txt', 'r') as f:
    distances5 = f.read()
    distances5 = ast.literal_eval(distances5)

# %%
with open('results/all_cpt_6.txt', 'r') as f:
    distances6 = f.read()
    distances6 = ast.literal_eval(distances6)

# %%
with open('results/all_cpt_7.txt', 'r') as f:
    distances7 = f.read()
    distances7 = ast.literal_eval(distances7)

# %%
avg1 = np.mean(distances1)
avg2 = np.mean(distances2)
avg3 = np.mean(distances3)
avg4 = np.mean(distances4)
avg5 = np.mean(distances5)
avg6 = np.mean(distances6)
avg7 = np.mean(distances7)

# %%
np.mean([avg1, avg2, avg2, avg3, avg4, avg5, avg6, avg7])
# Out:
# 0.3611702996320907

# %%
np.median([np.median(distances1), np.median(distances2), np.median(distances3), 
           np.median(distances4), np.median(distances5), np.median(distances6),
          np.median(distances7)])
# Out:
# 0.375
