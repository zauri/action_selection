# %%
import pandas as pd
import numpy as np
from fastDamerauLevenshtein import damerauLevenshtein

# %%
class Prediction():
    Item = None
    Parent = None
    Children = None

    def __init__(self, itemValue=None):
        self.Item = itemValue
        self.Children = []
        self.Parent = None

    def get_child(self, target):
        for chld in self.Children:
            if chld.Item == target:
                return chld
        return None

    def get_children(self):
        return self.Children

    def has_child(self, target):
        found = self.get_child(target)
        if found is not None:
            return True
        else:
            return False

    def add_new_child(self, child):
        newchild = Prediction(child)
        newchild.Parent = self
        self.Children.append(newchild)

    def remove_child(self, child):
        for chld in self.Children:
            if chld.Item == child:
                self.Children.remove(chld)

# %%
class CPT():
    alphabet = None
    root = None
    II = None
    LT = None
    def __init__(self):
        self.alphabet = set()
        self.root = Prediction()
        self.II = {}
        self.LT = {}

    def load_files(self, train_file, test_file=None):
        """
        This function reads in the wide csv file of sequences separated by commas and returns a list of list of those
        sequences. The sequences are defined as below.
        seq1 = A,B,C,D
        seq2  B,C,E
        Returns: [[A,B,C,D],[B,C,E]]
        """
        
        data = []
        target = []

        if train_file is None:
            return train_file

        train = pd.read_csv(train_file, header=0)

        for index, row in train.iterrows():
            data.append(row.values)

        if test_file is not None:

            test = pd.read_csv(test_file, header=None)

            for index, row in test.iterrows():
                data.append(row.values)
                target.append(list(row.values))

            return data, target

        return data


    def train(self, data):
        """
         This functions populates the Prediction Tree, Inverted Index and LookUp Table for the algorithm.
         Input: The list of list training data
         Output : Boolean True
         """

        cursornode = self.root

        for seqid, row in enumerate(data):
            for element in row:

                if cursornode.has_child(element) == False:
                    cursornode.add_new_child(element)
                    cursornode = cursornode.get_child(element)

                else:
                    cursornode = cursornode.get_child(element)

                # Adding to the Inverted Index

                if self.II.get(element) is None:
                    self.II[element] = set()

                self.II[element].add(seqid)

                self.alphabet.add(element)

            self.LT[seqid] = cursornode

            cursornode = self.root

        return True

    def score(self, counttable, key, length, target_size, number_of_similar_sequences, number_items_counttable):
        """
         This functions populates the Prediction Tree, Inverted Index and LookUp Table for the algorithm.
         Input: The list of list training data
         Output : Boolean True
         """
        
        weight_level = 1 / number_of_similar_sequences
        weight_distance = 1 / number_items_counttable
        score = 1 + weight_level + weight_distance * 0.001

        if counttable.get(key) is None:
            counttable[key] = score
        else:
            counttable[key] = score * counttable.get(key)

        return counttable

    def predict(self, data, target, k, n=1):
        """
        Here target is the test dataset in the form of list of list,
        k is the number of last elements that will be used to find similar sequences and,
        n is the number of predictions required.
        Input: training list of list, target list of list, k,n
        Output: max n predictions for each sequence
        """

        predictions = []

        for each_target in target:
            each_target = each_target[-k:]

            intersection = set(range(0, len(data)))

            for element in each_target:
                if self.II.get(element) is None:
                    continue
                intersection = intersection & self.II.get(element)

            similar_sequences = []

            for element in intersection:
                currentnode = self.LT.get(element)
                tmp = []
                while currentnode.Item is not None:
                    tmp.append(currentnode.Item)
                    currentnode = currentnode.Parent
                similar_sequences.append(tmp)

            for sequence in similar_sequences:
                sequence.reverse()

            counttable = {}

            for sequence in similar_sequences:
                try:
                    index = next(
                        i for i, v in zip(range(len(sequence) - 1, 0, -1), reversed(sequence)) if v == each_target[-1])
                except:
                    index = None
                if index is not None:
                    count = 1
                    for element in sequence[index + 1:]:
                        if element in each_target:
                            continue

                        counttable = self.score(counttable, element, len(each_target), len(each_target),
                                                len(similar_sequences), count)
                        count += 1

            pred = self.get_n_largest(counttable, n)
            predictions.append(pred)

        return predictions

    def get_n_largest(self, dictionary, n):

        largest = sorted(dictionary.items(), key=lambda t: t[1], reverse=True)[:n]
        return [key for key, _ in largest]

# %%
model = CPT()

# %%
data, target = model.load_files('data/h03_train.csv', 'data/h03_test.csv')

# %%
model.train(data)
# Out:
# True

# %%
predictions = model.predict(data, target, 3, 5)

# %%
i = 0
distances = []

for elem in predictions:
    pred = [x for x in target[i] if str(x) != 'nan']
    dat = [x for x in data[i] if str(x) != 'nan']
    predicted = str(''.join(pred) + ''.join(elem))
    observed = ''.join(dat)
    dl = damerauLevenshtein(predicted, observed)
    distances.append(dl)
    print(target[i])
    print('for sequence {0} prediction is {1}'.format(i, elem))
    print('edit distance between {0} and {1}: {2}'.format(predicted, observed, dl))
    i += 1
    print('----------')

print('Average similarity: {0}'.format(np.mean(distances)))
print('Median similarity: {0}'.format(np.median(distances)))
# Out:
# ['o', 'c', 's']
# for sequence 0 prediction is ['b', 'g', 'k', 'f', 'p']
# edit distance between ocsbgkfp and ocsfgkbp: 0.75
# ----------
# ['p', 'o', 's']
# for sequence 1 prediction is ['b', 'g', 'c', 'k', 'f']
# edit distance between posbgckf and posfkcgb: 0.5
# ----------
# ['p', 'o', 'g']
# for sequence 2 prediction is ['b', 'c', 'k', 's', 'f']
# edit distance between pogbcksf and pogbfkcs: 0.625
# ----------
# ['g', 'p', 'o']
# for sequence 3 prediction is ['b', 'c', 's', 'k', 'f']
# edit distance between gpobcskf and gpocksfb: 0.625
# ----------
# ['p', 'o', 'f']
# for sequence 4 prediction is ['b', 'g', 'c', 's', 'k']
# edit distance between pofbgcsk and pofkscgb: 0.5
# ----------
# ['p', 'o', 's']
# for sequence 5 prediction is ['b', 'g', 'c', 'k', 'f']
# edit distance between posbgckf and posgkbfc: 0.5
# ----------
# ['p', 'o', 'c']
# for sequence 6 prediction is ['b', 'g', 's', 'k', 'f']
# edit distance between pocbgskf and pocskfgb: 0.5
# ----------
# ['p', 's', 'f']
# for sequence 7 prediction is ['b', 'g', 'c', 'o', 'k']
# edit distance between psfbgcok and psfkbgco: 0.75
# ----------
# ['p', 'f', 'k']
# for sequence 8 prediction is ['b', 'g', 'c', 's', 'o']
# edit distance between pfkbgcso and pfkscbgo: 0.5
# ----------
# ['p', 'f', 's']
# for sequence 9 prediction is ['b', 'g', 'c', 'o', 'k']
# edit distance between pfsbgcok and pfskbgco: 0.75
# ----------
# ['p', 's', 'k']
# for sequence 10 prediction is ['b', 'g', 'c', 'o', 'f']
# edit distance between pskbgcof and pskfcbgo: 0.5
# ----------
# ['p', 'f', 'k']
# for sequence 11 prediction is ['b', 'g', 'c', 's', 'o']
# edit distance between pfkbgcso and pfkscbgo: 0.5
# ----------
# ['p', 's', 'f']
# for sequence 12 prediction is ['b', 'g', 'c', 'o', 'k']
# edit distance between psfbgcok and psfkgbco: 0.625
# ----------
# ['p', 'f', 'k']
# for sequence 13 prediction is ['b', 'g', 'c', 's', 'o']
# edit distance between pfkbgcso and pfkoscgb: 0.5
# ----------
# ['p', 'c', 'g']
# for sequence 14 prediction is ['b', 'o', 's', 'f', 'k']
# edit distance between pcgbosfk and pcgbfkos: 0.5
# ----------
# ['g', 'p', 'b']
# for sequence 15 prediction is ['o', 'c', 'k', 'f', 's']
# edit distance between gpbockfs and gpbokfsc: 0.75
# ----------
# ['p', 'b', 'o']
# for sequence 16 prediction is ['g', 'c', 's', 'k', 'f']
# edit distance between pbogcskf and pbokgcfs: 0.625
# ----------
# ['g', 'c', 'p']
# for sequence 17 prediction is ['b', 'k', 'o', 'f', 's']
# edit distance between gcpbkofs and gcpbokfs: 0.875
# ----------
# ['p', 'b', 's']
# for sequence 18 prediction is ['g', 'c', 'o', 'k', 'f']
# edit distance between pbsgcokf and pbsokfgc: 0.5
# ----------
# ['p', 'b', 'o']
# for sequence 19 prediction is ['g', 'c', 's', 'k', 'f']
# edit distance between pbogcskf and pbocgksf: 0.75
# ----------
# ['s', 'f', 'k']
# for sequence 20 prediction is ['b', 'g', 'c', 'o', 'p']
# edit distance between sfkbgcop and sfkpcgbo: 0.5
# ----------
# ['s', 'p', 'g']
# for sequence 21 prediction is ['b', 'c', 'o', 'f', 'k']
# edit distance between spgbcofk and spgokfcb: 0.375
# ----------
# ['s', 'p', 'b']
# for sequence 22 prediction is ['o', 'g', 'c', 'k', 'f']
# edit distance between spbogckf and spbkgfco: 0.5
# ----------
# ['c', 'g', 'o']
# for sequence 23 prediction is ['b', 's', 'k', 'f', 'p']
# edit distance between cgobskfp and cgokpbsf: 0.5
# ----------
# ['f', 'k', 's']
# for sequence 24 prediction is ['b', 'g', 'c', 'o', 'p']
# edit distance between fksbgcop and fkspcobg: 0.5
# ----------
# ['p', 'k', 'f']
# for sequence 25 prediction is ['b', 'g', 'c', 's', 'o']
# edit distance between pkfbgcso and pkfsogcb: 0.5
# ----------
# ['c', 'p', 'k']
# for sequence 26 prediction is ['b', 'g', 's', 'o', 'f']
# edit distance between cpkbgsof and cpkfgsob: 0.75
# ----------
# ['c', 'o', 'g']
# for sequence 27 prediction is ['b', 'k', 's', 'f', 'p']
# edit distance between cogbksfp and cogsfbpk: 0.5
# ----------
# ['c', 'g', 'p']
# for sequence 28 prediction is ['b', 'k', 'o', 'f', 's']
# edit distance between cgpbkofs and cgpsbkfo: 0.625
# ----------
# ['p', 'f', 'k']
# for sequence 29 prediction is ['b', 'g', 'c', 's', 'o']
# edit distance between pfkbgcso and pfksgcbo: 0.75
# ----------
# ['p', 'c', 's']
# for sequence 30 prediction is ['b', 'g', 'o', 'k', 'f']
# edit distance between pcsbgokf and pcskfogb: 0.5
# ----------
# ['s', 'o', 'k']
# for sequence 31 prediction is ['b', 'g', 'c', 'f', 'p']
# edit distance between sokbgcfp and sokpfcbg: 0.5
# ----------
# ['f', 'p', 'k']
# for sequence 32 prediction is ['b', 'g', 'c', 's', 'o']
# edit distance between fpkbgcso and fpkgosbc: 0.5
# ----------
# ['p', 'b', 'o']
# for sequence 33 prediction is ['g', 'c', 's', 'k', 'f']
# edit distance between pbogcskf and pbofgsck: 0.625
# ----------
# ['c', 'p', 'g']
# for sequence 34 prediction is ['b', 'o', 's', 'f', 'k']
# edit distance between cpgbosfk and cpgfksbo: 0.5
# ----------
# ['g', 'f', 'c']
# for sequence 35 prediction is ['b', 'o', 's', 'k', 'p']
# edit distance between gfcboskp and gfcspkob: 0.375
# ----------
# ['p', 'k', 'f']
# for sequence 36 prediction is ['b', 'g', 'c', 's', 'o']
# edit distance between pkfbgcso and pkfsobgc: 0.5
# ----------
# ['p', 'k', 'f']
# for sequence 37 prediction is ['b', 'g', 'c', 's', 'o']
# edit distance between pkfbgcso and pkfsogbc: 0.375
# ----------
# ['p', 'o', 'f']
# for sequence 38 prediction is ['b', 'g', 'c', 's', 'k']
# edit distance between pofbgcsk and pofkscgb: 0.5
# ----------
# ['o', 'p', 'k']
# for sequence 39 prediction is ['b', 'g', 'c', 's', 'f']
# edit distance between opkbgcsf and opksfcgb: 0.5
# ----------
# ['p', 'b', 'g']
# for sequence 40 prediction is ['c', 'o', 'f', 's', 'k']
# edit distance between pbgcofsk and pbgokfsc: 0.625
# ----------
# ['p', 'c', 'g']
# for sequence 41 prediction is ['b', 'o', 's', 'f', 'k']
# edit distance between pcgbosfk and pcgbfkso: 0.5
# ----------
# ['p', 'c', 's']
# for sequence 42 prediction is ['b', 'g', 'o', 'k', 'f']
# edit distance between pcsbgokf and pcsofkgb: 0.375
# ----------
# ['p', 'o', 's']
# for sequence 43 prediction is ['b', 'g', 'c', 'k', 'f']
# edit distance between posbgckf and poskfgcb: 0.5
# ----------
# ['p', 's', 'c']
# for sequence 44 prediction is ['b', 'g', 'o', 'k', 'f']
# edit distance between pscbgokf and pscgfobk: 0.5
# ----------
# ['p', 'f', 'k']
# for sequence 45 prediction is ['b', 'g', 'c', 's', 'o']
# edit distance between pfkbgcso and pfkcogsb: 0.5
# ----------
# ['p', 'k', 'f']
# for sequence 46 prediction is ['b', 'g', 'c', 's', 'o']
# edit distance between pkfbgcso and pkfsgcob: 0.625
# ----------
# ['p', 'c', 'f']
# for sequence 47 prediction is ['b', 'g', 's', 'o', 'k']
# edit distance between pcfbgsok and pcfksbgo: 0.5
# ----------
# ['p', 'o', 'c']
# for sequence 48 prediction is ['b', 'g', 's', 'k', 'f']
# edit distance between pocbgskf and pocfskgb: 0.5
# ----------
# ['p', 'o', 'f']
# for sequence 49 prediction is ['b', 'g', 'c', 's', 'k']
# edit distance between pofbgcsk and pofkcsgb: 0.5
# ----------
# ['p', 'c', 's']
# for sequence 50 prediction is ['b', 'g', 'o', 'k', 'f']
# edit distance between pcsbgokf and pcsfkogb: 0.5
# ----------
# ['p', 'k', 'f']
# for sequence 51 prediction is ['b', 'g', 'c', 's', 'o']
# edit distance between pkfbgcso and pkfsbogc: 0.5
# ----------
# ['p', 'k', 'f']
# for sequence 52 prediction is ['b', 'g', 'c', 's', 'o']
# edit distance between pkfbgcso and pkfsgcob: 0.625
# ----------
# ['p', 'k', 'f']
# for sequence 53 prediction is ['b', 'g', 'c', 's', 'o']
# edit distance between pkfbgcso and pkfsgcob: 0.625
# ----------
# ['p', 'k', 'f']
# for sequence 54 prediction is ['b', 'g', 'c', 's', 'o']
# edit distance between pkfbgcso and pkfsgcbo: 0.75
# ----------
# ['p', 'k', 'f']
# for sequence 55 prediction is ['b', 'g', 'c', 's', 'o']
# edit distance between pkfbgcso and pkfoscbg: 0.5
# ----------
# ['p', 'k', 'o']
# for sequence 56 prediction is ['b', 'g', 'c', 's', 'f']
# edit distance between pkobgcsf and pkosfgcb: 0.5
# ----------
# ['p', 'k', 'f']
# for sequence 57 prediction is ['b', 'g', 'c', 's', 'o']
# edit distance between pkfbgcso and pkfoscgb: 0.5
# ----------
# ['p', 'k', 'f']
# for sequence 58 prediction is ['b', 'g', 'c', 's', 'o']
# edit distance between pkfbgcso and pkfsogbc: 0.375
# ----------
# ['p', 'k', 'f']
# for sequence 59 prediction is ['b', 'g', 'c', 's', 'o']
# edit distance between pkfbgcso and pkfsbgoc: 0.625
# ----------
# ['p', 'k', 'f']
# for sequence 60 prediction is ['b', 'g', 'c', 's', 'o']
# edit distance between pkfbgcso and pkfsgcbo: 0.75
# ----------
# ['p', 'k', 'f']
# for sequence 61 prediction is ['b', 'g', 'c', 's', 'o']
# edit distance between pkfbgcso and pkfsgcob: 0.625
# ----------
# ['p', 'k', 'f']
# for sequence 62 prediction is ['b', 'g', 'c', 's', 'o']
# edit distance between pkfbgcso and pkfsgcbo: 0.75
# ----------
# ['p', 'k', 'f']
# for sequence 63 prediction is ['b', 'g', 'c', 's', 'o']
# edit distance between pkfbgcso and pkfsbcgo: 0.625
# ----------
# ['p', 'k', 'f']
# for sequence 64 prediction is ['b', 'g', 'c', 's', 'o']
# edit distance between pkfbgcso and pkfsocgb: 0.5
# ----------
# ['p', 'f', 's']
# for sequence 65 prediction is ['b', 'g', 'c', 'o', 'k']
# edit distance between pfsbgcok and pfskocgb: 0.5
# ----------
# ['p', 'o', 'k']
# for sequence 66 prediction is ['b', 'g', 'c', 's', 'f']
# edit distance between pokbgcsf and pokfscgb: 0.5
# ----------
# ['p', 'f', 's']
# for sequence 67 prediction is ['b', 'g', 'c', 'o', 'k']
# edit distance between pfsbgcok and pfskogcb: 0.5
# ----------
# Average similarity: 0.5569852941176471
# Median similarity: 0.5

# %%
# %store distances
# Out:
# Stored 'distances' (list)

# %%
distances
# Out:
# [0.75,
#  0.5,
#  0.625,
#  0.625,
#  0.5,
#  0.5,
#  0.5,
#  0.75,
#  0.5,
#  0.75,
#  0.5,
#  0.5,
#  0.625,
#  0.5,
#  0.5,
#  0.75,
#  0.625,
#  0.875,
#  0.5,
#  0.75,
#  0.5,
#  0.375,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.75,
#  0.5,
#  0.625,
#  0.75,
#  0.5,
#  0.5,
#  0.5,
#  0.625,
#  0.5,
#  0.375,
#  0.5,
#  0.375,
#  0.5,
#  0.5,
#  0.625,
#  0.5,
#  0.375,
#  0.5,
#  0.5,
#  0.5,
#  0.625,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.625,
#  0.625,
#  0.75,
#  0.5,
#  0.5,
#  0.5,
#  0.375,
#  0.625,
#  0.75,
#  0.625,
#  0.75,
#  0.625,
#  0.5,
#  0.5,
#  0.5,
#  0.5]
