# %%
import pandas as pd
import numpy as np
from fastDamerauLevenshtein import damerauLevenshtein

# %%
class Prediction():
    Item = None
    Parent = None
    Children = None

    def __init__(self, itemValue=None):
        self.Item = itemValue
        self.Children = []
        self.Parent = None

    def get_child(self, target):
        for chld in self.Children:
            if chld.Item == target:
                return chld
        return None

    def get_children(self):
        return self.Children

    def has_child(self, target):
        found = self.get_child(target)
        if found is not None:
            return True
        else:
            return False

    def add_new_child(self, child):
        newchild = Prediction(child)
        newchild.Parent = self
        self.Children.append(newchild)

    def remove_child(self, child):
        for chld in self.Children:
            if chld.Item == child:
                self.Children.remove(chld)

# %%
class CPT():
    alphabet = None
    root = None
    II = None
    LT = None
    def __init__(self):
        self.alphabet = set()
        self.root = Prediction()
        self.II = {}
        self.LT = {}

    def load_files(self, train_file, test_file=None):
        """
        This function reads in the wide csv file of sequences separated by commas and returns a list of list of those
        sequences. The sequences are defined as below.
        seq1 = A,B,C,D
        seq2  B,C,E
        Returns: [[A,B,C,D],[B,C,E]]
        """
        
        data = []
        target = []

        if train_file is None:
            return train_file

        train = pd.read_csv(train_file, header=0)

        for index, row in train.iterrows():
            data.append(row.values)

        if test_file is not None:

            test = pd.read_csv(test_file, header=None)

            for index, row in test.iterrows():
                data.append(row.values)
                target.append(list(row.values))

            return data, target

        return data


    def train(self, data):
        """
         This functions populates the Prediction Tree, Inverted Index and LookUp Table for the algorithm.
         Input: The list of list training data
         Output : Boolean True
         """

        cursornode = self.root

        for seqid, row in enumerate(data):
            for element in row:
                if element == element: # different sequence length support
                    
                    if cursornode.has_child(element) == False:
                        cursornode.add_new_child(element)
                        cursornode = cursornode.get_child(element)
                    else:
                        cursornode = cursornode.get_child(element)

                # adding to the inverted index

                    if self.II.get(element) is None:
                        self.II[element] = set()

                    self.II[element].add(seqid)

                    self.alphabet.add(element)

            self.LT[seqid] = cursornode

            cursornode = self.root

        return True

    def score(self, counttable, key, length, target_size, number_of_similar_sequences, number_items_counttable):
        """
         This functions populates the Prediction Tree, Inverted Index and LookUp Table for the algorithm.
         Input: The list of list training data
         Output : Boolean True
         """
        
        weight_level = 1 / number_of_similar_sequences
        weight_distance = 1 / number_items_counttable
        score = 1 + weight_level + weight_distance * 0.001

        if counttable.get(key) is None:
            counttable[key] = score
        else:
            counttable[key] = score * counttable.get(key)

        return counttable

    def predict(self, data, target, k, n_list):
        """
        Here target is the test dataset in the form of list of list,
        k is the number of last elements that will be used to find similar sequences and,
        n is the number of predictions required.
        Input: training list of list, target list of list, k,n
        Output: max n predictions for each sequence
        """

        predictions = []

        for index, each_target in enumerate(target):
            n = int(n_list[index])
            
            # different sequence length support
            i = 0
            while i < len(each_target) and each_target[i] == each_target[i]:  # find NaN start
                i = i + 1
            l = i - k - 1
            if l < 0:
                l = 0
            
            each_target = each_target[l:i]

            intersection = set(range(0, len(data)))

            for element in each_target:
                if self.II.get(element) is None:
                    continue
                intersection = intersection & self.II.get(element)

            similar_sequences = []

            for element in intersection:
                currentnode = self.LT.get(element)
                tmp = []
                while currentnode.Item is not None:
                    tmp.append(currentnode.Item)
                    currentnode = currentnode.Parent
                similar_sequences.append(tmp)

            for sequence in similar_sequences:
                sequence.reverse()

            counttable = {}

            for sequence in similar_sequences:
                try:
                    index = next(
                        i for i, v in zip(range(len(sequence) - 1, 0, -1), reversed(sequence)) if v == each_target[-1])
                except:
                    index = None
                if index is not None:
                    count = 1
                    for element in sequence[index + 1:]:
                        if element in each_target:
                            continue

                        counttable = self.score(counttable, element, len(each_target), len(each_target),
                                                len(similar_sequences), count)
                        count += 1

            pred = self.get_n_largest(counttable, n)
            predictions.append(pred)

        return predictions

    def get_n_largest(self, dictionary, n):

        largest = sorted(dictionary.items(), key=lambda t: t[1], reverse=True)[:n]
        return [key for key, _ in largest]

# %%
model = CPT()

# %%
data, target = model.load_files('data/all_data_train.csv', 'data/all_data_test_4.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-61-5fdbcb71f88c> in <module>
# ----> 1 data, target = model.load_files('data/all_data_train.csv', 'data/all_data_test_4.csv')
#
# <ipython-input-3-e84b5d8d4d94> in load_files(self, train_file, test_file)
#      25             return train_file
#      26
# ---> 27         train = pd.read_csv(train_file, header=0)
#      28
#      29         for index, row in train.iterrows():
#
# ~/files/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     684     )
#     685
# --> 686     return _read(filepath_or_buffer, kwds)
#     687
#     688
#
# ~/files/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     450
#     451     # Create the parser.
# --> 452     parser = TextFileReader(fp_or_buf, **kwds)
#     453
#     454     if chunksize or iterator:
#
# ~/files/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     944             self.options["has_index_names"] = kwds["has_index_names"]
#     945
# --> 946         self._make_engine(self.engine)
#     947
#     948     def close(self):
#
# ~/files/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1176     def _make_engine(self, engine="c"):
#    1177         if engine == "c":
# -> 1178             self._engine = CParserWrapper(self.f, **self.options)
#    1179         else:
#    1180             if engine == "python":
#
# ~/files/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    2006         kwds["usecols"] = self.usecols
#    2007
# -> 2008         self._reader = parsers.TextReader(src, **kwds)
#    2009         self.unnamed_cols = self._reader.unnamed_cols
#    2010
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/all_data_train.csv'

# %%
model.train(data)
# Out:
# True

# %%
# get length of each sequence (ignoring nan) minus given sequence in test
n_list = [np.count_nonzero(~pd.isnull(x)) - 2 for x in data]
n_list = [x if x > 0 else 0 for x in n_list]

# %%
predictions = model.predict(data, target, 7, n_list)

# %%
i = 0
distances = []

for elem in predictions:
    pred = [x for x in target[i] if str(x) != 'nan']
    dat = [x for x in data[i] if str(x) != 'nan']
    predicted = str(''.join(pred) + ''.join(elem))
    observed = ''.join(dat)
    dl = 1 - damerauLevenshtein(predicted, observed)
    distances.append(dl)
    print(target[i])
    print('for sequence {0} prediction is {1}'.format(i, elem))
    print('edit distance between {0} and {1}: {2}'.format(observed, predicted, dl))
    i += 1
    print('----------')

print('Average similarity: {0}'.format(np.mean(distances)))
print('Median similarity: {0}'.format(np.median(distances)))
# Out:
# ['p', 'o']
# for sequence 0 prediction is ['k', 'f', 'c', 'r']
# edit distance between pocgkr and pokfcr: 0.5
# ----------
# ['c', 'g']
# for sequence 1 prediction is ['k', 'a', 'f', 's', 'b', 'r']
# edit distance between cgwpcfks and cgkafsbr: 0.75
# ----------
# ['k', 'f']
# for sequence 2 prediction is ['s', 'g', 'c', 'a', 'b', 'r', 'e']
# edit distance between kfsfkspwg and kfsgcabre: 0.6666666666666667
# ----------
# ['p', 'f']
# for sequence 3 prediction is ['s', 'k', 'g', 'c', 'a', 'b', 'r', 'e', 'o', 'd', 'w']
# edit distance between pfkswkfsococg and pfskgcabreodw: 0.6923076923076923
# ----------
# ['w', 'p']
# for sequence 4 prediction is ['k', 'f', 's', 'g', 'r', 'o', 'c']
# edit distance between wptgkfsoc and wpkfsgroc: 0.4444444444444444
# ----------
# ['p', 'w']
# for sequence 5 prediction is ['f', 'k', 'g']
# edit distance between pwfkg and pwfkg: 0.0
# ----------
# ['p', 'o']
# for sequence 6 prediction is ['k', 'f', 'c', 'r']
# edit distance between powcer and pokfcr: 0.5
# ----------
# ['c', 'o']
# for sequence 7 prediction is ['k', 'f', 'r', 'g', 's']
# edit distance between coprerk and cokfrgs: 0.7142857142857143
# ----------
# ['w', 'o']
# for sequence 8 prediction is ['k', 'f', 'c', 'g', 'r', 's', 'e', 'p']
# edit distance between wopofkkskf and wokfcgrsep: 0.7
# ----------
# ['o', 'p']
# for sequence 9 prediction is ['k', 'f', 'r', 's', 'g', 'c', 'w']
# edit distance between opwpwgcoc and opkfrsgcw: 0.6666666666666667
# ----------
# ['p', 'o']
# for sequence 10 prediction is ['k', 'f', 'c', 'r', 'g', 's', 'w', 'e']
# edit distance between pocrfksfks and pokfcrgswe: 0.7
# ----------
# ['c', 'g']
# for sequence 11 prediction is ['k', 'a', 'f', 's', 'b', 'r']
# edit distance between cgpogpoc and cgkafsbr: 0.75
# ----------
# ['p', 'w']
# for sequence 12 prediction is ['f', 'k', 'g', 's', 'r', 'o', 'c', 'e', 't']
# edit distance between pwocgfkfsrere and pwfkgsrocet: 0.5384615384615384
# ----------
# ['o', 'c']
# for sequence 13 prediction is ['k', 'f', 'r', 'g']
# edit distance between ocwgrk and ockfrg: 0.5
# ----------
# ['w', 'p']
# for sequence 14 prediction is ['k', 'f', 's', 'g']
# edit distance between wpgsfk and wpkfsg: 0.5
# ----------
# ['p', 'w']
# for sequence 15 prediction is ['f', 'k', 'g', 's']
# edit distance between pwofsg and pwfkgs: 0.5
# ----------
# ['p', 'o']
# for sequence 16 prediction is ['k', 'f', 'c', 'r', 'g', 's', 'w', 'e', 't']
# edit distance between pocpocwgkfs and pokfcrgswet: 0.7272727272727273
# ----------
# ['p', 'o']
# for sequence 17 prediction is ['k', 'f', 'c', 'r']
# edit distance between pocgwg and pokfcr: 0.6666666666666667
# ----------
# ['p', 'w']
# for sequence 18 prediction is ['f', 'k', 'g', 's', 'r', 'o', 'c', 'e', 't']
# edit distance between pwgockfsfksret and pwfkgsrocet: 0.5714285714285714
# ----------
# ['o', 'c']
# for sequence 19 prediction is ['k', 'f', 'r', 'g', 's', 'w', 'e', 'p', 't', 'b']
# edit distance between ocpwgfkskfsrere and ockfrgsweptb: 0.7333333333333334
# ----------
# ['c', 'o']
# for sequence 20 prediction is ['k', 'f', 'r', 'g', 's', 'w', 'e', 'p', 't']
# edit distance between copwgwpresk and cokfrgswept: 0.7272727272727273
# ----------
# ['p', 'w']
# for sequence 21 prediction is ['f', 'k', 'g', 's', 'r', 'o']
# edit distance between pwterfkf and pwfkgsro: 0.75
# ----------
# ['p', 'o']
# for sequence 22 prediction is ['k', 'f', 'c', 'r', 'g', 's', 'w', 'e', 't', 'b']
# edit distance between pocwggpfkfksrer and pokfcrgswetb: 0.7333333333333334
# ----------
# ['w', 'p']
# for sequence 23 prediction is ['k', 'f', 's', 'g', 'r', 'o', 'c', 'e', 't']
# edit distance between wpofcgkrpwgfksocr and wpkfsgrocet: 0.6470588235294117
# ----------
# ['c', 'w']
# for sequence 24 prediction is ['f', 'k', 'r', 'g', 's', 'o']
# edit distance between cwpfksor and cwfkrgso: 0.5
# ----------
# ['p', 'w']
# for sequence 25 prediction is ['f', 'k', 'g', 's', 'r', 'o']
# edit distance between pwfksorc and pwfkgsro: 0.375
# ----------
# ['p', 'o']
# for sequence 26 prediction is ['k', 'f', 'c', 'r', 'g', 's', 'w', 'e', 't', 'b']
# edit distance between pocgwkfkfser and pokfcrgswetb: 0.75
# ----------
# ['p', 'o']
# for sequence 27 prediction is ['k', 'f', 'c', 'r', 'g', 's', 'w']
# edit distance between powctgcog and pokfcrgsw: 0.6666666666666667
# ----------
# ['p', 'o']
# for sequence 28 prediction is ['k', 'f', 'c', 'r', 'g']
# edit distance between powgcpo and pokfcrg: 0.5714285714285714
# ----------
# ['p', 'w']
# for sequence 29 prediction is ['f', 'k', 'g']
# edit distance between pwfkt and pwfkg: 0.19999999999999996
# ----------
# ['p', 'w']
# for sequence 30 prediction is ['f', 'k', 'g', 's', 'r', 'o']
# edit distance between pwokfkrg and pwfkgsro: 0.5
# ----------
# ['c', 'o']
# for sequence 31 prediction is ['k', 'f', 'r', 'g', 's', 'w', 'e', 'p', 't', 'b']
# edit distance between copcogpgwfksr and cokfrgsweptb: 0.6923076923076923
# ----------
# ['p', 'g']
# for sequence 32 prediction is ['k', 'f', 'a', 'c', 's', 'b', 'r']
# edit distance between pgsfkskfg and pgkfacsbr: 0.6666666666666667
# ----------
# ['w', 'g']
# for sequence 33 prediction is ['k', 'f', 'r', 's', 'e', 'c', 'o', 'p']
# edit distance between wgptocopwg and wgkfrsecop: 0.7
# ----------
# ['p', 'o']
# for sequence 34 prediction is ['k', 'f', 'c', 'r', 'g']
# edit distance between powcgre and pokfcrg: 0.5714285714285714
# ----------
# ['p', 'e']
# for sequence 35 prediction is ['k', 'r', 's', 'f', 't', 'c', 'w', 'o']
# edit distance between perkscwgtf and pekrsftcwo: 0.6
# ----------
# ['p', 'c']
# for sequence 36 prediction is ['k', 'f', 'g', 'a', 's', 'r', 'b', 'w', 'e']
# edit distance between pcgworkfkfs and pckfgasrbwe: 0.8181818181818181
# ----------
# ['p', 'o']
# for sequence 37 prediction is ['k', 'f', 'c', 'r', 'g', 's']
# edit distance between popocgkr and pokfcrgs: 0.625
# ----------
# ['p', 'w']
# for sequence 38 prediction is ['f', 'k', 'g', 's', 'r', 'o', 'c', 'e', 't']
# edit distance between pwtgcfkfksr and pwfkgsrocet: 0.8181818181818181
# ----------
# ['p', 'o']
# for sequence 39 prediction is ['k', 'f', 'c', 'r']
# edit distance between pocwkf and pokfcr: 0.6666666666666667
# ----------
# ['p', 'g']
# for sequence 40 prediction is ['k', 'f', 'a', 'c']
# edit distance between pgkfkf and pgkfac: 0.33333333333333337
# ----------
# ['c', 'w']
# for sequence 41 prediction is ['f', 'k', 'r']
# edit distance between cwopg and cwfkr: 0.6
# ----------
# ['p', 'o']
# for sequence 42 prediction is ['k', 'f', 'c', 'r', 'g', 's', 'w', 'e']
# edit distance between powcgkfkfr and pokfcrgswe: 0.8
# ----------
# ['w', 'p']
# for sequence 43 prediction is ['k', 'f', 's', 'g', 'r']
# edit distance between wpgfksk and wpkfsgr: 0.5714285714285714
# ----------
# ['p', 'o']
# for sequence 44 prediction is ['k', 'f', 'c', 'r', 'g', 's', 'w', 'e']
# edit distance between pocwcpoere and pokfcrgswe: 0.6
# ----------
# ['p', 'w']
# for sequence 45 prediction is ['f', 'k']
# edit distance between pwkf and pwfk: 0.25
# ----------
# ['c', 'p']
# for sequence 46 prediction is ['k', 'f', 's']
# edit distance between cptgo and cpkfs: 0.6
# ----------
# ['p', 'o']
# for sequence 47 prediction is ['k', 'f', 'c', 'r', 'g', 's', 'w']
# edit distance between pocfkswgr and pokfcrgsw: 0.6666666666666667
# ----------
# ['p', 'o']
# for sequence 48 prediction is ['k', 'f', 'c', 'r', 'g', 's']
# edit distance between powcfkfk and pokfcrgs: 0.625
# ----------
# ['p', 'w']
# for sequence 49 prediction is ['f', 'k', 'g', 's', 'r', 'o']
# edit distance between pwgfksfk and pwfkgsro: 0.5
# ----------
# ['g', 'p']
# for sequence 50 prediction is ['k', 'f', 's', 'c']
# edit distance between gpwfks and gpkfsc: 0.5
# ----------
# ['c', 'g']
# for sequence 51 prediction is ['k', 'a', 'f']
# edit distance between cgwpw and cgkaf: 0.6
# ----------
# ['c', 'w']
# for sequence 52 prediction is ['f', 'k', 'r', 'g', 's', 'o', 'e', 'p', 't']
# edit distance between cwopgtrekfksksf and cwfkrgsoept: 0.8
# ----------
# ['p', 'o']
# for sequence 53 prediction is ['k', 'f', 'c', 'r', 'g']
# edit distance between pocsfkw and pokfcrg: 0.7142857142857143
# ----------
# ['o', 'c']
# for sequence 54 prediction is ['k', 'f', 'r', 'g', 's', 'w']
# edit distance between ocpwgfkf and ockfrgsw: 0.75
# ----------
# ['p', 'w']
# for sequence 55 prediction is ['f', 'k', 'g', 's', 'r', 'o', 'c', 'e', 't']
# edit distance between pwgterkfsoc and pwfkgsrocet: 0.7272727272727273
# ----------
# ['p', 'o']
# for sequence 56 prediction is ['k', 'f', 'c', 'r', 'g', 's', 'w']
# edit distance between pocgwrkfs and pokfcrgsw: 0.6666666666666667
# ----------
# ['t', 'g']
# for sequence 57 prediction is ['f', 'k', 's', 'c', 'o']
# edit distance between tgcwpro and tgfksco: 0.5714285714285714
# ----------
# ['p', 'o']
# for sequence 58 prediction is ['k', 'f', 'c', 'r', 'g', 's', 'w', 'e']
# edit distance between pocgkfskfr and pokfcrgswe: 0.8
# ----------
# ['p', 'g']
# for sequence 59 prediction is ['k', 'f', 'a']
# edit distance between pgcow and pgkfa: 0.6
# ----------
# ['o', 'p']
# for sequence 60 prediction is ['k', 'f']
# edit distance between opwg and opkf: 0.5
# ----------
# ['w', 'p']
# for sequence 61 prediction is ['k', 'f', 's', 'g', 'r', 'o', 'c', 'e', 't']
# edit distance between wpgcowpcfksre and wpkfsgrocet: 0.8461538461538461
# ----------
# ['r', 'e']
# for sequence 62 prediction is []
# edit distance between re and re: 0.0
# ----------
# ['p', 't']
# for sequence 63 prediction is ['f', 'k', 'g', 'c', 'o']
# edit distance between ptwgfks and ptfkgco: 0.7142857142857143
# ----------
# ['p', 'o']
# for sequence 64 prediction is ['k', 'f', 'c', 'r', 'g', 's']
# edit distance between pocrfkfk and pokfcrgs: 0.75
# ----------
# ['p', 'o']
# for sequence 65 prediction is ['k', 'f', 'c']
# edit distance between pockr and pokfc: 0.6
# ----------
# ['p', 'o']
# for sequence 66 prediction is ['k', 'f', 'c', 'r', 'g', 's', 'w', 'e', 't', 'b']
# edit distance between pockfskfswgre and pokfcrgswetb: 0.5384615384615384
# ----------
# ['t', 'g']
# for sequence 67 prediction is ['f', 'k', 's', 'c', 'o', 'r', 'e', 'w', 'p']
# edit distance between tgpcowpgpwcog and tgfkscorewp: 0.7692307692307692
# ----------
# ['g', 'w']
# for sequence 68 prediction is ['k', 'f', 's', 'r', 'o', 'c']
# edit distance between gwpfrkst and gwkfsroc: 0.625
# ----------
# ['p', 'f']
# for sequence 69 prediction is ['s', 'k', 'g', 'c', 'a']
# edit distance between pfkfksg and pfskgca: 0.7142857142857143
# ----------
# ['p', 'w']
# for sequence 70 prediction is ['f', 'k', 'g', 's', 'r', 'o']
# edit distance between pwogsfkg and pwfkgsro: 0.625
# ----------
# ['p', 'w']
# for sequence 71 prediction is ['f', 'k']
# edit distance between pwkf and pwfk: 0.25
# ----------
# ['g', 'w']
# for sequence 72 prediction is ['k', 'f', 's', 'r', 'o', 'c', 'e', 'p', 't']
# edit distance between gwpocoskfsfk and gwkfsrocept: 0.8333333333333334
# ----------
# ['w', 't']
# for sequence 73 prediction is ['f', 'k', 'g', 'c', 'r', 'o', 's', 'e']
# edit distance between wtpcockfkf and wtfkgcrose: 0.7
# ----------
# ['w', 'p']
# for sequence 74 prediction is ['k', 'f', 's', 'g', 'r', 'o', 'c']
# edit distance between wpgfkfkre and wpkfsgroc: 0.6666666666666667
# ----------
# ['p', 'o']
# for sequence 75 prediction is ['k', 'f', 'c', 'r', 'g', 's', 'w', 'e', 't', 'b']
# edit distance between pococwtrfkfkg and pokfcrgswetb: 0.7692307692307692
# ----------
# ['p', 'w']
# for sequence 76 prediction is ['f', 'k', 'g', 's', 'r', 'o', 'c', 'e', 't']
# edit distance between pwocfksfksr and pwfkgsrocet: 0.7272727272727273
# ----------
# ['p', 'w']
# for sequence 77 prediction is ['f', 'k', 'g', 's', 'r']
# edit distance between pwgerks and pwfkgsr: 0.7142857142857143
# ----------
# ['p', 'o']
# for sequence 78 prediction is ['k', 'f', 'c', 'r', 'g', 's', 'w', 'e', 't']
# edit distance between poctfkfkrwg and pokfcrgswet: 0.7272727272727273
# ----------
# ['p', 'w']
# for sequence 79 prediction is ['f', 'k', 'g', 's', 'r', 'o']
# edit distance between pwfksocr and pwfkgsro: 0.375
# ----------
# ['t', 'n']
# for sequence 80 prediction is ['p', 'z', 'c']
# edit distance between tnpzc and tnpzc: 0.0
# ----------
# ['t', 'n']
# for sequence 81 prediction is ['p', 'z', 'c']
# edit distance between tnpcz and tnpzc: 0.19999999999999996
# ----------
# ['t', 'n']
# for sequence 82 prediction is ['p', 'z', 'c']
# edit distance between tnpzc and tnpzc: 0.0
# ----------
# ['t', 'n']
# for sequence 83 prediction is ['p', 'z', 'c']
# edit distance between tnzpc and tnpzc: 0.19999999999999996
# ----------
# ['p', 'm']
# for sequence 84 prediction is ['z']
# edit distance between pmz and pmz: 0.0
# ----------
# ['x', 'm']
# for sequence 85 prediction is ['b', 'z', 'd']
# edit distance between xmbzd and xmbzd: 0.0
# ----------
# ['p', 'I']
# for sequence 86 prediction is ['m', 'z']
# edit distance between pImz and pImz: 0.0
# ----------
# ['m', 'z']
# for sequence 87 prediction is ['d', 'x']
# edit distance between mzxp and mzdx: 0.5
# ----------
# ['p', 'b']
# for sequence 88 prediction is ['a']
# edit distance between pbz and pba: 0.33333333333333337
# ----------
# ['p', 'g']
# for sequence 89 prediction is ['k']
# edit distance between pgz and pgk: 0.33333333333333337
# ----------
# ['p', 'n']
# for sequence 90 prediction is ['z', 'c', 'd']
# edit distance between pnzga and pnzcd: 0.4
# ----------
# ['d', 'n']
# for sequence 91 prediction is ['z', 'g', 'p']
# edit distance between dnzgdp and dnzgp: 0.16666666666666663
# ----------
# ['p', 'n']
# for sequence 92 prediction is ['z', 'c']
# edit distance between pndz and pnzc: 0.5
# ----------
# ['n', 'z']
# for sequence 93 prediction is ['c', 'p', 'g', 'd', 'a']
# edit distance between nzpdgds and nzcpgda: 0.4285714285714286
# ----------
# ['m', 'c']
# for sequence 94 prediction is ['d', 'x', 'p']
# edit distance between mcddxp and mcdxp: 0.16666666666666663
# ----------
# ['p', 'c']
# for sequence 95 prediction is ['k', 'f', 'g', 'a', 's', 'r', 'b', 'w']
# edit distance between pcfkdddaag and pckfgasrbw: 0.7
# ----------
# ['d', 'a']
# for sequence 96 prediction is ['g', 'p', 'k']
# edit distance between dagpk and dagpk: 0.0
# ----------
# ['p', 'c']
# for sequence 97 prediction is []
# edit distance between pc and pc: 0.0
# ----------
# ['g', 'k']
# for sequence 98 prediction is ['s', 'f', 'a', 'c']
# edit distance between gkfadp and gksfac: 0.5
# ----------
# ['p', 'f']
# for sequence 99 prediction is ['s', 'k', 'g']
# edit distance between pfgds and pfskg: 0.6
# ----------
# ['b', 'c']
# for sequence 100 prediction is ['a', 'g', 's', 'k', 'f', 'p']
# edit distance between bcsfgkap and bcagskfp: 0.5
# ----------
# ['p', 'b']
# for sequence 101 prediction is ['a', 'g', 'c', 's', 'k', 'f']
# edit distance between pbsfkcga and pbagcskf: 0.75
# ----------
# ['p', 'b']
# for sequence 102 prediction is ['a', 'g', 'c', 's', 'k', 'f']
# edit distance between pbgafkcs and pbagcskf: 0.625
# ----------
# ['g', 'p']
# for sequence 103 prediction is ['k', 'f', 's', 'c', 'a', 'o']
# edit distance between gpbcksfa and gpkfscao: 0.625
# ----------
# ['p', 'b']
# for sequence 104 prediction is ['a', 'g', 'c', 's', 'k', 'f']
# edit distance between pbfkscga and pbagcskf: 0.625
# ----------
# ['p', 'b']
# for sequence 105 prediction is ['a', 'g', 'c', 's', 'k', 'f']
# edit distance between pbsgkafc and pbagcskf: 0.625
# ----------
# ['p', 'b']
# for sequence 106 prediction is ['a', 'g', 'c', 's', 'k', 'f']
# edit distance between pbcskfga and pbagcskf: 0.5
# ----------
# ['p', 's']
# for sequence 107 prediction is ['g', 'a', 'c', 'b', 'k', 'f']
# edit distance between psfkagcb and psgacbkf: 0.625
# ----------
# ['p', 'f']
# for sequence 108 prediction is ['s', 'k', 'g', 'c', 'a', 'b']
# edit distance between pfkscagb and pfskgcab: 0.375
# ----------
# ['p', 'f']
# for sequence 109 prediction is ['s', 'k', 'g', 'c', 'a', 'b']
# edit distance between pfskagcb and pfskgcab: 0.25
# ----------
# ['p', 's']
# for sequence 110 prediction is ['g', 'a', 'c', 'b', 'k', 'f']
# edit distance between pskfcagb and psgacbkf: 0.625
# ----------
# ['p', 'f']
# for sequence 111 prediction is ['s', 'k', 'g', 'c', 'a', 'b']
# edit distance between pfkscagb and pfskgcab: 0.375
# ----------
# ['p', 's']
# for sequence 112 prediction is ['g', 'a', 'c', 'b', 'k', 'f']
# edit distance between psfkgacb and psgacbkf: 0.5
# ----------
# ['p', 'f']
# for sequence 113 prediction is ['s', 'k', 'g', 'c', 'a', 'b']
# edit distance between pfkbscga and pfskgcab: 0.5
# ----------
# ['p', 'c']
# for sequence 114 prediction is ['k', 'f', 'g', 'a', 's', 'r']
# edit distance between pcgafkbs and pckfgasr: 0.625
# ----------
# ['g', 'p']
# for sequence 115 prediction is ['k', 'f', 's', 'c', 'a', 'o']
# edit distance between gpabkfsc and gpkfscao: 0.5
# ----------
# ['p', 'a']
# for sequence 116 prediction is ['b', 'g', 'c', 'k', 'f', 's']
# edit distance between pabkgcfs and pabgckfs: 0.25
# ----------
# ['g', 'c']
# for sequence 117 prediction is ['k', 'f', 'a', 's', 'b', 'r']
# edit distance between gcpabkfs and gckfasbr: 0.75
# ----------
# ['p', 'a']
# for sequence 118 prediction is ['b', 'g', 'c', 'k', 'f', 's']
# edit distance between pasbkfgc and pabgckfs: 0.625
# ----------
# ['p', 'a']
# for sequence 119 prediction is ['b', 'g', 'c', 'k', 'f', 's']
# edit distance between pabcgksf and pabgckfs: 0.25
# ----------
# ['s', 'f']
# for sequence 120 prediction is ['g', 'k', 'c', 'a', 'b', 'r']
# edit distance between sfkpcgab and sfgkcabr: 0.5
# ----------
# ['s', 'p']
# for sequence 121 prediction is ['k', 'f', 'g', 'c', 'a', 'b']
# edit distance between spgbkfca and spkfgcab: 0.5
# ----------
# ['s', 'p']
# for sequence 122 prediction is ['k', 'f', 'g', 'c', 'a', 'b']
# edit distance between spakgfcb and spkfgcab: 0.375
# ----------
# ['c', 'g']
# for sequence 123 prediction is ['k', 'a', 'f', 's', 'b', 'r']
# edit distance between cgbkpasf and cgkafsbr: 0.625
# ----------
# ['f', 'k']
# for sequence 124 prediction is ['s', 'g', 'c', 'a', 'b', 'r']
# edit distance between fkspcbag and fksgcabr: 0.375
# ----------
# ['p', 'k']
# for sequence 125 prediction is ['s', 'f', 'g', 'c', 'a', 'b']
# edit distance between pkfsbgca and pksfgcab: 0.375
# ----------
# ['c', 'p']
# for sequence 126 prediction is ['k', 'f', 's', 'g', 'o', 'r']
# edit distance between cpkfgsba and cpkfsgor: 0.375
# ----------
# ['c', 'b']
# for sequence 127 prediction is ['a', 'g', 's', 'k', 'f', 'p']
# edit distance between cbgsfapk and cbagskfp: 0.5
# ----------
# ['c', 'g']
# for sequence 128 prediction is ['k', 'a', 'f', 's', 'b', 'r']
# edit distance between cgpsakfb and cgkafsbr: 0.625
# ----------
# ['p', 'f']
# for sequence 129 prediction is ['s', 'k', 'g', 'c', 'a', 'b']
# edit distance between pfksgcab and pfskgcab: 0.125
# ----------
# ['p', 'c']
# for sequence 130 prediction is ['k', 'f', 'g', 'a', 's', 'r']
# edit distance between pcskfbga and pckfgasr: 0.5
# ----------
# ['s', 'b']
# for sequence 131 prediction is ['a', 'g', 'c', 'k', 'f', 'p']
# edit distance between sbkpfcag and sbagckfp: 0.75
# ----------
# ['f', 'p']
# for sequence 132 prediction is ['k', 's', 'g', 'c', 'a', 'b']
# edit distance between fpkgbsac and fpksgcab: 0.5
# ----------
# ['p', 'a']
# for sequence 133 prediction is ['b', 'g', 'c', 'k', 'f', 's']
# edit distance between pabfgsck and pabgckfs: 0.5
# ----------
# ['c', 'p']
# for sequence 134 prediction is ['k', 'f', 's', 'g', 'o', 'r']
# edit distance between cpgfksab and cpkfsgor: 0.625
# ----------
# ['g', 'f']
# for sequence 135 prediction is ['s', 'k', 'a', 'c', 'b', 'r']
# edit distance between gfcspkob and gfskacbr: 0.625
# ----------
# ['p', 'k']
# for sequence 136 prediction is ['s', 'f', 'g', 'c', 'a', 'b']
# edit distance between pkfsbagc and pksfgcab: 0.625
# ----------
# ['p', 'k']
# for sequence 137 prediction is ['s', 'f', 'g', 'c', 'a', 'b']
# edit distance between pkfsbgac and pksfgcab: 0.5
# ----------
# ['p', 'b']
# for sequence 138 prediction is ['a', 'g', 'c', 's', 'k', 'f']
# edit distance between pbfkscga and pbagcskf: 0.625
# ----------
# ['b', 'p']
# for sequence 139 prediction is ['a', 'k', 'f', 'c', 'g', 's']
# edit distance between bpksfcga and bpakfcgs: 0.375
# ----------
# ['p', 'a']
# for sequence 140 prediction is ['b', 'g', 'c', 'k', 'f', 's']
# edit distance between pagbkfsc and pabgckfs: 0.375
# ----------
# ['p', 'c']
# for sequence 141 prediction is ['k', 'f', 'g', 'a', 's', 'r']
# edit distance between pcgafksb and pckfgasr: 0.625
# ----------
# ['p', 'c']
# for sequence 142 prediction is ['k', 'f', 'g', 'a', 's', 'r']
# edit distance between pcsbfkga and pckfgasr: 0.625
# ----------
# ['p', 'b']
# for sequence 143 prediction is ['a', 'g', 'c', 's', 'k', 'f']
# edit distance between pbskfgca and pbagcskf: 0.75
# ----------
# ['p', 's']
# for sequence 144 prediction is ['g', 'a', 'c', 'b', 'k', 'f']
# edit distance between pscgfbak and psgacbkf: 0.625
# ----------
# ['p', 'f']
# for sequence 145 prediction is ['s', 'k', 'g', 'c', 'a', 'b']
# edit distance between pfkcbgsa and pfskgcab: 0.625
# ----------
# ['p', 'k']
# for sequence 146 prediction is ['s', 'f', 'g', 'c', 'a', 'b']
# edit distance between pkfsgcba and pksfgcab: 0.25
# ----------
# ['p', 'c']
# for sequence 147 prediction is ['k', 'f', 'g', 'a', 's', 'r']
# edit distance between pcfksagb and pckfgasr: 0.5
# ----------
# ['p', 'b']
# for sequence 148 prediction is ['a', 'g', 'c', 's', 'k', 'f']
# edit distance between pbcfskga and pbagcskf: 0.625
# ----------
# ['p', 'b']
# for sequence 149 prediction is ['a', 'g', 'c', 's', 'k', 'f']
# edit distance between pbfkcsga and pbagcskf: 0.5
# ----------
# ['p', 'c']
# for sequence 150 prediction is ['k', 'f', 'g', 'a', 's', 'r']
# edit distance between pcsfkbga and pckfgasr: 0.625
# ----------
# ['p', 'k']
# for sequence 151 prediction is ['s', 'f', 'g', 'c', 'a', 'b']
# edit distance between pkfsabgc and pksfgcab: 0.625
# ----------
# ['p', 'k']
# for sequence 152 prediction is ['s', 'f', 'g', 'c', 'a', 'b']
# edit distance between pkfsgcba and pksfgcab: 0.25
# ----------
# ['p', 'k']
# for sequence 153 prediction is ['s', 'f', 'g', 'c', 'a', 'b']
# edit distance between pkfsgcba and pksfgcab: 0.25
# ----------
# ['p', 'k']
# for sequence 154 prediction is ['s', 'f', 'g', 'c', 'a', 'b']
# edit distance between pkfsgcab and pksfgcab: 0.125
# ----------
# ['p', 'k']
# for sequence 155 prediction is ['s', 'f', 'g', 'c', 'a', 'b']
# edit distance between pkfbscag and pksfgcab: 0.5
# ----------
# ['p', 'k']
# for sequence 156 prediction is ['s', 'f', 'g', 'c', 'a', 'b']
# edit distance between pkbsfgca and pksfgcab: 0.25
# ----------
# ['p', 'k']
# for sequence 157 prediction is ['s', 'f', 'g', 'c', 'a', 'b']
# edit distance between pkfbscga and pksfgcab: 0.5
# ----------
# ['p', 'k']
# for sequence 158 prediction is ['s', 'f', 'g', 'c', 'a', 'b']
# edit distance between pkfsbgac and pksfgcab: 0.5
# ----------
# ['p', 'k']
# for sequence 159 prediction is ['s', 'f', 'g', 'c', 'a', 'b']
# edit distance between pkfsagbc and pksfgcab: 0.5
# ----------
# ['p', 'k']
# for sequence 160 prediction is ['s', 'f', 'g', 'c', 'a', 'b']
# edit distance between pkfsgcab and pksfgcab: 0.125
# ----------
# ['p', 'k']
# for sequence 161 prediction is ['s', 'f', 'g', 'c', 'a', 'b']
# edit distance between pkfsgcba and pksfgcab: 0.25
# ----------
# ['p', 'k']
# for sequence 162 prediction is ['s', 'f', 'g', 'c', 'a', 'b']
# edit distance between pkfsgcab and pksfgcab: 0.125
# ----------
# ['p', 'k']
# for sequence 163 prediction is ['s', 'f', 'g', 'c', 'a', 'b']
# edit distance between pkfsacgb and pksfgcab: 0.375
# ----------
# ['p', 'k']
# for sequence 164 prediction is ['s', 'f', 'g', 'c', 'a', 'b']
# edit distance between pkfsbcga and pksfgcab: 0.5
# ----------
# ['p', 'f']
# for sequence 165 prediction is ['s', 'k', 'g', 'c', 'a', 'b']
# edit distance between pfskbcga and pfskgcab: 0.375
# ----------
# ['p', 'b']
# for sequence 166 prediction is ['a', 'g', 'c', 's', 'k', 'f']
# edit distance between pbkfscga and pbagcskf: 0.625
# ----------
# ['p', 'f']
# for sequence 167 prediction is ['s', 'k', 'g', 'c', 'a', 'b']
# edit distance between pfskbgca and pfskgcab: 0.25
# ----------
# Average similarity: 0.5172670272460189
# Median similarity: 0.5714285714285714

# %%
with open('results/all_cpt_2.txt', 'w') as f:
    f.write(str(distances))
