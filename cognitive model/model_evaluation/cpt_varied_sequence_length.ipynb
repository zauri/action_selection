# %%
import pandas as pd
import numpy as np
from fastDamerauLevenshtein import damerauLevenshtein
from pyxdameraulevenshtein import damerau_levenshtein_distance

# %%
class Prediction():
    Item = None
    Parent = None
    Children = None

    def __init__(self, itemValue=None):
        self.Item = itemValue
        self.Children = []
        self.Parent = None

    def get_child(self, target):
        for chld in self.Children:
            if chld.Item == target:
                return chld
        return None

    def get_children(self):
        return self.Children

    def has_child(self, target):
        found = self.get_child(target)
        if found is not None:
            return True
        else:
            return False

    def add_new_child(self, child):
        newchild = Prediction(child)
        newchild.Parent = self
        self.Children.append(newchild)

    def remove_child(self, child):
        for chld in self.Children:
            if chld.Item == child:
                self.Children.remove(chld)

# %%
class CPT():
    alphabet = None
    root = None
    II = None
    LT = None
    def __init__(self):
        self.alphabet = set()
        self.root = Prediction()
        self.II = {}
        self.LT = {}

    def load_files(self, train_file, test_file=None):
        """
        This function reads in the wide csv file of sequences separated by commas and returns a list of list of those
        sequences. The sequences are defined as below.
        seq1 = A,B,C,D
        seq2  B,C,E
        Returns: [[A,B,C,D],[B,C,E]]
        """
        
        data = []
        target = []

        if train_file is None:
            return train_file

        train = pd.read_csv(train_file, header=0)

        for index, row in train.iterrows():
            data.append(row.values)

        if test_file is not None:

            test = pd.read_csv(test_file, header=None)

            for index, row in test.iterrows():
                data.append(row.values)
                target.append(list(row.values))

            return data, target

        return data


    def train(self, data):
        """
         This functions populates the Prediction Tree, Inverted Index and LookUp Table for the algorithm.
         Input: The list of list training data
         Output : Boolean True
         """

        cursornode = self.root

        for seqid, row in enumerate(data):
            for element in row:
                if element == element: # different sequence length support
                    
                    if cursornode.has_child(element) == False:
                        cursornode.add_new_child(element)
                        cursornode = cursornode.get_child(element)
                    else:
                        cursornode = cursornode.get_child(element)

                # adding to the inverted index

                    if self.II.get(element) is None:
                        self.II[element] = set()

                    self.II[element].add(seqid)

                    self.alphabet.add(element)

            self.LT[seqid] = cursornode

            cursornode = self.root

        return True

    def score(self, counttable, key, length, target_size, number_of_similar_sequences, number_items_counttable):
        """
         This functions populates the Prediction Tree, Inverted Index and LookUp Table for the algorithm.
         Input: The list of list training data
         Output : Boolean True
         """
        
        weight_level = 1 / number_of_similar_sequences
        weight_distance = 1 / number_items_counttable
        score = 1 + weight_level + weight_distance * 0.001

        if counttable.get(key) is None:
            counttable[key] = score
        else:
            counttable[key] = score * counttable.get(key)

        return counttable

    def predict(self, data, target, k, n_list):
        """
        Here target is the test dataset in the form of list of list,
        k is the number of last elements that will be used to find similar sequences and,
        n is the number of predictions required.
        Input: training list of list, target list of list, k,n
        Output: max n predictions for each sequence
        """

        predictions = []

        for index, each_target in enumerate(target):
            n = int(n_list[index])
            
            # different sequence length support
            i = 0
            while i < len(each_target) and each_target[i] == each_target[i]:  # find NaN start
                i = i + 1
            l = i - k - 1
            if l < 0:
                l = 0
            
            each_target = each_target[l:i]

            intersection = set(range(0, len(data)))

            for element in each_target:
                if self.II.get(element) is None:
                    continue
                intersection = intersection & self.II.get(element)

            similar_sequences = []

            for element in intersection:
                currentnode = self.LT.get(element)
                tmp = []
                while currentnode.Item is not None:
                    tmp.append(currentnode.Item)
                    currentnode = currentnode.Parent
                similar_sequences.append(tmp)

            for sequence in similar_sequences:
                sequence.reverse()

            counttable = {}

            for sequence in similar_sequences:
                try:
                    index = next(
                        i for i, v in zip(range(len(sequence) - 1, 0, -1), reversed(sequence)) if v == each_target[-1])
                except:
                    index = None
                if index is not None:
                    count = 1
                    for element in sequence[index + 1:]:
                        if element in each_target:
                            continue

                        counttable = self.score(counttable, element, len(each_target), len(each_target),
                                                len(similar_sequences), count)
                        count += 1

            pred = self.get_n_largest(counttable, n)
            predictions.append(pred)

        return predictions

    def get_n_largest(self, dictionary, n):

        largest = sorted(dictionary.items(), key=lambda t: t[1], reverse=True)[:n]
        return [key for key, _ in largest]

# %%
model = CPT()

# %%
data, target = model.load_files('data/automatica_train_cols.csv', 'data/automatica_test_cols.csv')

# %%
model.train(data)
# Out:
# True

# %%
# get length of each sequence (ignoring nan) minus given sequence in test
n_list = [np.count_nonzero(~pd.isnull(x)) - 3 for x in data]

# %%
predictions = model.predict(data, target, 7, n_list)

# %%
i = 0
distances = []

for elem in predictions:
    pred = [x for x in target[i] if str(x) != 'nan']
    dat = [x for x in data[i] if str(x) != 'nan']
    predicted = str(''.join(pred) + ''.join(elem))
    observed = ''.join(dat)
    dl = 1 - damerauLevenshtein(predicted, observed)
    distances.append(dl)
    print(target[i])
    print('for sequence {0} prediction is {1}'.format(i, elem))
    print('edit distance between {0} and {1}: {2}'.format(predicted, observed, dl))
    i += 1
    print('----------')

print('Average similarity: {0}'.format(np.mean(distances)))
print('Median similarity: {0}'.format(np.median(distances)))
# Out:
# ['p', 'o', 'c']
# for sequence 0 prediction is ['k', 'f', 'r']
# edit distance between pockfr and pocgkr: 0.33333333333333337
# ----------
# ['c', 'g', 'w']
# for sequence 1 prediction is ['f', 'k', 'r', 's', 'o']
# edit distance between cgwfkrso and cgwpcfks: 0.5
# ----------
# ['k', 'f', 's']
# for sequence 2 prediction is ['r', 'g', 'e', 'o', 'c', 'w']
# edit distance between kfsrgeocw and kfsfkspwg: 0.6666666666666667
# ----------
# ['p', 'f', 'k']
# for sequence 3 prediction is ['s', 'r', 'g', 'e', 'o', 'c', 'w', 't']
# edit distance between pfksrgeocwt and pfkswkfsococg: 0.5384615384615384
# ----------
# ['w', 'p', 't']
# for sequence 4 prediction is ['f', 'k', 'g', 'c', 'r', 'o']
# edit distance between wptfkgcro and wptgkfsoc: 0.5555555555555556
# ----------
# ['p', 'w', 'f']
# for sequence 5 prediction is ['k', 's']
# edit distance between pwfks and pwfkg: 0.19999999999999996
# ----------
# ['p', 'o', 'w']
# for sequence 6 prediction is ['f', 'k', 'g']
# edit distance between powfkg and powcer: 0.5
# ----------
# ['c', 'o', 'p']
# for sequence 7 prediction is ['k', 'f', 's', 'g']
# edit distance between copkfsg and coprerk: 0.5714285714285714
# ----------
# ['w', 'o', 'p']
# for sequence 8 prediction is ['k', 'f', 's', 'g', 'r', 'c', 'e']
# edit distance between wopkfsgrce and wopofkkskf: 0.6
# ----------
# ['o', 'p', 'w']
# for sequence 9 prediction is ['f', 'k', 'g', 'r', 's', 'c']
# edit distance between opwfkgrsc and opwpwgcoc: 0.4444444444444444
# ----------
# ['p', 'o', 'c']
# for sequence 10 prediction is ['k', 'f', 'r', 'g', 's', 'w', 'e']
# edit distance between pockfrgswe and pocrfksfks: 0.6
# ----------
# ['c', 'g', 'p']
# for sequence 11 prediction is ['k', 'f', 's', 'r', 'o']
# edit distance between cgpkfsro and cgpogpoc: 0.625
# ----------
# ['p', 'w', 'o']
# for sequence 12 prediction is ['k', 'f', 'c', 'g', 'r', 's', 'e', 't']
# edit distance between pwokfcgrset and pwocgfkfsrere: 0.5384615384615384
# ----------
# ['o', 'c', 'w']
# for sequence 13 prediction is ['f', 'k', 'g']
# edit distance between ocwfkg and ocwgrk: 0.5
# ----------
# ['w', 'p', 'g']
# for sequence 14 prediction is ['k', 'f', 'r']
# edit distance between wpgkfr and wpgsfk: 0.33333333333333337
# ----------
# ['p', 'w', 'o']
# for sequence 15 prediction is ['k', 'f', 'c']
# edit distance between pwokfc and pwofsg: 0.5
# ----------
# ['p', 'o', 'c']
# for sequence 16 prediction is ['k', 'f', 'r', 'g', 's', 'w', 'e', 't']
# edit distance between pockfrgswet and pocpocwgkfs: 0.7272727272727273
# ----------
# ['p', 'o', 'c']
# for sequence 17 prediction is ['k', 'f', 'r']
# edit distance between pockfr and pocgwg: 0.5
# ----------
# ['p', 'w', 'g']
# for sequence 18 prediction is ['k', 'f', 'r', 's', 'e', 'c', 'o', 't']
# edit distance between pwgkfrsecot and pwgockfsfksret: 0.5714285714285714
# ----------
# ['o', 'c', 'p']
# for sequence 19 prediction is ['k', 'f', 's', 'g', 'r', 'w', 'e', 't']
# edit distance between ocpkfsgrwet and ocpwgfkskfsrere: 0.6
# ----------
# ['c', 'o', 'p']
# for sequence 20 prediction is ['k', 'f', 's', 'g', 'r', 'w', 'e', 't']
# edit distance between copkfsgrwet and copwgwpresk: 0.6363636363636364
# ----------
# ['p', 'w', 't']
# for sequence 21 prediction is ['f', 'k', 'g', 'c', 'r']
# edit distance between pwtfkgcr and pwterfkf: 0.625
# ----------
# ['p', 'o', 'c']
# for sequence 22 prediction is ['k', 'f', 'r', 'g', 's', 'w', 'e', 't']
# edit distance between pockfrgswet and pocwggpfkfksrer: 0.6
# ----------
# ['w', 'p', 'o']
# for sequence 23 prediction is ['k', 'f', 'c', 'g', 'r', 's', 'e', 't']
# edit distance between wpokfcgrset and wpofcgkrpwgfksocr: 0.5882352941176471
# ----------
# ['c', 'w', 'p']
# for sequence 24 prediction is ['k', 'f', 's', 'g', 'o']
# edit distance between cwpkfsgo and cwpfksor: 0.375
# ----------
# ['p', 'w', 'f']
# for sequence 25 prediction is ['k', 's', 'r', 'g', 'e']
# edit distance between pwfksrge and pwfksorc: 0.375
# ----------
# ['p', 'o', 'c']
# for sequence 26 prediction is ['k', 'f', 'r', 'g', 's', 'w', 'e', 't']
# edit distance between pockfrgswet and pocgwkfkfser: 0.5
# ----------
# ['p', 'o', 'w']
# for sequence 27 prediction is ['f', 'k', 'g', 'r', 's', 'c']
# edit distance between powfkgrsc and powctgcog: 0.5555555555555556
# ----------
# ['p', 'o', 'w']
# for sequence 28 prediction is ['f', 'k', 'g', 'r']
# edit distance between powfkgr and powgcpo: 0.5714285714285714
# ----------
# ['p', 'w', 'f']
# for sequence 29 prediction is ['k', 's']
# edit distance between pwfks and pwfkt: 0.19999999999999996
# ----------
# ['p', 'w', 'o']
# for sequence 30 prediction is ['k', 'f', 'c', 'g', 'r']
# edit distance between pwokfcgr and pwokfkrg: 0.25
# ----------
# ['c', 'o', 'p']
# for sequence 31 prediction is ['k', 'f', 's', 'g', 'r', 'w', 'e', 't']
# edit distance between copkfsgrwet and copcogpgwfksr: 0.6923076923076923
# ----------
# ['p', 'g', 's']
# for sequence 32 prediction is ['r', 'f', 'k', 'e', 'o', 'c']
# edit distance between pgsrfkeoc and pgsfkskfg: 0.5555555555555556
# ----------
# ['w', 'g', 'p']
# for sequence 33 prediction is ['k', 'f', 's', 'r', 'o', 'c', 'e']
# edit distance between wgpkfsroce and wgptocopwg: 0.7
# ----------
# ['p', 'o', 'w']
# for sequence 34 prediction is ['f', 'k', 'g', 'r']
# edit distance between powfkgr and powcgre: 0.4285714285714286
# ----------
# ['p', 'e', 'r']
# for sequence 35 prediction is ['k', 's', 'f', 't', 'c', 'w', 'o']
# edit distance between perksftcwo and perkscwgtf: 0.5
# ----------
# ['p', 'c', 'g']
# for sequence 36 prediction is ['k', 'f', 'r', 's', 'e', 'w', 'o', 't']
# edit distance between pcgkfrsewot and pcgworkfkfs: 0.6363636363636364
# ----------
# ['p', 'o', 'p']
# for sequence 37 prediction is ['k', 'f', 's', 'g', 'r']
# edit distance between popkfsgr and popocgkr: 0.5
# ----------
# ['p', 'w', 't']
# for sequence 38 prediction is ['f', 'k', 'g', 'c', 'r', 'o', 's', 'e']
# edit distance between pwtfkgcrose and pwtgcfkfksr: 0.6363636363636364
# ----------
# ['p', 'o', 'c']
# for sequence 39 prediction is ['k', 'f', 'r']
# edit distance between pockfr and pocwkf: 0.33333333333333337
# ----------
# ['p', 'g', 'k']
# for sequence 40 prediction is ['s', 'r', 'f']
# edit distance between pgksrf and pgkfkf: 0.33333333333333337
# ----------
# ['c', 'w', 'o']
# for sequence 41 prediction is ['k', 'f']
# edit distance between cwokf and cwopg: 0.4
# ----------
# ['p', 'o', 'w']
# for sequence 42 prediction is ['f', 'k', 'g', 'r', 's', 'c', 'e']
# edit distance between powfkgrsce and powcgkfkfr: 0.6
# ----------
# ['w', 'p', 'g']
# for sequence 43 prediction is ['k', 'f', 'r', 's']
# edit distance between wpgkfrs and wpgfksk: 0.4285714285714286
# ----------
# ['p', 'o', 'c']
# for sequence 44 prediction is ['k', 'f', 'r', 'g', 's', 'w', 'e']
# edit distance between pockfrgswe and pocwcpoere: 0.6
# ----------
# ['p', 'w', 'k']
# for sequence 45 prediction is ['s']
# edit distance between pwks and pwkf: 0.25
# ----------
# ['c', 'p', 't']
# for sequence 46 prediction is ['f', 'k']
# edit distance between cptfk and cptgo: 0.4
# ----------
# ['p', 'o', 'c']
# for sequence 47 prediction is ['k', 'f', 'r', 'g', 's', 'w']
# edit distance between pockfrgsw and pocfkswgr: 0.5555555555555556
# ----------
# ['p', 'o', 'w']
# for sequence 48 prediction is ['f', 'k', 'g', 'r', 's']
# edit distance between powfkgrs and powcfkfk: 0.5
# ----------
# ['p', 'w', 'g']
# for sequence 49 prediction is ['k', 'f', 'r', 's', 'e']
# edit distance between pwgkfrse and pwgfksfk: 0.5
# ----------
# ['g', 'p', 'w']
# for sequence 50 prediction is ['f', 'k', 'r']
# edit distance between gpwfkr and gpwfks: 0.16666666666666663
# ----------
# ['c', 'g', 'w']
# for sequence 51 prediction is ['f', 'k']
# edit distance between cgwfk and cgwpw: 0.4
# ----------
# ['c', 'w', 'o']
# for sequence 52 prediction is ['k', 'f', 'r', 'g', 's', 'e', 'p', 't']
# edit distance between cwokfrgsept and cwopgtrekfksksf: 0.6666666666666667
# ----------
# ['p', 'o', 'c']
# for sequence 53 prediction is ['k', 'f', 'r', 'g']
# edit distance between pockfrg and pocsfkw: 0.4285714285714286
# ----------
# ['o', 'c', 'p']
# for sequence 54 prediction is ['k', 'f', 's', 'g', 'r']
# edit distance between ocpkfsgr and ocpwgfkf: 0.625
# ----------
# ['p', 'w', 'g']
# for sequence 55 prediction is ['k', 'f', 'r', 's', 'e', 'c', 'o', 't']
# edit distance between pwgkfrsecot and pwgterkfsoc: 0.5454545454545454
# ----------
# ['p', 'o', 'c']
# for sequence 56 prediction is ['k', 'f', 'r', 'g', 's', 'w']
# edit distance between pockfrgsw and pocgwrkfs: 0.5555555555555556
# ----------
# ['t', 'g', 'c']
# for sequence 57 prediction is ['f', 'k', 'w', 'r']
# edit distance between tgcfkwr and tgcwpro: 0.5714285714285714
# ----------
# ['p', 'o', 'c']
# for sequence 58 prediction is ['k', 'f', 'r', 'g', 's', 'w', 'e']
# edit distance between pockfrgswe and pocgkfskfr: 0.6
# ----------
# ['p', 'g', 'c']
# for sequence 59 prediction is ['k', 'f']
# edit distance between pgckf and pgcow: 0.4
# ----------
# ['o', 'p', 'w']
# for sequence 60 prediction is ['f']
# edit distance between opwf and opwg: 0.25
# ----------
# ['w', 'p', 'g']
# for sequence 61 prediction is ['k', 'f', 'r', 's', 'e', 'c', 'o', 't']
# edit distance between wpgkfrsecot and wpgcowpcfksre: 0.7692307692307692
# ----------
# ['r', 'e', nan]
# for sequence 62 prediction is ['k', 's', 'f', 't', 'c', 'w', 'o']
# edit distance between reksftcwo and re: 0.7777777777777778
# ----------
# ['p', 't', 'w']
# for sequence 63 prediction is ['f', 'k', 'g', 'r']
# edit distance between ptwfkgr and ptwgfks: 0.4285714285714286
# ----------
# ['p', 'o', 'c']
# for sequence 64 prediction is ['k', 'f', 'r', 'g', 's']
# edit distance between pockfrgs and pocrfkfk: 0.5
# ----------
# ['p', 'o', 'c']
# for sequence 65 prediction is ['k', 'f']
# edit distance between pockf and pockr: 0.19999999999999996
# ----------
# ['p', 'o', 'c']
# for sequence 66 prediction is ['k', 'f', 'r', 'g', 's', 'w', 'e', 't']
# edit distance between pockfrgswet and pockfskfswgre: 0.46153846153846156
# ----------
# ['t', 'g', 'p']
# for sequence 67 prediction is ['k', 'o', 'f', 's', 'r', 'w', 'c', 'e']
# edit distance between tgpkofsrwce and tgpcowpgpwcog: 0.5384615384615384
# ----------
# ['g', 'w', 'p']
# for sequence 68 prediction is ['k', 'f', 's', 'r', 'o']
# edit distance between gwpkfsro and gwpfrkst: 0.5
# ----------
# ['p', 'f', 'k']
# for sequence 69 prediction is ['s', 'r', 'g', 'e']
# edit distance between pfksrge and pfkfksg: 0.5714285714285714
# ----------
# ['p', 'w', 'o']
# for sequence 70 prediction is ['k', 'f', 'c', 'g', 'r']
# edit distance between pwokfcgr and pwogsfkg: 0.5
# ----------
# ['p', 'w', 'k']
# for sequence 71 prediction is ['s']
# edit distance between pwks and pwkf: 0.25
# ----------
# ['g', 'w', 'p']
# for sequence 72 prediction is ['k', 'f', 's', 'r', 'o', 'c', 'e', 't']
# edit distance between gwpkfsrocet and gwpocoskfsfk: 0.6666666666666667
# ----------
# ['w', 't', 'p']
# for sequence 73 prediction is ['k', 'f', 'g', 'c', 'o', 's', 'r']
# edit distance between wtpkfgcosr and wtpcockfkf: 0.7
# ----------
# ['w', 'p', 'g']
# for sequence 74 prediction is ['k', 'f', 'r', 's', 'e', 'c']
# edit distance between wpgkfrsec and wpgfkfkre: 0.4444444444444444
# ----------
# ['p', 'o', 'c']
# for sequence 75 prediction is ['k', 'f', 'r', 'g', 's', 'w', 'e', 't']
# edit distance between pockfrgswet and pococwtrfkfkg: 0.6923076923076923
# ----------
# ['p', 'w', 'o']
# for sequence 76 prediction is ['k', 'f', 'c', 'g', 'r', 's', 'e', 't']
# edit distance between pwokfcgrset and pwocfksfksr: 0.6363636363636364
# ----------
# ['p', 'w', 'g']
# for sequence 77 prediction is ['k', 'f', 'r', 's']
# edit distance between pwgkfrs and pwgerks: 0.4285714285714286
# ----------
# ['p', 'o', 'c']
# for sequence 78 prediction is ['k', 'f', 'r', 'g', 's', 'w', 'e', 't']
# edit distance between pockfrgswet and poctfkfkrwg: 0.6363636363636364
# ----------
# ['p', 'w', 'f']
# for sequence 79 prediction is ['k', 's', 'r', 'g', 'e']
# edit distance between pwfksrge and pwfksocr: 0.375
# ----------
# Average similarity: 0.5064749302984597
# Median similarity: 0.5192307692307692

# %%
with open('automatica_cpt.txt', 'w') as f:
    f.write(str(distances))
