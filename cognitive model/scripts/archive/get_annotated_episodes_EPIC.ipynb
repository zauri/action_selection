# %%
import pandas as pd

# %%
df = pd.read_csv('data/EPIC_2018_original_annotation_all_timestamps.csv', header=0)

# %%
df
# Out:
#          uid participant_id video_id         narration start_timestamp  \
# 0          0            P01   P01_01         open door         00:00.1
# 1          1            P01   P01_01     turn on light         00:04.4
# 2          2            P01   P01_01        close door         00:07.0
# 3          3            P01   P01_01       open fridge         00:12.8
# 4          4            P01   P01_01       take celery         00:15.2
# ...      ...            ...      ...               ...             ...
# 28467  39232            P31   P31_14        wash glass         03:53.2
# 28468  39233            P31   P31_14         dry hands         04:51.2
# 28469  39234            P31   P31_14   pick up napkins         04:59.5
# 28470  39235            P31   P31_14  put down napkins         05:02.3
# 28471  39236            P31   P31_14        close door         05:10.9
#
#       stop_timestamp  start_frame  stop_frame      verb  verb_class  ...  \
# ...

# %%
grid_location_set = df[pd.notna(df['grid_location'])]

# %%
IDs = grid_location_set['video_id'].unique()

# %%
len(IDs)
# Out:
# 137

# %%
annotated_episodes = df[df['video_id'].isin(IDs)]

# %%
annotated_episodes
# Out:
#          uid participant_id video_id                     narration  \
# 0          0            P01   P01_01                     open door
# 1          1            P01   P01_01                 turn on light
# 2          2            P01   P01_01                    close door
# 3          3            P01   P01_01                   open fridge
# 4          4            P01   P01_01                   take celery
# ...      ...            ...      ...                           ...
# 27916  38583            P30   P30_10  continue washing hob surface
# 27917  38584            P30   P30_10  continue washing hob surface
# 27918  38585            P30   P30_10  continue washing hob surface
# 27919  38586            P30   P30_10  continue washing hob surface
# 27920  38587            P30   P30_10                     dry hands
#
#       start_timestamp stop_timestamp  start_frame  stop_frame     verb  \
# 0             00:00.1        00:03.4            8         202     open
# ...
